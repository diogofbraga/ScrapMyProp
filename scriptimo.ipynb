# %% [markdown]
# # Scrap My Prop
#
# ### Laboratórios de Engenharia Informática
#
# #### "Development of an IT solution for the extraction and automatic analysis of data and relevant information for the calculation of land and properties."

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # Imovirtual

# %% [markdown]
# ## Ler Dados do CSV

# %%
data_imo = pd.read_csv('dados/dados_imovirtual_08_04.csv', engine='python', encoding='utf8')
pd.set_option('display.max_columns', 999)
data_imo
# Out:
#                                                    Nome        Id  \
# 0      Apartamento T3 Novo na malha do Centro Histórico  15024495
# 1                        Moradia Geminada T3+1 em Braga  15337986
# 2                       Moradia em Banda T3 em Palmeira  15199439
# 3     Moradia Individual T3 Nova, com arquitectura m...  15388755
# 4     Oferta da escritura. Apartamento T3 renovado, ...  15386584
# ...                                                 ...       ...
# 5620  Moradia T4 Venda em Este (São Pedro e São Mame...  14968844
# 5621    Terreno  Venda em Ferreiros e Gondizalves,Braga  14790616
# 5622    Terreno  Venda em Ferreiros e Gondizalves,Braga  14772154
# 5623    Terreno Para Construção  Venda em Gualtar,Braga  14968858
# 5624  Terreno T3 Venda em Celeirós, Aveleda e Vimiei...  14968896
#
#      Tipo de imóvel     Preço Preço m/2          Distrito Concelho  \
# 0       Apartamento  170 000     1 532   Braga (distrito)    Braga
# 1           Moradia  275 000       764   Braga (distrito)    Braga
# 2           Moradia  230 000     1 420   Braga (distrito)    Braga
# 3           Moradia  279 900     1 676   Braga (distrito)    Braga
# 4       Apartamento  149 000     1 759   Braga (distrito)    Braga
# ...             ...       ...       ...               ...      ...
# 5620        Moradia  318 000     1 104   Braga (distrito)    Braga
# 5621        Terreno   50 000       205   Braga (distrito)    Braga
# 5622        Terreno   50 000       218   Braga (distrito)    Braga
# 5623        Terreno   49 000       297   Braga (distrito)    Braga
# 5624        Terreno   57 500       160   Braga (distrito)    Braga
#
#                              Freguesia                   Rua Tipologia  \
# 0     Braga (Maximinos, Sé e Cividade)  Rua da Boavista - Sé        T3
# 1         Celeirós, Aveleda e Vimieiro                   NaN        T3
# 2                             Palmeira                   NaN        T3
# 3                 Real, Dume e Semelhe                   NaN        T3
# 4     Braga (Maximinos, Sé e Cividade)                   NaN        T3
# ...                                ...                   ...       ...
# 5620     Este (São Pedro e São Mamede)                   NaN        T4
# 5621           Ferreiros e Gondizalves                   NaN       NaN
# 5622           Ferreiros e Gondizalves                   NaN       NaN
# 5623                           Gualtar                   NaN       NaN
# 5624      Celeirós, Aveleda e Vimieiro                   NaN       NaN
#
#      Nº Casas de Banho Área útil m/2 Área bruta m/2  Ano construção  \
# 0                    2        111 m²            NaN          2020.0
# 1                    3        360 m²            NaN          2020.0
# 2                  NaN        162 m²            NaN          2020.0
# 3                    3        167 m²         188 m²          2020.0
# 4                    2      84,72 m²      105,09 m²          1987.0
# ...                ...           ...            ...             ...
# 5620               NaN        288 m²            NaN             NaN
# 5621               NaN           NaN            NaN             NaN
# 5622               NaN           NaN            NaN             NaN
# 5623               NaN           NaN            NaN             NaN
# 5624               NaN           NaN            NaN             NaN
#
#      Certificado energético Armário Cozinha equipada Garagem box  \
# 0                       NaN    True              NaN         NaN
# 1                        A+     NaN              NaN        True
# 2                    Isento     NaN              NaN        True
# 3                       NaN     NaN              NaN        True
# 4                         C     NaN              NaN        True
# ...                     ...     ...              ...         ...
# 5620                    NaN     NaN              NaN         NaN
# 5621                    NaN     NaN              NaN         NaN
# 5622                    NaN     NaN              NaN         NaN
# 5623                    NaN     NaN              NaN         NaN
# 5624                    NaN     NaN              NaN         NaN
#
#      Gás canalizado Lareira Marquise Suite Varanda Vista de cidade  \
# 0              True     NaN      NaN  True     NaN             NaN
# 1               NaN     NaN      NaN   NaN     NaN             NaN
# 2               NaN     NaN      NaN   NaN     NaN             NaN
# 3               NaN     NaN      NaN   NaN    True             NaN
# 4               NaN    True      NaN   NaN    True             NaN
# ...             ...     ...      ...   ...     ...             ...
# 5620            NaN     NaN      NaN   NaN     NaN             NaN
# 5621            NaN     NaN      NaN   NaN     NaN             NaN
# 5622            NaN     NaN      NaN   NaN     NaN             NaN
# 5623            NaN     NaN      NaN   NaN     NaN             NaN
# 5624            NaN     NaN      NaN   NaN     NaN             NaN
#
#            Condição Despensa Arrecadação Porta blindada Video Porteiro  \
# 0              Novo      NaN         NaN            NaN           True
# 1     Em construção      NaN         NaN            NaN            NaN
# 2              Novo      NaN         NaN            NaN            NaN
# 3     Em construção      NaN         NaN            NaN            NaN
# 4          Renovado      NaN         NaN            NaN            NaN
# ...             ...      ...         ...            ...            ...
# 5620           Novo      NaN         NaN            NaN            NaN
# 5621            NaN      NaN         NaN            NaN            NaN
# 5622            NaN      NaN         NaN            NaN            NaN
# 5623            NaN      NaN         NaN            NaN            NaN
# 5624            NaN      NaN         NaN            NaN            NaN
#
#      Empreendimento Ar condicionado Elevador  Estores elétricos Fibra ótica  \
# 0               NaN             NaN      NaN                NaN         NaN
# 1               não            True      NaN                NaN         NaN
# 2               não             NaN      NaN                NaN         NaN
# 3               NaN            True      NaN                NaN         NaN
# 4               não             NaN      NaN                NaN         NaN
# ...             ...             ...      ...                ...         ...
# 5620            não             NaN      NaN                NaN         NaN
# 5621            NaN             NaN      NaN                NaN         NaN
# 5622            NaN             NaN      NaN                NaN         NaN
# 5623            NaN             NaN      NaN                NaN         NaN
# 5624            NaN             NaN      NaN                NaN         NaN
#
#      Pré-instalação de ar condicionado Terraço  Área de terreno m/2 Churrasco  \
# 0                                 True     NaN                  NaN       NaN
# 1                                  NaN     NaN                  NaN       NaN
# 2                                  NaN     NaN                  NaN       NaN
# 3                                  NaN     NaN                  NaN       NaN
# 4                                  NaN     NaN                  NaN       NaN
# ...                                ...     ...                  ...       ...
# 5620                               NaN     NaN                  NaN       NaN
# 5621                               NaN     NaN                  NaN       NaN
# 5622                               NaN     NaN                  NaN       NaN
# 5623                               NaN     NaN                  NaN       NaN
# 5624                               NaN     NaN                  NaN       NaN
#
#      Árvores de fruto Sotão Cave Jardim Aquecimento central Caldeira  \
# 0                 NaN   NaN  NaN    NaN                 NaN      NaN
# 1                 NaN   NaN  NaN   True                 NaN      NaN
# 2                 NaN   NaN  NaN   True                 NaN      NaN
# 3                 NaN   NaN  NaN   True                 NaN      NaN
# 4                 NaN   NaN  NaN    NaN                 NaN      NaN
# ...               ...   ...  ...    ...                 ...      ...
# 5620              NaN   NaN  NaN    NaN                 NaN      NaN
# 5621              NaN   NaN  NaN    NaN                 NaN      NaN
# 5622              NaN   NaN  NaN    NaN                 NaN      NaN
# 5623              NaN   NaN  NaN    NaN                 NaN      NaN
# 5624              NaN   NaN  NaN    NaN                 NaN      NaN
#
#      Acessibilidade a pessoas com mobilidade condicionada  Box 2 carros  \
# 0                                                   NaN             NaN
# 1                                                   NaN             NaN
# 2                                                   NaN             NaN
# 3                                                  True             NaN
# 4                                                   NaN             NaN
# ...                                                 ...             ...
# 5620                                                NaN             NaN
# 5621                                                NaN             NaN
# 5622                                                NaN             NaN
# 5623                                                NaN             NaN
# 5624                                                NaN             NaN
#
#      Detetor de gás Painéis solares Recuperação de calor Vista de campo/serra  \
# 0               NaN             NaN                 True                  NaN
# 1               NaN             NaN                  NaN                  NaN
# 2               NaN             NaN                  NaN                  NaN
# 3               NaN             NaN                  NaN                 True
# 4               NaN             NaN                  NaN                  NaN
# ...             ...             ...                  ...                  ...
# 5620            NaN             NaN                  NaN                  NaN
# 5621            NaN             NaN                  NaN                  NaN
# 5622            NaN             NaN                  NaN                  NaN
# 5623            NaN             NaN                  NaN                  NaN
# 5624            NaN             NaN                  NaN                  NaN
#
#       Box 1 carro Portaria Estacionamento Piso radiante Som ambiente  \
# 0             NaN      NaN            NaN           NaN          NaN
# 1             NaN      NaN            NaN           NaN          NaN
# 2             NaN      NaN            NaN           NaN          NaN
# 3             NaN      NaN           True           NaN          NaN
# 4             NaN      NaN            NaN           NaN          NaN
# ...           ...      ...            ...           ...          ...
# 5620          NaN      NaN            NaN           NaN          NaN
# 5621          NaN      NaN            NaN           NaN          NaN
# 5622          NaN      NaN            NaN           NaN          NaN
# 5623          NaN      NaN            NaN           NaN          NaN
# 5624          NaN      NaN            NaN           NaN          NaN
#
#      Aspiração central Finalidade Tipo de terreno Acesso pavimentado  \
# 0                  NaN        NaN             NaN                NaN
# 1                  NaN        NaN             NaN                NaN
# 2                  NaN        NaN             NaN                NaN
# 3                  NaN        NaN             NaN                NaN
# 4                  NaN        NaN             NaN                NaN
# ...                ...        ...             ...                ...
# 5620               NaN        NaN             NaN                NaN
# 5621               NaN        NaN             NaN                NaN
# 5622               NaN        NaN             NaN                NaN
# 5623               NaN        NaN             NaN                NaN
# 5624               NaN        NaN             NaN                NaN
#
#      Asfaltado Iluminação pública Zona arborizada Declive Ruína Alarme  \
# 0          NaN                NaN             NaN     NaN   NaN    NaN
# 1          NaN                NaN             NaN     NaN   NaN    NaN
# 2          NaN                NaN             NaN     NaN   NaN    NaN
# 3          NaN                NaN             NaN     NaN   NaN    NaN
# 4          NaN                NaN             NaN     NaN   NaN    NaN
# ...        ...                ...             ...     ...   ...    ...
# 5620       NaN                NaN             NaN     NaN   NaN    NaN
# 5621       NaN                NaN             NaN     NaN   NaN    NaN
# 5622       NaN                NaN             NaN     NaN   NaN    NaN
# 5623       NaN                NaN             NaN     NaN   NaN    NaN
# 5624       NaN                NaN             NaN     NaN   NaN    NaN
#
#      Furo de água Domótica  Casa das máquinas Condomínio Fechado  \
# 0             NaN      NaN                NaN                NaN
# 1             NaN      NaN                NaN                NaN
# 2             NaN      NaN                NaN                NaN
# 3             NaN      NaN                NaN                NaN
# 4             NaN      NaN                NaN                NaN
# ...           ...      ...                ...                ...
# 5620          NaN      NaN                NaN                NaN
# 5621          NaN      NaN                NaN                NaN
# 5622          NaN      NaN                NaN                NaN
# 5623          NaN      NaN                NaN                NaN
# 5624          NaN      NaN                NaN                NaN
#
#      Parque infantil Piscina Piscina Privada Termoacumulador Garagem exterior  \
# 0                NaN     NaN             NaN             NaN              NaN
# 1                NaN     NaN             NaN             NaN              NaN
# 2                NaN     NaN             NaN             NaN              NaN
# 3                NaN     NaN             NaN             NaN              NaN
# 4                NaN     NaN             NaN            True              NaN
# ...              ...     ...             ...             ...              ...
# 5620             NaN     NaN             NaN             NaN              NaN
# 5621             NaN     NaN             NaN             NaN              NaN
# 5622             NaN     NaN             NaN             NaN              NaN
# 5623             NaN     NaN             NaN             NaN              NaN
# 5624             NaN     NaN             NaN             NaN              NaN
#
#      Mobilado Hidromassagem/jacuzzi Quintal/horta Ginásio Kitchenette  \
# 0         NaN                   NaN           NaN     NaN         NaN
# 1         NaN                   NaN           NaN     NaN         NaN
# 2         NaN                   NaN           NaN     NaN         NaN
# 3         NaN                   NaN          True     NaN         NaN
# 4         NaN                   NaN           NaN     NaN         NaN
# ...       ...                   ...           ...     ...         ...
# 5620      NaN                   NaN           NaN     NaN         NaN
# 5621      NaN                   NaN           NaN     NaN         NaN
# 5622      NaN                   NaN           NaN     NaN         NaN
# 5623      NaN                   NaN           NaN     NaN         NaN
# 5624      NaN                   NaN           NaN     NaN         NaN
#
#      Vigilância/segurança Campo de ténis Segurança 24 horas Vedação  \
# 0                     NaN            NaN                NaN     NaN
# 1                     NaN            NaN                NaN     NaN
# 2                     NaN            NaN                NaN     NaN
# 3                     NaN            NaN                NaN     NaN
# 4                     NaN            NaN                NaN     NaN
# ...                   ...            ...                ...     ...
# 5620                  NaN            NaN                NaN     NaN
# 5621                  NaN            NaN                NaN     NaN
# 5622                  NaN            NaN                NaN     NaN
# 5623                  NaN            NaN                NaN     NaN
# 5624                  NaN            NaN                NaN     NaN
#
#      Parqueamento (1 carro) Ligação a rede de água  \
# 0                       NaN                    NaN
# 1                       NaN                    NaN
# 2                       NaN                    NaN
# 3                       NaN                    NaN
# 4                       NaN                    NaN
# ...                     ...                    ...
# 5620                    NaN                    NaN
# 5621                    NaN                    NaN
# 5622                    NaN                    NaN
# 5623                    NaN                    NaN
# 5624                    NaN                    NaN
#
#       Ligação a rede de saneamento Ligação a rede elétrica Animais permitidos  \
# 0                              NaN                     NaN                NaN
# 1                              NaN                     NaN                NaN
# 2                              NaN                     NaN                NaN
# 3                              NaN                     NaN                NaN
# 4                              NaN                     NaN                NaN
# ...                            ...                     ...                ...
# 5620                           NaN                     NaN                NaN
# 5621                           NaN                     NaN                NaN
# 5622                           NaN                     NaN                NaN
# 5623                           NaN                     NaN                NaN
# 5624                           NaN                     NaN                NaN
#
#      Parqueamento (2 carros) Cofre Vista de rio  Nº divisões Tipo  Pisos  \
# 0                        NaN   NaN          NaN          NaN  NaN    NaN
# 1                        NaN   NaN          NaN          NaN  NaN    NaN
# 2                        NaN   NaN          NaN          NaN  NaN    NaN
# 3                        NaN   NaN          NaN          NaN  NaN    NaN
# 4                        NaN   NaN          NaN          NaN  NaN    NaN
# ...                      ...   ...          ...          ...  ...    ...
# 5620                     NaN   NaN          NaN          NaN  NaN    NaN
# 5621                     NaN   NaN          NaN          NaN  NaN    NaN
# 5622                     NaN   NaN          NaN          NaN  NaN    NaN
# 5623                     NaN   NaN          NaN          NaN  NaN    NaN
# 5624                     NaN   NaN          NaN          NaN  NaN    NaN
#
#      Com WC Montra Anexo habitacional  Detetor de incêndio  \
# 0       NaN    NaN                NaN                  NaN
# 1       NaN    NaN                NaN                  NaN
# 2       NaN    NaN                NaN                  NaN
# 3       NaN    NaN                NaN                  NaN
# 4       NaN    NaN                NaN                  NaN
# ...     ...    ...                ...                  ...
# 5620    NaN    NaN                NaN                  NaN
# 5621    NaN    NaN                NaN                  NaN
# 5622    NaN    NaN                NaN                  NaN
# 5623    NaN    NaN                NaN                  NaN
# 5624    NaN    NaN                NaN                  NaN
#
#       Detetor de Inundução Vista de cidade.1 Área (m/2) Vista de mar Jacuzzi  \
# 0                      NaN               NaN        NaN          NaN     NaN
# 1                      NaN               NaN        NaN          NaN     NaN
# 2                      NaN               NaN        NaN          NaN     NaN
# 3                      NaN               NaN        NaN          NaN     NaN
# 4                      NaN               NaN        NaN          NaN     NaN
# ...                    ...               ...        ...          ...     ...
# 5620                   NaN               NaN        NaN          NaN     NaN
# 5621                   NaN               NaN        NaN          NaN     NaN
# 5622                   NaN               NaN        NaN          NaN     NaN
# 5623                   NaN               NaN        NaN          NaN     NaN
# 5624                   NaN               NaN        NaN          NaN     NaN
#
#      Património classificado Adaptada a mobilidade reduzida Com cozinha  \
# 0                        NaN                            NaN         NaN
# 1                        NaN                            NaN         NaN
# 2                        NaN                            NaN         NaN
# 3                        NaN                            NaN         NaN
# 4                        NaN                            NaN         NaN
# ...                      ...                            ...         ...
# 5620                     NaN                            NaN         NaN
# 5621                     NaN                            NaN         NaN
# 5622                     NaN                            NaN         NaN
# 5623                     NaN                            NaN         NaN
# 5624                     NaN                            NaN         NaN
#
#      Imóvel de banca Vista de lago Fossa séptica  Licensa de construção  \
# 0                NaN           NaN           NaN                    NaN
# 1                NaN           NaN           NaN                    NaN
# 2                NaN           NaN           NaN                    NaN
# 3                NaN           NaN           NaN                    NaN
# 4                NaN           NaN           NaN                    NaN
# ...              ...           ...           ...                    ...
# 5620             NaN           NaN           NaN                    NaN
# 5621             NaN           NaN           NaN                    NaN
# 5622             NaN           NaN           NaN                    NaN
# 5623             NaN           NaN           NaN                    NaN
# 5624             NaN           NaN           NaN                    NaN
#
#      Acesso a veículos pesados Área administrativa Copa Recepção Refeitório  \
# 0                          NaN                 NaN  NaN      NaN        NaN
# 1                          NaN                 NaN  NaN      NaN        NaN
# 2                          NaN                 NaN  NaN      NaN        NaN
# 3                          NaN                 NaN  NaN      NaN        NaN
# 4                          NaN                 NaN  NaN      NaN        NaN
# ...                        ...                 ...  ...      ...        ...
# 5620                       NaN                 NaN  NaN      NaN        NaN
# 5621                       NaN                 NaN  NaN      NaN        NaN
# 5622                       NaN                 NaN  NaN      NaN        NaN
# 5623                       NaN                 NaN  NaN      NaN        NaN
# 5624                       NaN                 NaN  NaN      NaN        NaN
#
#      Sala de reuniões Área florestal Hidromassagem Percurso de água Armazém  \
# 0                 NaN            NaN           NaN              NaN     NaN
# 1                 NaN            NaN           NaN              NaN     NaN
# 2                 NaN            NaN           NaN              NaN     NaN
# 3                 NaN            NaN           NaN              NaN     NaN
# 4                 NaN            NaN           NaN              NaN     NaN
# ...               ...            ...           ...              ...     ...
# 5620              NaN            NaN           NaN              NaN     NaN
# 5621              NaN            NaN           NaN              NaN     NaN
# 5622              NaN            NaN           NaN              NaN     NaN
# 5623              NaN            NaN           NaN              NaN     NaN
# 5624              NaN            NaN           NaN              NaN     NaN
#
#      Vista de Serra Adaptado a mobilidade reduzida Terra batida  \
# 0               NaN                            NaN          NaN
# 1               NaN                            NaN          NaN
# 2               NaN                            NaN          NaN
# 3               NaN                            NaN          NaN
# 4               NaN                            NaN          NaN
# ...             ...                            ...          ...
# 5620            NaN                            NaN          NaN
# 5621            NaN                            NaN          NaN
# 5622            NaN                            NaN          NaN
# 5623            NaN                            NaN          NaN
# 5624            NaN                            NaN          NaN
#
#      Video vigilância  Espaço frigorífico Espaço para arrumação  \
# 0                 NaN                 NaN                   NaN
# 1                 NaN                 NaN                   NaN
# 2                 NaN                 NaN                   NaN
# 3                 NaN                 NaN                   NaN
# 4                 NaN                 NaN                   NaN
# ...               ...                 ...                   ...
# 5620              NaN                 NaN                   NaN
# 5621              NaN                 NaN                   NaN
# 5622              NaN                 NaN                   NaN
# 5623              NaN                 NaN                   NaN
# 5624              NaN                 NaN                   NaN
#
#      Casa de banho partilhada Poço Sótão Paisagem protegida
# 0                         NaN  NaN   NaN                NaN
# 1                         NaN  NaN   NaN                NaN
# 2                         NaN  NaN   NaN                NaN
# 3                         NaN  NaN   NaN                NaN
# 4                         NaN  NaN   NaN                NaN
# ...                       ...  ...   ...                ...
# 5620                      NaN  NaN   NaN                NaN
# 5621                      NaN  NaN   NaN                NaN
# 5622                      NaN  NaN   NaN                NaN
# 5623                      NaN  NaN   NaN                NaN
# 5624                      NaN  NaN   NaN                NaN
#
# [5625 rows x 130 columns]

# %% [markdown]
# ## Pré porcessamento diferenciado por tipologias

# %% [markdown]
# ** Listar todas as tipologias existentes **

# %%
data_imo['Tipo de imóvel'].unique()
# Out:
# array(['Apartamento', 'Moradia', 'Terreno', 'Quintas', 'Prédio', 'Loja',
#        'Trespasses', 'Armazém', 'Garagem', 'Escritório'], dtype=object)

# %% [markdown]
# #### Separar os dados por tipo de imóvel

# %%
data_imo_apartamentos = data_imo.loc[(data_imo['Tipo de imóvel'] == 'Apartamento')]
data_imo_moradias = data_imo.loc[(data_imo['Tipo de imóvel'] == 'Moradia')]
data_imo_terreno = data_imo.loc[(data_imo['Tipo de imóvel']== 'Terreno')]
data_imo_quintas = data_imo.loc[(data_imo['Tipo de imóvel']== 'Quintas')]
data_imo_prédio = data_imo.loc[(data_imo['Tipo de imóvel']== 'Prédio')]
data_imo_loja = data_imo.loc[(data_imo['Tipo de imóvel']== 'Loja')]
data_imo_trespasses = data_imo.loc[(data_imo['Tipo de imóvel']== 'Trespasses')]
data_imo_escritório = data_imo.loc[(data_imo['Tipo de imóvel']== 'Escritório')]
data_imo_armazém = data_imo.loc[(data_imo['Tipo de imóvel']== 'Armazém')]
data_imo_garagem = data_imo.loc[(data_imo['Tipo de imóvel']== 'Garagem')]
#data_imo_outros = data_imo.loc[(data_imo['Tipo de imóvel']== None) | pd.isna(data_imo['Tipo de imóvel'])]

# %% [markdown]
# ## Dados - Apartamentos

# %%
data_imo_apartamentos.head()
data_imo_apartamentos.info()
pd.set_option('display.max_rows', 20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1965 entries, 0 to 5580
# Data columns (total 74 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Património classificado                               1 non-null      object
#  1   Árvores de fruto                                      1 non-null      object
#  2   Imóvel de banca                                       2 non-null      object
#  3   Jacuzzi                                               2 non-null      object
#  4   Vigilância/segurança                                  7 non-null      object
#  5   Quintal/horta                                         7 non-null      object
#  6   Portaria                                              9 non-null      object
#  7   Vista de mar                                          9 non-null      object
#  8   Vista de rio                                          9 non-null      object
#  9   Piso radiante                                         9 non-null      object
#  10  Cofre                                                 10 non-null     object
#  11  Domótica                                              10 non-null     object
#  12  Segurança 24 horas                                    13 non-null     object
#  13  Parqueamento (2 carros)                               16 non-null     object
#  14  Campo de ténis                                        16 non-null     object
#  15  Marquise                                              18 non-null     object
#  16  Piscina Privada                                       21 non-null     object
#  17  Som ambiente                                          28 non-null     object
#  18  Piscina                                               30 non-null     object
#  19  Hidromassagem/jacuzzi                                 32 non-null     object
#  20  Parqueamento (1 carro)                                37 non-null     object
#  21  Detetor de gás                                        41 non-null     object
#  22  Arrecadação                                           43 non-null     object
#  23  Kitchenette                                           43 non-null     object
#  24  Parque infantil                                       45 non-null     object
#  25  Condomínio Fechado                                    49 non-null     object
#  26  Caldeira                                              60 non-null     object
#  27  Pré-instalação de ar condicionado                     66 non-null     object
#  28  Terraço                                               74 non-null     object
#  29  Alarme                                                81 non-null     object
#  30  Fibra ótica                                           85 non-null     object
#  31  Armário                                               94 non-null     object
#  32  Aspiração central                                     105 non-null    object
#  33  Vista de campo/serra                                  118 non-null    object
#  34  Rua                                                   119 non-null    object
#  35  Despensa                                              126 non-null    object
#  36  Ginásio                                               126 non-null    object
#  37  Porta blindada                                        130 non-null    object
#  38  Mobilado                                              138 non-null    object
#  39  Painéis solares                                       141 non-null    object
#  40  Termoacumulador                                       167 non-null    object
#  41  Estacionamento                                        181 non-null    object
#  42  Churrasco                                             185 non-null    object
#  43  Recuperação de calor                                  198 non-null    object
#  44  Acessibilidade a pessoas com mobilidade condicionada  206 non-null    object
#  45  Jardim                                                206 non-null    object
#  46  Lareira                                               212 non-null    object
#  47  Aquecimento central                                   218 non-null    object
#  48  Vista de cidade.1                                     275 non-null    object
#  49  Cozinha equipada                                      275 non-null    object
#  50  Vista de cidade                                       275 non-null    object
#  51  Suite                                                 347 non-null    object
#  52  Video Porteiro                                        398 non-null    object
#  53  Gás canalizado                                        431 non-null    object
#  54  Varanda                                               531 non-null    object
#  55  Ar condicionado                                       638 non-null    object
#  56  Garagem box                                           713 non-null    object
#  57  Elevador                                              894 non-null    object
#  58  Área bruta m/2                                        922 non-null    object
#  59  Certificado energético                                1003 non-null   object
#  60  Ano construção                                        1005 non-null   float64
#  61  Empreendimento                                        1128 non-null   object
#  62  Nº Casas de Banho                                     1286 non-null   object
#  63  Condição                                              1467 non-null   object
#  64  Preço                                                 1947 non-null   object
#  65  Preço m/2                                             1947 non-null   object
#  66  Tipo de imóvel                                        1965 non-null   object
#  67  Distrito                                              1965 non-null   object
#  68  Id                                                    1965 non-null   int64
#  69  Concelho                                              1965 non-null   object
#  70  Freguesia                                             1965 non-null   object
#  71  Tipologia                                             1965 non-null   object
#  72  Área útil m/2                                         1965 non-null   object
#  73  Nome                                                  1965 non-null   object
# dtypes: float64(1), int64(1), object(72)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Dados em falta por linha

# %%
percent_missing = (1 - data_imo_apartamentos.apply(lambda x: x.count(), axis=1) / len(data_imo_apartamentos.columns)) * 100
missing_value_data_imo_apartamentos_rows = pd.DataFrame({'percent_missing (%)': percent_missing})
missing_value_data_imo_apartamentos_rows.sort_values('percent_missing (%)', inplace=True, ascending=False)
missing_value_data_imo_apartamentos_rows
# Out:
#       percent_missing (%)
# 3584            86.486486
# 4422            86.486486
# 2833            86.486486
# 5392            86.486486
# 2842            86.486486
# ...                   ...
# 394             45.945946
# 874             44.594595
# 1497            37.837838
# 1532            37.837838
# 737             32.432432
#
# [1965 rows x 1 columns]

# %% [markdown]
# #### Dados em falta por coluna

# %%
percent_missing = data_imo_apartamentos.isnull().sum() * 100 / len(data_imo_apartamentos)
missing_value_data_imo_apartamentos_columns = pd.DataFrame({'percent_missing (%)': percent_missing})
missing_value_data_imo_apartamentos_columns.sort_values('percent_missing (%)', inplace=True, ascending=False)
pd.set_option('display.max_rows', 20)
missing_value_data_imo_apartamentos_columns
# Out:
#                          percent_missing (%)
# Património classificado            99.949109
# Árvores de fruto                   99.949109
# Imóvel de banca                    99.898219
# Jacuzzi                            99.898219
# Vigilância/segurança               99.643766
# ...                                      ...
# Concelho                            0.000000
# Freguesia                           0.000000
# Tipologia                           0.000000
# Área útil m/2                       0.000000
# Nome                                0.000000
#
# [74 rows x 1 columns]

# %% [markdown]
# ### Retirar as colunas que têm 99% de missing values

# %%
a_manter = list(missing_value_data_imo_apartamentos_columns.index[missing_value_data_imo_apartamentos_columns['percent_missing (%)'] < 99])
print(len(a_manter))
print(a_manter)
data_imo_apartamentos = data_imo_apartamentos[a_manter]
data_imo_apartamentos
# Out:
# 58
# ['Piscina Privada', 'Som ambiente', 'Piscina', 'Hidromassagem/jacuzzi', 'Parqueamento (1 carro)', 'Detetor de gás', 'Arrecadação', 'Kitchenette', 'Parque infantil', 'Condomínio Fechado', 'Caldeira', 'Pré-instalação de ar condicionado', 'Terraço', 'Alarme', 'Fibra ótica', 'Armário', 'Aspiração central', 'Vista de campo/serra', 'Rua', 'Despensa', 'Ginásio', 'Porta blindada', 'Mobilado', 'Painéis solares', 'Termoacumulador', 'Estacionamento', 'Churrasco', 'Recuperação de calor', 'Acessibilidade a pessoas com mobilidade condicionada', 'Jardim', 'Lareira', 'Aquecimento central', 'Vista de cidade.1', 'Cozinha equipada', 'Vista de cidade', 'Suite', 'Video Porteiro', 'Gás canalizado', 'Varanda', 'Ar condicionado', 'Garagem box', 'Elevador', 'Área bruta m/2', 'Certificado energético', 'Ano construção', 'Empreendimento', 'Nº Casas de Banho', 'Condição', 'Preço', 'Preço m/2', 'Tipo de imóvel', 'Distrito', 'Id', 'Concelho', 'Freguesia', 'Tipologia', 'Área útil m/2', 'Nome']
#      Piscina Privada Som ambiente Piscina Hidromassagem/jacuzzi  \
# 0                NaN          NaN     NaN                   NaN
# 4                NaN          NaN     NaN                   NaN
# 5                NaN          NaN     NaN                   NaN
# 6                NaN          NaN     NaN                  True
# 8                NaN          NaN     NaN                   NaN
# ...              ...          ...     ...                   ...
# 5562             NaN          NaN     NaN                   NaN
# 5563             NaN          NaN     NaN                   NaN
# 5570             NaN          NaN     NaN                   NaN
# 5579             NaN          NaN     NaN                   NaN
# 5580             NaN          NaN     NaN                   NaN
#
#      Parqueamento (1 carro) Detetor de gás Arrecadação Kitchenette  \
# 0                       NaN            NaN         NaN         NaN
# 4                       NaN            NaN         NaN         NaN
# 5                       NaN            NaN         NaN         NaN
# 6                       NaN            NaN         NaN         NaN
# 8                       NaN            NaN         NaN         NaN
# ...                     ...            ...         ...         ...
# 5562                    NaN            NaN         NaN         NaN
# 5563                    NaN            NaN         NaN         NaN
# 5570                    NaN            NaN         NaN         NaN
# 5579                    NaN            NaN         NaN         NaN
# 5580                    NaN            NaN         NaN         NaN
#
#      Parque infantil Condomínio Fechado Caldeira  \
# 0                NaN                NaN      NaN
# 4                NaN                NaN      NaN
# 5                NaN                NaN      NaN
# 6                NaN                NaN      NaN
# 8                NaN                NaN      NaN
# ...              ...                ...      ...
# 5562             NaN                NaN      NaN
# 5563             NaN                NaN      NaN
# 5570             NaN                NaN      NaN
# 5579             NaN                NaN      NaN
# 5580             NaN                NaN      NaN
#
#      Pré-instalação de ar condicionado Terraço Alarme Fibra ótica Armário  \
# 0                                 True     NaN    NaN         NaN    True
# 4                                  NaN     NaN    NaN         NaN     NaN
# 5                                  NaN     NaN   True        True     NaN
# 6                                  NaN     NaN    NaN         NaN     NaN
# 8                                  NaN     NaN    NaN         NaN     NaN
# ...                                ...     ...    ...         ...     ...
# 5562                               NaN     NaN    NaN         NaN     NaN
# 5563                               NaN     NaN    NaN         NaN     NaN
# 5570                               NaN     NaN    NaN         NaN     NaN
# 5579                               NaN     NaN    NaN         NaN     NaN
# 5580                               NaN     NaN    NaN         NaN     NaN
#
#      Aspiração central Vista de campo/serra                   Rua Despensa  \
# 0                  NaN                  NaN  Rua da Boavista - Sé      NaN
# 4                  NaN                  NaN                   NaN      NaN
# 5                 True                 True                   NaN      NaN
# 6                  NaN                  NaN                   NaN      NaN
# 8                  NaN                  NaN                   NaN      NaN
# ...                ...                  ...                   ...      ...
# 5562               NaN                  NaN                   NaN      NaN
# 5563               NaN                  NaN                   NaN      NaN
# 5570               NaN                  NaN                   NaN      NaN
# 5579               NaN                  NaN                   NaN      NaN
# 5580               NaN                  NaN                   NaN      NaN
#
#      Ginásio Porta blindada Mobilado Painéis solares Termoacumulador  \
# 0        NaN            NaN      NaN             NaN             NaN
# 4        NaN            NaN      NaN             NaN            True
# 5        NaN           True      NaN            True             NaN
# 6        NaN            NaN      NaN             NaN             NaN
# 8        NaN            NaN      NaN             NaN             NaN
# ...      ...            ...      ...             ...             ...
# 5562     NaN            NaN      NaN             NaN             NaN
# 5563     NaN            NaN      NaN             NaN             NaN
# 5570     NaN            NaN      NaN             NaN             NaN
# 5579     NaN            NaN      NaN             NaN             NaN
# 5580     NaN            NaN      NaN             NaN             NaN
#
#      Estacionamento Churrasco Recuperação de calor  \
# 0               NaN       NaN                 True
# 4               NaN       NaN                  NaN
# 5               NaN       NaN                  NaN
# 6               NaN       NaN                  NaN
# 8               NaN       NaN                  NaN
# ...             ...       ...                  ...
# 5562            NaN       NaN                  NaN
# 5563            NaN       NaN                  NaN
# 5570            NaN       NaN                  NaN
# 5579            NaN       NaN                  NaN
# 5580            NaN       NaN                  NaN
#
#      Acessibilidade a pessoas com mobilidade condicionada Jardim Lareira  \
# 0                                                   NaN      NaN     NaN
# 4                                                   NaN      NaN    True
# 5                                                   NaN      NaN    True
# 6                                                  True     True     NaN
# 8                                                   NaN      NaN     NaN
# ...                                                 ...      ...     ...
# 5562                                                NaN      NaN     NaN
# 5563                                                NaN      NaN     NaN
# 5570                                                NaN      NaN     NaN
# 5579                                                NaN      NaN     NaN
# 5580                                                NaN      NaN     NaN
#
#      Aquecimento central Vista de cidade.1 Cozinha equipada Vista de cidade  \
# 0                    NaN               NaN              NaN             NaN
# 4                    NaN               NaN              NaN             NaN
# 5                    NaN               NaN             True             NaN
# 6                    NaN               NaN              NaN             NaN
# 8                    NaN               NaN              NaN             NaN
# ...                  ...               ...              ...             ...
# 5562                 NaN               NaN              NaN             NaN
# 5563                 NaN               NaN              NaN             NaN
# 5570                 NaN               NaN              NaN             NaN
# 5579                 NaN               NaN              NaN             NaN
# 5580                 NaN               NaN              NaN             NaN
#
#      Suite Video Porteiro Gás canalizado Varanda Ar condicionado Garagem box  \
# 0     True           True           True     NaN             NaN         NaN
# 4      NaN            NaN            NaN    True             NaN        True
# 5     True            NaN           True    True            True         NaN
# 6      NaN            NaN            NaN     NaN            True        True
# 8      NaN            NaN            NaN     NaN            True         NaN
# ...    ...            ...            ...     ...             ...         ...
# 5562   NaN            NaN            NaN     NaN             NaN         NaN
# 5563   NaN            NaN            NaN     NaN             NaN         NaN
# 5570   NaN            NaN            NaN     NaN             NaN         NaN
# 5579   NaN            NaN            NaN     NaN             NaN         NaN
# 5580   NaN            NaN            NaN     NaN             NaN         NaN
#
#      Elevador Área bruta m/2 Certificado energético  Ano construção  \
# 0         NaN            NaN                    NaN          2020.0
# 4         NaN      105,09 m²                      C          1987.0
# 5        True         150 m²                      A          2011.0
# 6        True            NaN                     A+          2020.0
# 8         NaN            NaN                    NaN          2020.0
# ...       ...            ...                    ...             ...
# 5562      NaN            NaN                    NaN          2019.0
# 5563      NaN            NaN                    NaN          2019.0
# 5570      NaN            NaN                    NaN             NaN
# 5579      NaN         135 m²                    NaN             NaN
# 5580      NaN            NaN                    NaN             NaN
#
#      Empreendimento Nº Casas de Banho       Condição     Preço Preço m/2  \
# 0               NaN                 2           Novo  170 000     1 532
# 4               não                 2       Renovado  149 000     1 759
# 5               NaN                 2          Usado  199 500     1 330
# 6               não                 1  Em construção  165 000     1 250
# 8               não               NaN            NaN  125 000     2 092
# ...             ...               ...            ...       ...       ...
# 5562            NaN               NaN            NaN  270 000     3 439
# 5563            NaN               NaN            NaN  245 000     4 261
# 5570            não                 2          Usado  238 500     2 051
# 5579            não               NaN          Usado  105 000       840
# 5580            NaN                 1          Usado  140 000     1 400
#
#      Tipo de imóvel          Distrito        Id Concelho  \
# 0       Apartamento  Braga (distrito)  15024495    Braga
# 4       Apartamento  Braga (distrito)  15386584    Braga
# 5       Apartamento  Braga (distrito)  11667094    Braga
# 6       Apartamento  Braga (distrito)  15135292    Braga
# 8       Apartamento  Braga (distrito)  15023391    Braga
# ...             ...               ...       ...      ...
# 5562    Apartamento  Braga (distrito)  14869231    Braga
# 5563    Apartamento  Braga (distrito)  14869219    Braga
# 5570    Apartamento  Braga (distrito)  15286851    Braga
# 5579    Apartamento  Braga (distrito)  15363375    Braga
# 5580    Apartamento  Braga (distrito)  14992429    Braga
#
#                                               Freguesia Tipologia  \
# 0                      Braga (Maximinos, Sé e Cividade)        T3
# 4                      Braga (Maximinos, Sé e Cividade)        T3
# 5                           Nogueira, Fraião e Lamaçães        T3
# 6                                  Real, Dume e Semelhe        T3
# 8                      Braga (Maximinos, Sé e Cividade)        T1
# ...                                                 ...       ...
# 5562  Braga (São José de São Lázaro e São João do So...        T1
# 5563  Braga (São José de São Lázaro e São João do So...        T1
# 5570                        Nogueira, Fraião e Lamaçães        T3
# 5579                                         São Victor        T0
# 5580                                      Lomar e Arcos        T2
#
#      Área útil m/2                                               Nome
# 0           111 m²   Apartamento T3 Novo na malha do Centro Histórico
# 4         84,72 m²  Oferta da escritura. Apartamento T3 renovado, ...
# 5           150 m²                        Apartamento T3 Oportunidade
# 6           132 m²                        Apartamento Novo T3 em Real
# 8         59,75 m²                  Apartamento T1 - Cividade - Braga
# ...            ...                                                ...
# 5562      78,50 m²  Apartamento T1 Piso 2 no centro da cidade de B...
# 5563      57,50 m²  Apartamento T1 Piso 3 no centro da cidade de B...
# 5570     116,30 m²                    Apartamento T3 de Luxo - Fraião
# 5579        125 m²    Apartamento T3 Venda em Braga (São Vítor),Braga
# 5580        100 m²                                        Apartamento
#
# [1965 rows x 58 columns]

# %% [markdown]
# ## Dados - Moradias

# %%
data_imo_moradias.head()
data_imo_moradias.info()
pd.set_option('display.max_rows', 20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 5620
# Data columns (total 82 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Portaria                                              1 non-null      object
#  1   Imóvel de banca                                       1 non-null      object
#  2   Fossa séptica                                         1 non-null      object
#  3   Paisagem protegida                                    1 non-null      object
#  4   Vista de mar                                          1 non-null      object
#  5   Vista de lago                                         1 non-null      object
#  6   Condomínio Fechado                                    2 non-null      object
#  7   Kitchenette                                           2 non-null      object
#  8   Jacuzzi                                               2 non-null      object
#  9   Parque infantil                                       3 non-null      object
#  10  Segurança 24 horas                                    4 non-null      object
#  11  Campo de ténis                                        4 non-null      object
#  12  Cofre                                                 5 non-null      object
#  13  Anexo habitacional                                    7 non-null      object
#  14  Detetor de gás                                        8 non-null      object
#  15  Piso radiante                                         9 non-null      object
#  16  Marquise                                              12 non-null     object
#  17  Animais permitidos                                    13 non-null     object
#  18  Vista de rio                                          14 non-null     object
#  19  Vedação                                               16 non-null     object
#  20  Garagem exterior                                      16 non-null     object
#  21  Vista de Serra                                        16 non-null     object
#  22  Domótica                                              16 non-null     object
#  23  Árvores de fruto                                      17 non-null     object
#  24  Vigilância/segurança                                  18 non-null     object
#  25  Sotão                                                 22 non-null     object
#  26  Mobilado                                              23 non-null     object
#  27  Furo de água                                          26 non-null     object
#  28  Ginásio                                               34 non-null     object
#  29  Elevador                                              34 non-null     object
#  30  Som ambiente                                          35 non-null     object
#  31  Piscina Privada                                       36 non-null     object
#  32  Fibra ótica                                           40 non-null     object
#  33  Cave                                                  46 non-null     object
#  34  Caldeira                                              47 non-null     object
#  35  Hidromassagem/jacuzzi                                 47 non-null     object
#  36  Porta blindada                                        49 non-null     object
#  37  Acessibilidade a pessoas com mobilidade condicionada  50 non-null     object
#  38  Arrecadação                                           54 non-null     object
#  39  Armário                                               57 non-null     object
#  40  Termoacumulador                                       65 non-null     object
#  41  Despensa                                              85 non-null     object
#  42  Rua                                                   87 non-null     object
#  43  Pré-instalação de ar condicionado                     91 non-null     object
#  44  Quintal/horta                                         95 non-null     object
#  45  Piscina                                               97 non-null     object
#  46  Estacionamento                                        119 non-null    object
#  47  Terraço                                               127 non-null    object
#  48  Churrasco                                             129 non-null    object
#  49  Vista de cidade                                       133 non-null    object
#  50  Vista de cidade.1                                     133 non-null    object
#  51  Aspiração central                                     155 non-null    object
#  52  Painéis solares                                       156 non-null    object
#  53  Vista de campo/serra                                  160 non-null    object
#  54  Cozinha equipada                                      184 non-null    object
#  55  Recuperação de calor                                  188 non-null    object
#  56  Gás canalizado                                        202 non-null    object
#  57  Lareira                                               233 non-null    object
#  58  Alarme                                                235 non-null    object
#  59  Video Porteiro                                        245 non-null    object
#  60  Suite                                                 263 non-null    object
#  61  Aquecimento central                                   286 non-null    object
#  62  Ar condicionado                                       299 non-null    object
#  63  Varanda                                               323 non-null    object
#  64  Jardim                                                409 non-null    object
#  65  Garagem box                                           653 non-null    object
#  66  Ano construção                                        659 non-null    float64
#  67  Certificado energético                                663 non-null    object
#  68  Área bruta m/2                                        674 non-null    object
#  69  Empreendimento                                        841 non-null    object
#  70  Nº Casas de Banho                                     855 non-null    object
#  71  Condição                                              1087 non-null   object
#  72  Preço m/2                                             1423 non-null   object
#  73  Preço                                                 1423 non-null   object
#  74  Distrito                                              1460 non-null   object
#  75  Tipo de imóvel                                        1460 non-null   object
#  76  Área útil m/2                                         1460 non-null   object
#  77  Concelho                                              1460 non-null   object
#  78  Freguesia                                             1460 non-null   object
#  79  Id                                                    1460 non-null   int64
#  80  Tipologia                                             1460 non-null   object
#  81  Nome                                                  1460 non-null   object
# dtypes: float64(1), int64(1), object(80)
# memory usage: 946.7+ KB

# %% [markdown]
# #### Dados em falta por linha

# %%
percent_missing = (1 - data_imo_moradias.apply(lambda x: x.count(), axis=1) / len(data_imo_moradias.columns)) * 100
missing_value_data_imo_moradias_rows = pd.DataFrame({'percent_missing (%)': percent_missing})
missing_value_data_imo_moradias_rows.sort_values('percent_missing (%)', inplace=True, ascending=False)
missing_value_data_imo_moradias_rows
# Out:
#       percent_missing (%)
# 4232            87.804878
# 3152            87.804878
# 4529            87.804878
# 3248            87.804878
# 2660            87.804878
# ...                   ...
# 3979            54.878049
# 1883            53.658537
# 474             53.658537
# 688             48.780488
# 3181            47.560976
#
# [1460 rows x 1 columns]

# %% [markdown]
# #### Dados em falta por coluna

# %%
percent_missing = data_imo_moradias.isnull().sum() * 100 / len(data_imo_moradias)
missing_value_data_imo_moradias_columns = pd.DataFrame({'percent_missing (%)': percent_missing})
missing_value_data_imo_moradias_columns.sort_values('percent_missing (%)', inplace=True, ascending=False)
pd.set_option('display.max_rows', 20)
missing_value_data_imo_moradias_columns
# Out:
#                     percent_missing (%)
# Portaria                      99.931507
# Vista de mar                  99.931507
# Vista de lago                 99.931507
# Imóvel de banca               99.931507
# Paisagem protegida            99.931507
# ...                                 ...
# Concelho                       0.000000
# Freguesia                      0.000000
# Id                             0.000000
# Tipologia                      0.000000
# Nome                           0.000000
#
# [82 rows x 1 columns]

# %% [markdown]
# ### Retirar as colunas que têm 99% de missing values

# %%
a_manter = list(missing_value_data_imo_moradias_columns.index[missing_value_data_imo_moradias_columns['percent_missing (%)'] < 99])
print(len(a_manter))
print(a_manter)
data_imo_moradias = data_imo_moradias[a_manter]
data_imo_moradias
# Out:
# 63
# ['Vista de Serra', 'Domótica', 'Garagem exterior', 'Vedação', 'Árvores de fruto', 'Vigilância/segurança', 'Sotão', 'Mobilado', 'Furo de água', 'Ginásio', 'Elevador', 'Som ambiente', 'Piscina Privada', 'Fibra ótica', 'Cave', 'Caldeira', 'Hidromassagem/jacuzzi', 'Porta blindada', 'Acessibilidade a pessoas com mobilidade condicionada', 'Arrecadação', 'Armário', 'Termoacumulador', 'Despensa', 'Rua', 'Pré-instalação de ar condicionado', 'Quintal/horta', 'Piscina', 'Estacionamento', 'Terraço', 'Churrasco', 'Vista de cidade', 'Vista de cidade.1', 'Aspiração central', 'Painéis solares', 'Vista de campo/serra', 'Cozinha equipada', 'Recuperação de calor', 'Gás canalizado', 'Lareira', 'Alarme', 'Video Porteiro', 'Suite', 'Aquecimento central', 'Ar condicionado', 'Varanda', 'Jardim', 'Garagem box', 'Ano construção', 'Certificado energético', 'Área bruta m/2', 'Empreendimento', 'Nº Casas de Banho', 'Condição', 'Preço', 'Preço m/2', 'Distrito', 'Tipo de imóvel', 'Área útil m/2', 'Concelho', 'Freguesia', 'Id', 'Tipologia', 'Nome']
#      Vista de Serra Domótica Garagem exterior Vedação Árvores de fruto  \
# 1               NaN      NaN              NaN     NaN              NaN
# 2               NaN      NaN              NaN     NaN              NaN
# 3               NaN      NaN              NaN     NaN              NaN
# 10              NaN      NaN              NaN     NaN              NaN
# 11              NaN      NaN              NaN     NaN              NaN
# ...             ...      ...              ...     ...              ...
# 5595            NaN      NaN              NaN     NaN              NaN
# 5596            NaN      NaN              NaN     NaN              NaN
# 5597            NaN      NaN              NaN     NaN              NaN
# 5598            NaN      NaN              NaN     NaN              NaN
# 5620            NaN      NaN              NaN     NaN              NaN
#
#      Vigilância/segurança Sotão Mobilado Furo de água Ginásio Elevador  \
# 1                     NaN   NaN      NaN          NaN     NaN      NaN
# 2                     NaN   NaN      NaN          NaN     NaN      NaN
# 3                     NaN   NaN      NaN          NaN     NaN      NaN
# 10                    NaN   NaN      NaN          NaN     NaN      NaN
# 11                    NaN   NaN      NaN          NaN     NaN      NaN
# ...                   ...   ...      ...          ...     ...      ...
# 5595                  NaN   NaN      NaN          NaN     NaN      NaN
# 5596                  NaN   NaN      NaN          NaN     NaN      NaN
# 5597                  NaN   NaN      NaN          NaN     NaN      NaN
# 5598                  NaN   NaN      NaN          NaN     NaN      NaN
# 5620                  NaN   NaN      NaN          NaN     NaN      NaN
#
#      Som ambiente Piscina Privada Fibra ótica Cave Caldeira  \
# 1             NaN             NaN         NaN  NaN      NaN
# 2             NaN             NaN         NaN  NaN      NaN
# 3             NaN             NaN         NaN  NaN      NaN
# 10            NaN             NaN         NaN  NaN      NaN
# 11            NaN             NaN         NaN  NaN      NaN
# ...           ...             ...         ...  ...      ...
# 5595          NaN             NaN         NaN  NaN      NaN
# 5596          NaN             NaN         NaN  NaN      NaN
# 5597          NaN             NaN         NaN  NaN      NaN
# 5598          NaN             NaN         NaN  NaN      NaN
# 5620          NaN             NaN         NaN  NaN      NaN
#
#      Hidromassagem/jacuzzi Porta blindada  \
# 1                      NaN            NaN
# 2                      NaN            NaN
# 3                      NaN            NaN
# 10                     NaN            NaN
# 11                     NaN            NaN
# ...                    ...            ...
# 5595                   NaN            NaN
# 5596                   NaN            NaN
# 5597                   NaN            NaN
# 5598                   NaN            NaN
# 5620                   NaN            NaN
#
#      Acessibilidade a pessoas com mobilidade condicionada Arrecadação Armário  \
# 1                                                   NaN           NaN     NaN
# 2                                                   NaN           NaN     NaN
# 3                                                  True           NaN     NaN
# 10                                                  NaN           NaN     NaN
# 11                                                  NaN           NaN     NaN
# ...                                                 ...           ...     ...
# 5595                                                NaN           NaN     NaN
# 5596                                                NaN           NaN     NaN
# 5597                                                NaN           NaN     NaN
# 5598                                                NaN           NaN     NaN
# 5620                                                NaN           NaN     NaN
#
#      Termoacumulador Despensa  Rua Pré-instalação de ar condicionado  \
# 1                NaN      NaN  NaN                               NaN
# 2                NaN      NaN  NaN                               NaN
# 3                NaN      NaN  NaN                               NaN
# 10               NaN      NaN  NaN                              True
# 11               NaN      NaN  NaN                              True
# ...              ...      ...  ...                               ...
# 5595             NaN      NaN  NaN                               NaN
# 5596             NaN      NaN  NaN                               NaN
# 5597             NaN      NaN  NaN                               NaN
# 5598             NaN      NaN  NaN                               NaN
# 5620             NaN      NaN  NaN                               NaN
#
#      Quintal/horta Piscina Estacionamento Terraço Churrasco Vista de cidade  \
# 1              NaN     NaN            NaN     NaN       NaN             NaN
# 2              NaN     NaN            NaN     NaN       NaN             NaN
# 3             True     NaN           True     NaN       NaN             NaN
# 10             NaN     NaN            NaN    True       NaN             NaN
# 11             NaN     NaN            NaN    True       NaN             NaN
# ...            ...     ...            ...     ...       ...             ...
# 5595           NaN     NaN            NaN     NaN       NaN             NaN
# 5596           NaN     NaN            NaN     NaN       NaN             NaN
# 5597           NaN     NaN            NaN     NaN       NaN             NaN
# 5598           NaN     NaN            NaN     NaN       NaN             NaN
# 5620           NaN     NaN            NaN     NaN       NaN             NaN
#
#      Vista de cidade.1 Aspiração central Painéis solares Vista de campo/serra  \
# 1                  NaN               NaN             NaN                  NaN
# 2                  NaN               NaN             NaN                  NaN
# 3                  NaN               NaN             NaN                 True
# 10                 NaN               NaN             NaN                  NaN
# 11                 NaN               NaN             NaN                  NaN
# ...                ...               ...             ...                  ...
# 5595               NaN               NaN             NaN                  NaN
# 5596               NaN               NaN             NaN                  NaN
# 5597               NaN               NaN             NaN                  NaN
# 5598               NaN               NaN             NaN                  NaN
# 5620               NaN               NaN             NaN                  NaN
#
#      Cozinha equipada Recuperação de calor Gás canalizado Lareira Alarme  \
# 1                 NaN                  NaN            NaN     NaN    NaN
# 2                 NaN                  NaN            NaN     NaN    NaN
# 3                 NaN                  NaN            NaN     NaN    NaN
# 10                NaN                  NaN            NaN    True    NaN
# 11                NaN                  NaN            NaN    True    NaN
# ...               ...                  ...            ...     ...    ...
# 5595              NaN                  NaN            NaN     NaN    NaN
# 5596              NaN                  NaN            NaN     NaN    NaN
# 5597              NaN                  NaN            NaN     NaN    NaN
# 5598              NaN                  NaN            NaN     NaN    NaN
# 5620              NaN                  NaN            NaN     NaN    NaN
#
#      Video Porteiro Suite Aquecimento central Ar condicionado Varanda Jardim  \
# 1               NaN   NaN                 NaN            True     NaN   True
# 2               NaN   NaN                 NaN             NaN     NaN   True
# 3               NaN   NaN                 NaN            True    True   True
# 10              NaN   NaN                 NaN            True     NaN   True
# 11              NaN   NaN                 NaN            True     NaN   True
# ...             ...   ...                 ...             ...     ...    ...
# 5595            NaN   NaN                 NaN             NaN     NaN    NaN
# 5596            NaN   NaN                 NaN             NaN     NaN    NaN
# 5597            NaN   NaN                 NaN             NaN     NaN    NaN
# 5598            NaN   NaN                 NaN             NaN     NaN    NaN
# 5620            NaN   NaN                 NaN             NaN     NaN    NaN
#
#      Garagem box  Ano construção Certificado energético Área bruta m/2  \
# 1           True          2020.0                     A+            NaN
# 2           True          2020.0                 Isento            NaN
# 3           True          2020.0                    NaN         188 m²
# 10           NaN             NaN                    NaN            NaN
# 11           NaN             NaN                    NaN            NaN
# ...          ...             ...                    ...            ...
# 5595         NaN             NaN                    NaN            NaN
# 5596         NaN          1987.0                      E         220 m²
# 5597         NaN          2019.0                    NaN            NaN
# 5598         NaN          2019.0                    NaN            NaN
# 5620         NaN             NaN                    NaN            NaN
#
#      Empreendimento Nº Casas de Banho       Condição     Preço Preço m/2  \
# 1               não                 3  Em construção  275 000       764
# 2               não               NaN           Novo  230 000     1 420
# 3               NaN                 3  Em construção  279 900     1 676
# 10              não                 3           Novo  495 000     3 538
# 11              não                 3           Novo  495 000     3 538
# ...             ...               ...            ...       ...       ...
# 5595            NaN               NaN            NaN  220 000       917
# 5596            não               NaN          Usado  183 000       963
# 5597            não               NaN  Em construção  240 000       800
# 5598            não               NaN  Em construção  400 000     2 857
# 5620            não               NaN           Novo  318 000     1 104
#
#               Distrito Tipo de imóvel Área útil m/2 Concelho  \
# 1     Braga (distrito)        Moradia        360 m²    Braga
# 2     Braga (distrito)        Moradia        162 m²    Braga
# 3     Braga (distrito)        Moradia        167 m²    Braga
# 10    Braga (distrito)        Moradia     139,91 m²    Braga
# 11    Braga (distrito)        Moradia     139,91 m²    Braga
# ...                ...            ...           ...      ...
# 5595  Braga (distrito)        Moradia        240 m²    Braga
# 5596  Braga (distrito)        Moradia        190 m²    Braga
# 5597  Braga (distrito)        Moradia        300 m²    Braga
# 5598  Braga (distrito)        Moradia        140 m²    Braga
# 5620  Braga (distrito)        Moradia        288 m²    Braga
#
#                           Freguesia        Id Tipologia  \
# 1      Celeirós, Aveleda e Vimieiro  15337986        T3
# 2                          Palmeira  15199439        T3
# 3              Real, Dume e Semelhe  15388755        T3
# 10            Morreira e Trandeiras  15387414        T3
# 11            Morreira e Trandeiras  15387413        T3
# ...                             ...       ...       ...
# 5595                        Gualtar  11653699        T4
# 5596                       Palmeira  14801249        T3
# 5597                        Gualtar  14798176        T4
# 5598                     São Victor  14479261        T4
# 5620  Este (São Pedro e São Mamede)  14968844        T4
#
#                                                    Nome
# 1                        Moradia Geminada T3+1 em Braga
# 2                       Moradia em Banda T3 em Palmeira
# 3     Moradia Individual T3 Nova, com arquitectura m...
# 10       Moderna villa de 3 quartos à venda em Mallorca
# 11       Moderna villa de 3 quartos à venda em Mallorca
# ...                                                 ...
# 5595                                    Moradia Gualtar
# 5596                 Moradia T3 Venda em Palmeira,Braga
# 5597                  Moradia T4 Venda em Gualtar,Braga
# 5598        Moradia T4 Venda em Braga (São Vítor),Braga
# 5620  Moradia T4 Venda em Este (São Pedro e São Mame...
#
# [1460 rows x 63 columns]

# %% [markdown]
# ## Dados - Terreno

# %%
data_imo_terreno.head()
data_imo_terreno.info()
pd.set_option('display.max_rows', 20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1082 entries, 7 to 5624
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Terra batida             1 non-null      object
#  1   Área florestal           1 non-null      object
#  2   Percurso de água         1 non-null      object
#  3   Ruína                    2 non-null      object
#  4   Vista de rio             3 non-null      object
#  5   Zona arborizada          5 non-null      object
#  6   Imóvel de banca          6 non-null      object
#  7   Árvores de fruto         8 non-null      object
#  8   Ligação a rede elétrica  13 non-null     object
#  9   Ligação a rede de água   17 non-null     object
#  10  Vista de Serra           18 non-null     object
#  11  Asfaltado                20 non-null     object
#  12  Declive                  24 non-null     object
#  13  Vista de cidade          25 non-null     object
#  14  Vista de cidade.1        25 non-null     object
#  15  Iluminação pública       26 non-null     object
#  16  Acesso pavimentado       27 non-null     object
#  17  Rua                      76 non-null     object
#  18  Finalidade               102 non-null    object
#  19  Tipo de terreno          223 non-null    object
#  20  Preço m/2                1064 non-null   object
#  21  Preço                    1064 non-null   object
#  22  Id                       1082 non-null   int64
#  23  Freguesia                1082 non-null   object
#  24  Concelho                 1082 non-null   object
#  25  Distrito                 1082 non-null   object
#  26  Tipo de imóvel           1082 non-null   object
#  27  Nome                     1082 non-null   object
# dtypes: int64(1), object(27)
# memory usage: 245.1+ KB

# %% [markdown]
# #### Dados em falta por linha

# %%
percent_missing = (1 - data_imo_terreno.apply(lambda x: x.count(), axis=1) / len(data_imo_terreno.columns)) * 100
missing_value_data_imo_terreno_rows = pd.DataFrame({'percent_missing (%)': percent_missing})
missing_value_data_imo_terreno_rows.sort_values('percent_missing (%)', inplace=True, ascending=False)
missing_value_data_imo_terreno_rows
# Out:
#       percent_missing (%)
# 5214            78.571429
# 4570            78.571429
# 3928            78.571429
# 5030            78.571429
# 5203            78.571429
# ...                   ...
# 3885            39.285714
# 4807            35.714286
# 7               32.142857
# 155             32.142857
# 1908            28.571429
#
# [1082 rows x 1 columns]

# %% [markdown]
# #### Dados em falta por coluna

# %%
percent_missing = data_imo_terreno.isnull().sum() * 100 / len(data_imo_terreno)
missing_value_data_imo_terreno_columns = pd.DataFrame({'percent_missing (%)': percent_missing})
missing_value_data_imo_terreno_columns.sort_values('percent_missing (%)', inplace=True, ascending=False)
pd.set_option('display.max_rows', 20)
missing_value_data_imo_terreno_columns
# Out:
#                   percent_missing (%)
# Terra batida                99.907579
# Área florestal              99.907579
# Percurso de água            99.907579
# Ruína                       99.815157
# Vista de rio                99.722736
# ...                               ...
# Freguesia                    0.000000
# Concelho                     0.000000
# Distrito                     0.000000
# Tipo de imóvel               0.000000
# Nome                         0.000000
#
# [28 rows x 1 columns]

# %% [markdown]
# ### Retirar as colunas que têm 99% de missing values

# %%
a_manter = list(missing_value_data_imo_terreno_columns.index[missing_value_data_imo_terreno_columns['percent_missing (%)'] < 99])
print(len(a_manter))
print(a_manter)
data_imo_terreno = data_imo_terreno[a_manter]
data_imo_terreno
# Out:
# 20
# ['Ligação a rede elétrica', 'Ligação a rede de água', 'Vista de Serra', 'Asfaltado', 'Declive', 'Vista de cidade.1', 'Vista de cidade', 'Iluminação pública', 'Acesso pavimentado', 'Rua', 'Finalidade', 'Tipo de terreno', 'Preço m/2', 'Preço', 'Id', 'Freguesia', 'Concelho', 'Distrito', 'Tipo de imóvel', 'Nome']
#      Ligação a rede elétrica Ligação a rede de água Vista de Serra Asfaltado  \
# 7                       True                    NaN           True      True
# 52                       NaN                    NaN            NaN      True
# 54                       NaN                    NaN            NaN      True
# 55                       NaN                    NaN           True       NaN
# 66                       NaN                    NaN           True       NaN
# ...                      ...                    ...            ...       ...
# 5619                     NaN                    NaN            NaN       NaN
# 5621                     NaN                    NaN            NaN       NaN
# 5622                     NaN                    NaN            NaN       NaN
# 5623                     NaN                    NaN            NaN       NaN
# 5624                     NaN                    NaN            NaN       NaN
#
#                       Declive Vista de cidade.1 Vista de cidade  \
# 7     Suave (entre 10º e 20º)              True            True
# 52                        NaN               NaN             NaN
# 54                      Plano              True            True
# 55                        NaN              True            True
# 66    Suave (entre 10º e 20º)               NaN             NaN
# ...                       ...               ...             ...
# 5619                      NaN               NaN             NaN
# 5621                      NaN               NaN             NaN
# 5622                      NaN               NaN             NaN
# 5623                      NaN               NaN             NaN
# 5624                      NaN               NaN             NaN
#
#      Iluminação pública Acesso pavimentado                            Rua  \
# 7                  True               True  Avenida dos Lusíadas - Tenões
# 52                 True               True               Rua da Bouça Boa
# 54                 True               True                  Rua da Tapada
# 55                 True               True                    Rua da Eira
# 66                 True               True           Largo da Praça Velha
# ...                 ...                ...                            ...
# 5619                NaN                NaN                            NaN
# 5621                NaN                NaN                            NaN
# 5622                NaN                NaN                            NaN
# 5623                NaN                NaN                            NaN
# 5624                NaN                NaN                            NaN
#
#      Finalidade Tipo de terreno Preço m/2     Preço        Id  \
# 7     Habitação          Urbano      274    69 900   15385127
# 52    Habitação          Urbano      108    49 900   15261885
# 54    Habitação          Urbano      227    55 000   14884360
# 55    Habitação          Urbano      267   229 000   14805068
# 66    Habitação     Urbanizável       70    42 500   14864377
# ...         ...             ...       ...       ...       ...
# 5619        NaN             NaN       71   250 000   14968859
# 5621        NaN             NaN      205    50 000   14790616
# 5622        NaN             NaN      218    50 000   14772154
# 5623        NaN             NaN      297    49 000   14968858
# 5624        NaN             NaN      160    57 500   14968896
#
#                           Freguesia Concelho          Distrito Tipo de imóvel  \
# 7                 Nogueiró e Tenões    Braga  Braga (distrito)        Terreno
# 52             Real, Dume e Semelhe    Braga  Braga (distrito)        Terreno
# 54             Real, Dume e Semelhe    Braga  Braga (distrito)        Terreno
# 55                Nogueiró e Tenões    Braga  Braga (distrito)        Terreno
# 66                         Sequeira    Braga  Braga (distrito)        Terreno
# ...                             ...      ...               ...            ...
# 5619  Este (São Pedro e São Mamede)    Braga  Braga (distrito)        Terreno
# 5621        Ferreiros e Gondizalves    Braga  Braga (distrito)        Terreno
# 5622        Ferreiros e Gondizalves    Braga  Braga (distrito)        Terreno
# 5623                        Gualtar    Braga  Braga (distrito)        Terreno
# 5624   Celeirós, Aveleda e Vimieiro    Braga  Braga (distrito)        Terreno
#
#                                                    Nome
# 7     Lote de Terreno P/construção de Moradia em Nog...
# 52    Lote de Terreno P/Construção de Moradia Gemina...
# 54    Lote de Terreno P/Construção de Moradia Gaveto...
# 55    Moradia p/Restauro próximo do Bom Jesus de Braga!
# 66    Lote de Terreno c/610 m2 junto ao Santuário do...
# ...                                                 ...
# 5619  Terreno  Venda em Este (São Pedro e São Mamede...
# 5621    Terreno  Venda em Ferreiros e Gondizalves,Braga
# 5622    Terreno  Venda em Ferreiros e Gondizalves,Braga
# 5623    Terreno Para Construção  Venda em Gualtar,Braga
# 5624  Terreno T3 Venda em Celeirós, Aveleda e Vimiei...
#
# [1082 rows x 20 columns]

# %% [markdown]
# ## Dados - Quintas

# %%
data_imo_quintas.head()
data_imo_quintas.info()
pd.set_option('display.max_rows', 20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85 entries, 137 to 5576
# Data columns (total 47 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Adaptada a mobilidade reduzida     1 non-null      object
#  1   Poço                               1 non-null      object
#  2   Vista de cidade.1                  1 non-null      object
#  3   Furo de água                       1 non-null      object
#  4   Ligação a rede elétrica            1 non-null      object
#  5   Cave                               1 non-null      object
#  6   Segurança 24 horas                 1 non-null      object
#  7   Armário                            1 non-null      object
#  8   Vista de cidade                    1 non-null      object
#  9   Alarme                             1 non-null      object
#  10  Ruína                              1 non-null      object
#  11  Video Porteiro                     1 non-null      object
#  12  Acesso pavimentado                 1 non-null      object
#  13  Recuperação de calor               1 non-null      object
#  14  Caldeira                           1 non-null      object
#  15  Pré-instalação de ar condicionado  1 non-null      object
#  16  Hidromassagem                      2 non-null      object
#  17  Vedação                            2 non-null      object
#  18  Churrasco                          2 non-null      object
#  19  Vista de Serra                     2 non-null      object
#  20  Garagem exterior                   2 non-null      object
#  21  Sótão                              2 non-null      object
#  22  Zona arborizada                    3 non-null      object
#  23  Suite                              3 non-null      object
#  24  Aquecimento central                4 non-null      object
#  25  Ar condicionado                    4 non-null      object
#  26  Percurso de água                   4 non-null      object
#  27  Anexo habitacional                 5 non-null      object
#  28  Árvores de fruto                   5 non-null      object
#  29  Rua                                6 non-null      object
#  30  Piscina                            6 non-null      object
#  31  Jardim                             10 non-null     object
#  32  Lareira                            10 non-null     object
#  33  Ano construção                     26 non-null     float64
#  34  Certificado energético             30 non-null     object
#  35  Tipologia                          33 non-null     object
#  36  Área bruta m/2                     49 non-null     object
#  37  Área útil m/2                      57 non-null     object
#  38  Condição                           64 non-null     object
#  39  Preço m/2                          83 non-null     object
#  40  Preço                              83 non-null     object
#  41  Freguesia                          85 non-null     object
#  42  Concelho                           85 non-null     object
#  43  Distrito                           85 non-null     object
#  44  Tipo de imóvel                     85 non-null     object
#  45  Id                                 85 non-null     int64
#  46  Nome                               85 non-null     object
# dtypes: float64(1), int64(1), object(45)
# memory usage: 31.9+ KB

# %% [markdown]
# #### Dados em falta por linha

# %%
percent_missing = (1 - data_imo_quintas.apply(lambda x: x.count(), axis=1) / len(data_imo_quintas.columns)) * 100
missing_value_data_imo_quintas_rows = pd.DataFrame({'percent_missing (%)': percent_missing})
missing_value_data_imo_quintas_rows.sort_values('percent_missing (%)', inplace=True, ascending=False)
missing_value_data_imo_quintas_rows
# Out:
#       percent_missing (%)
# 1830            82.978723
# 1658            82.978723
# 2711            80.851064
# 2728            80.851064
# 4473            80.851064
# ...                   ...
# 844             59.574468
# 3485            57.446809
# 137             53.191489
# 402             48.936170
# 4826            46.808511
#
# [85 rows x 1 columns]

# %% [markdown]
# #### Dados em falta por coluna

# %%
percent_missing = data_imo_quintas.isnull().sum() * 100 / len(data_imo_quintas)
missing_value_data_imo_quintas_columns = pd.DataFrame({'percent_missing (%)': percent_missing})
missing_value_data_imo_quintas_columns.sort_values('percent_missing (%)', inplace=True, ascending=False)
pd.set_option('display.max_rows', 20)
missing_value_data_imo_quintas_columns
# Out:
#                                    percent_missing (%)
# Adaptada a mobilidade reduzida               98.823529
# Alarme                                       98.823529
# Pré-instalação de ar condicionado            98.823529
# Caldeira                                     98.823529
# Recuperação de calor                         98.823529
# ...                                                ...
# Concelho                                      0.000000
# Distrito                                      0.000000
# Tipo de imóvel                                0.000000
# Id                                            0.000000
# Nome                                          0.000000
#
# [47 rows x 1 columns]

# %% [markdown]
# ### Retirar as colunas que têm 99% de missing values (NÃO HÁ)

# %%
a_manter = list(missing_value_data_imo_quintas_columns.index[missing_value_data_imo_quintas_columns['percent_missing (%)'] < 99])
print(len(a_manter))
print(a_manter)
data_imo_quintas = data_imo_quintas[a_manter]
data_imo_quintas
# Out:
# 47
# ['Adaptada a mobilidade reduzida', 'Alarme', 'Pré-instalação de ar condicionado', 'Caldeira', 'Recuperação de calor', 'Acesso pavimentado', 'Poço', 'Ruína', 'Video Porteiro', 'Vista de cidade', 'Armário', 'Segurança 24 horas', 'Cave', 'Ligação a rede elétrica', 'Furo de água', 'Vista de cidade.1', 'Hidromassagem', 'Vedação', 'Churrasco', 'Vista de Serra', 'Garagem exterior', 'Sótão', 'Suite', 'Zona arborizada', 'Aquecimento central', 'Ar condicionado', 'Percurso de água', 'Anexo habitacional', 'Árvores de fruto', 'Rua', 'Piscina', 'Jardim', 'Lareira', 'Ano construção', 'Certificado energético', 'Tipologia', 'Área bruta m/2', 'Área útil m/2', 'Condição', 'Preço m/2', 'Preço', 'Freguesia', 'Concelho', 'Distrito', 'Tipo de imóvel', 'Id', 'Nome']
#      Adaptada a mobilidade reduzida Alarme Pré-instalação de ar condicionado  \
# 137                             NaN    NaN                               NaN
# 402                             NaN   True                               NaN
# 410                             NaN    NaN                               NaN
# 418                             NaN    NaN                               NaN
# 555                             NaN    NaN                               NaN
# ...                             ...    ...                               ...
# 4274                            NaN    NaN                               NaN
# 4473                            NaN    NaN                               NaN
# 4826                            NaN    NaN                               NaN
# 4832                            NaN    NaN                               NaN
# 5576                            NaN    NaN                               NaN
#
#      Caldeira Recuperação de calor Acesso pavimentado  Poço Ruína  \
# 137       NaN                 True               True   NaN   NaN
# 402      True                  NaN                NaN   NaN   NaN
# 410       NaN                  NaN                NaN   NaN   NaN
# 418       NaN                  NaN                NaN   NaN   NaN
# 555       NaN                  NaN                NaN   NaN   NaN
# ...       ...                  ...                ...   ...   ...
# 4274      NaN                  NaN                NaN   NaN   NaN
# 4473      NaN                  NaN                NaN   NaN   NaN
# 4826      NaN                  NaN                NaN  True   NaN
# 4832      NaN                  NaN                NaN   NaN   NaN
# 5576      NaN                  NaN                NaN   NaN   NaN
#
#      Video Porteiro Vista de cidade Armário Segurança 24 horas  Cave  \
# 137             NaN             NaN     NaN                NaN   NaN
# 402            True             NaN     NaN               True  True
# 410             NaN             NaN     NaN                NaN   NaN
# 418             NaN             NaN     NaN                NaN   NaN
# 555             NaN             NaN     NaN                NaN   NaN
# ...             ...             ...     ...                ...   ...
# 4274            NaN             NaN     NaN                NaN   NaN
# 4473            NaN             NaN     NaN                NaN   NaN
# 4826            NaN            True     NaN                NaN   NaN
# 4832            NaN             NaN     NaN                NaN   NaN
# 5576            NaN             NaN     NaN                NaN   NaN
#
#      Ligação a rede elétrica Furo de água Vista de cidade.1 Hidromassagem  \
# 137                      NaN          NaN               NaN           NaN
# 402                      NaN          NaN               NaN           NaN
# 410                      NaN          NaN               NaN           NaN
# 418                      NaN          NaN               NaN           NaN
# 555                      NaN          NaN               NaN           NaN
# ...                      ...          ...               ...           ...
# 4274                     NaN          NaN               NaN           NaN
# 4473                     NaN          NaN               NaN           NaN
# 4826                    True         True              True           NaN
# 4832                     NaN          NaN               NaN           NaN
# 5576                     NaN          NaN               NaN           NaN
#
#      Vedação Churrasco Vista de Serra Garagem exterior Sótão Suite  \
# 137      NaN       NaN           True             True   NaN  True
# 402     True       NaN            NaN              NaN  True  True
# 410      NaN       NaN            NaN              NaN   NaN   NaN
# 418      NaN       NaN            NaN              NaN   NaN   NaN
# 555      NaN       NaN            NaN              NaN   NaN   NaN
# ...      ...       ...            ...              ...   ...   ...
# 4274     NaN       NaN            NaN              NaN   NaN   NaN
# 4473     NaN       NaN            NaN              NaN   NaN   NaN
# 4826     NaN       NaN            NaN              NaN  True   NaN
# 4832     NaN       NaN            NaN              NaN   NaN   NaN
# 5576     NaN       NaN            NaN              NaN   NaN   NaN
#
#      Zona arborizada Aquecimento central Ar condicionado Percurso de água  \
# 137             True                 NaN            True              NaN
# 402              NaN                True             NaN             True
# 410              NaN                 NaN             NaN              NaN
# 418              NaN                 NaN             NaN              NaN
# 555              NaN                 NaN             NaN              NaN
# ...              ...                 ...             ...              ...
# 4274             NaN                 NaN             NaN              NaN
# 4473             NaN                 NaN             NaN              NaN
# 4826            True                 NaN             NaN             True
# 4832             NaN                 NaN             NaN              NaN
# 5576             NaN                 NaN             NaN              NaN
#
#      Anexo habitacional Árvores de fruto             Rua Piscina Jardim  \
# 137                 NaN              NaN     Rua do Paço    True   True
# 402                True             True             NaN     NaN   True
# 410                 NaN              NaN             NaN     NaN    NaN
# 418                 NaN              NaN             NaN     NaN    NaN
# 555                 NaN              NaN             NaN     NaN    NaN
# ...                 ...              ...             ...     ...    ...
# 4274                NaN              NaN  Rua de Espinde     NaN    NaN
# 4473                NaN              NaN             NaN     NaN    NaN
# 4826                NaN             True             NaN     NaN   True
# 4832                NaN              NaN             NaN     NaN    NaN
# 5576                NaN              NaN             NaN     NaN    NaN
#
#      Lareira  Ano construção Certificado energético        Tipologia  \
# 137      NaN             NaN                      D               T5
# 402     True             NaN                      C              NaN
# 410      NaN             NaN                      D               T5
# 418      NaN          1937.0                 Isento               T0
# 555      NaN             NaN                      F              NaN
# ...      ...             ...                    ...              ...
# 4274     NaN          2008.0                    NaN              NaN
# 4473     NaN             NaN                    NaN              NaN
# 4826    True          1920.0                      F  T10 ou superior
# 4832     NaN             NaN                    NaN              NaN
# 5576     NaN             NaN                    NaN              NaN
#
#      Área bruta m/2 Área útil m/2        Condição Preço m/2       Preço  \
# 137             NaN        536 m²           Usado      194   1 750 000
# 402             NaN      1 372 m²             NaN       19   2 500 000
# 410          536 m²        451 m²        Renovado      194   1 750 000
# 418           50 m²        100 m²           Usado       18     330 000
# 555          203 m²        203 m²           Usado        5     249 000
# ...             ...           ...             ...       ...         ...
# 4274       7 122 m²        149 m²             NaN       27     190 000
# 4473      47 500 m²     47 500 m²  Para recuperar       NaN         NaN
# 4826       1 100 m²        900 m²           Usado       51     850 000
# 4832      15 000 m²     15 000 m²             NaN       20     300 000
# 5576         225 m²        100 m²           Usado       69     350 000
#
#                                              Freguesia Concelho  \
# 137                      Este (São Pedro e São Mamede)    Braga
# 402                                             Adaúfe    Braga
# 410                      Este (São Pedro e São Mamede)    Braga
# 418                                             Adaúfe    Braga
# 555   Escudeiros e Penso (Santo Estêvão e São Vicente)    Braga
# ...                                                ...      ...
# 4274                                    Padim da Graça    Braga
# 4473                                          Palmeira    Braga
# 4826                           Ferreiros e Gondizalves    Braga
# 4832               Santa Lucrécia de Algeriz e Navarra    Braga
# 5576                                     Lomar e Arcos    Braga
#
#               Distrito Tipo de imóvel        Id  \
# 137   Braga (distrito)        Quintas  14800502
# 402   Braga (distrito)        Quintas  15092871
# 410   Braga (distrito)        Quintas  14427775
# 418   Braga (distrito)        Quintas  12588232
# 555   Braga (distrito)        Quintas  15064851
# ...                ...            ...       ...
# 4274  Braga (distrito)        Quintas  15201040
# 4473  Braga (distrito)        Quintas  14801205
# 4826  Braga (distrito)        Quintas  14785899
# 4832  Braga (distrito)        Quintas  15228182
# 5576  Braga (distrito)        Quintas  14833619
#
#                                                    Nome
# 137                          Casa do Paço de S. Mamede!
# 402                                        Quinta Rural
# 410                          Casa do Paço de S. Mamede!
# 418                                        Quinta Rural
# 555   Quinta T5 Venda em Guisande e Oliveira (São Pe...
# ...                                                 ...
# 4274                          Quinta em Barcelos, Braga
# 4473                    Quinta  Venda em Palmeira,Braga
# 4826  Encantadora Quinta com 1.6ha de terreno e com ...
# 4832  Quinta  Venda em Santa Lucrécia de Algeriz e N...
# 5576                          Vende-se Quintinha -Braga
#
# [85 rows x 47 columns]

# %% [markdown]
# ## Dados - Prédio

# %%
data_imo_prédio.head()
data_imo_prédio.info()
pd.set_option('display.max_rows', 20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 127 entries, 143 to 5547
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Fibra ótica                     1 non-null      object
#  1   Adaptada a mobilidade reduzida  1 non-null      object
#  2   Vista de Serra                  1 non-null      object
#  3   Alarme                          3 non-null      object
#  4   Terraço                         5 non-null      object
#  5   Rua                             6 non-null      object
#  6   Elevador                        6 non-null      object
#  7   Gás canalizado                  8 non-null      object
#  8   Vista de cidade.1               8 non-null      object
#  9   Vista de cidade                 8 non-null      object
#  10  Ar condicionado                 8 non-null      object
#  11  Ano construção                  25 non-null     float64
#  12  Certificado energético          43 non-null     object
#  13  Área bruta m/2                  50 non-null     object
#  14  Condição                        100 non-null    object
#  15  Preço m/2                       122 non-null    object
#  16  Preço                           122 non-null    object
#  17  Área útil m/2                   127 non-null    object
#  18  Id                              127 non-null    int64
#  19  Freguesia                       127 non-null    object
#  20  Concelho                        127 non-null    object
#  21  Distrito                        127 non-null    object
#  22  Tipo de imóvel                  127 non-null    object
#  23  Nome                            127 non-null    object
# dtypes: float64(1), int64(1), object(22)
# memory usage: 24.8+ KB

# %% [markdown]
# #### Dados em falta por linha

# %%
percent_missing = (1 - data_imo_prédio.apply(lambda x: x.count(), axis=1) / len(data_imo_prédio.columns)) * 100
missing_value_data_imo_prédio_rows = pd.DataFrame({'percent_missing (%)': percent_missing})
missing_value_data_imo_prédio_rows.sort_values('percent_missing (%)', inplace=True, ascending=False)
missing_value_data_imo_prédio_rows
# Out:
#       percent_missing (%)
# 3691            70.833333
# 4989            62.500000
# 4943            62.500000
# 1810            62.500000
# 3555            62.500000
# ...                   ...
# 5397            45.833333
# 2007            37.500000
# 361             37.500000
# 355             37.500000
# 383             33.333333
#
# [127 rows x 1 columns]

# %% [markdown]
# #### Dados em falta por coluna

# %%
percent_missing = data_imo_prédio.isnull().sum() * 100 / len(data_imo_prédio)
missing_value_data_imo_prédio_columns = pd.DataFrame({'percent_missing (%)': percent_missing})
missing_value_data_imo_prédio_columns.sort_values('percent_missing (%)', inplace=True, ascending=False)
pd.set_option('display.max_rows', 20)
missing_value_data_imo_prédio_columns
# Out:
#                                 percent_missing (%)
# Fibra ótica                               99.212598
# Adaptada a mobilidade reduzida            99.212598
# Vista de Serra                            99.212598
# Alarme                                    97.637795
# Terraço                                   96.062992
# ...                                             ...
# Freguesia                                  0.000000
# Concelho                                   0.000000
# Distrito                                   0.000000
# Tipo de imóvel                             0.000000
# Nome                                       0.000000
#
# [24 rows x 1 columns]

# %% [markdown]
# ### Retirar as colunas que têm 99% de missing values

# %%
a_manter = list(missing_value_data_imo_prédio_columns.index[missing_value_data_imo_prédio_columns['percent_missing (%)'] < 99])
print(len(a_manter))
print(a_manter)
data_imo_prédio = data_imo_prédio[a_manter]
data_imo_prédio
# Out:
# 21
# ['Alarme', 'Terraço', 'Rua', 'Elevador', 'Gás canalizado', 'Vista de cidade.1', 'Vista de cidade', 'Ar condicionado', 'Ano construção', 'Certificado energético', 'Área bruta m/2', 'Condição', 'Preço m/2', 'Preço', 'Área útil m/2', 'Id', 'Freguesia', 'Concelho', 'Distrito', 'Tipo de imóvel', 'Nome']
#      Alarme Terraço  Rua Elevador Gás canalizado Vista de cidade.1  \
# 143     NaN     NaN  NaN      NaN            NaN               NaN
# 209    True     NaN  NaN      NaN            NaN               NaN
# 236     NaN     NaN  NaN     True            NaN               NaN
# 355    True    True  NaN      NaN            NaN               NaN
# 361     NaN    True  NaN     True            NaN               NaN
# ...     ...     ...  ...      ...            ...               ...
# 5498    NaN     NaN  NaN      NaN            NaN               NaN
# 5505    NaN     NaN  NaN      NaN            NaN               NaN
# 5525    NaN     NaN  NaN      NaN            NaN               NaN
# 5537    NaN     NaN  NaN      NaN            NaN               NaN
# 5547    NaN     NaN  NaN      NaN            NaN               NaN
#
#      Vista de cidade Ar condicionado  Ano construção Certificado energético  \
# 143              NaN             NaN             NaN                      E
# 209              NaN            True          2000.0                    NaN
# 236              NaN            True             NaN                    NaN
# 355              NaN             NaN          2003.0                      B
# 361              NaN             NaN          2011.0                     B-
# ...              ...             ...             ...                    ...
# 5498             NaN             NaN             NaN                 Isento
# 5505             NaN             NaN             NaN                    NaN
# 5525             NaN             NaN             NaN                    NaN
# 5537             NaN             NaN             NaN                    NaN
# 5547             NaN             NaN             NaN                    NaN
#
#      Área bruta m/2        Condição Preço m/2       Preço Área útil m/2  \
# 143          412 m²           Usado      727     199 900         275 m²
# 209             NaN             NaN    1 167   3 500 000       3 000 m²
# 236          367 m²        Renovado    3 678   1 350 000         367 m²
# 355          524 m²           Usado    1 423     350 000         246 m²
# 361        1 362 m²           Usado    1 385   1 800 000       1 300 m²
# ...             ...             ...       ...         ...           ...
# 5498            NaN             NaN  366 667     440 000        1,20 m²
# 5505            NaN  Para recuperar    1 841     950 000         516 m²
# 5525            NaN           Usado      779     560 000      718,83 m²
# 5537            NaN  Para recuperar      851     800 000         940 m²
# 5547            NaN           Usado      101   3 000 000      29 600 m²
#
#             Id                                          Freguesia Concelho  \
# 143   15382302                               Real, Dume e Semelhe    Braga
# 209   15098262                                            Espinho    Braga
# 236   14719179  Braga (São José de São Lázaro e São João do So...    Braga
# 355   14137264                                        São Vicente    Braga
# 361   11829739                                         São Victor    Braga
# ...        ...                                                ...      ...
# 5498   9943450                                         São Victor    Braga
# 5505  15201445                                        São Vicente    Braga
# 5525  14554204  Braga (São José de São Lázaro e São João do So...    Braga
# 5537  15363376                   Braga (Maximinos, Sé e Cividade)    Braga
# 5547  14801239                                  Nogueiró e Tenões    Braga
#
#               Distrito Tipo de imóvel  \
# 143   Braga (distrito)         Prédio
# 209   Braga (distrito)         Prédio
# 236   Braga (distrito)         Prédio
# 355   Braga (distrito)         Prédio
# 361   Braga (distrito)         Prédio
# ...                ...            ...
# 5498  Braga (distrito)         Prédio
# 5505  Braga (distrito)         Prédio
# 5525  Braga (distrito)         Prédio
# 5537  Braga (distrito)         Prédio
# 5547  Braga (distrito)         Prédio
#
#                                                    Nome
# 143   Prédio T4 unifamiliar, para recuperar em Real ...
# 209                         Hotel - Restaurante - Braga
# 236        Prédio Renovado no Centro da Cidade de Braga
# 355   Oferta da escritura. Prédio junto ao Liceu Sá ...
# 361    Mansão destinada a serviços no coração de Braga.
# ...                                                 ...
# 5498                                 Prédios - S. Vitor
# 5505       Prédio no centro da cidade para reconstrução
# 5525  Prédio  Venda em Braga (São José de São Lázaro...
# 5537  Prédio  Venda em Braga (Maximinos, Sé e Civida...
# 5547            Hotel  Venda em Nogueiró e Tenões,Braga
#
# [127 rows x 21 columns]

# %% [markdown]
# ## Dados - Loja

# %%
data_imo_loja.head()
data_imo_loja.info()
pd.set_option('display.max_rows', 20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 605 entries, 176 to 5594
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Segurança 24 horas              1 non-null      object
#  1   Video vigilância                1 non-null      object
#  2   Armazém                         2 non-null      object
#  3   Terraço                         2 non-null      object
#  4   Fibra ótica                     2 non-null      object
#  5   Adaptado a mobilidade reduzida  2 non-null      object
#  6   Arrecadação                     3 non-null      object
#  7   Com cozinha                     3 non-null      object
#  8   Elevador                        7 non-null      object
#  9   Alarme                          7 non-null      object
#  10  Gás canalizado                  7 non-null      object
#  11  Ar condicionado                 9 non-null      object
#  12  Pisos                           9 non-null      float64
#  13  Nº divisões                     12 non-null     float64
#  14  Montra                          15 non-null     object
#  15  Imóvel de banca                 17 non-null     object
#  16  Rua                             40 non-null     object
#  17  Tipo                            49 non-null     object
#  18  Com WC                          63 non-null     object
#  19  Ano construção                  194 non-null    float64
#  20  Área bruta m/2                  202 non-null    object
#  21  Certificado energético          229 non-null    object
#  22  Empreendimento                  346 non-null    object
#  23  Condição                        468 non-null    object
#  24  Preço m/2                       604 non-null    object
#  25  Preço                           604 non-null    object
#  26  Área útil m/2                   605 non-null    object
#  27  Freguesia                       605 non-null    object
#  28  Id                              605 non-null    int64
#  29  Concelho                        605 non-null    object
#  30  Distrito                        605 non-null    object
#  31  Tipo de imóvel                  605 non-null    object
#  32  Nome                            605 non-null    object
# dtypes: float64(3), int64(1), object(29)
# memory usage: 160.7+ KB

# %% [markdown]
# #### Dados em falta por linha

# %%
percent_missing = (1 - data_imo_loja.apply(lambda x: x.count(), axis=1) / len(data_imo_loja.columns)) * 100
missing_value_data_imo_loja_rows = pd.DataFrame({'percent_missing (%)': percent_missing})
missing_value_data_imo_loja_rows.sort_values('percent_missing (%)', inplace=True, ascending=False)
missing_value_data_imo_loja_rows
# Out:
#       percent_missing (%)
# 4700            72.727273
# 1927            72.727273
# 1353            72.727273
# 4924            72.727273
# 4928            72.727273
# ...                   ...
# 4553            48.484848
# 3453            45.454545
# 1007            45.454545
# 1915            42.424242
# 3600            36.363636
#
# [605 rows x 1 columns]

# %% [markdown]
# #### Dados em falta por coluna

# %%
percent_missing = data_imo_loja.isnull().sum() * 100 / len(data_imo_loja)
missing_value_data_imo_loja_columns = pd.DataFrame({'percent_missing (%)': percent_missing})
missing_value_data_imo_loja_columns.sort_values('percent_missing (%)', inplace=True, ascending=False)
pd.set_option('display.max_rows', 20)
missing_value_data_imo_loja_columns
# Out:
#                     percent_missing (%)
# Segurança 24 horas            99.834711
# Video vigilância              99.834711
# Armazém                       99.669421
# Terraço                       99.669421
# Fibra ótica                   99.669421
# ...                                 ...
# Id                             0.000000
# Concelho                       0.000000
# Distrito                       0.000000
# Tipo de imóvel                 0.000000
# Nome                           0.000000
#
# [33 rows x 1 columns]

# %% [markdown]
# ### Retirar as colunas que têm 99% de missing values

# %%
a_manter = list(missing_value_data_imo_loja_columns.index[missing_value_data_imo_loja_columns['percent_missing (%)'] < 99])
print(len(a_manter))
print(a_manter)
data_imo_loja = data_imo_loja[a_manter]
data_imo_loja
# Out:
# 25
# ['Elevador', 'Alarme', 'Gás canalizado', 'Ar condicionado', 'Pisos', 'Nº divisões', 'Montra', 'Imóvel de banca', 'Rua', 'Tipo', 'Com WC', 'Ano construção', 'Área bruta m/2', 'Certificado energético', 'Empreendimento', 'Condição', 'Preço m/2', 'Preço', 'Área útil m/2', 'Freguesia', 'Id', 'Concelho', 'Distrito', 'Tipo de imóvel', 'Nome']
#      Elevador Alarme Gás canalizado Ar condicionado  Pisos  Nº divisões  \
# 176       NaN    NaN            NaN             NaN    NaN          NaN
# 270       NaN    NaN            NaN             NaN    1.0          2.0
# 348       NaN    NaN            NaN             NaN    1.0          2.0
# 585       NaN   True           True            True    NaN          NaN
# 695      True    NaN            NaN             NaN    NaN          NaN
# ...       ...    ...            ...             ...    ...          ...
# 5590      NaN    NaN            NaN             NaN    NaN          NaN
# 5591      NaN    NaN            NaN             NaN    NaN          NaN
# 5592      NaN    NaN            NaN             NaN    NaN          NaN
# 5593      NaN    NaN            NaN             NaN    NaN          NaN
# 5594      NaN    NaN            NaN             NaN    NaN          NaN
#
#      Montra Imóvel de banca                       Rua  Tipo Com WC  \
# 176     NaN             NaN  Rua da Granja - Nogueira   NaN    NaN
# 270    True             NaN   Rua Inácio José Peixoto  Loja   True
# 348    True             NaN   Avenida Barros e Soares  Loja   True
# 585     NaN             NaN       Avenida do Covedêlo   NaN    NaN
# 695     NaN             NaN                       NaN   NaN    NaN
# ...     ...             ...                       ...   ...    ...
# 5590    NaN             NaN                       NaN   NaN    NaN
# 5591    NaN             NaN                       NaN   NaN    NaN
# 5592    NaN             NaN                       NaN   NaN    NaN
# 5593    NaN             NaN                       NaN   NaN    NaN
# 5594    NaN             NaN                       NaN   NaN    NaN
#
#       Ano construção Área bruta m/2 Certificado energético Empreendimento  \
# 176              NaN         112 m²                    NaN            não
# 270              NaN            NaN                      C            NaN
# 348           1994.0            NaN                      B            NaN
# 585              NaN            NaN                 Isento            NaN
# 695           2008.0       3 994 m²                    NaN            não
# ...              ...            ...                    ...            ...
# 5590          2018.0            NaN                    NaN            não
# 5591          2018.0            NaN                    NaN            não
# 5592          2018.0            NaN                    NaN            não
# 5593          1984.0            NaN                    NaN            não
# 5594             NaN            NaN                    NaN            não
#
#       Condição Preço m/2       Preço Área útil m/2  \
# 176        NaN    1 420     159 000         112 m²
# 270      Usado      622      19 900          32 m²
# 348        NaN      316      29 990          95 m²
# 585   Renovado      350      50 000         143 m²
# 695      Usado    1 773   2 000 000       1 128 m²
# ...        ...       ...         ...           ...
# 5590      Novo      460      40 000          87 m²
# 5591      Novo      485      50 000         103 m²
# 5592      Novo      449      40 000          89 m²
# 5593      Novo      714      25 000          35 m²
# 5594     Usado    1 000     110 000         110 m²
#
#                          Freguesia        Id Concelho          Distrito  \
# 176    Nogueira, Fraião e Lamaçães  15188247    Braga  Braga (distrito)
# 270                       Sequeira  14804552    Braga  Braga (distrito)
# 348    Nogueira, Fraião e Lamaçães  14804152    Braga  Braga (distrito)
# 585   Celeirós, Aveleda e Vimieiro  14842246    Braga  Braga (distrito)
# 695              Nogueiró e Tenões  15248530    Braga  Braga (distrito)
# ...                            ...       ...      ...               ...
# 5590          Real, Dume e Semelhe  14800704    Braga  Braga (distrito)
# 5591          Real, Dume e Semelhe  14800694    Braga  Braga (distrito)
# 5592          Real, Dume e Semelhe  14800692    Braga  Braga (distrito)
# 5593                    São Victor  14798961    Braga  Braga (distrito)
# 5594  Celeirós, Aveleda e Vimieiro  14479228    Braga  Braga (distrito)
#
#      Tipo de imóvel                                               Nome
# 176            Loja                                   Loja em Nogueira
# 270            Loja  Loja comercial Junto ao Centro da Cidade de Br...
# 348            Loja  Loja comercial c/95 m2 de área Junto ao Centro...
# 585            Loja  Café  Venda em Celeirós, Aveleda e Vimieiro,Braga
# 695            Loja                            Hotel Bom Jesus - Braga
# ...             ...                                                ...
# 5590           Loja          Loja  Venda em Real, Dume e Semelhe,Braga
# 5591           Loja          Loja  Venda em Real, Dume e Semelhe,Braga
# 5592           Loja          Loja  Venda em Real, Dume e Semelhe,Braga
# 5593           Loja             Loja  Venda em Braga (São Vítor),Braga
# 5594           Loja  Loja  Venda em Celeirós, Aveleda e Vimieiro,Braga
#
# [605 rows x 25 columns]

# %% [markdown]
# ## Dados - Trespasses

# %%
data_imo_trespasses.head()
data_imo_trespasses.info()
pd.set_option('display.max_rows', 20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85 entries, 567 to 5459
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Com cozinha             5 non-null      object
#  1   Rua                     5 non-null      object
#  2   Nº divisões             7 non-null      float64
#  3   Com WC                  12 non-null     object
#  4   Ano construção          13 non-null     float64
#  5   Tipo                    14 non-null     object
#  6   Certificado energético  20 non-null     object
#  7   Condição                62 non-null     object
#  8   Preço m/2               84 non-null     object
#  9   Preço                   84 non-null     object
#  10  Área (m/2)              85 non-null     object
#  11  Id                      85 non-null     int64
#  12  Freguesia               85 non-null     object
#  13  Concelho                85 non-null     object
#  14  Distrito                85 non-null     object
#  15  Tipo de imóvel          85 non-null     object
#  16  Nome                    85 non-null     object
# dtypes: float64(2), int64(1), object(14)
# memory usage: 12.0+ KB

# %% [markdown]
# #### Dados em falta por linha

# %%
percent_missing = (1 - data_imo_trespasses.apply(lambda x: x.count(), axis=1) / len(data_imo_trespasses.columns)) * 100
missing_value_data_imo_trespasses_rows = pd.DataFrame({'percent_missing (%)': percent_missing})
missing_value_data_imo_trespasses_rows.sort_values('percent_missing (%)', inplace=True, ascending=False)
missing_value_data_imo_trespasses_rows
# Out:
#       percent_missing (%)
# 4441            47.058824
# 4992            47.058824
# 3554            47.058824
# 3036            47.058824
# 3765            47.058824
# ...                   ...
# 3153            17.647059
# 4604            11.764706
# 5373            11.764706
# 3172            11.764706
# 3177            11.764706
#
# [85 rows x 1 columns]

# %% [markdown]
# #### Dados em falta por coluna

# %%
percent_missing = data_imo_trespasses.isnull().sum() * 100 / len(data_imo_trespasses)
missing_value_data_imo_trespasses_columns = pd.DataFrame({'percent_missing (%)': percent_missing})
missing_value_data_imo_trespasses_columns.sort_values('percent_missing (%)', inplace=True, ascending=False)
pd.set_option('display.max_rows', 20)
missing_value_data_imo_trespasses_columns
# Out:
#                         percent_missing (%)
# Com cozinha                       94.117647
# Rua                               94.117647
# Nº divisões                       91.764706
# Com WC                            85.882353
# Ano construção                    84.705882
# Tipo                              83.529412
# Certificado energético            76.470588
# Condição                          27.058824
# Preço                              1.176471
# Preço m/2                          1.176471
# Área (m/2)                         0.000000
# Id                                 0.000000
# Freguesia                          0.000000
# Concelho                           0.000000
# Distrito                           0.000000
# Tipo de imóvel                     0.000000
# Nome                               0.000000

# %% [markdown]
# ### Retirar as colunas que têm 99% de missing values (NÃO HÁ)

# %%
a_manter = list(missing_value_data_imo_trespasses_columns.index[missing_value_data_imo_trespasses_columns['percent_missing (%)'] < 100])
print(len(a_manter))
print(a_manter)
data_imo_trespasses = data_imo_trespasses[a_manter]
data_imo_trespasses
# Out:
# 17
# ['Com cozinha', 'Rua', 'Nº divisões', 'Com WC', 'Ano construção', 'Tipo', 'Certificado energético', 'Condição', 'Preço', 'Preço m/2', 'Área (m/2)', 'Id', 'Freguesia', 'Concelho', 'Distrito', 'Tipo de imóvel', 'Nome']
#      Com cozinha                             Rua  Nº divisões Com WC  \
# 567          NaN  Rua de São Victor - São Victor          NaN    NaN
# 740          NaN                             NaN          NaN    NaN
# 1077         NaN                             NaN          NaN    NaN
# 1137         NaN                             NaN          NaN    NaN
# 1250         NaN                             NaN          NaN    NaN
# ...          ...                             ...          ...    ...
# 5208         NaN                             NaN          NaN    NaN
# 5373        True                             NaN          5.0   True
# 5427         NaN                             NaN          NaN    NaN
# 5436         NaN                             NaN          NaN    NaN
# 5459         NaN                             NaN          NaN    NaN
#
#       Ano construção Tipo Certificado energético Condição     Preço Preço m/2  \
# 567           1988.0  NaN                 Isento    Usado   27 000       325
# 740           1980.0  NaN                 Isento    Usado   45 000       168
# 1077          2011.0  NaN                      G      NaN   98 400       856
# 1137             NaN  NaN                 Isento      NaN   77 500       596
# 1250             NaN  NaN                    NaN    Usado   85 000       567
# ...              ...  ...                    ...      ...       ...       ...
# 5208             NaN  NaN                    NaN    Usado   25 000       263
# 5373          1995.0  Bar                    NaN    Usado   50 000       746
# 5427             NaN  NaN                    NaN    Usado   25 000       417
# 5436             NaN  NaN                    NaN    Usado   67 500       493
# 5459             NaN  NaN                    NaN    Usado  100 000       250
#
#      Área (m/2)        Id                                          Freguesia  \
# 567       83 m²  14971581                                         São Victor
# 740      268 m²  15078158  Braga (São José de São Lázaro e São João do So...
# 1077     115 m²  15251369                                            Gualtar
# 1137     130 m²  14896035                                         São Victor
# 1250     150 m²  15341132                               Real, Dume e Semelhe
# ...         ...       ...                                                ...
# 5208      95 m²  15146279                                         São Victor
# 5373      67 m²  15222039                   Braga (Maximinos, Sé e Cividade)
# 5427      60 m²  14667279  Braga (São José de São Lázaro e São João do So...
# 5436     137 m²  13161934                                            Gualtar
# 5459     400 m²  15322470                      Merelim (São Pedro) e Frossos
#
#      Concelho          Distrito Tipo de imóvel  \
# 567     Braga  Braga (distrito)     Trespasses
# 740     Braga  Braga (distrito)     Trespasses
# 1077    Braga  Braga (distrito)     Trespasses
# 1137    Braga  Braga (distrito)     Trespasses
# 1250    Braga  Braga (distrito)     Trespasses
# ...       ...               ...            ...
# 5208    Braga  Braga (distrito)     Trespasses
# 5373    Braga  Braga (distrito)     Trespasses
# 5427    Braga  Braga (distrito)     Trespasses
# 5436    Braga  Braga (distrito)     Trespasses
# 5459    Braga  Braga (distrito)     Trespasses
#
#                                                    Nome
# 567                    Trespasse de Café em Santa Tecla
# 740   Trespasse de Cafetaria e organização de evento...
# 1077                 Café Italiamo n o centro de Braga.
# 1137  Café Snack bar Restaurante no largo da Senhora...
# 1250  Trespasse: Cafetaria/Pastelaria/Pão Quente - P...
# ...                                                 ...
# 5208  Restaurante  Trespasse em Braga (São Vítor),Braga
# 5373                                   Café - Maximinos
# 5427                   Café / Snack Bar Trespasse Braga
# 5436  TRESPASSE: Estabelecimento comercial em Óptima...
# 5459                   Trespasse de café c/ Euromilhões
#
# [85 rows x 17 columns]

# %% [markdown]
# ## Dados - Escritório

# %%
data_imo_escritório.head()
data_imo_escritório.info()
pd.set_option('display.max_rows', 20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88 entries, 791 to 5511
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Ar condicionado                 1 non-null      object
#  1   Porta blindada                  1 non-null      object
#  2   Adaptada a mobilidade reduzida  1 non-null      object
#  3   Varanda                         1 non-null      object
#  4   Casa de banho partilhada        1 non-null      object
#  5   Alarme                          1 non-null      object
#  6   Elevador                        2 non-null      object
#  7   Terraço                         2 non-null      object
#  8   Nº divisões                     4 non-null      float64
#  9   Rua                             5 non-null      object
#  10  Com WC                          12 non-null     object
#  11  Ano construção                  26 non-null     float64
#  12  Área bruta m/2                  28 non-null     object
#  13  Certificado energético          31 non-null     object
#  14  Condição                        64 non-null     object
#  15  Área (m/2)                      88 non-null     object
#  16  Freguesia                       88 non-null     object
#  17  Concelho                        88 non-null     object
#  18  Distrito                        88 non-null     object
#  19  Preço m/2                       88 non-null     object
#  20  Id                              88 non-null     int64
#  21  Preço                           88 non-null     object
#  22  Tipo de imóvel                  88 non-null     object
#  23  Nome                            88 non-null     object
# dtypes: float64(2), int64(1), object(21)
# memory usage: 17.2+ KB

# %% [markdown]
# #### Dados em falta por linha

# %%
percent_missing = (1 - data_imo_escritório.apply(lambda x: x.count(), axis=1) / len(data_imo_escritório.columns)) * 100
missing_value_data_imo_escritório_rows = pd.DataFrame({'percent_missing (%)': percent_missing})
missing_value_data_imo_escritório_rows.sort_values('percent_missing (%)', inplace=True, ascending=False)
missing_value_data_imo_escritório_rows
# Out:
#       percent_missing (%)
# 5511            62.500000
# 5457            62.500000
# 4495            62.500000
# 4418            62.500000
# 4927            62.500000
# ...                   ...
# 4156            45.833333
# 791             45.833333
# 1403            41.666667
# 4155            41.666667
# 2406            37.500000
#
# [88 rows x 1 columns]

# %% [markdown]
# #### Dados em falta por coluna

# %%
percent_missing = data_imo_escritório.isnull().sum() * 100 / len(data_imo_escritório)
missing_value_data_imo_escritório_columns = pd.DataFrame({'percent_missing (%)': percent_missing})
missing_value_data_imo_escritório_columns.sort_values('percent_missing (%)', inplace=True, ascending=False)
pd.set_option('display.max_rows', 20)
missing_value_data_imo_escritório_columns
# Out:
#                                 percent_missing (%)
# Ar condicionado                           98.863636
# Porta blindada                            98.863636
# Adaptada a mobilidade reduzida            98.863636
# Varanda                                   98.863636
# Casa de banho partilhada                  98.863636
# ...                                             ...
# Preço m/2                                  0.000000
# Id                                         0.000000
# Preço                                      0.000000
# Tipo de imóvel                             0.000000
# Nome                                       0.000000
#
# [24 rows x 1 columns]

# %% [markdown]
# ### Retirar as colunas que têm 99% de missing values (NÃO HÁ)

# %%
a_manter = list(missing_value_data_imo_escritório_columns.index[missing_value_data_imo_escritório_columns['percent_missing (%)'] < 99])
print(len(a_manter))
print(a_manter)
data_imo_escritório = data_imo_escritório[a_manter]
data_imo_escritório
# Out:
# 24
# ['Ar condicionado', 'Porta blindada', 'Adaptada a mobilidade reduzida', 'Varanda', 'Casa de banho partilhada', 'Alarme', 'Elevador', 'Terraço', 'Nº divisões', 'Rua', 'Com WC', 'Ano construção', 'Área bruta m/2', 'Certificado energético', 'Condição', 'Área (m/2)', 'Freguesia', 'Concelho', 'Distrito', 'Preço m/2', 'Id', 'Preço', 'Tipo de imóvel', 'Nome']
#      Ar condicionado Porta blindada Adaptada a mobilidade reduzida Varanda  \
# 791              NaN            NaN                            NaN     NaN
# 795              NaN            NaN                            NaN     NaN
# 1087             NaN            NaN                            NaN     NaN
# 1267             NaN            NaN                            NaN     NaN
# 1268             NaN            NaN                            NaN     NaN
# ...              ...            ...                            ...     ...
# 5468             NaN            NaN                            NaN     NaN
# 5482             NaN            NaN                            NaN     NaN
# 5508             NaN            NaN                            NaN     NaN
# 5509             NaN            NaN                            NaN     NaN
# 5511             NaN            NaN                            NaN     NaN
#
#      Casa de banho partilhada Alarme Elevador Terraço  Nº divisões  \
# 791                       NaN    NaN      NaN     NaN          NaN
# 795                       NaN    NaN      NaN     NaN          NaN
# 1087                      NaN    NaN      NaN     NaN          NaN
# 1267                      NaN    NaN      NaN     NaN          NaN
# 1268                      NaN    NaN      NaN     NaN          NaN
# ...                       ...    ...      ...     ...          ...
# 5468                      NaN    NaN      NaN    True          NaN
# 5482                      NaN    NaN      NaN     NaN          NaN
# 5508                      NaN    NaN      NaN     NaN          NaN
# 5509                      NaN    NaN      NaN     NaN          NaN
# 5511                      NaN    NaN      NaN     NaN          NaN
#
#                     Rua Com WC  Ano construção Área bruta m/2  \
# 791                 NaN    NaN          1992.0         100 m²
# 795                 NaN    NaN          1987.0          64 m²
# 1087  Rua de São Lázaro    NaN          1986.0          54 m²
# 1267                NaN    NaN             NaN          33 m²
# 1268                NaN    NaN          1985.0          43 m²
# ...                 ...    ...             ...            ...
# 5468                NaN   True             NaN            NaN
# 5482                NaN    NaN             NaN            NaN
# 5508                NaN    NaN             NaN            NaN
# 5509                NaN    NaN             NaN            NaN
# 5511                NaN    NaN             NaN            NaN
#
#      Certificado energético  Condição Área (m/2)  \
# 791                       C  Renovado     100 m²
# 795                       D     Usado      64 m²
# 1087                    NaN       NaN      54 m²
# 1267                      C     Usado      33 m²
# 1268                      C     Usado      43 m²
# ...                     ...       ...        ...
# 5468                    NaN     Usado      30 m²
# 5482                    NaN     Usado     132 m²
# 5508                    NaN       NaN      33 m²
# 5509                    NaN       NaN      20 m²
# 5511                    NaN       NaN      30 m²
#
#                                               Freguesia Concelho  \
# 791                                         São Vicente    Braga
# 795                                         São Vicente    Braga
# 1087  Braga (São José de São Lázaro e São João do So...    Braga
# 1267                   Braga (Maximinos, Sé e Cividade)    Braga
# 1268                   Braga (Maximinos, Sé e Cividade)    Braga
# ...                                                 ...      ...
# 5468                                         São Victor    Braga
# 5482  Braga (São José de São Lázaro e São João do So...    Braga
# 5508                                        São Vicente    Braga
# 5509                                        São Vicente    Braga
# 5511                                        São Vicente    Braga
#
#               Distrito Preço m/2        Id    Preço Tipo de imóvel  \
# 791   Braga (distrito)      790   14423839  79 000      Escritório
# 795   Braga (distrito)      766   14421601  49 000      Escritório
# 1087  Braga (distrito)    1 046   15201036  56 500      Escritório
# 1267  Braga (distrito)    1 045   15298848  34 500      Escritório
# 1268  Braga (distrito)      849   15298849  36 500      Escritório
# ...                ...       ...       ...      ...            ...
# 5468  Braga (distrito)    1 000   14667339  30 000      Escritório
# 5482  Braga (distrito)      411   13152766  54 200      Escritório
# 5508  Braga (distrito)    2 258   14968860  74 500      Escritório
# 5509  Braga (distrito)    1 988   14968861  39 750      Escritório
# 5511  Braga (distrito)    2 300   14968849  69 000      Escritório
#
#                                                    Nome
# 791   Loja / Escritório com 100 M2 remodelada junto ...
# 795   Escritório no Centro histórico em S.Vicente, B...
# 1087                          Escritório Braga 54,00 m2
# 1267                    Escritório em Maximinos - Braga
# 1268                 Escritório para venda em Maximinos
# ...                                                 ...
# 5468           Escritório para venda em Braga no centro
# 5482                     Escritório no centro da cidade
# 5508     Escritório  Venda em Braga (São Vicente),Braga
# 5509     Escritório  Venda em Braga (São Vicente),Braga
# 5511     Escritório  Venda em Braga (São Vicente),Braga
#
# [88 rows x 24 columns]

# %% [markdown]
# ## Dados - Armazém

# %%
data_imo_armazém.head()
data_imo_armazém.info()
pd.set_option('display.max_rows', 20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 762 to 5609
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Sala de reuniões           1 non-null      object
#  1   Recepção                   1 non-null      object
#  2   Ligação a rede de água     1 non-null      object
#  3   Com cozinha                1 non-null      object
#  4   Refeitório                 1 non-null      object
#  5   Arrecadação                1 non-null      object
#  6   Alarme                     2 non-null      object
#  7   Vedação                    2 non-null      object
#  8   Nº divisões                2 non-null      float64
#  9   Acesso a veículos pesados  2 non-null      object
#  10  Área administrativa        2 non-null      object
#  11  Copa                       2 non-null      object
#  12  Pisos                      2 non-null      float64
#  13  Ar condicionado            3 non-null      object
#  14  Imóvel de banca            5 non-null      object
#  15  Rua                        7 non-null      object
#  16  Com WC                     13 non-null     object
#  17  Ano construção             23 non-null     float64
#  18  Certificado energético     26 non-null     object
#  19  Área bruta m/2             34 non-null     object
#  20  Empreendimento             59 non-null     object
#  21  Condição                   67 non-null     object
#  22  Preço m/2                  98 non-null     object
#  23  Preço                      98 non-null     object
#  24  Área (m/2)                 99 non-null     object
#  25  Id                         99 non-null     int64
#  26  Freguesia                  99 non-null     object
#  27  Concelho                   99 non-null     object
#  28  Distrito                   99 non-null     object
#  29  Tipo de imóvel             99 non-null     object
#  30  Nome                       99 non-null     object
# dtypes: float64(3), int64(1), object(27)
# memory usage: 24.8+ KB

# %% [markdown]
# #### Dados em falta por linha

# %%
percent_missing = (1 - data_imo_armazém.apply(lambda x: x.count(), axis=1) / len(data_imo_armazém.columns)) * 100
missing_value_data_imo_armazém_rows = pd.DataFrame({'percent_missing (%)': percent_missing})
missing_value_data_imo_armazém_rows.sort_values('percent_missing (%)', inplace=True, ascending=False)
missing_value_data_imo_armazém_rows
# Out:
#       percent_missing (%)
# 4178            70.967742
# 4997            70.967742
# 3805            70.967742
# 5609            67.741935
# 4905            67.741935
# ...                   ...
# 2140            54.838710
# 3642            54.838710
# 1832            51.612903
# 2554            38.709677
# 1896            22.580645
#
# [99 rows x 1 columns]

# %% [markdown]
# #### Dados em falta por coluna

# %%
percent_missing = data_imo_armazém.isnull().sum() * 100 / len(data_imo_armazém)
missing_value_data_imo_armazém_columns = pd.DataFrame({'percent_missing (%)': percent_missing})
missing_value_data_imo_armazém_columns.sort_values('percent_missing (%)', inplace=True, ascending=False)
pd.set_option('display.max_rows', 20)
missing_value_data_imo_armazém_columns
# Out:
#                         percent_missing (%)
# Sala de reuniões                  98.989899
# Recepção                          98.989899
# Ligação a rede de água            98.989899
# Com cozinha                       98.989899
# Refeitório                        98.989899
# ...                                     ...
# Freguesia                          0.000000
# Concelho                           0.000000
# Distrito                           0.000000
# Tipo de imóvel                     0.000000
# Nome                               0.000000
#
# [31 rows x 1 columns]

# %% [markdown]
# ### Retirar as colunas que têm 99% de missing values (NÃO HÁ)

# %%
a_manter = list(missing_value_data_imo_armazém_columns.index[missing_value_data_imo_armazém_columns['percent_missing (%)'] < 99])
print(len(a_manter))
print(a_manter)
data_imo_armazém = data_imo_armazém[a_manter]
data_imo_armazém
# Out:
# 31
# ['Sala de reuniões', 'Recepção', 'Ligação a rede de água', 'Com cozinha', 'Refeitório', 'Arrecadação', 'Alarme', 'Vedação', 'Nº divisões', 'Acesso a veículos pesados', 'Área administrativa', 'Copa', 'Pisos', 'Ar condicionado', 'Imóvel de banca', 'Rua', 'Com WC', 'Ano construção', 'Certificado energético', 'Área bruta m/2', 'Empreendimento', 'Condição', 'Preço m/2', 'Preço', 'Área (m/2)', 'Id', 'Freguesia', 'Concelho', 'Distrito', 'Tipo de imóvel', 'Nome']
#      Sala de reuniões Recepção Ligação a rede de água Com cozinha Refeitório  \
# 762               NaN      NaN                    NaN         NaN        NaN
# 799               NaN      NaN                    NaN         NaN        NaN
# 1060              NaN      NaN                    NaN         NaN        NaN
# 1281              NaN      NaN                    NaN         NaN        NaN
# 1303              NaN      NaN                    NaN         NaN        NaN
# ...               ...      ...                    ...         ...        ...
# 5376              NaN      NaN                    NaN         NaN        NaN
# 5393              NaN      NaN                    NaN         NaN        NaN
# 5545              NaN      NaN                    NaN         NaN        NaN
# 5586              NaN      NaN                    NaN         NaN        NaN
# 5609              NaN      NaN                    NaN         NaN        NaN
#
#      Arrecadação Alarme Vedação  Nº divisões Acesso a veículos pesados  \
# 762          NaN    NaN     NaN          NaN                       NaN
# 799          NaN    NaN     NaN          NaN                       NaN
# 1060         NaN    NaN     NaN          NaN                       NaN
# 1281         NaN    NaN     NaN          NaN                       NaN
# 1303         NaN    NaN     NaN          NaN                       NaN
# ...          ...    ...     ...          ...                       ...
# 5376         NaN    NaN     NaN          NaN                       NaN
# 5393         NaN    NaN     NaN          NaN                       NaN
# 5545         NaN    NaN     NaN          NaN                       NaN
# 5586         NaN    NaN     NaN          NaN                       NaN
# 5609         NaN    NaN     NaN          NaN                       NaN
#
#      Área administrativa Copa  Pisos Ar condicionado Imóvel de banca  \
# 762                  NaN  NaN    NaN             NaN             NaN
# 799                  NaN  NaN    NaN             NaN             NaN
# 1060                 NaN  NaN    NaN             NaN            True
# 1281                 NaN  NaN    NaN             NaN            True
# 1303                 NaN  NaN    NaN            True             NaN
# ...                  ...  ...    ...             ...             ...
# 5376                 NaN  NaN    NaN             NaN            True
# 5393                 NaN  NaN    NaN             NaN             NaN
# 5545                 NaN  NaN    NaN             NaN             NaN
# 5586                 NaN  NaN    NaN             NaN             NaN
# 5609                 NaN  NaN    NaN             NaN             NaN
#
#                        Rua Com WC  Ano construção Certificado energético  \
# 762                    NaN    NaN             NaN                 Isento
# 799                    NaN    NaN          2001.0                 Isento
# 1060  Sem Nome - Ferreiros    NaN             NaN                    NaN
# 1281                   NaN    NaN             NaN                    NaN
# 1303                   NaN    NaN             NaN                    NaN
# ...                    ...    ...             ...                    ...
# 5376                   NaN    NaN             NaN                    NaN
# 5393                   NaN    NaN             NaN                 Isento
# 5545                   NaN    NaN          1997.0                    NaN
# 5586                   NaN    NaN             NaN                    NaN
# 5609                   NaN    NaN             NaN                    NaN
#
#      Área bruta m/2 Empreendimento Condição Preço m/2       Preço Área (m/2)  \
# 762          465 m²            NaN    Usado      344     160 000      465 m²
# 799          946 m²            NaN    Usado      460     434 900      946 m²
# 1060            NaN            não      NaN    2 037   1 100 000      540 m²
# 1281            NaN            não      NaN      340   1 100 000    3 240 m²
# 1303            NaN            não    Usado      500     400 000      800 m²
# ...             ...            ...      ...       ...         ...        ...
# 5376            NaN            não      NaN      260     210 000      809 m²
# 5393            NaN            não      NaN      672      82 000      122 m²
# 5545            NaN            não    Usado      394     785 000    1 990 m²
# 5586            NaN            não      NaN      257     180 000      700 m²
# 5609            NaN            NaN    Usado      257     180 000      700 m²
#
#             Id                     Freguesia Concelho          Distrito  \
# 762   14883356                 Lomar e Arcos    Braga  Braga (distrito)
# 799   14420422   Nogueira, Fraião e Lamaçães    Braga  Braga (distrito)
# 1060  15316849       Ferreiros e Gondizalves    Braga  Braga (distrito)
# 1281  15276323  Celeirós, Aveleda e Vimieiro    Braga  Braga (distrito)
# 1303  15228278                        Adaúfe    Braga  Braga (distrito)
# ...        ...                           ...      ...               ...
# 5376  15088328                   São Vicente    Braga  Braga (distrito)
# 5393  11276398          Real, Dume e Semelhe    Braga  Braga (distrito)
# 5545  15387753  Celeirós, Aveleda e Vimieiro    Braga  Braga (distrito)
# 5586  15383162                      Sequeira    Braga  Braga (distrito)
# 5609  14703000                      Sequeira    Braga  Braga (distrito)
#
#      Tipo de imóvel                                               Nome
# 762         Armazém                Armazém para venda em Lomar ,Braga.
# 799         Armazém         Pavilhão c/ 950 m2 junto ao Recheio, Braga
# 1060        Armazém                         Armazém Industrial - Braga
# 1281        Armazém                        Armazém Industrial em Braga
# 1303        Armazém                     Armazém  Venda em Adaúfe,Braga
# ...             ...                                                ...
# 5376        Armazém                            Vende-se Armazém, Braga
# 5393        Armazém                               Armazém Braga | Real
# 5545        Armazém  Armazém  Venda em Celeirós, Aveleda e Vimieiro...
# 5586        Armazém                   Armazém  Venda em Sequeira,Braga
# 5609        Armazém                         Armazén em Braga, Sequeira
#
# [99 rows x 31 columns]

# %% [markdown]
# ## Dados - Garagem

# %%
data_imo_garagem.head()
data_imo_garagem.info()
pd.set_option('display.max_rows', 20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 772 to 5604
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Tipo                   1 non-null      object
#  1   Espaço para arrumação  1 non-null      object
#  2   Ano construção         6 non-null      float64
#  3   Condição               17 non-null     object
#  4   Empreendimento         18 non-null     object
#  5   Id                     29 non-null     int64
#  6   Freguesia              29 non-null     object
#  7   Concelho               29 non-null     object
#  8   Distrito               29 non-null     object
#  9   Área (m/2)             29 non-null     object
#  10  Preço m/2              29 non-null     object
#  11  Preço                  29 non-null     object
#  12  Tipo de imóvel         29 non-null     object
#  13  Nome                   29 non-null     object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 3.4+ KB

# %% [markdown]
# #### Dados em falta por linha

# %%
percent_missing = (1 - data_imo_garagem.apply(lambda x: x.count(), axis=1) / len(data_imo_garagem.columns)) * 100
missing_value_data_imo_garagem_rows = pd.DataFrame({'percent_missing (%)': percent_missing})
missing_value_data_imo_garagem_rows.sort_values('percent_missing (%)', inplace=True, ascending=False)
missing_value_data_imo_garagem_rows
# Out:
#       percent_missing (%)
# 4931            35.714286
# 5531            35.714286
# 3713            28.571429
# 4988            28.571429
# 1344            28.571429
# ...                   ...
# 1822            21.428571
# 1524            21.428571
# 4631            21.428571
# 3625            14.285714
# 5455            14.285714
#
# [29 rows x 1 columns]

# %% [markdown]
# #### Dados em falta por coluna

# %%
percent_missing = data_imo_garagem.isnull().sum() * 100 / len(data_imo_garagem)
missing_value_data_imo_garagem_columns = pd.DataFrame({'percent_missing (%)': percent_missing})
missing_value_data_imo_garagem_columns.sort_values('percent_missing (%)', inplace=True, ascending=False)
pd.set_option('display.max_rows', 20)
missing_value_data_imo_garagem_columns
# Out:
#                        percent_missing (%)
# Tipo                             96.551724
# Espaço para arrumação            96.551724
# Ano construção                   79.310345
# Condição                         41.379310
# Empreendimento                   37.931034
# Id                                0.000000
# Freguesia                         0.000000
# Concelho                          0.000000
# Distrito                          0.000000
# Área (m/2)                        0.000000
# Preço m/2                         0.000000
# Preço                             0.000000
# Tipo de imóvel                    0.000000
# Nome                              0.000000

# %% [markdown]
# ### Retirar as colunas que têm 99% de missing values (NÃO HÁ)

# %%
a_manter = list(missing_value_data_imo_garagem_columns.index[missing_value_data_imo_garagem_columns['percent_missing (%)'] < 99])
print(len(a_manter))
print(a_manter)
data_imo_garagem = data_imo_garagem[a_manter]
data_imo_garagem
# Out:
# 14
# ['Tipo', 'Espaço para arrumação', 'Ano construção', 'Condição', 'Empreendimento', 'Id', 'Freguesia', 'Concelho', 'Distrito', 'Área (m/2)', 'Preço m/2', 'Preço', 'Tipo de imóvel', 'Nome']
#      Tipo Espaço para arrumação  Ano construção Condição Empreendimento  \
# 772   NaN                   NaN          1993.0    Usado            NaN
# 1344  NaN                   NaN             NaN    Usado            NaN
# 1524  NaN                   NaN          2006.0    Usado            NaN
# 1751  NaN                   NaN             NaN    Usado            NaN
# 1822  NaN                   NaN          1997.0    Usado            NaN
# ...   ...                   ...             ...      ...            ...
# 5389  NaN                   NaN             NaN     Novo            não
# 5390  NaN                   NaN             NaN     Novo            não
# 5455  NaN                   NaN          1990.0    Usado            não
# 5531  NaN                   NaN             NaN      NaN            NaN
# 5604  NaN                   NaN             NaN      NaN            não
#
#             Id                                          Freguesia Concelho  \
# 772   14800021                                      Lomar e Arcos    Braga
# 1344  15086074  Braga (São José de São Lázaro e São João do So...    Braga
# 1524  15103154  Braga (São José de São Lázaro e São João do So...    Braga
# 1751  14775741                               Real, Dume e Semelhe    Braga
# 1822  14426398                                         São Victor    Braga
# ...        ...                                                ...      ...
# 5389  12826294  Braga (São José de São Lázaro e São João do So...    Braga
# 5390  12826285                        Nogueira, Fraião e Lamaçães    Braga
# 5455  15385876                                         São Victor    Braga
# 5531  11436415                        Nogueira, Fraião e Lamaçães    Braga
# 5604  14968886                                         São Victor    Braga
#
#               Distrito Área (m/2) Preço m/2    Preço Tipo de imóvel  \
# 772   Braga (distrito)     225 m²      344   77 500         Garagem
# 1344  Braga (distrito)      20 m²      975   19 500         Garagem
# 1524  Braga (distrito)     118 m²      441   52 000         Garagem
# 1751  Braga (distrito)      26 m²      496   12 900         Garagem
# 1822  Braga (distrito)      18 m²      833   15 000         Garagem
# ...                ...        ...       ...      ...            ...
# 5389  Braga (distrito)      16 m²      781   12 500         Garagem
# 5390  Braga (distrito)      23 m²      326    7 500         Garagem
# 5455  Braga (distrito)      36 m²      222    8 000         Garagem
# 5531  Braga (distrito)   22,90 m²      349    8 000         Garagem
# 5604  Braga (distrito)       5 m²    1 400    7 000         Garagem
#
#                                                    Nome
# 772                   Garagem com 225m2 em Lomar, Braga
# 1344                 Venda de Garagem, São Vitor, Braga
# 1524             Magnifica Garagem com cerca de 146 m2.
# 1751                    Garagem fechada na zona de Real
# 1822  Garagem individual, fechada, na zona do Braga ...
# ...                                                 ...
# 5389                           Garagem em S. João Souto
# 5390                                Garagem em Nogueira
# 5455                                   Garagem em Braga
# 5531              Garagens Autónomas - Nogueira - Braga
# 5604          Garagem  Venda em Braga (São Vítor),Braga
#
# [29 rows x 14 columns]
