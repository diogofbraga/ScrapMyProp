# %% [markdown]
# # Scrap My Prop
#
# ### Laboratórios de Engenharia Informática
#
# **"Development of an IT solution for the extraction and automatic analysis of data and relevant information for the calculation of land and properties."**

# %% [markdown]
# ## Importar Bibliotecas Python

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from IPython.core.debugger import set_trace
import geopy.distance
import os.path
from sklearn import metrics

# %% [markdown]
# # 'Imovirtual'

# %% [markdown]
# ## Ler Dados do CSV

# %% [markdown]
# **Junção dos datasets através do 'id'**

# %%
k = True

for mes in range(4,6):
    if mes > 0 and mes < 10:
        mes = str(mes).zfill(2)
    print("------ Mês:", mes)
    for dia in range(1,31):
        if dia > 0 and dia < 10:
            dia = str(dia).zfill(2)
        print("--- Dia:", dia)
        if os.path.isfile(f'../dados/dados_imovirtual_{dia}_{mes}.csv'):
            if k:
                data_imo = pd.read_csv(f'../dados/dados_imovirtual_{dia}_{mes}.csv', engine='python', encoding='utf8')
                print(data_imo.shape)
                k = False
            else:
                csv = pd.read_csv(f'../dados/dados_imovirtual_{dia}_{mes}.csv', engine='python', encoding='utf8')
                data_imo = data_imo.append(csv,sort=False)
                data_imo = data_imo.drop_duplicates(subset='Id', keep="last")
                data_imo.index = np.arange(1, len(data_imo) + 1)
                print(data_imo.shape)
# Out:
# ------ Mês: 04
# --- Dia: 01
# --- Dia: 02
# --- Dia: 03
# --- Dia: 04
# --- Dia: 05
# --- Dia: 06
# --- Dia: 07
# --- Dia: 08
# --- Dia: 09
# --- Dia: 10
# --- Dia: 11
# --- Dia: 12
# --- Dia: 13
# --- Dia: 14
# --- Dia: 15
# (5618, 132)
# --- Dia: 16
# (5684, 132)
# --- Dia: 17
# (5712, 132)
# --- Dia: 18
# (5740, 132)
# --- Dia: 19
# (5742, 132)
# --- Dia: 20
# (5755, 132)
# --- Dia: 21
# (5758, 132)
# --- Dia: 22
# (5796, 132)
# --- Dia: 23
# (5803, 132)
# --- Dia: 24
# (5827, 132)
# --- Dia: 25
# (5874, 132)
# --- Dia: 26
# (5877, 132)
# --- Dia: 27
# (5880, 132)
# --- Dia: 28
# --- Dia: 29
# --- Dia: 30
# ------ Mês: 05
# --- Dia: 01
# --- Dia: 02
# --- Dia: 03
# --- Dia: 04
# --- Dia: 05
# --- Dia: 06
# --- Dia: 07
# --- Dia: 08
# --- Dia: 09
# (6160, 132)
# --- Dia: 10
# (6160, 132)
# --- Dia: 11
# (6162, 132)
# --- Dia: 12
# (6195, 132)
# --- Dia: 13
# (6222, 132)
# --- Dia: 14
# (6252, 132)
# --- Dia: 15
# (6289, 132)
# --- Dia: 16
# (6372, 132)
# --- Dia: 17
# (6373, 132)
# --- Dia: 18
# (6383, 132)
# --- Dia: 19
# (6437, 132)
# --- Dia: 20
# (6453, 132)
# --- Dia: 21
# --- Dia: 22
# (6513, 132)
# --- Dia: 23
# (6532, 132)
# --- Dia: 24
# (6535, 132)
# --- Dia: 25
# (6543, 132)
# --- Dia: 26
# (6588, 132)
# --- Dia: 27
# (6604, 132)
# --- Dia: 28
# (6636, 132)
# --- Dia: 29
# (6652, 132)
# --- Dia: 30
# (6664, 132)

# %%
#data_imo = pd.read_csv('../dados/dados_imovirtual_08_05.csv', engine='python', encoding='utf8')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10)
data_imo.head()
# Out:
#                                                 Nome          Id  \
# 1  Loja comercial Junto ao Centro da Cidade de Br...  14804552.0
# 2               Excelente Terreno em Fradelos, Braga  14976693.0
# 3                            Moradia Terrea em Lomar  15377577.0
# 4                    Moradia p/ Restauro - Maximinos  14698254.0
# 5        Moradia c/362 m2 “NOVA” em Nogueiró, Braga!  14979186.0
#
#   Tipo de imóvel     Preço Preço m/2          Distrito Concelho  \
# 1           Loja   19 900       622   Braga (distrito)    Braga
# 2        Terreno   97 000        60   Braga (distrito)    Braga
# 3        Moradia       NaN       NaN  Braga (distrito)    Braga
# 4        Moradia  149 500     1 495   Braga (distrito)    Braga
# 5        Moradia  288 000     1 200   Braga (distrito)    Braga
#
#                           Freguesia                            Rua   Latitude  \
# 1                          Sequeira        Rua Inácio José Peixoto  41.554660
# 2                 Vilaça e Fradelos                            NaN  41.507746
# 3                     Lomar e Arcos  Rua Quinta das Mouras - Lomar  41.527420
# 4  Braga (Maximinos, Sé e Cividade)                            NaN  41.549550
# 5       Nogueira, Fraião e Lamaçães                            NaN  41.548575
#
#    Longitude Tipologia Nº Casas de Banho Área útil m/2 Área bruta m/2  \
# 1  -8.432971       NaN               NaN         32 m²            NaN
# 2  -8.477455       NaN               NaN           NaN            NaN
# 3  -8.423300        T4         4 ou mais        537 m²       2 448 m²
# 4  -8.437720        T0               NaN        100 m²         131 m²
# 5  -8.390454        T4                 2        240 m²         362 m²
#
#    Ano construção Certificado energético Armário Cozinha equipada Garagem box  \
# 1             NaN                      C     NaN              NaN         NaN
# 2             NaN                    NaN     NaN              NaN         NaN
# 3          2018.0                    NaN     NaN              NaN         NaN
# 4          1980.0                    NaN     NaN              NaN         NaN
# 5             NaN                      B     NaN              NaN        True
#
#   Gás canalizado Lareira Marquise Suite Varanda Vista de cidade Condição  \
# 1            NaN     NaN      NaN   NaN     NaN             NaN    Usado
# 2            NaN     NaN      NaN   NaN     NaN             NaN      NaN
# 3            NaN     NaN      NaN   NaN     NaN             NaN      NaN
# 4            NaN     NaN      NaN   NaN     NaN             NaN    Ruína
# 5            NaN     NaN      NaN   NaN    True             NaN     Novo
#
#   Despensa Arrecadação Porta blindada Video Porteiro Empreendimento  \
# 1      NaN         NaN            NaN            NaN            NaN
# 2      NaN         NaN            NaN            NaN            NaN
# 3      NaN         NaN            NaN            NaN            não
# 4      NaN         NaN            NaN            NaN            NaN
# 5      NaN         NaN            NaN            NaN            NaN
#
#   Ar condicionado Elevador  Estores elétricos Fibra ótica  \
# 1             NaN      NaN                NaN         NaN
# 2             NaN      NaN                NaN         NaN
# 3             NaN      NaN                NaN         NaN
# 4             NaN      NaN                NaN         NaN
# 5             NaN      NaN                NaN         NaN
#
#   Pré-instalação de ar condicionado Terraço  Área de terreno m/2 Churrasco  \
# 1                               NaN     NaN                  NaN       NaN
# 2                               NaN     NaN                  NaN       NaN
# 3                               NaN     NaN                  NaN       NaN
# 4                               NaN     NaN                  NaN       NaN
# 5                               NaN     NaN                  NaN       NaN
#
#   Árvores de fruto Sotão Cave Jardim Aquecimento central Caldeira  \
# 1              NaN   NaN  NaN    NaN                 NaN      NaN
# 2              NaN   NaN  NaN    NaN                 NaN      NaN
# 3              NaN   NaN  NaN    NaN                 NaN      NaN
# 4              NaN   NaN  NaN    NaN                 NaN      NaN
# 5              NaN   NaN  NaN   True                 NaN      NaN
#
#   Acessibilidade a pessoas com mobilidade condicionada  Box 2 carros  \
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
# 5                                                NaN             NaN
#
#   Detetor de gás Painéis solares Recuperação de calor Vista de campo/serra  \
# 1            NaN             NaN                  NaN                  NaN
# 2            NaN             NaN                  NaN                  NaN
# 3            NaN             NaN                  NaN                  NaN
# 4            NaN             NaN                  NaN                  NaN
# 5            NaN             NaN                  NaN                  NaN
#
#    Box 1 carro Portaria Estacionamento Piso radiante Som ambiente  \
# 1          NaN      NaN            NaN           NaN          NaN
# 2          NaN      NaN            NaN           NaN          NaN
# 3          NaN      NaN            NaN           NaN          NaN
# 4          NaN      NaN            NaN           NaN          NaN
# 5          NaN      NaN            NaN           NaN          NaN
#
#   Aspiração central Finalidade Tipo de terreno Acesso pavimentado Asfaltado  \
# 1               NaN        NaN             NaN                NaN       NaN
# 2               NaN        NaN         Rústico                NaN       NaN
# 3               NaN        NaN             NaN                NaN       NaN
# 4               NaN        NaN             NaN                NaN       NaN
# 5               NaN        NaN             NaN                NaN       NaN
#
#   Iluminação pública Zona arborizada Declive Ruína Alarme Furo de água  \
# 1                NaN             NaN     NaN   NaN    NaN          NaN
# 2                NaN             NaN     NaN   NaN    NaN          NaN
# 3                NaN             NaN     NaN   NaN    NaN          NaN
# 4                NaN             NaN     NaN   NaN    NaN          NaN
# 5                NaN             NaN     NaN   NaN    NaN          NaN
#
#   Domótica  Casa das máquinas Condomínio Fechado Parque infantil Piscina  \
# 1      NaN                NaN                NaN             NaN     NaN
# 2      NaN                NaN                NaN             NaN     NaN
# 3      NaN                NaN                NaN             NaN     NaN
# 4      NaN                NaN                NaN             NaN     NaN
# 5      NaN                NaN                NaN             NaN     NaN
#
#   Piscina Privada Termoacumulador Garagem exterior Mobilado  \
# 1             NaN             NaN              NaN      NaN
# 2             NaN             NaN              NaN      NaN
# 3             NaN             NaN              NaN      NaN
# 4             NaN             NaN              NaN      NaN
# 5             NaN             NaN              NaN      NaN
#
#   Hidromassagem/jacuzzi Quintal/horta Ginásio Kitchenette  \
# 1                   NaN           NaN     NaN         NaN
# 2                   NaN           NaN     NaN         NaN
# 3                   NaN           NaN     NaN         NaN
# 4                   NaN           NaN     NaN         NaN
# 5                   NaN          True     NaN         NaN
#
#   Vigilância/segurança Campo de ténis Segurança 24 horas Vedação  \
# 1                  NaN            NaN                NaN     NaN
# 2                  NaN            NaN                NaN     NaN
# 3                  NaN            NaN                NaN     NaN
# 4                  NaN            NaN                NaN     NaN
# 5                  NaN            NaN                NaN     NaN
#
#   Parqueamento (1 carro) Ligação a rede de água  Ligação a rede de saneamento  \
# 1                    NaN                    NaN                           NaN
# 2                    NaN                    NaN                           NaN
# 3                    NaN                    NaN                           NaN
# 4                    NaN                    NaN                           NaN
# 5                    NaN                    NaN                           NaN
#
#   Ligação a rede elétrica Animais permitidos Parqueamento (2 carros) Cofre  \
# 1                     NaN                NaN                     NaN   NaN
# 2                     NaN                NaN                     NaN   NaN
# 3                     NaN                NaN                     NaN   NaN
# 4                     NaN                NaN                     NaN   NaN
# 5                     NaN                NaN                     NaN   NaN
#
#   Vista de rio  Nº divisões  Tipo  Pisos Com WC Montra Anexo habitacional  \
# 1          NaN          2.0  Loja    1.0   True   True                NaN
# 2          NaN          NaN   NaN    NaN    NaN    NaN                NaN
# 3          NaN          NaN   NaN    NaN    NaN    NaN                NaN
# 4          NaN          NaN   NaN    NaN    NaN    NaN                NaN
# 5          NaN          NaN   NaN    NaN    NaN    NaN                NaN
#
#    Detetor de incêndio  Detetor de Inundução Vista de cidade.1 Área (m/2)  \
# 1                  NaN                   NaN               NaN        NaN
# 2                  NaN                   NaN               NaN        NaN
# 3                  NaN                   NaN               NaN        NaN
# 4                  NaN                   NaN               NaN        NaN
# 5                  NaN                   NaN               NaN        NaN
#
#   Vista de mar Jacuzzi Património classificado Adaptada a mobilidade reduzida  \
# 1          NaN     NaN                     NaN                            NaN
# 2          NaN     NaN                     NaN                            NaN
# 3          NaN     NaN                     NaN                            NaN
# 4          NaN     NaN                     NaN                            NaN
# 5          NaN     NaN                     NaN                            NaN
#
#   Com cozinha Imóvel de banca Vista de lago Fossa séptica  \
# 1         NaN             NaN           NaN           NaN
# 2         NaN             NaN           NaN           NaN
# 3         NaN             NaN           NaN           NaN
# 4         NaN             NaN           NaN           NaN
# 5         NaN             NaN           NaN           NaN
#
#    Licensa de construção Acesso a veículos pesados Área administrativa Copa  \
# 1                    NaN                       NaN                 NaN  NaN
# 2                    NaN                       NaN                 NaN  NaN
# 3                    NaN                       NaN                 NaN  NaN
# 4                    NaN                       NaN                 NaN  NaN
# 5                    NaN                       NaN                 NaN  NaN
#
#   Recepção Refeitório Sala de reuniões Área florestal Hidromassagem  \
# 1      NaN        NaN              NaN            NaN           NaN
# 2      NaN        NaN              NaN            NaN           NaN
# 3      NaN        NaN              NaN            NaN           NaN
# 4      NaN        NaN              NaN            NaN           NaN
# 5      NaN        NaN              NaN            NaN           NaN
#
#   Percurso de água Armazém Vista de Serra Adaptado a mobilidade reduzida  \
# 1              NaN     NaN            NaN                            NaN
# 2              NaN     NaN            NaN                            NaN
# 3              NaN     NaN            NaN                            NaN
# 4              NaN     NaN            NaN                            NaN
# 5              NaN     NaN            NaN                            NaN
#
#   Terra batida Video vigilância  Espaço frigorífico Espaço para arrumação  \
# 1          NaN              NaN                 NaN                   NaN
# 2          NaN              NaN                 NaN                   NaN
# 3          NaN              NaN                 NaN                   NaN
# 4          NaN              NaN                 NaN                   NaN
# 5          NaN              NaN                 NaN                   NaN
#
#   Casa de banho partilhada Poço Sótão Paisagem protegida
# 1                      NaN  NaN   NaN                NaN
# 2                      NaN  NaN   NaN                NaN
# 3                      NaN  NaN   NaN                NaN
# 4                      NaN  NaN   NaN                NaN
# 5                      NaN  NaN   NaN                NaN

# %% [markdown]
# ## Pré-processamento comum a todo o Dataset

# %% [markdown]
# **Funções auxiliares**

# %%
def toNumeric(string):
    res = str(string)
    res = res.replace(" ", "")
    res = res.replace(",", ".")
    res = float(pd.to_numeric(res, errors='ignore')) # tem que ser float porque esse tipo consegue interpretar o np.nan
    return res

# %% [markdown]
# **Colunas 'Distrito' e 'Concelho': Retirar colunas de forma total porque já era uma pré-condição do projeto, mas primeiro verificar se, de facto, todos os campos estão preenchidos com 'Braga';**

# %%
print("Distritos existentes:", data_imo['Distrito'].unique())
print("Concelhos existentes:", data_imo['Concelho'].unique())
# Out:
# Distritos existentes: ['Braga (distrito)' nan]
# Concelhos existentes: ['Braga' nan]

# %%
if 'Distrito' in data_imo.columns:
    data_imo = data_imo.drop(['Distrito'], axis = 1) 
if 'Concelho' in data_imo.columns:
    data_imo = data_imo.drop(['Concelho'], axis = 1)

# %% [markdown]
# **Coluna 'Nome': Não é característica dos imóveis mas sim identificador, portanto não deve entrar nos cálculos (Drop);**

# %%
if 'Nome' in data_imo.columns:
    data_imo = data_imo.drop(['Nome'], axis = 1)

# %% [markdown]
# **Coluna 'Id': Drop linhas sem 'Id'; float -> int;**

# %%
data_imo = data_imo.dropna(subset=['Id'])
data_imo.index = np.arange(1, len(data_imo) + 1)

# %%
data_imo['Id'] = data_imo['Id'].astype(int)

# %% [markdown]
# **Dar join a colunas que, apesar de aparentarem ter nomes diferentes, representam o mesmo**

# %% [markdown]
# **Exemplo: Valores de 'Box 1 carro' e 'Box 2 carros' -> 'Garagem box'; Valores de 'Parqueamento (1 carro)' e 'Parqueamento (2 carros)' -> 'Estacionamento'; Valores de 'Hidromassagem' e 'Jacuzzi' -> 'Hidromassagem/jacuzzi'; ...**

# %% [markdown]
# **Fazer o mesmo com piscina e piscina privada???**

# %%
#pd.set_option('display.max_columns', None)
#data_imo.columns.to_numpy()

# %%
for index,val in data_imo['Vista de cidade.1'].items():
    if (val==True):
        data_imo['Vista de cidade'].iloc[index] = True
for index,val in data_imo['Sótão'].items():
    if (val==True):
        data_imo['Sotão'].iloc[index] = True
for index,val in data_imo['Vista de Serra'].items():
    if (val==True):
        data_imo['Vista de campo/serra'].iloc[index] = True
for index,val in data_imo['Adaptada a mobilidade reduzida'].items():
    if (val==True):
        data_imo['Adaptado a mobilidade reduzida'].iloc[index] = True
for index,val in data_imo['Box 1 carro'].items():
    if (val==True):
        data_imo['Garagem box'].iloc[index] = True
for index,val in data_imo['Box 2 carros'].items():
    if (val==True):
        data_imo['Garagem box'].iloc[index] = True
for index,val in data_imo['Parqueamento (1 carro)'].items():
    if (val==True):
        data_imo['Estacionamento'].iloc[index] = True
for index,val in data_imo['Parqueamento (2 carros)'].items():
    if (val==True):
        data_imo['Estacionamento'].iloc[index] = True
for index,val in data_imo['Hidromassagem'].items():
    if (val==True):
        data_imo['Hidromassagem/jacuzzi'].iloc[index] = True
for index,val in data_imo['Jacuzzi'].items():
    if (val==True):
        data_imo['Hidromassagem/jacuzzi'].iloc[index] = True
        
data_imo=data_imo.drop(['Vista de cidade.1', 'Sótão', 'Vista de Serra', 'Hidromassagem', 'Jacuzzi', 'Adaptada a mobilidade reduzida'], axis=1)
# Out:
# C:\Users\Rui\Anaconda3\envs\LEI\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#data_imo.info(verbose=True, null_counts=True)

# %% [markdown]
# **Normalizar os valores de todas as áreas; Transformar em dado numérico;**

# %%
for column in data_imo.columns:
    if "Área" in column and "Área administrativa" not in column and "Área florestal" not in column:
        for i in range(len(data_imo[column])):
            if not pd.isnull(data_imo[column].iloc[i]):
                #print(data_imo[column].iloc[i])
                data_imo[column].iloc[i]=toNumeric(str(data_imo[column].iloc[i])[0:-3])
                #print(data_imo[column].iloc[i])
                #print(type(data_imo[column].iloc[i]))

# %% [markdown]
# **Coluna 'Preço' e 'Preço m/2': Drop dos imóveis com valor 'nan'; Transformar em dado numérico;**

# %%
data_imo['Preço'] = data_imo['Preço'].apply(toNumeric)

nan_prices = data_imo['Preço'].index[data_imo['Preço'].apply(np.isnan)]
data_imo = data_imo.drop(nan_prices)
data_imo.index = np.arange(1, len(data_imo) + 1)

data_imo['Preço'] = data_imo['Preço'].apply(int)

# ------

data_imo['Preço m/2'] = data_imo['Preço m/2'].apply(toNumeric)

nan_prices = data_imo['Preço m/2'].index[data_imo['Preço m/2'].apply(np.isnan)]
data_imo = data_imo.drop(nan_prices)
data_imo.index = np.arange(1, len(data_imo) + 1)

data_imo['Preço m/2'] = data_imo['Preço m/2'].apply(int)

# %%
data_imo.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6567 entries, 1 to 6567
# Data columns (total 123 columns):
#  #   Column                                                Dtype
# ---  ------                                                -----
#  0   Id                                                    int32
#  1   Tipo de imóvel                                        object
#  2   Preço                                                 int64
#  3   Preço m/2                                             int64
#  4   Freguesia                                             object
#  5   Rua                                                   object
#  6   Latitude                                              float64
#  7   Longitude                                             float64
#  8   Tipologia                                             object
#  9   Nº Casas de Banho                                     object
#  10  Área útil m/2                                         object
#  11  Área bruta m/2                                        object
#  12  Ano construção                                        float64
#  13  Certificado energético                                object
#  14  Armário                                               object
#  15  Cozinha equipada                                      object
#  16  Garagem box                                           object
#  17  Gás canalizado                                        object
#  18  Lareira                                               object
#  19  Marquise                                              object
#  20  Suite                                                 object
#  21  Varanda                                               object
#  22  Vista de cidade                                       object
#  23  Condição                                              object
#  24  Despensa                                              object
#  25  Arrecadação                                           object
#  26  Porta blindada                                        object
#  27  Video Porteiro                                        object
#  28  Empreendimento                                        object
#  29  Ar condicionado                                       object
#  30  Elevador                                              object
#  31  Estores elétricos                                     float64
#  32  Fibra ótica                                           object
#  33  Pré-instalação de ar condicionado                     object
#  34  Terraço                                               object
#  35  Área de terreno m/2                                   float64
#  36  Churrasco                                             object
#  37  Árvores de fruto                                      object
#  38  Sotão                                                 object
#  39  Cave                                                  object
#  40  Jardim                                                object
#  41  Aquecimento central                                   object
#  42  Caldeira                                              object
#  43  Acessibilidade a pessoas com mobilidade condicionada  object
#  44  Box 2 carros                                          float64
#  45  Detetor de gás                                        object
#  46  Painéis solares                                       object
#  47  Recuperação de calor                                  object
#  48  Vista de campo/serra                                  object
#  49  Box 1 carro                                           float64
#  50  Portaria                                              object
#  51  Estacionamento                                        object
#  52  Piso radiante                                         object
#  53  Som ambiente                                          object
#  54  Aspiração central                                     object
#  55  Finalidade                                            object
#  56  Tipo de terreno                                       object
#  57  Acesso pavimentado                                    object
#  58  Asfaltado                                             object
#  59  Iluminação pública                                    object
#  60  Zona arborizada                                       object
#  61  Declive                                               object
#  62  Ruína                                                 object
#  63  Alarme                                                object
#  64  Furo de água                                          object
#  65  Domótica                                              object
#  66  Casa das máquinas                                     float64
#  67  Condomínio Fechado                                    object
#  68  Parque infantil                                       object
#  69  Piscina                                               object
#  70  Piscina Privada                                       object
#  71  Termoacumulador                                       object
#  72  Garagem exterior                                      object
#  73  Mobilado                                              object
#  74  Hidromassagem/jacuzzi                                 object
#  75  Quintal/horta                                         object
#  76  Ginásio                                               object
#  77  Kitchenette                                           object
#  78  Vigilância/segurança                                  object
#  79  Campo de ténis                                        object
#  80  Segurança 24 horas                                    object
#  81  Vedação                                               object
#  82  Parqueamento (1 carro)                                object
#  83  Ligação a rede de água                                object
#  84  Ligação a rede de saneamento                          float64
#  85  Ligação a rede elétrica                               object
#  86  Animais permitidos                                    object
#  87  Parqueamento (2 carros)                               object
#  88  Cofre                                                 object
#  89  Vista de rio                                          object
#  90  Nº divisões                                           float64
#  91  Tipo                                                  object
#  92  Pisos                                                 float64
#  93  Com WC                                                object
#  94  Montra                                                object
#  95  Anexo habitacional                                    object
#  96  Detetor de incêndio                                   float64
#  97  Detetor de Inundução                                  float64
#  98  Área (m/2)                                            object
#  99  Vista de mar                                          object
#  100 Património classificado                               object
#  101 Com cozinha                                           object
#  102 Imóvel de banca                                       object
#  103 Vista de lago                                         object
#  104 Fossa séptica                                         object
#  105 Licensa de construção                                 float64
#  106 Acesso a veículos pesados                             object
#  107 Área administrativa                                   object
#  108 Copa                                                  object
#  109 Recepção                                              object
#  110 Refeitório                                            object
#  111 Sala de reuniões                                      object
#  112 Área florestal                                        object
#  113 Percurso de água                                      object
#  114 Armazém                                               object
#  115 Adaptado a mobilidade reduzida                        object
#  116 Terra batida                                          object
#  117 Video vigilância                                      object
#  118 Espaço frigorífico                                    float64
#  119 Espaço para arrumação                                 object
#  120 Casa de banho partilhada                              object
#  121 Poço                                                  object
#  122 Paisagem protegida                                    object
# dtypes: float64(15), int32(1), int64(2), object(105)
# memory usage: 6.2+ MB

# %% [markdown]
# # Dados - Quintas

# %% [markdown]
# **Ver os valores únicos de cada coluna para proceder ao processamento**

# %%
for col in data_imo.columns:
    uniques=data_imo[col].unique()
    print("Valores únicos para a coluna ", col, ": ", uniques)

# %% [markdown]
# **Dividir os dados por tipo de imóvel**

# %%
data_imo_quintas = data_imo.loc[(data_imo['Tipo de imóvel'] == 'Quintas')]
data_imo_quintas.index = np.arange(1, len(data_imo_quintas) + 1)

# %%
data_imo_quintas.head()
# Out:
#          Id Tipo de imóvel    Preço  Preço m/2  \
# 1  14773461        Quintas   285000         71
# 2  15293372        Quintas  1800000         33
# 3  15147059        Quintas  1800000       6977
# 4  15235231        Quintas  2000000        364
# 5  15234875        Quintas   110000         55
#
#                                           Freguesia  Rua   Latitude  \
# 1                                          Palmeira  NaN  41.590424
# 2  Escudeiros e Penso (Santo Estêvão e São Vicente)  NaN  41.477932
# 3  Escudeiros e Penso (Santo Estêvão e São Vicente)  NaN  41.475043
# 4                                       São Vicente  NaN  41.554339
# 5  Escudeiros e Penso (Santo Estêvão e São Vicente)  NaN  41.477688
#
#    Longitude Tipologia Nº Casas de Banho Área útil m/2 Área bruta m/2  \
# 1  -8.426242       NaN               NaN           NaN            NaN
# 2  -8.426478       NaN               NaN           NaN            653
# 3  -8.432176        T5               NaN           NaN            258
# 4  -8.427382       NaN               NaN          5500            NaN
# 5  -8.426569       NaN               NaN          2000           2000
#
#    Ano construção Certificado energético Armário Cozinha equipada Garagem box  \
# 1             NaN                    NaN     NaN              NaN         NaN
# 2             NaN                    NaN     NaN              NaN         NaN
# 3          1736.0                      F     NaN              NaN         NaN
# 4             NaN                    NaN     NaN              NaN         NaN
# 5             NaN                    NaN     NaN              NaN         NaN
#
#   Gás canalizado Lareira Marquise Suite Varanda Vista de cidade  \
# 1            NaN     NaN      NaN   NaN     NaN             NaN
# 2            NaN    True      NaN   NaN     NaN             NaN
# 3            NaN     NaN      NaN   NaN     NaN             NaN
# 4            NaN     NaN      NaN   NaN     NaN             NaN
# 5            NaN     NaN      NaN   NaN     NaN             NaN
#
#          Condição Despensa Arrecadação Porta blindada Video Porteiro  \
# 1  Para recuperar      NaN         NaN            NaN            NaN
# 2           Usado      NaN         NaN            NaN            NaN
# 3           Usado      NaN         NaN            NaN            NaN
# 4           Usado      NaN         NaN            NaN            NaN
# 5             NaN      NaN         NaN            NaN            NaN
#
#   Empreendimento Ar condicionado Elevador  Estores elétricos Fibra ótica  \
# 1            NaN             NaN      NaN                NaN         NaN
# 2            NaN             NaN      NaN                NaN         NaN
# 3            NaN             NaN      NaN                NaN         NaN
# 4            NaN             NaN      NaN                NaN         NaN
# 5            NaN             NaN      NaN                NaN         NaN
#
#   Pré-instalação de ar condicionado Terraço  Área de terreno m/2 Churrasco  \
# 1                               NaN     NaN                  NaN       NaN
# 2                               NaN     NaN                  NaN      True
# 3                               NaN     NaN                  NaN       NaN
# 4                               NaN     NaN                  NaN       NaN
# 5                               NaN     NaN                  NaN       NaN
#
#   Árvores de fruto Sotão Cave Jardim Aquecimento central Caldeira  \
# 1              NaN   NaN  NaN    NaN                 NaN      NaN
# 2             True   NaN  NaN   True                 NaN      NaN
# 3              NaN   NaN  NaN    NaN                 NaN      NaN
# 4              NaN   NaN  NaN    NaN                 NaN      NaN
# 5              NaN   NaN  NaN    NaN                 NaN      NaN
#
#   Acessibilidade a pessoas com mobilidade condicionada  Box 2 carros  \
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
# 5                                                NaN             NaN
#
#   Detetor de gás Painéis solares Recuperação de calor Vista de campo/serra  \
# 1            NaN             NaN                  NaN                  NaN
# 2            NaN             NaN                  NaN                  NaN
# 3            NaN             NaN                  NaN                  NaN
# 4            NaN             NaN                  NaN                  NaN
# 5            NaN             NaN                  NaN                  NaN
#
#    Box 1 carro Portaria Estacionamento Piso radiante Som ambiente  \
# 1          NaN      NaN            NaN           NaN          NaN
# 2          NaN      NaN            NaN           NaN          NaN
# 3          NaN      NaN            NaN           NaN          NaN
# 4          NaN      NaN            NaN           NaN          NaN
# 5          NaN      NaN            NaN           NaN          NaN
#
#   Aspiração central Finalidade Tipo de terreno Acesso pavimentado Asfaltado  \
# 1               NaN        NaN             NaN                NaN       NaN
# 2               NaN        NaN             NaN                NaN       NaN
# 3               NaN        NaN             NaN                NaN       NaN
# 4               NaN        NaN             NaN                NaN       NaN
# 5               NaN        NaN             NaN                NaN       NaN
#
#   Iluminação pública Zona arborizada Declive Ruína Alarme Furo de água  \
# 1                NaN             NaN     NaN   NaN    NaN          NaN
# 2                NaN             NaN     NaN   NaN    NaN          NaN
# 3                NaN             NaN     NaN   NaN    NaN          NaN
# 4                NaN             NaN     NaN   NaN    NaN          NaN
# 5                NaN             NaN     NaN   NaN    NaN          NaN
#
#   Domótica  Casa das máquinas Condomínio Fechado Parque infantil Piscina  \
# 1      NaN                NaN                NaN             NaN     NaN
# 2      NaN                NaN                NaN             NaN    True
# 3      NaN                NaN                NaN             NaN     NaN
# 4      NaN                NaN                NaN             NaN     NaN
# 5      NaN                NaN                NaN             NaN     NaN
#
#   Piscina Privada Termoacumulador Garagem exterior Mobilado  \
# 1             NaN             NaN              NaN      NaN
# 2             NaN             NaN              NaN      NaN
# 3             NaN             NaN              NaN      NaN
# 4             NaN             NaN              NaN      NaN
# 5             NaN             NaN              NaN      NaN
#
#   Hidromassagem/jacuzzi Quintal/horta Ginásio Kitchenette  \
# 1                   NaN           NaN     NaN         NaN
# 2                   NaN           NaN     NaN         NaN
# 3                   NaN           NaN     NaN         NaN
# 4                   NaN           NaN     NaN         NaN
# 5                   NaN           NaN     NaN         NaN
#
#   Vigilância/segurança Campo de ténis Segurança 24 horas Vedação  \
# 1                  NaN            NaN                NaN     NaN
# 2                  NaN            NaN                NaN     NaN
# 3                  NaN            NaN                NaN     NaN
# 4                  NaN            NaN                NaN     NaN
# 5                  NaN            NaN                NaN     NaN
#
#   Parqueamento (1 carro) Ligação a rede de água  Ligação a rede de saneamento  \
# 1                    NaN                    NaN                           NaN
# 2                    NaN                    NaN                           NaN
# 3                    NaN                    NaN                           NaN
# 4                    NaN                    NaN                           NaN
# 5                    NaN                    NaN                           NaN
#
#   Ligação a rede elétrica Animais permitidos Parqueamento (2 carros) Cofre  \
# 1                     NaN                NaN                     NaN   NaN
# 2                     NaN                NaN                     NaN   NaN
# 3                     NaN                NaN                     NaN   NaN
# 4                     NaN                NaN                     NaN   NaN
# 5                     NaN                NaN                     NaN   NaN
#
#   Vista de rio  Nº divisões Tipo  Pisos Com WC Montra Anexo habitacional  \
# 1          NaN          NaN  NaN    NaN    NaN    NaN                NaN
# 2          NaN          NaN  NaN    NaN    NaN    NaN               True
# 3          NaN          NaN  NaN    NaN    NaN    NaN                NaN
# 4          NaN          NaN  NaN    NaN    NaN    NaN                NaN
# 5          NaN          NaN  NaN    NaN    NaN    NaN                NaN
#
#    Detetor de incêndio  Detetor de Inundução Área (m/2) Vista de mar  \
# 1                  NaN                   NaN        NaN          NaN
# 2                  NaN                   NaN        NaN          NaN
# 3                  NaN                   NaN        NaN          NaN
# 4                  NaN                   NaN        NaN          NaN
# 5                  NaN                   NaN        NaN          NaN
#
#   Património classificado Com cozinha Imóvel de banca Vista de lago  \
# 1                     NaN         NaN             NaN           NaN
# 2                     NaN         NaN             NaN           NaN
# 3                     NaN         NaN             NaN           NaN
# 4                     NaN         NaN             NaN           NaN
# 5                     NaN         NaN             NaN           NaN
#
#   Fossa séptica  Licensa de construção Acesso a veículos pesados  \
# 1           NaN                    NaN                       NaN
# 2           NaN                    NaN                       NaN
# 3           NaN                    NaN                       NaN
# 4           NaN                    NaN                       NaN
# 5           NaN                    NaN                       NaN
#
#   Área administrativa Copa Recepção Refeitório Sala de reuniões  \
# 1                 NaN  NaN      NaN        NaN              NaN
# 2                 NaN  NaN      NaN        NaN              NaN
# 3                 NaN  NaN      NaN        NaN              NaN
# 4                 NaN  NaN      NaN        NaN              NaN
# 5                 NaN  NaN      NaN        NaN              NaN
#
#   Área florestal Percurso de água Armazém Adaptado a mobilidade reduzida  \
# 1            NaN              NaN     NaN                            NaN
# 2            NaN             True     NaN                            NaN
# 3            NaN              NaN     NaN                            NaN
# 4            NaN              NaN     NaN                            NaN
# 5            NaN              NaN     NaN                            NaN
#
#   Terra batida Video vigilância  Espaço frigorífico Espaço para arrumação  \
# 1          NaN              NaN                 NaN                   NaN
# 2          NaN              NaN                 NaN                   NaN
# 3          NaN              NaN                 NaN                   NaN
# 4          NaN              NaN                 NaN                   NaN
# 5          NaN              NaN                 NaN                   NaN
#
#   Casa de banho partilhada Poço Paisagem protegida
# 1                      NaN  NaN                NaN
# 2                      NaN  NaN                NaN
# 3                      NaN  NaN                NaN
# 4                      NaN  NaN                NaN
# 5                      NaN  NaN                NaN

# %%
#data_imo_quintas.info(verbose=True, null_counts=True)

# %% [markdown]
# ## Análise exploratória de dados

# %% [markdown]
# *Distribuição da feature 'Preço'*

# %%
fig = plt.figure(figsize = (20,5))
sns.set_style('darkgrid')
data_imo_quintas['Preço'].hist(bins=30)
plt.xlabel('Preço')
# Out:
# Text(0.5, 0, 'Preço')

# %%
fig = plt.figure(figsize = (10,3))
sns.boxplot(x=data_imo_quintas['Preço'])

# %% [markdown]
# *Distribuição da feature 'Preço' - Outliers visuais*

# %%
a_excluir = data_imo_quintas[(data_imo_quintas['Preço'] >= 4000000)]
#a_excluir = data_imo_quintas[(data_imo_quintas['Preço'] >= 400000) | (data_imo_quintas['Preço'] <= 150000)]
data_imo_quintas = data_imo_quintas.drop(a_excluir.index)
data_imo_quintas.index = np.arange(1, len(data_imo_quintas) + 1)
a_excluir
# Out:
#           Id Tipo de imóvel     Preço  Preço m/2  \
# 81  10631929        Quintas  10000000         71
# 83  15036812        Quintas   4200000       2471
#
#                                            Freguesia  Rua   Latitude  \
# 81    Merelim (São Paio), Panoias e Parada de Tibães  NaN  41.579005
# 83  Escudeiros e Penso (Santo Estêvão e São Vicente)  NaN  41.481730
#
#     Longitude Tipologia Nº Casas de Banho Área útil m/2 Área bruta m/2  \
# 81  -8.476157       NaN               NaN          1816           1816
# 83  -8.429371        T6               NaN          1500           1500
#
#     Ano construção Certificado energético Armário Cozinha equipada  \
# 81             NaN                 Isento     NaN              NaN
# 83          1880.0                    NaN     NaN              NaN
#
#    Garagem box Gás canalizado Lareira Marquise Suite Varanda Vista de cidade  \
# 81         NaN            NaN     NaN      NaN   NaN     NaN             NaN
# 83         NaN            NaN    True      NaN  True     NaN             NaN
#
#    Condição Despensa Arrecadação Porta blindada Video Porteiro Empreendimento  \
# 81    Usado      NaN         NaN            NaN            NaN            NaN
# 83    Usado      NaN         NaN            NaN            NaN            NaN
#
#    Ar condicionado Elevador  Estores elétricos Fibra ótica  \
# 81             NaN      NaN                NaN         NaN
# 83            True      NaN                NaN         NaN
#
#    Pré-instalação de ar condicionado Terraço  Área de terreno m/2 Churrasco  \
# 81                               NaN     NaN                  NaN       NaN
# 83                               NaN     NaN                  NaN       NaN
#
#    Árvores de fruto Sotão Cave Jardim Aquecimento central Caldeira  \
# 81              NaN   NaN  NaN    NaN                 NaN      NaN
# 83              NaN   NaN  NaN   True                 NaN      NaN
#
#    Acessibilidade a pessoas com mobilidade condicionada  Box 2 carros  \
# 81                                                NaN             NaN
# 83                                                NaN             NaN
#
#    Detetor de gás Painéis solares Recuperação de calor Vista de campo/serra  \
# 81            NaN             NaN                  NaN                  NaN
# 83            NaN             NaN                  NaN                  NaN
#
#     Box 1 carro Portaria Estacionamento Piso radiante Som ambiente  \
# 81          NaN      NaN            NaN           NaN          NaN
# 83          NaN      NaN            NaN           NaN          NaN
#
#    Aspiração central Finalidade Tipo de terreno Acesso pavimentado Asfaltado  \
# 81               NaN        NaN             NaN                NaN       NaN
# 83               NaN        NaN             NaN                NaN       NaN
#
#    Iluminação pública Zona arborizada Declive Ruína Alarme Furo de água  \
# 81                NaN             NaN     NaN   NaN    NaN          NaN
# 83                NaN             NaN     NaN   NaN    NaN          NaN
#
#    Domótica  Casa das máquinas Condomínio Fechado Parque infantil Piscina  \
# 81      NaN                NaN                NaN             NaN     NaN
# 83      NaN                NaN                NaN             NaN    True
#
#    Piscina Privada Termoacumulador Garagem exterior Mobilado  \
# 81             NaN             NaN              NaN      NaN
# 83             NaN             NaN             True      NaN
#
#    Hidromassagem/jacuzzi Quintal/horta Ginásio Kitchenette  \
# 81                   NaN           NaN     NaN         NaN
# 83                   NaN           NaN     NaN         NaN
#
#    Vigilância/segurança Campo de ténis Segurança 24 horas Vedação  \
# 81                  NaN            NaN                NaN     NaN
# 83                  NaN            NaN                NaN     NaN
#
#    Parqueamento (1 carro) Ligação a rede de água  \
# 81                    NaN                    NaN
# 83                    NaN                    NaN
#
#     Ligação a rede de saneamento Ligação a rede elétrica Animais permitidos  \
# 81                           NaN                     NaN                NaN
# 83                           NaN                     NaN                NaN
#
#    Parqueamento (2 carros) Cofre Vista de rio  Nº divisões Tipo  Pisos Com WC  \
# 81                     NaN   NaN          NaN          NaN  NaN    NaN    NaN
# 83                     NaN   NaN          NaN          NaN  NaN    NaN    NaN
#
#    Montra Anexo habitacional  Detetor de incêndio  Detetor de Inundução  \
# 81    NaN                NaN                  NaN                   NaN
# 83    NaN                NaN                  NaN                   NaN
#
#    Área (m/2) Vista de mar Património classificado Com cozinha  \
# 81        NaN          NaN                     NaN         NaN
# 83        NaN          NaN                     NaN         NaN
#
#    Imóvel de banca Vista de lago Fossa séptica  Licensa de construção  \
# 81             NaN           NaN           NaN                    NaN
# 83             NaN           NaN           NaN                    NaN
#
#    Acesso a veículos pesados Área administrativa Copa Recepção Refeitório  \
# 81                       NaN                 NaN  NaN      NaN        NaN
# 83                       NaN                 NaN  NaN      NaN        NaN
#
#    Sala de reuniões Área florestal Percurso de água Armazém  \
# 81              NaN            NaN              NaN     NaN
# 83              NaN            NaN              NaN     NaN
#
#    Adaptado a mobilidade reduzida Terra batida Video vigilância  \
# 81                            NaN          NaN              NaN
# 83                            NaN          NaN              NaN
#
#     Espaço frigorífico Espaço para arrumação Casa de banho partilhada Poço  \
# 81                 NaN                   NaN                      NaN  NaN
# 83                 NaN                   NaN                      NaN  NaN
#
#    Paisagem protegida
# 81                NaN
# 83                NaN

# %% [markdown]
# *Relação entre o Preço e outras variáveis*

# %%
fig = plt.figure(figsize = (30,15))

ax1 = fig.add_subplot(2,3,1)
ax1.scatter(data_imo_quintas['Área útil m/2'], data_imo_quintas['Preço'])
ax1.set_xlabel('Área útil')
ax1.set_ylabel('Preço')
# Out:
# Text(0, 0.5, 'Preço')

# %% [markdown]
# *Relação entre o Preço e Área útil - Outliers visuais*

# %%
a_excluir = data_imo_quintas[(data_imo_quintas['Área útil m/2'] >= 25000)]
data_imo_quintas = data_imo_quintas.drop(a_excluir.index)
data_imo_quintas.index = np.arange(1, len(data_imo_quintas) + 1)
a_excluir
# Out:
#           Id Tipo de imóvel   Preço  Preço m/2 Freguesia  Rua   Latitude  \
# 13  14835628        Quintas  525000         16    Adaúfe  NaN  41.584698
# 77   8672617        Quintas  445000         17    Adaúfe  NaN  41.598200
#
#     Longitude Tipologia Nº Casas de Banho Área útil m/2 Área bruta m/2  \
# 13  -8.402739       NaN               NaN         32010            NaN
# 77  -8.402237       NaN               NaN         26361          26361
#
#     Ano construção Certificado energético Armário Cozinha equipada  \
# 13             NaN                    NaN     NaN              NaN
# 77             NaN                    NaN     NaN              NaN
#
#    Garagem box Gás canalizado Lareira Marquise Suite Varanda Vista de cidade  \
# 13         NaN            NaN     NaN      NaN   NaN     NaN             NaN
# 77         NaN            NaN     NaN      NaN   NaN     NaN             NaN
#
#           Condição Despensa Arrecadação Porta blindada Video Porteiro  \
# 13             NaN      NaN         NaN            NaN            NaN
# 77  Para recuperar      NaN         NaN            NaN            NaN
#
#    Empreendimento Ar condicionado Elevador  Estores elétricos Fibra ótica  \
# 13            NaN             NaN      NaN                NaN         NaN
# 77            NaN             NaN      NaN                NaN         NaN
#
#    Pré-instalação de ar condicionado Terraço  Área de terreno m/2 Churrasco  \
# 13                               NaN     NaN                  NaN       NaN
# 77                               NaN     NaN                  NaN       NaN
#
#    Árvores de fruto Sotão Cave Jardim Aquecimento central Caldeira  \
# 13              NaN   NaN  NaN    NaN                 NaN      NaN
# 77              NaN   NaN  NaN    NaN                 NaN      NaN
#
#    Acessibilidade a pessoas com mobilidade condicionada  Box 2 carros  \
# 13                                                NaN             NaN
# 77                                                NaN             NaN
#
#    Detetor de gás Painéis solares Recuperação de calor Vista de campo/serra  \
# 13            NaN             NaN                  NaN                  NaN
# 77            NaN             NaN                  NaN                  NaN
#
#     Box 1 carro Portaria Estacionamento Piso radiante Som ambiente  \
# 13          NaN      NaN            NaN           NaN          NaN
# 77          NaN      NaN            NaN           NaN          NaN
#
#    Aspiração central Finalidade Tipo de terreno Acesso pavimentado Asfaltado  \
# 13               NaN        NaN             NaN                NaN       NaN
# 77               NaN        NaN             NaN                NaN       NaN
#
#    Iluminação pública Zona arborizada Declive Ruína Alarme Furo de água  \
# 13                NaN             NaN     NaN   NaN    NaN          NaN
# 77                NaN             NaN     NaN   NaN    NaN          NaN
#
#    Domótica  Casa das máquinas Condomínio Fechado Parque infantil Piscina  \
# 13      NaN                NaN                NaN             NaN     NaN
# 77      NaN                NaN                NaN             NaN     NaN
#
#    Piscina Privada Termoacumulador Garagem exterior Mobilado  \
# 13             NaN             NaN              NaN      NaN
# 77             NaN             NaN              NaN      NaN
#
#    Hidromassagem/jacuzzi Quintal/horta Ginásio Kitchenette  \
# 13                   NaN           NaN     NaN         NaN
# 77                   NaN           NaN     NaN         NaN
#
#    Vigilância/segurança Campo de ténis Segurança 24 horas Vedação  \
# 13                  NaN            NaN                NaN     NaN
# 77                  NaN            NaN                NaN     NaN
#
#    Parqueamento (1 carro) Ligação a rede de água  \
# 13                    NaN                    NaN
# 77                    NaN                    NaN
#
#     Ligação a rede de saneamento Ligação a rede elétrica Animais permitidos  \
# 13                           NaN                     NaN                NaN
# 77                           NaN                     NaN                NaN
#
#    Parqueamento (2 carros) Cofre Vista de rio  Nº divisões Tipo  Pisos Com WC  \
# 13                     NaN   NaN          NaN          NaN  NaN    NaN    NaN
# 77                     NaN   NaN          NaN          NaN  NaN    NaN    NaN
#
#    Montra Anexo habitacional  Detetor de incêndio  Detetor de Inundução  \
# 13    NaN                NaN                  NaN                   NaN
# 77    NaN                NaN                  NaN                   NaN
#
#    Área (m/2) Vista de mar Património classificado Com cozinha  \
# 13        NaN          NaN                     NaN         NaN
# 77        NaN          NaN                     NaN         NaN
#
#    Imóvel de banca Vista de lago Fossa séptica  Licensa de construção  \
# 13             NaN           NaN           NaN                    NaN
# 77             NaN           NaN           NaN                    NaN
#
#    Acesso a veículos pesados Área administrativa Copa Recepção Refeitório  \
# 13                       NaN                 NaN  NaN      NaN        NaN
# 77                       NaN                 NaN  NaN      NaN        NaN
#
#    Sala de reuniões Área florestal Percurso de água Armazém  \
# 13              NaN            NaN              NaN     NaN
# 77              NaN            NaN              NaN     NaN
#
#    Adaptado a mobilidade reduzida Terra batida Video vigilância  \
# 13                            NaN          NaN              NaN
# 77                            NaN          NaN              NaN
#
#     Espaço frigorífico Espaço para arrumação Casa de banho partilhada Poço  \
# 13                 NaN                   NaN                      NaN  NaN
# 77                 NaN                   NaN                      NaN  NaN
#
#    Paisagem protegida
# 13                NaN
# 77                NaN

# %% [markdown]
# *Relacionamento do 'Preço' com outras features categóricas importantes*

# %%
cat_data = data_imo_quintas[['Freguesia']]

# %%
for cat in cat_data.dtypes[:10].index.values:
    plt.figure(figsize=(20, 8))
    plt.xticks(rotation=90)
    sns.boxplot(x=cat, y='Preço', data=data_imo_quintas) 
    sns.swarmplot(x=cat, y='Preço', data=data_imo_quintas)
    plt.show()

# %% [markdown]
# **Dados em falta por coluna**

# %%
pd.set_option('display.max_rows', None)
percent_missing = data_imo_quintas.isnull().sum() * 100 / len(data_imo_quintas)
missing_value_data_imo_quintas_columns = pd.DataFrame({'percent_missing (%)': percent_missing})
sort_data = missing_value_data_imo_quintas_columns.copy()
sort_data.sort_values('percent_missing (%)', inplace=True, ascending=False)
sort_data
# Out:
#                                                     percent_missing (%)
# Declive                                                      100.000000
# Kitchenette                                                  100.000000
# Tipo                                                         100.000000
# Nº divisões                                                  100.000000
# Vista de rio                                                 100.000000
# Cofre                                                        100.000000
# Parqueamento (2 carros)                                      100.000000
# Animais permitidos                                           100.000000
# Ligação a rede de saneamento                                 100.000000
# Ligação a rede de água                                       100.000000
# Parqueamento (1 carro)                                       100.000000
# Campo de ténis                                               100.000000
# Vigilância/segurança                                         100.000000
# Ginásio                                                      100.000000
# Finalidade                                                   100.000000
# Quintal/horta                                                100.000000
# Hidromassagem/jacuzzi                                        100.000000
# Mobilado                                                     100.000000
# Termoacumulador                                              100.000000
# Piscina Privada                                              100.000000
# Parque infantil                                              100.000000
# Condomínio Fechado                                           100.000000
# Casa das máquinas                                            100.000000
# Domótica                                                     100.000000
# Iluminação pública                                           100.000000
# Asfaltado                                                    100.000000
# Pisos                                                        100.000000
# Com WC                                                       100.000000
# Montra                                                       100.000000
# Detetor de incêndio                                          100.000000
# Casa de banho partilhada                                     100.000000
# Espaço para arrumação                                        100.000000
# Espaço frigorífico                                           100.000000
# Video vigilância                                             100.000000
# Terra batida                                                 100.000000
# Adaptado a mobilidade reduzida                               100.000000
# Armazém                                                      100.000000
# Área florestal                                               100.000000
# Sala de reuniões                                             100.000000
# Refeitório                                                   100.000000
# Recepção                                                     100.000000
# Copa                                                         100.000000
# Área administrativa                                          100.000000
# Acesso a veículos pesados                                    100.000000
# Licensa de construção                                        100.000000
# Fossa séptica                                                100.000000
# Vista de lago                                                100.000000
# Imóvel de banca                                              100.000000
# Com cozinha                                                  100.000000
# Património classificado                                      100.000000
# Vista de mar                                                 100.000000
# Área (m/2)                                                   100.000000
# Detetor de Inundução                                         100.000000
# Tipo de terreno                                              100.000000
# Paisagem protegida                                           100.000000
# Aspiração central                                            100.000000
# Acessibilidade a pessoas com mobilidade condici...           100.000000
# Área de terreno m/2                                          100.000000
# Terraço                                                      100.000000
# Fibra ótica                                                  100.000000
# Som ambiente                                                 100.000000
# Elevador                                                     100.000000
# Empreendimento                                               100.000000
# Porta blindada                                               100.000000
# Arrecadação                                                  100.000000
# Despensa                                                     100.000000
# Varanda                                                      100.000000
# Marquise                                                     100.000000
# Gás canalizado                                               100.000000
# Garagem box                                                  100.000000
# Cozinha equipada                                             100.000000
# Nº Casas de Banho                                            100.000000
# Sotão                                                        100.000000
# Estores elétricos                                            100.000000
# Box 2 carros                                                 100.000000
# Detetor de gás                                               100.000000
# Piso radiante                                                100.000000
# Box 1 carro                                                  100.000000
# Vista de campo/serra                                         100.000000
# Painéis solares                                              100.000000
# Portaria                                                     100.000000
# Caldeira                                                      98.863636
# Alarme                                                        98.863636
# Acesso pavimentado                                            98.863636
# Segurança 24 horas                                            98.863636
# Ligação a rede elétrica                                       98.863636
# Garagem exterior                                              98.863636
# Pré-instalação de ar condicionado                             98.863636
# Armário                                                       98.863636
# Recuperação de calor                                          98.863636
# Cave                                                          98.863636
# Estacionamento                                                98.863636
# Poço                                                          98.863636
# Video Porteiro                                                98.863636
# Ruína                                                         98.863636
# Furo de água                                                  98.863636
# Suite                                                         97.727273
# Vedação                                                       97.727273
# Churrasco                                                     97.727273
# Zona arborizada                                               96.590909
# Ar condicionado                                               96.590909
# Aquecimento central                                           95.454545
# Percurso de água                                              95.454545
# Piscina                                                       94.318182
# Árvores de fruto                                              94.318182
# Anexo habitacional                                            94.318182
# Rua                                                           93.181818
# Vista de cidade                                               90.909091
# Lareira                                                       89.772727
# Jardim                                                        89.772727
# Ano construção                                                68.181818
# Certificado energético                                        63.636364
# Tipologia                                                     60.227273
# Área bruta m/2                                                48.863636
# Área útil m/2                                                 34.090909
# Condição                                                      26.136364
# Latitude                                                       0.000000
# Longitude                                                      0.000000
# Freguesia                                                      0.000000
# Preço m/2                                                      0.000000
# Preço                                                          0.000000
# Tipo de imóvel                                                 0.000000
# Id                                                             0.000000

# %%
pd.set_option('display.max_rows', 10)

# %% [markdown]
# **Remover colunas que tenham mais de 30% (?) de missing values**

# %%
a_manter = list(missing_value_data_imo_quintas_columns.index[missing_value_data_imo_quintas_columns['percent_missing (%)'] < 30])
data_imo_quintas = data_imo_quintas[a_manter]
data_imo_quintas
# Out:
#           Id Tipo de imóvel    Preço  Preço m/2  \
# 1   14773461        Quintas   285000         71
# 2   15293372        Quintas  1800000         33
# 3   15147059        Quintas  1800000       6977
# 4   15235231        Quintas  2000000        364
# 5   15234875        Quintas   110000         55
# ..       ...            ...      ...        ...
# 84  15201040        Quintas   190000         27
# 85  15479862        Quintas   950000        397
# 86   6683850        Quintas  1500000        150
# 87  14785899        Quintas   850000         51
# 88  15228182        Quintas   300000         20
#
#                                            Freguesia   Latitude  Longitude  \
# 1                                           Palmeira  41.590424  -8.426242
# 2   Escudeiros e Penso (Santo Estêvão e São Vicente)  41.477932  -8.426478
# 3   Escudeiros e Penso (Santo Estêvão e São Vicente)  41.475043  -8.432176
# 4                                        São Vicente  41.554339  -8.427382
# 5   Escudeiros e Penso (Santo Estêvão e São Vicente)  41.477688  -8.426569
# ..                                               ...        ...        ...
# 84                                    Padim da Graça  41.556538  -8.509524
# 85                                           Gualtar  41.572156  -8.379372
# 86                           Ferreiros e Gondizalves  41.534685  -8.439408
# 87                           Ferreiros e Gondizalves  41.531691  -8.439698
# 88               Santa Lucrécia de Algeriz e Navarra  41.592976  -8.373467
#
#           Condição
# 1   Para recuperar
# 2            Usado
# 3            Usado
# 4            Usado
# 5              NaN
# ..             ...
# 84             NaN
# 85             NaN
# 86             NaN
# 87           Usado
# 88             NaN
#
# [88 rows x 8 columns]

# %% [markdown]
# **Dados em falta por linha**

# %%
percent_missing = (1 - data_imo_quintas.apply(lambda x: x.count(), axis=1) / len(data_imo_quintas.columns)) * 100
missing_value_data_imo_quintas_rows = pd.DataFrame({'percent_missing (%)': percent_missing})
sort_data = missing_value_data_imo_quintas_rows.copy()
sort_data.sort_values('percent_missing (%)', inplace=True, ascending=False)
sort_data
# Out:
#     percent_missing (%)
# 88                 12.5
# 79                 12.5
# 62                 12.5
# 69                 12.5
# 59                 12.5
# ..                  ...
# 34                  0.0
# 33                  0.0
# 31                  0.0
# 30                  0.0
# 45                  0.0
#
# [88 rows x 1 columns]

# %% [markdown]
# **Remover linhas com percentagem de dados em falta superior a 50%**

# %%
a_excluir = missing_value_data_imo_quintas_rows[(missing_value_data_imo_quintas_rows['percent_missing (%)'] >= 50)]
data_imo_quintas = data_imo_quintas.drop(a_excluir.index)
data_imo_quintas.index = np.arange(1, len(data_imo_quintas) + 1)

# %% [markdown]
# **Inserir dados em falta**

# %%
for x in data_imo_quintas.select_dtypes(include=['float64']).columns.tolist():
    median_value=data_imo_quintas[x].median()
    data_imo_quintas[x]=data_imo_quintas[x].fillna(median_value)

for y in data_imo_quintas.select_dtypes(include=['object']).columns.tolist():
    mode_value=data_imo_quintas[y].mode()
    data_imo_quintas[y]=data_imo_quintas[y].fillna(mode_value[0])    
    
data_imo_quintas
# Out:
#           Id Tipo de imóvel    Preço  Preço m/2  \
# 1   14773461        Quintas   285000         71
# 2   15293372        Quintas  1800000         33
# 3   15147059        Quintas  1800000       6977
# 4   15235231        Quintas  2000000        364
# 5   15234875        Quintas   110000         55
# ..       ...            ...      ...        ...
# 84  15201040        Quintas   190000         27
# 85  15479862        Quintas   950000        397
# 86   6683850        Quintas  1500000        150
# 87  14785899        Quintas   850000         51
# 88  15228182        Quintas   300000         20
#
#                                            Freguesia   Latitude  Longitude  \
# 1                                           Palmeira  41.590424  -8.426242
# 2   Escudeiros e Penso (Santo Estêvão e São Vicente)  41.477932  -8.426478
# 3   Escudeiros e Penso (Santo Estêvão e São Vicente)  41.475043  -8.432176
# 4                                        São Vicente  41.554339  -8.427382
# 5   Escudeiros e Penso (Santo Estêvão e São Vicente)  41.477688  -8.426569
# ..                                               ...        ...        ...
# 84                                    Padim da Graça  41.556538  -8.509524
# 85                                           Gualtar  41.572156  -8.379372
# 86                           Ferreiros e Gondizalves  41.534685  -8.439408
# 87                           Ferreiros e Gondizalves  41.531691  -8.439698
# 88               Santa Lucrécia de Algeriz e Navarra  41.592976  -8.373467
#
#           Condição
# 1   Para recuperar
# 2            Usado
# 3            Usado
# 4            Usado
# 5            Usado
# ..             ...
# 84           Usado
# 85           Usado
# 86           Usado
# 87           Usado
# 88           Usado
#
# [88 rows x 8 columns]

# %%
sns.heatmap(data_imo_quintas.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# ## Estruturação dos Dados

# %% [markdown]
# ## Inserção de dados acerca da localização do imóvel
#
# *www.google.com/maps/*

# %% [markdown]
# **Funções auxiliares**

# %%
def distance_coordinates(lat1,lon1,lat2,lon2):
    
    coords_1 = (lat1, lon1)
    coords_2 = (lat2, lon2)
    
    res = geopy.distance.geodesic(coords_1, coords_2).km

    return round(res,3)

def minDist(data_imo, values):
    distancias = []
    for index, row in data_imo.iterrows():
        min_dist = 99999999.9
        for value in values.values():
            dist = distance_coordinates(data_imo_quintas.iloc[index-1]['Latitude'],data_imo_quintas.iloc[index-1]['Longitude'],value[0],value[1])
            if dist < min_dist:
                min_dist = dist    
        distancias.append(min_dist)
    return distancias

# %% [markdown]
# **Centro da Cidade**

# %%
centro_cidade = {}
centro_cidade['Centro'] = 41.5514083,-8.4230248

# %%
data_imo_quintas['Centro Cidade (km)'] = minDist(data_imo_quintas, centro_cidade)

# %% [markdown]
# **Hospitais**

# %%
hospitais = {}
hospitais['Hospital de Braga'] = 41.5679738,-8.3990116
hospitais['Trofa Saúde - Braga Sul'] = 41.5246625,-8.4141593
hospitais['Trofa Saúde - Braga Centro'] = 41.5498965,-8.4187538
hospitais['Lusíadas Braga'] = 41.5476764,-8.4224197

# %%
data_imo_quintas['Hospitais (km)'] = minDist(data_imo_quintas, hospitais)

# %% [markdown]
# **Centros de Saúde**

# %%
centros_saude = {}
centros_saude['Braga Centro'] = 41.5471857,-8.4279198
centros_saude['Infias'] = 41.5602432,-8.4228005
centros_saude['USF do Minho'] = 41.5465815,-8.4147386
centros_saude['Clinica de Sao Marcos'] = 41.5454486,-8.426507
centros_saude['O Poverello'] = 41.5703584,-8.4114745
centros_saude['Clinica Cubana Braga'] = 41.5492599,-8.4262347
centros_saude['Clinica Médico - Cirurgica De Santa Tecla'] = 41.5489178,-8.4117642
centros_saude['Hemoatlantico - Braga'] = 41.5459355,-8.4314237
centros_saude['Centro de Vacinação Internacional'] = 41.5586578,-8.3999608
centros_saude['Clinica Enguardas'] = 41.5571581,-8.4127898
centros_saude['USF Braga Norte'] = 41.5603489,-8.4227264
centros_saude['USF Carandá'] = 41.5525337,-8.4123
centros_saude['USF Bracara Augusta'] = 41.5422297,-8.4105532
centros_saude['USF Maxisaúde'] = 41.5473324,-8.4279983
centros_saude['USF São Lourenço'] = 41.5142651,-8.4559502
centros_saude['USF São João de Braga'] = 41.5463782,-8.4145564
centros_saude['USF Manuel Rocha Peixoto'] = 41.5473003,-8.4279339
centros_saude['USF Gualtar'] = 41.5682764,-8.3871645
centros_saude['USF Saúde Oeste'] = 41.5325817,-8.4733681
centros_saude['USF Tadim'] = 41.5079792,-8.4879975
centros_saude['Gualtar'] = 41.5683003,-8.3872187
centros_saude['USF Esporões'] = 41.5120606,-8.4201814
centros_saude['USF Salutis'] = 41.5465247,-8.4147014
centros_saude['USP de Braga'] = 41.5588888,-8.3998833

# %%
data_imo_quintas['Centros Saúde (km)'] = minDist(data_imo_quintas, centros_saude)

# %% [markdown]
# **Centros Comerciais**

# %%
centroscomerciais = {}
centroscomerciais['Braga Parque'] = 41.5577669,-8.4060603
centroscomerciais['Minho Center'] = 41.540935,-8.400464
centroscomerciais['Nova Arcada'] = 41.579068,-8.429654

# %%
data_imo_quintas['Centro Comerciais (km)'] = minDist(data_imo_quintas, centroscomerciais)

# %% [markdown]
# **Escolas**

# %%
escolas = {}
escolas['Secundária Sá de Miranda'] = 41.5568137,-8.4182525
escolas['Básica Francisco Sanches'] = 41.5548131,-8.4118978
escolas['Básica de Gualtar'] = 41.5669867,-8.38796
escolas['Básica de Lamaçães'] = 41.5471216,-8.4016327
escolas['Secundária Carlos Amarante'] = 41.5509961,-8.413909
escolas['Básica de Palmeira'] = 41.5771831,-8.4245399
escolas['Secundária de Maximinos'] = 41.5424538,-8.4415713
escolas['Básica André Soares'] = 41.5470115,-8.415924
escolas['Básica do 1º Ciclo de São Vitor'] = 41.55186,-8.4129202
escolas['Básica de Real'] = 41.5577824,-8.4395854
escolas['Jardim Escola João de Deus'] = 41.5447436,-8.407904
escolas['Colégio Luso Internacional de Braga'] = 41.56979,-8.3885487
escolas['EB1 Quinta da Veiga'] = 41.5590263,-8.4239226
escolas['Secundária D. Maria II'] = 41.5487484,-8.4177364
escolas['Básica Bairro da Misericórdia'] = 41.5578043,-8.4262862
escolas['EB1 Carandá'] = 41.5452545,-8.4156397
escolas['Colégio Dom Diogo de Sousa'] = 41.5575,-8.415931
escolas['Centro Escolar Ponte Pedrinha'] = 41.5403601,-8.4294783
escolas['EB1/J1 Bairro da Alegria'] = 41.5638599,-8.402921

# %%
data_imo_quintas['Escolas (km)'] = minDist(data_imo_quintas, escolas)

# %% [markdown]
# **Universidades**

# %%
universidades = {}
universidades['Universidade do Minho - Campus de Gualtar'] = 41.5607319,-8.3962368
universidades['IPCA - Pólo de Braga'] = 41.5421121,-8.4210972
universidades['Universidade Católica Portuguesa'] = 41.554852,-8.4209143

# %%
data_imo_quintas['Universidades (km)'] = minDist(data_imo_quintas, universidades)

# %% [markdown]
# **Estação de Comboios**

# %%
estacao = {}
estacao['Estacao'] = 41.548143,-8.4344431

# %%
data_imo_quintas['Estação de Comboios (km)'] = minDist(data_imo_quintas, estacao)

# %% [markdown]
# **Parques Industriais**
#
# *www.igogo.pt/parques-industriais-braga/*

# %%
parques_industriais = {}
parques_industriais['Frossos'] = 41.5595545,-8.447319
parques_industriais['Quinta do Carreiro'] = 41.5653531,-8.4454561
parques_industriais['Adaúfe'] = 41.5974779,-8.4135554
parques_industriais['Celeirós'] = 41.5109663,-8.454419
parques_industriais['Marvilha'] = 41.5318363,-8.4735374
parques_industriais['Mire de Tibães'] = 41.5819656,-8.4767172
parques_industriais['Padim da Graça'] = 41.5692605,-8.4890601
parques_industriais['Pitancinhos'] = 41.5840245,-8.4219733
parques_industriais['Vilça'] = 41.5154222,-8.4937553

# %%
data_imo_quintas['Parques Industriais (km)'] = minDist(data_imo_quintas, parques_industriais)

# %% [markdown]
# **Central de Autocarros**

# %%
central_autocarros = {}
central_autocarros['Central'] = 41.555324,-8.425410

# %%
data_imo_quintas['Central Autocarros (km)'] = minDist(data_imo_quintas, central_autocarros)

# %% [markdown]
# **Bancos**

# %%
bancos = {}
bancos['BPI Frossos'] = 41.561298,-8.447379
bancos['BPI Gualtar'] = 41.5647823,-8.3876109
bancos['Crédito Agrícola Braga'] = 41.5514726,-8.4278259
bancos['Activo Bank'] = 41.5521836,-8.4267081
bancos['Banif Centro'] = 41.5524396,-8.4236611
bancos['Banco de Portugal'] = 41.5518264,-8.4234077
bancos['Montepio Centro'] = 41.5517009,-8.4180607
bancos['Montepio Centro 2'] = 41.5507289,-8.4250391
bancos['Novo Banco Centro'] = 41.5507776,-8.4238804
bancos['Banco de Investimento Global'] = 41.5495727,-8.4251216
bancos['Novo Banco Centro 2'] = 41.5492902,-8.4121129
bancos['Banco Millenium BCP São Lázaro'] = 41.5475307,-8.4210104
bancos['BBVA São Lázaro'] = 41.5464477,-8.4199778
bancos['Santander Totta Lamaçães'] = 41.5479773,-8.4033012
bancos['Caixa Geral de Depósito Lamaçães'] = 41.5480627,-8.4035902
bancos['BPI Dume'] = 41.5450355,-8.4019862
bancos['Novo Banco Maximinos'] = 41.5448869,-8.4337664
bancos['Caixa Geral de Depósitos Maximinos'] = 41.547196,-8.4338421
bancos['BPI N14'] = 41.53774,-8.434457

# %%
data_imo_quintas['Bancos (km)'] = minDist(data_imo_quintas, bancos)

# %% [markdown]
# **Correios**

# %%
correios = {}
correios['CTT Maximinos'] = 41.5444322,-8.4340695
correios['CTT São Lázaro'] = 41.544917,-8.420586
correios['CTT Fonte Seca'] = 41.535935,-8.4016483
correios['CTT 25 de Abril'] = 41.5474966,-8.4204056
correios['Estação de Correios de Santa Tecla'] = 41.5484275,-8.4118152
correios['CTT Nogueira, Fraiões e Lamaçães'] = 41.5480095,-8.4040274
correios['Posto de Correios de Braga (São José de Lázaro)'] = 41.5497985,-8.4193059
correios['CTT Largo de São Francisco'] = 41.5518429,-8.423987
correios['CTT Braga Parque'] = 41.556725,-8.4056481
correios['CTT Largo de Infias'] = 41.5579778,-8.4165392

# %%
data_imo_quintas['Correios (km)'] = minDist(data_imo_quintas, correios)

# %% [markdown]
# **Parques e zonas verdes**

# %%
parques_lazer = {}
parques_lazer['Parque de Lazer de Gerizes'] = 41.5835983,-8.449529
parques_lazer['Parque da Rodovia'] = 41.552828,-8.4031463
parques_lazer['Jardim da Avenida Central'] = 41.551519,-8.421523
parques_lazer['Parque São João da Ponte'] = 41.5454706,-8.4265083
parques_lazer['Parque da Ponte'] = 41.541304, -8.419441
parques_lazer['Parque de Lazer da Rampa da Falperra'] = 41.5309717,-8.3944834
parques_lazer['Parque de Lazer do Ribeiro dos Prados'] = 41.5052344,-8.4422877

# %%
data_imo_quintas['Parques e Zonas Verdes (km)'] = minDist(data_imo_quintas, parques_lazer)

# %% [markdown]
# **Serviços Públicos**
#
# *https://eportugal.gov.pt/locais-de-atendimento-de-servicos-publicos/-/pesquisa/search_stores*

# %%
servicos_publicos = {}
servicos_publicos['Finanças 1'] = 41.5498747,-8.4194008
servicos_publicos['Finanças 2'] = 41.5440114,-8.4358346
servicos_publicos['Segurança Social'] = 41.5477731,-8.4129363
servicos_publicos['Serviços de RSI'] = 41.5424794,-8.4360436
servicos_publicos['Gabinete de Atendimento ao Cidadão'] = 41.5561192,-8.4121799
servicos_publicos['Conservatória do Registo Civil'] = 41.5518773,-8.4222603
servicos_publicos['IEFP - Centro de Emprego'] = 41.5423426,-8.4339527
servicos_publicos['SEF - Loja do Cidadão de Braga'] = 41.5474961,-8.421969
servicos_publicos['Espaço Cidadão Sobreposta'] = 41.547783,-8.3619992
servicos_publicos['Espaço Cidadão Adaúfe'] = 41.5861605,-8.3926854
servicos_publicos['Espaço Cidadão Figueiredo'] = 41.5048946,-8.4349509
servicos_publicos['Espaço Cidadão Real'] = 41.5575145,-8.4440584
servicos_publicos['Espaço Cidadão S. Vicente'] = 41.5565553,-8.4241112
servicos_publicos['Espaço Cidadão Sequeira'] = 41.5323623,-8.4732977
servicos_publicos['Espaço Cidadão Tadim'] = 41.5057871,-8.4916939

# %%
data_imo_quintas['Serviços Públicos (km)'] = minDist(data_imo_quintas, servicos_publicos)

# %% [markdown]
# **Policia Municipal**

# %%
policia = {}
policia['Policia'] = 41.5495054,-8.4267993

# %%
data_imo_quintas['Policia Municipal (km)'] = minDist(data_imo_quintas, policia)

# %% [markdown]
# **Farmácias**
#
# *https://portalnacional.com.pt/braga/braga/farmacias/*

# %%
farmacias = {}
farmacias['Adaúfe'] = 41.5858796,-8.4020402
farmacias['Alvim - Merelim (São Pedro) e Frossos'] = 41.5595977,8.4479227
farmacias['Araújo Rodrigues - Celeirós'] = 41.5129219,-8.4503908
farmacias['Beatriz - São Vitor'] = 41.5492671,-8.4133199
farmacias['Braga - São Vitor'] = 41.5511534,-8.4064856
farmacias['Brito - São José de São Lázaro e São João do Souto'] = 41.5505688,-8.4228146
farmacias['Carmo - Merelim (São Pedro) e Frossos'] = 41.5716977,-8.45249
farmacias['Central - São José de São Lázaro e São João do Souto'] = 41.551847,-8.4250035
farmacias['Coelho - Maximinos, Sé e Cividade'] = 41.5514527,-8.4280069
farmacias['Cristal - São José de São Lázaro'] = 41.5486228,-8.4216631
farmacias['Santa Casa da Misericórdia - São José de São Lázaro e São João do Souto'] = 41.5490779,-8.4232058
farmacias['Esporões'] = 41.5119635,-8.4203129
farmacias['Gualtar'] = 41.565306,-8.3872187
farmacias['Lamaçães'] = 41.547976,-8.4012761
farmacias['Lomar'] = 41.5307238,-8.427394
farmacias['Henriquina - São Vitor'] = 41.5524657,-8.4139864
farmacias['Lima - São José de São Lázaro e São João do Souto'] = 41.5536114,-8.4235402
farmacias['Loureiro Basto - Palmeira'] = 41.5905331,-8.4295469
farmacias['Marques - São José de São Lázaro e São João do Souto'] = 41.550423,-8.423677
farmacias['Martins - São José de São Lázaro e São João do Souto'] = 41.5510726,-8.4223516
farmacias['Narcisa C. Dias - Veiga do Penso, Escudeiros e Penso'] = 41.4868491,-8.4292978
farmacias['Nova de Nogueira - Nogueira'] = 41.5304337,-8.4102638
farmacias['Nuno Barros - Real'] = 41.554171,-8.438716
farmacias['Oliveira - Ferreiros'] = 41.5345909,-8.4400511
farmacias['Osório - Ruães'] = 41.5808657,-8.4758667
farmacias['Pimenta - Cabreiros'] = 41.5334211,-8.4965154
farmacias['Farmácia Pimentel - Sao Vitor'] = 41.557452,-8.408761
farmacias['Farmácia Pinheiro - Maximinos, Sé e Cividadee'] = 41.5456516,-8.4334375
farmacias['Farmácia Pipa - Nogueira, Fraião e Lamaçães'] = 41.5435379,-8.3995875
farmacias['Farmácia Rodrigues - Maximinos, Sé e Cividade'] = 41.5503813,-8.4287748
farmacias['Farmácia Roma - São José de São Lázaro e São João do Souto'] = 41.5532189,-8.4237785
farmacias['Farmácia Santos - São Vicente'] = 41.5566642,-8.4197066
farmacias['Farmácia Santos da Cunha - Maximinos, Sé e Cividade'] = 41.5417512,-8.4298574
farmacias['Farmácia São João - São José de São Lázaro e São João do Souto'] = 41.5450471,-8.4196004
farmacias['Farmácia Silva - São Vítor'] = 41.551804,-8.4174405
farmacias['Farmácia Sousa Gomes - Maximinos, Sé e Cividade'] = 41.5512345,-8.4288927
farmacias['Farmácia Tebosa - Laião-Tebosa'] = 41.4863814,-8.4758655
farmacias['Farmácia Vidal - Tadim'] = 41.5078378,-8.4869193

# %%
data_imo_quintas['Farmácias (km)'] = minDist(data_imo_quintas, farmacias)

# %% [markdown]
# **Outliers (Localização do imóvel errada)**

# %%
a_excluir = data_imo_quintas[(data_imo_quintas['Centro Cidade (km)'] >= 30)]
data_imo_quintas = data_imo_quintas.drop(a_excluir.index)
data_imo_quintas.index = np.arange(1, len(data_imo_quintas) + 1)
#a_excluir

# %% [markdown]
# **Retirar identificadores**

# %%
data_imo_quintas = data_imo_quintas.drop(columns=['Preço m/2','Tipo de imóvel','Longitude','Latitude'])

# %% [markdown]
# ### Outliers Visuais

# %% [markdown]
# *Preço*

# %%
fig = plt.figure(figsize = (20,5))
sns.set_style('darkgrid')
data_imo_quintas['Preço'].hist(bins=30)
plt.xlabel('Preço')
# Out:
# Text(0.5, 0, 'Preço')

# %%
fig = plt.figure(figsize = (10,3))
sns.boxplot(x=data_imo_quintas['Preço'])

# %%
a_excluir = data_imo_quintas[(data_imo_quintas['Preço'] >= 2000000)]
data_imo_quintas = data_imo_quintas.drop(a_excluir.index)
data_imo_quintas.index = np.arange(1, len(data_imo_quintas) + 1)
a_excluir.shape
# Out:
# (9, 19)

# %% [markdown]
# *Condição*

# %%
sns.jointplot(data_imo_quintas['Condição'], data_imo_quintas['Preço'], kind='reg')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-00976981d51e> in <module>
# ----> 1 sns.jointplot(data_imo_quintas['Condição'], data_imo_quintas['Preço'], kind='reg')
#
# ~\Anaconda3\envs\LEI\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2330
#    2331         marginal_kws.setdefault("color", color)
# -> 2332         grid.plot_marginals(distplot, **marginal_kws)
#    2333
#    2334         joint_kws.setdefault("color", color)
#
# ~\Anaconda3\envs\LEI\lib\site-packages\seaborn\axisgrid.py in plot_marginals(self, func, **kwargs)
#    1808         kwargs["vertical"] = False
#    1809         plt.sca(self.ax_marg_x)
# -> 1810         func(self.x, **kwargs)
#    1811
#    1812         kwargs["vertical"] = True
#
# ~\Anaconda3\envs\LEI\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     177
#     178     # Make a a 1-d float array
# --> 179     a = np.asarray(a, np.float)
#     180     if a.ndim > 1:
#     181         a = a.squeeze()
#
# ~\Anaconda3\envs\LEI\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'Para recuperar'

# %%
a_excluir = data_imo_quintas[(data_imo_quintas['Área útil m/2'] >= 800)]
data_imo_quintas = data_imo_quintas.drop(a_excluir.index)
data_imo_quintas.index = np.arange(1, len(data_imo_quintas) + 1)
a_excluir.shape
# Out:
# (32, 20)

# %%
data_imo_quintas = data_imo_quintas.drop(data_imo_quintas[(data_imo_quintas['Área útil m/2']>500) & (data_imo_quintas['Preço']<100000)].index).reset_index(drop=True)

# %% [markdown]
# *Freguesia*

# %%
plt.figure(figsize=(20, 8))
plt.xticks(rotation=90)
sns.boxplot(data_imo_quintas['Freguesia'], data_imo_quintas['Preço'])
sns.swarmplot(data_imo_quintas['Freguesia'], data_imo_quintas['Preço'])
plt.show()

# %% [markdown]
# *Tipologia*

# %%
plt.figure(figsize=(20, 8))
sns.boxplot(data_imo_quintas['Tipologia'], data_imo_quintas['Preço'], order=['T0','T1','T2','T3','T4','T5','T6','T7','T8','T9','T10 ou superior'])
sns.swarmplot(data_imo_quintas['Tipologia'], data_imo_quintas['Preço'], order=['T0','T1','T2','T3','T4','T5','T6','T7','T8','T9','T10 ou superior'])
plt.show()

# %%
a_excluir = data_imo_quintas[(data_imo_quintas['Tipologia'] == 'T0') | (data_imo_quintas['Tipologia'] == 'T7') | (data_imo_quintas['Tipologia'] == 'T8') | (data_imo_quintas['Tipologia'] == 'T9') | (data_imo_quintas['Tipologia'] == 'T10 ou superior')]
data_imo_quintas = data_imo_quintas.drop(a_excluir.index)
data_imo_quintas.index = np.arange(1, len(data_imo_quintas) + 1)
a_excluir
# Out:
#             Id   Preço                                       Freguesia  \
# 0     14698254  149500                Braga (Maximinos, Sé e Cividade)
# 45    14421247  165000                                        Palmeira
# 145   14927162  105000                   Merelim (São Pedro) e Frossos
# 148   15350558  129900  Merelim (São Paio), Panoias e Parada de Tibães
# 184   14968843  325000                            Real, Dume e Semelhe
# ...        ...     ...                                             ...
# 1516  15255680   42500                               Crespos e Pousada
# 1557  10219711   35500                 Guisande e Oliveira (São Pedro)
# 1597  15359419  214000                               Nogueiró e Tenões
# 1598  15359398  199000                   Este (São Pedro e São Mamede)
# 1739  10796464  120000                     Nogueira, Fraião e Lamaçães
#
#      Tipologia  Área útil m/2  Centro Cidade (km)  Hospitais (km)  \
# 0           T0          100.0                0.80            0.77
# 45          T0           48.0                0.20            0.27
# 145         T0          282.0                0.24            0.22
# 148         T7          319.0                0.28            0.26
# 184         T8          160.3                0.51            0.45
# ...        ...            ...                 ...             ...
# 1516        T0          279.0                0.13            0.19
# 1557        T0           48.0                0.12            0.16
# 1597        T0          232.0                0.33            0.47
# 1598        T0          212.0                0.22            0.39
# 1739        T0          160.0                0.36            2.71
#
#       Centros Saúde (km)  Centro Comerciais (km)  Escolas (km)  \
# 0                   1.51                    0.36          1.18
# 45                  0.32                    0.47          0.45
# 145                 0.29                    0.50          0.41
# 148                 0.30                    0.31          0.49
# 184                 0.57                    0.38          2.29
# ...                  ...                     ...           ...
# 1516                0.22                    0.16          0.22
# 1557                0.27                    0.12          0.14
# 1597                0.72                    0.61          0.74
# 1598                0.62                    0.32          0.62
# 1739                0.62                    0.46          0.55
#
#       Universidades (km)  Estação de Comboios (km)  Parques Industriais (km)  \
# 0                   0.66                      3.17                      0.73
# 45                  0.22                      0.18                      1.51
# 145                 0.25                      0.25                      0.54
# 148                 0.28                      0.34                      0.74
# 184                 0.49                      0.71                      3.85
# ...                  ...                       ...                       ...
# 1516                0.18                      0.11                      0.23
# 1557                0.13                      0.13                      0.29
# 1597                0.76                      0.25                      0.21
# 1598                0.45                      0.18                      0.20
# 1739                0.57                      0.36                      0.28
#
#       Central Autocarros (km)  Bancos (km)  Correios (km)  \
# 0                        0.83         2.40           1.55
# 45                       0.22         0.22           0.23
# 145                      0.27         0.45           0.25
# 148                      0.31         0.77           0.31
# 184                      0.61         2.44           0.57
# ...                       ...          ...            ...
# 1516                     0.13         0.20           0.15
# 1557                     0.11         0.15           0.13
# 1597                     0.30         0.68           0.66
# 1598                     0.21         0.65           0.32
# 1739                     0.31         0.54           0.59
#
#       Parques e Zonas Verdes (km)  Serviços Públicos (km)  \
# 0                            0.96                    1.57
# 45                           0.36                    0.37
# 145                          2.19                    0.37
# 148                          0.41                    0.59
# 184                          0.48                   10.53
# ...                           ...                     ...
# 1516                         0.15                    0.30
# 1557                         0.31                    0.28
# 1597                         0.71                    0.48
# 1598                         0.33                    0.56
# 1739                         0.61                    0.45
#
#       Policia Municipal (km)  Farmácias (km)
# 0                       1.10            1.92
# 45                      0.19            1.01
# 145                     0.24            0.98
# 148                     0.30            0.85
# 184                     0.56            1.48
# ...                      ...             ...
# 1516                    0.12            0.25
# 1557                    0.12            0.77
# 1597                    0.30            0.77
# 1598                    0.20            0.66
# 1739                    0.38            1.32
#
# [27 rows x 20 columns]

# %% [markdown]
# ### Encoding Str -> Int

# %%
data_imo_quintas_mlp = data_imo_quintas.copy()
data_imo_quintas = data_imo_quintas.drop(columns=['Id'])

# %%
#freguesia = pd.get_dummies(data_imo_quintas['Freguesia'])
#tipologia = pd.get_dummies(data_imo_quintas['Tipologia'])
#condicao = pd.get_dummies(data_imo_quintas['Condição'])

#data_imo_quintas.drop(['Freguesia','Tipologia','Condição'],axis=1,inplace=True)
#data_imo_quintas = pd.concat([data_imo_quintas,freguesia,tipologia,condicao],axis=1)
#data_imo_quintas

from sklearn.preprocessing import LabelEncoder
cat_features = data_imo_quintas.dtypes[data_imo_quintas.dtypes == "object"].index 
for c in cat_features.to_list():
    lbl = LabelEncoder() 
    lbl.fit(list(data_imo_quintas[c].values)) 
    data_imo_quintas[c] = lbl.transform(list(data_imo_quintas[c].values))

# %% [markdown]
# ### Outliers Z-Score

# %%
z = np.abs(stats.zscore(data_imo_quintas))
threshold = 3
print(np.where(z > threshold))
# The first array contains the list of row numbers and second array respective column numbers
# Out:
# (array([   1,    2,    4,   12,   22,   23,   24,   27,   27,   27,   27,
#          27,   38,   52,   62,   73,   73,   77,   78,   90,   91,   91,
#         103,  106,  112,  118,  121,  126,  127,  128,  128,  129,  135,
#         138,  138,  138,  143,  144,  147,  149,  150,  150,  151,  152,
#         153,  154,  159,  160,  160,  160,  163,  169,  175,  176,  176,
#         177,  178,  179,  180,  180,  180,  180,  185,  188,  191,  193,
#         204,  206,  207,  208,  211,  214,  215,  218,  221,  221,  224,
#         226,  233,  241,  241,  242,  242,  243,  243,  244,  244,  246,
#         246,  253,  253,  259,  269,  271,  272,  272,  272,  287,  290,
#         293,  293,  294,  294,  295,  295,  304,  310,  318,  320,  321,
#         322,  324,  325,  346,  346,  352,  364,  364,  364,  364,  364,
#         365,  365,  365,  365,  365,  367,  369,  371,  373,  378,  388,
#         390,  395,  403,  404,  408,  408,  411,  411,  411,  415,  415,
#         431,  431,  431,  431,  431,  436,  436,  440,  441,  446,  446,
#         453,  458,  464,  476,  476,  479,  481,  481,  492,  492,  492,
#         492,  492,  502,  505,  505,  530,  546,  560,  560,  560,  570,
#         577,  579,  580,  580,  589,  591,  604,  617,  621,  622,  624,
#         626,  630,  634,  635,  637,  638,  639,  640,  643,  648,  648,
#         648,  648,  648,  649,  649,  649,  649,  649,  651,  651,  664,
#         668,  678,  679,  686,  692,  694,  694,  694,  694,  694,  703,
#         713,  720,  720,  723,  728,  728,  728,  730,  742,  757,  768,
#         768,  772,  775,  795,  795,  795,  815,  815,  816,  819,  819,
#         819,  821,  847,  851,  867,  874,  891,  894,  899,  901,  903,
#         906,  912,  913,  914,  918,  923,  924,  925,  928,  937,  949,
#         950,  953,  953,  953,  955,  956,  964,  972,  973,  995,  995,
#         995, 1001, 1002, 1004, 1008, 1013, 1013, 1021, 1024, 1024, 1024,
#        1024, 1028, 1038, 1039, 1040, 1059, 1063, 1068, 1070, 1070, 1070,
#        1078, 1084, 1085, 1092, 1092, 1105, 1106, 1110, 1131, 1133, 1133,
#        1133, 1133, 1137, 1139, 1147, 1148, 1155, 1159, 1166, 1180, 1181,
#        1183, 1194, 1208, 1208, 1208, 1209, 1209, 1209, 1209, 1209, 1209,
#        1212, 1221, 1221, 1221, 1222, 1230, 1233, 1233, 1233, 1233, 1233,
#        1240, 1241, 1245, 1252, 1253, 1257, 1261, 1268, 1282, 1284, 1289,
#        1289, 1301, 1303, 1304, 1304, 1304, 1311, 1340, 1346, 1348, 1357,
#        1363, 1374, 1380, 1403, 1410, 1414, 1428, 1430, 1432, 1458, 1467,
#        1468, 1468, 1468, 1480, 1480, 1488, 1493, 1499, 1499, 1508, 1509,
#        1510, 1511, 1511, 1511, 1511, 1511, 1512, 1512, 1512, 1512, 1512,
#        1523, 1525, 1525, 1525, 1546, 1546, 1547, 1562, 1562, 1562, 1562,
#        1562, 1567, 1567, 1567, 1569, 1572, 1572, 1572, 1573, 1592, 1593,
#        1603, 1614, 1619, 1621, 1624, 1624, 1627, 1629, 1633, 1633, 1633,
#        1633, 1644, 1644, 1644, 1644, 1644, 1645, 1645, 1645, 1645, 1646,
#        1646, 1647, 1647, 1647, 1647, 1647, 1656, 1664, 1692, 1697, 1705,
#        1705, 1711, 1713, 1713, 1717, 1718, 1718, 1718, 1724, 1728, 1731,
#        1736, 1736], dtype=int64), array([ 5,  5, 14, 14,  5,  2,  5,  4,  6, 10, 15, 17,  9,  5,  3,  7, 14,
#        14,  9, 18,  2, 10,  5, 14, 14,  8,  5, 14, 14,  2,  3, 14,  5,  4,
#         9, 12,  2,  2, 14,  5,  8, 18, 13,  6,  6,  5, 14,  4, 10, 17, 14,
#         6, 13,  8, 18,  5,  5,  2,  4,  9, 12, 17, 16, 13, 14, 13, 16, 18,
#         5,  6, 14, 16,  6, 14,  8, 18, 13,  2,  2, 11, 13, 11, 13, 11, 13,
#        11, 13, 11, 13,  8, 12,  8,  6,  5,  6, 10, 17,  6, 11, 11, 13,  8,
#        12,  8, 12,  8, 11, 14,  8, 15, 15, 15,  8,  6,  8,  5,  4,  5,  6,
#        10, 17,  4,  5,  6, 10, 17,  3,  5,  6, 14, 16, 10,  7, 16, 13,  2,
#        11, 13,  4,  9, 12, 10, 17,  4,  5,  9, 12, 17, 10, 17, 14,  8, 10,
#        17,  2,  8,  8,  8, 12,  5,  2, 10,  4,  5,  9, 12, 17,  2, 10, 17,
#        14,  6,  4,  9, 12, 10,  2,  2,  8, 14,  5,  8,  6, 14,  5,  2,  6,
#         5,  5,  8, 16, 16, 16,  6, 16,  8,  4,  6, 10, 15, 17,  4,  6, 10,
#        15, 17,  8, 12,  6,  8,  3,  3, 16,  5,  4,  5,  9, 12, 17,  3, 18,
#         8, 12, 16,  4, 10, 17, 18,  3,  3, 10, 17,  5, 16,  4,  9, 12, 13,
#        14, 13, 10, 15, 17,  2,  6,  5,  3, 16,  5,  3,  5,  2, 13, 13,  5,
#        14, 14, 14,  3, 13, 14,  6,  6, 15, 14,  4,  9, 12, 14, 16, 14,  5,
#         8, 10, 15, 17, 14, 14,  2, 14,  8, 12, 13,  4,  9, 12, 17, 12,  3,
#        16, 16,  3, 14, 10,  4,  9, 12, 16,  6, 16,  3,  5, 14,  6, 16,  3,
#         4,  5,  9, 12,  6,  5, 13,  7, 16,  5, 16, 14,  6,  3,  6,  4,  9,
#        12,  2,  4,  6, 10, 15, 17, 16,  5, 15, 17, 14,  2,  4,  6, 10, 15,
#        17, 14, 14,  3,  3, 14, 13, 14,  9, 16, 16,  6,  8,  5, 16,  4, 10,
#        17, 16,  6, 18,  6, 10,  9,  5,  5,  6,  6,  6, 10, 14,  6, 10, 14,
#         4, 10, 17,  8, 12,  2,  6, 10, 17,  6,  6, 16,  4,  6, 10, 15, 17,
#         4,  6, 10, 15, 17,  5,  4, 10, 17,  7, 14, 14,  4,  5, 12, 13, 17,
#         4,  9, 12, 16,  2, 11, 13,  5,  8,  6,  6,  9, 16,  9, 10, 17,  8,
#         2,  4,  9, 12, 17,  4,  6, 10, 15, 17,  4,  9, 12, 17,  6,  8,  4,
#         6, 10, 15, 17,  6, 16,  6, 14, 11, 13,  2,  8, 12, 16,  4,  5, 17,
#         8, 14,  8,  6,  8], dtype=int64))

# %%
# Só fazer 1 vez
data_imo_quintas = data_imo_quintas[(np.abs(stats.zscore(data_imo_quintas)) < 3).all(axis=1)]
data_imo_quintas.index = np.arange(1, len(data_imo_quintas) + 1)
data_imo_quintas

#data_imo_quintas = data_imo_quintas[(np.abs(stats.zscore(data_imo_quintas['Preço'])) < 1)]
#data_imo_quintas.index = np.arange(1, len(data_imo_quintas) + 1)
#data_imo_quintas
# Out:
#        Preço  Freguesia  Tipologia  Área útil m/2  Centro Cidade (km)  \
# 1     288000         21          3          240.0                0.37
# 2     350000         22          3          300.0                0.35
# 3     177000         16          3          198.0                0.28
# 4     270000         17          3          270.0                0.23
# 5     250000         21          3          300.0                0.34
# ...      ...        ...        ...            ...                 ...
# 1422  225000         18          2          288.0                0.35
# 1423  195000          7          3          291.0                0.13
# 1424  320000         24          2          285.0                0.20
# 1425  240000         24          3          330.0                0.20
# 1426  275000         22          2          165.0                0.30
#
#       Hospitais (km)  Centros Saúde (km)  Centro Comerciais (km)  \
# 1               0.44                0.73                    0.84
# 2               0.46                0.74                    0.70
# 3               0.58                0.67                    0.28
# 4               0.21                0.25                    0.33
# 5               0.71                0.67                    0.95
# ...              ...                 ...                     ...
# 1422            0.32                0.41                    0.44
# 1423            0.20                0.29                    0.14
# 1424            0.24                0.30                    0.54
# 1425            0.24                0.30                    0.54
# 1426            0.42                0.59                    0.57
#
#       Escolas (km)  Universidades (km)  Estação de Comboios (km)  \
# 1             1.06                0.70                      0.27
# 2             0.88                0.74                      0.26
# 3             0.45                0.38                      0.33
# 4             0.35                0.23                      0.25
# 5             0.62                0.47                      0.29
# ...            ...                 ...                       ...
# 1422          0.74                0.35                      0.41
# 1423          0.15                0.15                      0.13
# 1424          0.46                0.22                      0.19
# 1425          0.46                0.22                      0.19
# 1426          0.64                0.62                      0.23
#
#       Parques Industriais (km)  Central Autocarros (km)  Bancos (km)  \
# 1                         0.21                     0.33         0.96
# 2                         0.21                     0.32         0.80
# 3                         0.50                     0.26         0.53
# 4                         0.82                     0.25         0.47
# 5                         0.20                     0.29         0.66
# ...                        ...                      ...          ...
# 1422                      2.11                     0.41         1.56
# 1423                      0.24                     0.12         0.16
# 1424                      0.61                     0.22         0.26
# 1425                      0.61                     0.22         0.26
# 1426                      0.20                     0.28         0.61
#
#       Correios (km)  Parques e Zonas Verdes (km)  Serviços Públicos (km)  \
# 1              0.88                         0.86                    0.53
# 2              0.76                         0.80                    0.49
# 3              0.38                         0.54                    0.57
# 4              0.23                         0.61                    0.38
# 5              1.93                         2.19                    0.47
# ...             ...                          ...                     ...
# 1422           0.36                         0.52                    0.87
# 1423           0.16                         0.33                    0.36
# 1424           0.23                         0.56                    0.27
# 1425           0.23                         0.56                    0.27
# 1426           0.58                         0.60                    0.56
#
#       Policia Municipal (km)  Farmácias (km)
# 1                       0.33            1.10
# 2                       0.31            0.92
# 3                       0.31            0.80
# 4                       0.23            0.92
# 5                       0.33            1.15
# ...                      ...             ...
# 1422                    0.36            1.67
# 1423                    0.13            1.36
# 1424                    0.20            1.47
# 1425                    0.20            1.47
# 1426                    0.28            0.66
#
# [1426 rows x 19 columns]

# %% [markdown]
# **Análise exploratória dos dados sem outliers**

# %% [markdown]
# ----

# %% [markdown]
# ## Skewness

# %%
sns.distplot(data_imo_quintas['Preço'], fit=stats.norm);
fig = plt.figure()
res = stats.probplot(data_imo_quintas['Preço'], plot=plt)

# %%
sns.distplot(data_imo_quintas['Área útil m/2'], fit=stats.norm);
fig = plt.figure()
res = stats.probplot(data_imo_quintas['Área útil m/2'], plot=plt)

# %% [markdown]
# ## Dataset estruturado

# %%
data_imo_quintas
# Out:
#        Preço  Freguesia  Tipologia  Área útil m/2  Centro Cidade (km)  \
# 1     288000         21          3          240.0                0.37
# 2     350000         22          3          300.0                0.35
# 3     177000         16          3          198.0                0.28
# 4     270000         17          3          270.0                0.23
# 5     250000         21          3          300.0                0.34
# ...      ...        ...        ...            ...                 ...
# 1422  225000         18          2          288.0                0.35
# 1423  195000          7          3          291.0                0.13
# 1424  320000         24          2          285.0                0.20
# 1425  240000         24          3          330.0                0.20
# 1426  275000         22          2          165.0                0.30
#
#       Hospitais (km)  Centros Saúde (km)  Centro Comerciais (km)  \
# 1               0.44                0.73                    0.84
# 2               0.46                0.74                    0.70
# 3               0.58                0.67                    0.28
# 4               0.21                0.25                    0.33
# 5               0.71                0.67                    0.95
# ...              ...                 ...                     ...
# 1422            0.32                0.41                    0.44
# 1423            0.20                0.29                    0.14
# 1424            0.24                0.30                    0.54
# 1425            0.24                0.30                    0.54
# 1426            0.42                0.59                    0.57
#
#       Escolas (km)  Universidades (km)  Estação de Comboios (km)  \
# 1             1.06                0.70                      0.27
# 2             0.88                0.74                      0.26
# 3             0.45                0.38                      0.33
# 4             0.35                0.23                      0.25
# 5             0.62                0.47                      0.29
# ...            ...                 ...                       ...
# 1422          0.74                0.35                      0.41
# 1423          0.15                0.15                      0.13
# 1424          0.46                0.22                      0.19
# 1425          0.46                0.22                      0.19
# 1426          0.64                0.62                      0.23
#
#       Parques Industriais (km)  Central Autocarros (km)  Bancos (km)  \
# 1                         0.21                     0.33         0.96
# 2                         0.21                     0.32         0.80
# 3                         0.50                     0.26         0.53
# 4                         0.82                     0.25         0.47
# 5                         0.20                     0.29         0.66
# ...                        ...                      ...          ...
# 1422                      2.11                     0.41         1.56
# 1423                      0.24                     0.12         0.16
# 1424                      0.61                     0.22         0.26
# 1425                      0.61                     0.22         0.26
# 1426                      0.20                     0.28         0.61
#
#       Correios (km)  Parques e Zonas Verdes (km)  Serviços Públicos (km)  \
# 1              0.88                         0.86                    0.53
# 2              0.76                         0.80                    0.49
# 3              0.38                         0.54                    0.57
# 4              0.23                         0.61                    0.38
# 5              1.93                         2.19                    0.47
# ...             ...                          ...                     ...
# 1422           0.36                         0.52                    0.87
# 1423           0.16                         0.33                    0.36
# 1424           0.23                         0.56                    0.27
# 1425           0.23                         0.56                    0.27
# 1426           0.58                         0.60                    0.56
#
#       Policia Municipal (km)  Farmácias (km)
# 1                       0.33            1.10
# 2                       0.31            0.92
# 3                       0.31            0.80
# 4                       0.23            0.92
# 5                       0.33            1.15
# ...                      ...             ...
# 1422                    0.36            1.67
# 1423                    0.13            1.36
# 1424                    0.20            1.47
# 1425                    0.20            1.47
# 1426                    0.28            0.66
#
# [1426 rows x 19 columns]

# %% [markdown]
# ## Modelos de regressão

# %%
corr = data_imo_quintas.corr()
plt.subplots(figsize=(20,9))
sns.heatmap(corr, annot=True)

# %%
top_feature = corr.index[abs(corr['Preço']>0.1)]
plt.subplots(figsize=(12, 8))
top_corr = data_imo_quintas[top_feature].corr()
sns.heatmap(top_corr, annot=True)
plt.show()

# %% [markdown]
# **Features mais importantes relativamente ao target**

# %%
corr = data_imo_quintas.corr()
corr.sort_values(['Preço'], ascending=False, inplace=True)
corr.Preço
# Out:
# Preço                       1.000000
# Área útil m/2               0.386214
# Tipologia                   0.225361
# Universidades (km)          0.168065
# Hospitais (km)              0.127001
#                               ...
# Central Autocarros (km)    -0.012844
# Farmácias (km)             -0.039524
# Estação de Comboios (km)   -0.073965
# Serviços Públicos (km)     -0.121067
# Parques Industriais (km)   -0.149914
# Name: Preço, Length: 19, dtype: float64

# %% [markdown]
# ## Train Test Split

# %%
y = data_imo_quintas['Preço']

# %%
X = data_imo_quintas.drop('Preço',axis=1)

# %%
X = X.values
y = y.values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)
X_train.shape
# Out:
# (1140, 18)

# %% [markdown]
# ### Regression Evaluation Metrics
#
#
# Here are three common evaluation metrics for regression problems:
#
# **Mean Absolute Error** (MAE) is the mean of the absolute value of the errors:
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
#
# **Mean Squared Error** (MSE) is the mean of the squared errors:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# **Root Mean Squared Error** (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$
#
# Comparing these metrics:
#
# - **MAE** is the easiest to understand, because it's the average error.
# - **MSE** is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# - **RMSE** is even more popular than MSE, because RMSE is interpretable in the "y" units.
#
# All of these are **loss functions**, because we want to minimize them.

# %% [markdown]
# **Funções auxiliares**

# %%
def printMetrics(y_test, predictions):
    print('MAE:', metrics.mean_absolute_error(y_test, predictions))
    print('MSE:', metrics.mean_squared_error(y_test, predictions))
    print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
    
def drawPlots(y_test, predictions, model):
    plt.plot(predictions, color= 'red')
    plt.plot(y_test, color= 'green')
    plt.title("Valores dos preços previstos e reais")
    plt.xlabel("Row")
    plt.ylabel("Preço")
    plt.legend(['previsto', 'real'], loc='upper right')
    plt.show()

    plt.plot(y_test, color= 'green')
    plt.plot(predictions, color= 'red')
    plt.title("Valores dos preços previstos e reais")
    plt.xlabel("Row")
    plt.ylabel("Preço")
    plt.legend(['real', 'previsto'], loc='upper right')
    plt.show()

    plt.scatter(predictions, y_test, alpha=.25,color='b') #alpha helps to show overlapping data
    plt.xlabel('Predicted Price')
    plt.ylabel('Actual Price')
    plt.title(model)
    plt.show()
    
    sns.jointplot(predictions, y_test, kind='reg')
    plt.xlabel('Predicted Price')
    plt.ylabel('Actual Price')
    plt.show()

# %% [markdown]
# ### Linear Regression

# %%
from sklearn import linear_model

# Compile the model
model = linear_model.LinearRegression()

# Fit the model
model.fit(X_train, y_train)

# Predict
predictions = model.predict(X_test)

# Metrics
printMetrics(y_test, predictions)

# %%
print("Predict value " + str(predictions[50]))
print("Real value " + str(y_test[50]))

# %%
drawPlots(y_test, predictions, 'Linear Regression')

# %% [markdown]
# ### RandomForestRegression

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# Compile the model
rf = RandomForestRegressor(random_state = 42)


#Hyperparamater tuning using RanodomSearchCV
param_grid = { 
    'n_estimators': [int(x) for x in np.linspace(start = 600, stop = 1300, num = 10)],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [12,14,16],
    'min_samples_split' : [2, 4, 6],
    'min_samples_leaf' : [1, 2]
}
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 5, n_jobs = -1, verbose = 2)
grid_search.fit(X_train, y_train)
print(grid_search.best_params_)
print(grid_search.best_score_)


# Fit the model
#rf.fit(X_train,y_train)

# Predict
#predictions = rf.predict(X_test)
predictions = grid_search.predict(X_test)

# Metrics
printMetrics(y_test, predictions)

# %%
print("Predict value " + str(predictions[50]))
print("Real value " + str(y_test[50]))

# %%
drawPlots(y_test, predictions, 'Random Forest')

# %% [markdown]
# ### Standard Machine Learning Models (TEMPORÁRIO)

# %%
# Standard ML Models for comparison
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR

# Splitting data into training/testing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error, median_absolute_error

# %%
def evaluate(X_train, X_test, y_train, y_test):
    # Names of models
    model_name_list = ['Linear Regression', 'ElasticNet Regression',
                      'Random Forest', 'Extra Trees', 'SVM',
                       'Gradient Boosted', 'Baseline']
    
    # Instantiate the models
    model1 = LinearRegression()
    model2 = ElasticNet(alpha=1.0, l1_ratio=0.5)
    model3 = RandomForestRegressor(n_estimators=50)
    model4 = ExtraTreesRegressor(n_estimators=50)
    model5 = SVR(kernel='rbf', degree=3, C=1.0, gamma='auto')
    model6 = GradientBoostingRegressor(n_estimators=20)
    
    # Dataframe for results
    results = pd.DataFrame(columns=['mae', 'rmse'], index = model_name_list)
    
    # Train and predict with each model
    for i, model in enumerate([model1, model2, model3, model4, model5, model6]):
        model.fit(X_train, y_train)
        predictions = model.predict(X_test)
        
        # Metrics
        mae = np.mean(abs(predictions - y_test))
        rmse = np.sqrt(np.mean((predictions - y_test) ** 2))
        
        # Insert results into the dataframe
        model_name = model_name_list[i]
        results.loc[model_name, :] = [mae, rmse]
    
    # Median Value Baseline Metrics
    baseline = np.median(y_train)
    baseline_mae = np.mean(abs(baseline - y_test))
    baseline_rmse = np.sqrt(np.mean((baseline - y_test) ** 2))
    
    results.loc['Baseline', :] = [baseline_mae, baseline_rmse]
    
    return results

# %%
results = evaluate(X_train, X_test, y_train, y_test)

# %%
# Matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib

# %%
fig = plt.figure(figsize = (20,10))
# Root mean squared error
ax =  plt.subplot(1, 2, 1)
results.sort_values('mae', ascending = True).plot.bar(y = 'mae', color = 'b', ax = ax)
plt.title('Model Mean Absolute Error'); plt.ylabel('MAE');

# Median absolute percentage error
ax = plt.subplot(1, 2, 2)
results.sort_values('rmse', ascending = True).plot.bar(y = 'rmse', color = 'r', ax = ax)
plt.title('Model Root Mean Squared Error'); plt.ylabel('RMSE');

plt.tight_layout()

# %% [markdown]
# ### Ridge Regression

# %% [markdown]
# **GridSearchCV**

# %%
from sklearn.linear_model import Ridge

# Parameters
params_ridge ={
        'alpha':[0.5,0.75,1,1.25,1.5],
        'solver':['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga'],
        'max_iter':[500,750,1000,1250,1500]
        }

# Compile the model
ridge = Ridge()
ridge_grid = GridSearchCV(estimator = ridge, param_grid = params_ridge, cv = 5, n_jobs = -1, verbose = 2)

# Fit the model
ridge_grid.fit(X_train, y_train)
print(ridge_grid.best_params_)
print(ridge_grid.best_score_)

# Predict
predictions = ridge_grid.predict(X_test)

# Metrics
printMetrics(y_test, predictions)

# %%
print("Predict value " + str(predictions[50]))
print("Real value " + str(y_test[50]))

# %%
drawPlots(y_test, predictions, 'Ridge Regression GridSearchCV')

# %% [markdown]
# ### GradientBoostingRegressor

# %% [markdown]
# **GridSearchCV**

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Parameters
params_gbr={
    'loss':['ls', 'lad', 'huber', 'quantile'],
    'n_estimators':[15,25,50,100],
    'min_samples_split':[1,2,3],
    'max_depth':[4,6,8,10],
    'max_features':['auto', 'sqrt', 'log2']
}

# Compile the model
gbr = GradientBoostingRegressor()
gbr_grid = GridSearchCV(estimator=gbr, param_grid=params_gbr, cv=5, n_jobs=-1, verbose=2)

# Fit the model
gbr_grid.fit(X_train, y_train)
print(gbr_grid.best_params_)
print(gbr_grid.best_score_)

# Predict
predictions = gbr_grid.predict(X_test)

# Metrics
printMetrics(y_test, predictions)

# %%
print("Predict value " + str(predictions[50]))
print("Real value " + str(y_test[50]))

# %%
drawPlots(y_test, predictions, 'GradientBoostingRegressor GridSearchCV')

# %% [markdown]
# ### Decision Tree Regression with AdaBoost

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor

rng = np.random.RandomState(1)

# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=4)

regr_2 = AdaBoostRegressor(DecisionTreeRegressor(max_depth=4), n_estimators=300, random_state=rng)

regr_1.fit(X, y)
regr_2.fit(X, y)

# Predict
y_1 = regr_1.predict(X)
y_2 = regr_2.predict(X)

# Metrics
printMetrics(y_2, y)

# %%
print("Predict value " + str(y_1[60]))
print("Real value " + str(y[60]))

# %%
drawPlots(y, y_1, 'Decision Tree Regression with AdaBoost')

# %% [markdown]
# ### LGBM & ANN - Data Preparation

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from keras.callbacks import ModelCheckpoint

# %%
data_imo_quintas_mlp

# %%
data_imo_quintas_mlp = pd.get_dummies(data_imo_quintas_mlp)

# %%
data_imo_quintas_mlp.shape

# %%
y_mlp = data_imo_quintas_mlp['Preço']
X_mlp = data_imo_quintas_mlp.drop('Preço',axis=1)

from sklearn.model_selection import train_test_split
X_train_mlp, X_test_mlp, y_train_mlp, y_test_mlp = train_test_split(X, y, test_size=0.2, random_state=7)
X_train_mlp.shape

# %%
y_train_mlp = pd.DataFrame({'Preço':y_train})

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc_y = StandardScaler()
sc_X = StandardScaler()
y_train_mlp = sc_y.fit_transform(y_train_mlp)
X_train_mlp = sc_X.fit_transform(X_train_mlp)
X_test_mlp = sc_X.transform(X_test_mlp)

# %%
y_train_mlp.shape

# %%
flat_y_mlp = y_train_mlp.flatten()
flat_y_mlp.shape

# %% [markdown]
# ### LGBM

# %%
import lightgbm as lgb

# create dataset for lightgbm
lgb_train = lgb.Dataset(X_train_mlp, flat_y_mlp)

# specify your configurations as a dict
params = {
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': {'l2', 'l1'},
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0
}

print('Starting training...')

# train
gbm = lgb.train(params, lgb_train, num_boost_round=250)

# predict
lgbm_prediction_tr = gbm.predict(X_train_mlp, num_iteration=gbm.best_iteration)
lgbm_prediction_te = gbm.predict(X_test_mlp, num_iteration=gbm.best_iteration)

# %%
train = lgbm_prediction_tr
test = lgbm_prediction_te

# %%
y_pred_mlp = sc_y.inverse_transform(lgbm_prediction_te)

# %%
y_pred_mlp

# %%
# Metrics
printMetrics(y_test, y_pred_mlp)

# %%
drawPlots(y_test, y_pred_mlp, 'LGBM')

# %% [markdown]
# ### ANN

# %%
def print_history_mae(history):
    print(history.history.keys())
    plt.plot(history.history['mae'])
    plt.plot(history.history['val_mae'])
    plt.title('model mae')
    plt.ylabel('mae')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()


def print_history_loss(history):
    print(history.history.keys())
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from keras import models, layers

model = models.Sequential()
model.add(layers.Dense(18, activation='relu', input_shape=[X_train.shape[1]]))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(32, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(layers.Dense(64, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(layers.Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(layers.Dense(1))

model.compile(optimizer='rmsprop', loss='mae', metrics=['mae'])

# %%
print(model.summary())

# %%
model_filepath = 'min_vl_model.h5'
checkpoint = ModelCheckpoint(model_filepath, monitor = 'val_mae', verbose=1, save_best_only = True, mode='min')

history = model.fit(X_train_scaled, y_train, validation_split=0.2, epochs=3000, callbacks=[checkpoint])

model.load_weights(model_filepath)

# %%
print_history_mae(history)
print_history_loss(history)

# %%
y_pred_mlp = model.predict(X_test_scaled)

# %%
y_pred_mlp

# %%
y_preds = []

for item in y_pred_mlp:
    y_preds.append(item[0])

# %%
# Metrics
printMetrics(y_test, y_preds)

# %%
drawPlots(y_test, y_preds, 'MLP')
