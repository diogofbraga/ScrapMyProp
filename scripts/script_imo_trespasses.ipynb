# %% [markdown]
# # Scrap My Prop
#
# ### Laboratórios de Engenharia Informática
#
# **"Development of an IT solution for the extraction and automatic analysis of data and relevant information for the calculation of land and properties."**

# %% [markdown]
# ## Importar Bibliotecas Python

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from IPython.core.debugger import set_trace
import geopy.distance
import os.path
from sklearn import metrics

# %% [markdown]
# # 'Imovirtual'

# %% [markdown]
# ## Ler Dados do CSV

# %% [markdown]
# **Junção dos datasets através do 'id'**

# %%
k = True

for mes in range(4,6):
    if mes > 0 and mes < 10:
        mes = str(mes).zfill(2)
    print("------ Mês:", mes)
    for dia in range(1,31):
        if dia > 0 and dia < 10:
            dia = str(dia).zfill(2)
        print("--- Dia:", dia)
        if os.path.isfile(f'../dados/dados_imovirtual_{dia}_{mes}.csv'):
            if k:
                data_imo = pd.read_csv(f'../dados/dados_imovirtual_{dia}_{mes}.csv', engine='python', encoding='utf8')
                print(data_imo.shape)
                k = False
            else:
                csv = pd.read_csv(f'../dados/dados_imovirtual_{dia}_{mes}.csv', engine='python', encoding='utf8')
                data_imo = data_imo.append(csv,sort=False)
                data_imo = data_imo.drop_duplicates(subset='Id', keep="last")
                data_imo.index = np.arange(1, len(data_imo) + 1)
                print(data_imo.shape)
# Out:
# ------ Mês: 04
# --- Dia: 01
# --- Dia: 02
# --- Dia: 03
# --- Dia: 04
# --- Dia: 05
# --- Dia: 06
# --- Dia: 07
# --- Dia: 08
# --- Dia: 09
# --- Dia: 10
# --- Dia: 11
# --- Dia: 12
# --- Dia: 13
# --- Dia: 14
# --- Dia: 15
# (5618, 132)
# --- Dia: 16
# (5684, 132)
# --- Dia: 17
# (5712, 132)
# --- Dia: 18
# (5740, 132)
# --- Dia: 19
# (5742, 132)
# --- Dia: 20
# (5755, 132)
# --- Dia: 21
# (5758, 132)
# --- Dia: 22
# (5796, 132)
# --- Dia: 23
# (5803, 132)
# --- Dia: 24
# (5827, 132)
# --- Dia: 25
# (5874, 132)
# --- Dia: 26
# (5877, 132)
# --- Dia: 27
# (5880, 132)
# --- Dia: 28
# --- Dia: 29
# --- Dia: 30
# ------ Mês: 05
# --- Dia: 01
# --- Dia: 02
# --- Dia: 03
# --- Dia: 04
# --- Dia: 05
# --- Dia: 06
# --- Dia: 07
# --- Dia: 08
# --- Dia: 09
# (6160, 132)
# --- Dia: 10
# (6160, 132)
# --- Dia: 11
# (6162, 132)
# --- Dia: 12
# (6195, 132)
# --- Dia: 13
# (6222, 132)
# --- Dia: 14
# (6252, 132)
# --- Dia: 15
# (6289, 132)
# --- Dia: 16
# (6372, 132)
# --- Dia: 17
# (6373, 132)
# --- Dia: 18
# (6383, 132)
# --- Dia: 19
# (6437, 132)
# --- Dia: 20
# (6453, 132)
# --- Dia: 21
# --- Dia: 22
# (6513, 132)
# --- Dia: 23
# (6532, 132)
# --- Dia: 24
# (6535, 132)
# --- Dia: 25
# (6543, 132)
# --- Dia: 26
# (6588, 132)
# --- Dia: 27
# (6604, 132)
# --- Dia: 28
# (6636, 132)
# --- Dia: 29
# (6652, 132)
# --- Dia: 30
# (6664, 132)

# %%
#data_imo = pd.read_csv('../dados/dados_imovirtual_08_05.csv', engine='python', encoding='utf8')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10)
data_imo.head()
# Out:
#                                                 Nome          Id  \
# 1  Loja comercial Junto ao Centro da Cidade de Br...  14804552.0
# 2               Excelente Terreno em Fradelos, Braga  14976693.0
# 3                            Moradia Terrea em Lomar  15377577.0
# 4                    Moradia p/ Restauro - Maximinos  14698254.0
# 5        Moradia c/362 m2 “NOVA” em Nogueiró, Braga!  14979186.0
#
#   Tipo de imóvel     Preço Preço m/2          Distrito Concelho  \
# 1           Loja   19 900       622   Braga (distrito)    Braga
# 2        Terreno   97 000        60   Braga (distrito)    Braga
# 3        Moradia       NaN       NaN  Braga (distrito)    Braga
# 4        Moradia  149 500     1 495   Braga (distrito)    Braga
# 5        Moradia  288 000     1 200   Braga (distrito)    Braga
#
#                           Freguesia                            Rua   Latitude  \
# 1                          Sequeira        Rua Inácio José Peixoto  41.554660
# 2                 Vilaça e Fradelos                            NaN  41.507746
# 3                     Lomar e Arcos  Rua Quinta das Mouras - Lomar  41.527420
# 4  Braga (Maximinos, Sé e Cividade)                            NaN  41.549550
# 5       Nogueira, Fraião e Lamaçães                            NaN  41.548575
#
#    Longitude Tipologia Nº Casas de Banho Área útil m/2 Área bruta m/2  \
# 1  -8.432971       NaN               NaN         32 m²            NaN
# 2  -8.477455       NaN               NaN           NaN            NaN
# 3  -8.423300        T4         4 ou mais        537 m²       2 448 m²
# 4  -8.437720        T0               NaN        100 m²         131 m²
# 5  -8.390454        T4                 2        240 m²         362 m²
#
#    Ano construção Certificado energético Armário Cozinha equipada Garagem box  \
# 1             NaN                      C     NaN              NaN         NaN
# 2             NaN                    NaN     NaN              NaN         NaN
# 3          2018.0                    NaN     NaN              NaN         NaN
# 4          1980.0                    NaN     NaN              NaN         NaN
# 5             NaN                      B     NaN              NaN        True
#
#   Gás canalizado Lareira Marquise Suite Varanda Vista de cidade Condição  \
# 1            NaN     NaN      NaN   NaN     NaN             NaN    Usado
# 2            NaN     NaN      NaN   NaN     NaN             NaN      NaN
# 3            NaN     NaN      NaN   NaN     NaN             NaN      NaN
# 4            NaN     NaN      NaN   NaN     NaN             NaN    Ruína
# 5            NaN     NaN      NaN   NaN    True             NaN     Novo
#
#   Despensa Arrecadação Porta blindada Video Porteiro Empreendimento  \
# 1      NaN         NaN            NaN            NaN            NaN
# 2      NaN         NaN            NaN            NaN            NaN
# 3      NaN         NaN            NaN            NaN            não
# 4      NaN         NaN            NaN            NaN            NaN
# 5      NaN         NaN            NaN            NaN            NaN
#
#   Ar condicionado Elevador  Estores elétricos Fibra ótica  \
# 1             NaN      NaN                NaN         NaN
# 2             NaN      NaN                NaN         NaN
# 3             NaN      NaN                NaN         NaN
# 4             NaN      NaN                NaN         NaN
# 5             NaN      NaN                NaN         NaN
#
#   Pré-instalação de ar condicionado Terraço  Área de terreno m/2 Churrasco  \
# 1                               NaN     NaN                  NaN       NaN
# 2                               NaN     NaN                  NaN       NaN
# 3                               NaN     NaN                  NaN       NaN
# 4                               NaN     NaN                  NaN       NaN
# 5                               NaN     NaN                  NaN       NaN
#
#   Árvores de fruto Sotão Cave Jardim Aquecimento central Caldeira  \
# 1              NaN   NaN  NaN    NaN                 NaN      NaN
# 2              NaN   NaN  NaN    NaN                 NaN      NaN
# 3              NaN   NaN  NaN    NaN                 NaN      NaN
# 4              NaN   NaN  NaN    NaN                 NaN      NaN
# 5              NaN   NaN  NaN   True                 NaN      NaN
#
#   Acessibilidade a pessoas com mobilidade condicionada  Box 2 carros  \
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
# 5                                                NaN             NaN
#
#   Detetor de gás Painéis solares Recuperação de calor Vista de campo/serra  \
# 1            NaN             NaN                  NaN                  NaN
# 2            NaN             NaN                  NaN                  NaN
# 3            NaN             NaN                  NaN                  NaN
# 4            NaN             NaN                  NaN                  NaN
# 5            NaN             NaN                  NaN                  NaN
#
#    Box 1 carro Portaria Estacionamento Piso radiante Som ambiente  \
# 1          NaN      NaN            NaN           NaN          NaN
# 2          NaN      NaN            NaN           NaN          NaN
# 3          NaN      NaN            NaN           NaN          NaN
# 4          NaN      NaN            NaN           NaN          NaN
# 5          NaN      NaN            NaN           NaN          NaN
#
#   Aspiração central Finalidade Tipo de terreno Acesso pavimentado Asfaltado  \
# 1               NaN        NaN             NaN                NaN       NaN
# 2               NaN        NaN         Rústico                NaN       NaN
# 3               NaN        NaN             NaN                NaN       NaN
# 4               NaN        NaN             NaN                NaN       NaN
# 5               NaN        NaN             NaN                NaN       NaN
#
#   Iluminação pública Zona arborizada Declive Ruína Alarme Furo de água  \
# 1                NaN             NaN     NaN   NaN    NaN          NaN
# 2                NaN             NaN     NaN   NaN    NaN          NaN
# 3                NaN             NaN     NaN   NaN    NaN          NaN
# 4                NaN             NaN     NaN   NaN    NaN          NaN
# 5                NaN             NaN     NaN   NaN    NaN          NaN
#
#   Domótica  Casa das máquinas Condomínio Fechado Parque infantil Piscina  \
# 1      NaN                NaN                NaN             NaN     NaN
# 2      NaN                NaN                NaN             NaN     NaN
# 3      NaN                NaN                NaN             NaN     NaN
# 4      NaN                NaN                NaN             NaN     NaN
# 5      NaN                NaN                NaN             NaN     NaN
#
#   Piscina Privada Termoacumulador Garagem exterior Mobilado  \
# 1             NaN             NaN              NaN      NaN
# 2             NaN             NaN              NaN      NaN
# 3             NaN             NaN              NaN      NaN
# 4             NaN             NaN              NaN      NaN
# 5             NaN             NaN              NaN      NaN
#
#   Hidromassagem/jacuzzi Quintal/horta Ginásio Kitchenette  \
# 1                   NaN           NaN     NaN         NaN
# 2                   NaN           NaN     NaN         NaN
# 3                   NaN           NaN     NaN         NaN
# 4                   NaN           NaN     NaN         NaN
# 5                   NaN          True     NaN         NaN
#
#   Vigilância/segurança Campo de ténis Segurança 24 horas Vedação  \
# 1                  NaN            NaN                NaN     NaN
# 2                  NaN            NaN                NaN     NaN
# 3                  NaN            NaN                NaN     NaN
# 4                  NaN            NaN                NaN     NaN
# 5                  NaN            NaN                NaN     NaN
#
#   Parqueamento (1 carro) Ligação a rede de água  Ligação a rede de saneamento  \
# 1                    NaN                    NaN                           NaN
# 2                    NaN                    NaN                           NaN
# 4                      NaN  NaN   NaN                NaN
# 5                      NaN  NaN   NaN                NaN

# %% [markdown]
# ## Pré-processamento comum a todo o Dataset

# %% [markdown]
# **Funções auxiliares**

# %%
def toNumeric(string):
    res = str(string)
    res = res.replace(" ", "")
    res = res.replace(",", ".")
    res = float(pd.to_numeric(res, errors='ignore')) # tem que ser float porque esse tipo consegue interpretar o np.nan
    return res

# %% [markdown]
# **Colunas 'Distrito' e 'Concelho': Retirar colunas de forma total porque já era uma pré-condição do projeto, mas primeiro verificar se, de facto, todos os campos estão preenchidos com 'Braga';**

# %%
print("Distritos existentes:", data_imo['Distrito'].unique())
print("Concelhos existentes:", data_imo['Concelho'].unique())
# Out:
# Distritos existentes: ['Braga (distrito)' nan]
# Concelhos existentes: ['Braga' nan]

# %%
if 'Distrito' in data_imo.columns:
    data_imo = data_imo.drop(['Distrito'], axis = 1) 
if 'Concelho' in data_imo.columns:
    data_imo = data_imo.drop(['Concelho'], axis = 1)

# %% [markdown]
# **Coluna 'Nome': Não é característica dos imóveis mas sim identificador, portanto não deve entrar nos cálculos (Drop);**

# %%
if 'Nome' in data_imo.columns:
    data_imo = data_imo.drop(['Nome'], axis = 1)

# %% [markdown]
# **Coluna 'Id': Drop linhas sem 'Id'; float -> int;**

# %%
data_imo = data_imo.dropna(subset=['Id'])
data_imo.index = np.arange(1, len(data_imo) + 1)

# %%
data_imo['Id'] = data_imo['Id'].astype(int)

# %% [markdown]
# **Dar join a colunas que, apesar de aparentarem ter nomes diferentes, representam o mesmo**

# %% [markdown]
# **Exemplo: Valores de 'Box 1 carro' e 'Box 2 carros' -> 'Garagem box'; Valores de 'Parqueamento (1 carro)' e 'Parqueamento (2 carros)' -> 'Estacionamento'; Valores de 'Hidromassagem' e 'Jacuzzi' -> 'Hidromassagem/jacuzzi'; ...**

# %% [markdown]
# **Fazer o mesmo com piscina e piscina privada???**

# %%
#pd.set_option('display.max_columns', None)
#data_imo.columns.to_numpy()

# %%
for index,val in data_imo['Vista de cidade.1'].items():
    if (val==True):
        data_imo['Vista de cidade'].iloc[index] = True
for index,val in data_imo['Sótão'].items():
    if (val==True):
        data_imo['Sotão'].iloc[index] = True
for index,val in data_imo['Vista de Serra'].items():
    if (val==True):
        data_imo['Vista de campo/serra'].iloc[index] = True
for index,val in data_imo['Adaptada a mobilidade reduzida'].items():
    if (val==True):
        data_imo['Adaptado a mobilidade reduzida'].iloc[index] = True
for index,val in data_imo['Box 1 carro'].items():
    if (val==True):
        data_imo['Garagem box'].iloc[index] = True
for index,val in data_imo['Box 2 carros'].items():
    if (val==True):
        data_imo['Garagem box'].iloc[index] = True
for index,val in data_imo['Parqueamento (1 carro)'].items():
    if (val==True):
        data_imo['Estacionamento'].iloc[index] = True
for index,val in data_imo['Parqueamento (2 carros)'].items():
    if (val==True):
        data_imo['Estacionamento'].iloc[index] = True
for index,val in data_imo['Hidromassagem'].items():
    if (val==True):
        data_imo['Hidromassagem/jacuzzi'].iloc[index] = True
for index,val in data_imo['Jacuzzi'].items():
    if (val==True):
        data_imo['Hidromassagem/jacuzzi'].iloc[index] = True
        
data_imo=data_imo.drop(['Vista de cidade.1', 'Sótão', 'Vista de Serra', 'Hidromassagem', 'Jacuzzi', 'Adaptada a mobilidade reduzida'], axis=1)
# Out:
# C:\Users\Rui\Anaconda3\envs\LEI\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#data_imo.info(verbose=True, null_counts=True)

# %% [markdown]
# **Normalizar os valores de todas as áreas; Transformar em dado numérico;**

# %%
for column in data_imo.columns:
    if "Área" in column and "Área administrativa" not in column and "Área florestal" not in column:
        for i in range(len(data_imo[column])):
            if not pd.isnull(data_imo[column].iloc[i]):
                #print(data_imo[column].iloc[i])
                data_imo[column].iloc[i]=toNumeric(str(data_imo[column].iloc[i])[0:-3])
                #print(data_imo[column].iloc[i])
                #print(type(data_imo[column].iloc[i]))

# %% [markdown]
# **Coluna 'Preço' e 'Preço m/2': Drop dos imóveis com valor 'nan'; Transformar em dado numérico;**

# %%
data_imo['Preço'] = data_imo['Preço'].apply(toNumeric)

nan_prices = data_imo['Preço'].index[data_imo['Preço'].apply(np.isnan)]
data_imo = data_imo.drop(nan_prices)
data_imo.index = np.arange(1, len(data_imo) + 1)

data_imo['Preço'] = data_imo['Preço'].apply(int)

# ------

data_imo['Preço m/2'] = data_imo['Preço m/2'].apply(toNumeric)

nan_prices = data_imo['Preço m/2'].index[data_imo['Preço m/2'].apply(np.isnan)]
data_imo = data_imo.drop(nan_prices)
data_imo.index = np.arange(1, len(data_imo) + 1)

data_imo['Preço m/2'] = data_imo['Preço m/2'].apply(int)

# %%
data_imo.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6567 entries, 1 to 6567
# Data columns (total 123 columns):
#  #   Column                                                Dtype
# ---  ------                                                -----
#  0   Id                                                    int32
#  1   Tipo de imóvel                                        object
#  2   Preço                                                 int64
#  3   Preço m/2                                             int64
#  4   Freguesia                                             object
#  5   Rua                                                   object
#  6   Latitude                                              float64
#  7   Longitude                                             float64
#  8   Tipologia                                             object
#  9   Nº Casas de Banho                                     object
#  10  Área útil m/2                                         object
#  11  Área bruta m/2                                        object
#  12  Ano construção                                        float64
#  13  Certificado energético                                object
#  14  Armário                                               object
#  15  Cozinha equipada                                      object
#  16  Garagem box                                           object
#  17  Gás canalizado                                        object
#  18  Lareira                                               object
#  19  Marquise                                              object
#  20  Suite                                                 object
#  21  Varanda                                               object
#  22  Vista de cidade                                       object
#  23  Condição                                              object
#  24  Despensa                                              object
#  25  Arrecadação                                           object
#  26  Porta blindada                                        object
#  27  Video Porteiro                                        object
#  28  Empreendimento                                        object
#  29  Ar condicionado                                       object
#  30  Elevador                                              object
#  31  Estores elétricos                                     float64
#  32  Fibra ótica                                           object
#  33  Pré-instalação de ar condicionado                     object
#  34  Terraço                                               object
#  35  Área de terreno m/2                                   float64
#  36  Churrasco                                             object
#  37  Árvores de fruto                                      object
#  38  Sotão                                                 object
#  39  Cave                                                  object
#  40  Jardim                                                object
#  41  Aquecimento central                                   object
#  42  Caldeira                                              object
#  43  Acessibilidade a pessoas com mobilidade condicionada  object
#  44  Box 2 carros                                          float64
#  45  Detetor de gás                                        object
#  46  Painéis solares                                       object
#  47  Recuperação de calor                                  object
#  48  Vista de campo/serra                                  object
#  49  Box 1 carro                                           float64
#  50  Portaria                                              object
#  51  Estacionamento                                        object
#  52  Piso radiante                                         object
#  53  Som ambiente                                          object
#  54  Aspiração central                                     object
#  55  Finalidade                                            object
#  56  Tipo de terreno                                       object
#  57  Acesso pavimentado                                    object
#  58  Asfaltado                                             object
#  59  Iluminação pública                                    object
#  60  Zona arborizada                                       object
#  61  Declive                                               object
#  62  Ruína                                                 object
#  63  Alarme                                                object
#  64  Furo de água                                          object
#  65  Domótica                                              object
#  66  Casa das máquinas                                     float64
#  67  Condomínio Fechado                                    object
#  68  Parque infantil                                       object
#  69  Piscina                                               object
#  70  Piscina Privada                                       object
#  71  Termoacumulador                                       object
#  72  Garagem exterior                                      object
#  73  Mobilado                                              object
#  74  Hidromassagem/jacuzzi                                 object
#  75  Quintal/horta                                         object
#  76  Ginásio                                               object
#  77  Kitchenette                                           object
#  78  Vigilância/segurança                                  object
#  79  Campo de ténis                                        object
#  80  Segurança 24 horas                                    object
#  81  Vedação                                               object
#  82  Parqueamento (1 carro)                                object
#  83  Ligação a rede de água                                object
#  84  Ligação a rede de saneamento                          float64
#  85  Ligação a rede elétrica                               object
#  86  Animais permitidos                                    object
#  87  Parqueamento (2 carros)                               object
#  88  Cofre                                                 object
#  89  Vista de rio                                          object
#  90  Nº divisões                                           float64
#  91  Tipo                                                  object
#  92  Pisos                                                 float64
#  93  Com WC                                                object
#  94  Montra                                                object
#  95  Anexo habitacional                                    object
#  96  Detetor de incêndio                                   float64
#  97  Detetor de Inundução                                  float64
#  98  Área (m/2)                                            object
#  99  Vista de mar                                          object
#  100 Património classificado                               object
#  101 Com cozinha                                           object
#  102 Imóvel de banca                                       object
#  103 Vista de lago                                         object
#  104 Fossa séptica                                         object
#  105 Licensa de construção                                 float64
#  106 Acesso a veículos pesados                             object
#  107 Área administrativa                                   object
#  108 Copa                                                  object
#  109 Recepção                                              object
#  110 Refeitório                                            object
#  111 Sala de reuniões                                      object
#  112 Área florestal                                        object
#  113 Percurso de água                                      object
#  114 Armazém                                               object
#  115 Adaptado a mobilidade reduzida                        object
#  116 Terra batida                                          object
#  117 Video vigilância                                      object
#  118 Espaço frigorífico                                    float64
#  119 Espaço para arrumação                                 object
#  120 Casa de banho partilhada                              object
#  121 Poço                                                  object
#  122 Paisagem protegida                                    object
# dtypes: float64(15), int32(1), int64(2), object(105)
# memory usage: 6.2+ MB

# %% [markdown]
# # Dados - Trespasses

# %% [markdown]
# **Ver os valores únicos de cada coluna para proceder ao processamento**

# %%
for col in data_imo.columns:
    uniques=data_imo[col].unique()
    print("Valores únicos para a coluna ", col, ": ", uniques)
# Out:
# Valores únicos para a coluna  Id :  [14804552 14976693 14698254 ... 12380131  6701616  6701610]
# Valores únicos para a coluna  Tipo de imóvel :  ['Loja' 'Terreno' 'Moradia' 'Apartamento' 'Escritório' 'Prédio' 'Quintas'
#  'Armazém' 'Garagem' 'Trespasses']
#  'Celeirós, Aveleda e Vimieiro' 'Ferreiros e Gondizalves'
#  'Real, Dume e Semelhe' 'Merelim (São Pedro) e Frossos' 'São Vicente'
#  'Gualtar' 'Adaúfe' 'Priscos' 'Esporões' 'Morreira e Trandeiras'
#  'Santa Lucrécia de Algeriz e Navarra' 'Ruílhe'
#  'Escudeiros e Penso (Santo Estêvão e São Vicente)' 'Tadim' 'Figueiredo'
#  'Tebosa' 'Pedralva' 'Arentim e Cunha' 'Padim da Graça' 'Lamas'
#  'Crespos e Pousada' 'Mire de Tibães' 'Espinho' 'Sobreposta'
#  'Guisande e Oliveira (São Pedro)']
# Valores únicos para a coluna  Rua :  ['Rua Inácio José Peixoto' nan 'Rua Quinta da Barra'
#  'Praceta das Amoreiras' 'Avenida da Liberdade - São José de São Lázaro'
#  'Rua Fernando Namora - Sé' 'Rua Doutor Faria - Fraião'
#  'Rua Monsenhor Airosa - Cividade' 'Largo do Arco' 'Beco do Servo'
#  'Rua Virgílio Ferreira - Real' 'Rua de Quintão' 'Rua das Cavadas'
#  'Sem Nome - Ferreiros' 'Rua José Sarmento'
#  'Rua Doutor Manuel Rodrigues de Abreu - São Victor' 'Avenida do Cávado'
#  'Praça da República - São João do Souto' 'Praceta Padre Sena de Freitas'
#  'Rua Cangosta da Missa' 'Rua das Flores' 'Rua do Bairro - Ferreiros'
#  'Travessa da Agrela' 'Rua dos Capelistas'
#  'Rua António Marinho - São Vicente' 'Rua de Caires'
#  'Rua Padre Freitas - Real' 'Rua Faustino Ferrador - São Victor'
#  'Rua João Pereira Neto' 'Rua Doutor Francisco Duarte - São Victor'
#  'Rua das Vinhas Novas' 'Largo do Espadanido - Fraião'
#  'Rua David Mourão Ferreira - Real' 'Rua da Boavista - Sé'
#  'Rua Padre António Vieira - São Victor' 'Rua das Margaridas'
#  'Rua da Escola' 'Rua da Cruz' 'Rua de Santa Margarida - São Vicente'
#  'Rua das Bretas - Fraião' 'Rua de São Valério - Real' 'Lugar da Naia'
#  'Rua Magalhães Lima' 'Largo do Cruzeiro' 'Rua das Alminhas - Tenões'
#  'Travessa Manuel Ferreira Gomes' 'Rua das Cavadas - São Pedro ( Este)'
#  'Rua do Parque Norte - Real' 'Rua do Raio' 'Rua Artur Garibaldi'
#  'Rua de Alvar' 'Avenida Senhor da Paciência'
#  'Travessa da Fábrica - São Victor' 'Praça São José - São Victor'
#  'Rua Cónego Doutor António José Ribeiro'
#  'Rua de São Barnabé - São Vicente' 'Travessa do Palácio'
#  'Rua Quinta do Carreiro - Frossos' 'Rua do Cornido' 'Rua da Casa Nova'
#  'Largo de Sobremoure - Dume' 'Praceta Amândio Ferreira Pinto - Gualtar'
#  'Rua de São Vicente - São Vicente'
#  'Praça Mouzinho de Albuquerque - São José de São Lázaro'
#  'Rua de São Domingos - São Vicente'
#  'Rua da Devesa - São José de São Lázaro' 'Praça do Condestável'
#  'Rua José Maria Ottony' 'Avenida do Fojo - São Pedro ( Este)'
#  'Praça dos Arsenalistas' 'Calçada de Vilar' 'Sem Nome' 'Rua Mira A Naia'
#  'Rua Doutor José Vilaça - São José de São Lázaro'
#  'Rua Jaime Sotto Mayor - São Victor' 'Rua dos Biscaínhos'
#  'Rua dos Pereiros - São Pedro ( Este)'
#  'Rua Doutor António Brandão Pereira' 'Rua do Pica'
#  'Rua de São João Batista - Semelhe' 'Travessa 10 de Junho'
#  'Alameda do Fujacal' 'Rua José Afonso - São Vicente'
#  'Avenida Robert Smith - Fraião' 'Caminho do Peixoto'
#  'Rua dos Amões - São Pedro ( Este)' 'Travessa da Naia'
#  'Rua 8 de Dezembro - São Pedro ( Este)' 'Largo da Amarela - Gondizalves'
#  'Rua Doutor Costa Júnior' 'Praceta Joaquim Chaves' 'Rua 25 de Abril'
#  'Rua da Ribeira' 'Rua da Herdade' 'Rua Óscar Dias Pereira - Gualtar'
#  'Avenida de Trezeste' 'Rua Doutor Sérgio Silva Pinto'
#  'Rua José Ferreira Alves' 'Tebosa' 'Rua do Ventoso - Lomar'
#  'Rua das Rosas - Tenões' 'Rua dos Leões' 'Rua da Cachada - Gondizalves'
#  'Rua Fotógrafo Arcelino' 'Praça Ricardo da Rocha - São Victor'
#  'Rua da Confeiteira' 'Avenida de São Roque' 'Rua de Ruílhe - Ruílhe'
#  'Rua da Taxa - São Victor' 'Praceta Manuel Álvares - São Vicente'
#  'Rua das Andorinheiras' 'Rua 15 de Maio - Tenões'
#  'Rua Senhor dos Aflitos' 'Rua do Marco' 'Travessa do Carmo'
#  'Travessa Encosta do Monte' 'Praça Doutor José Augusto Ferreira Salgado'
#  'Avenida Central - São José de São Lázaro' 'Rua de Vila Nova'
#  'Rua de Casais - Ferreiros' 'Rua de São João' 'Rua Emílio Rodrigues'
#  'Rua Padre Manuel Guimarães - Real' 'Rua de Areias' 'Rua da Rasa'
#  'Avenida de Sequeira' 'Rua Infantário' 'Rua Damião de Góis'
#  'Rua Doutor Justino da Cruz' 'Largo do Paço'
#  'Rua Dom António Ferreira Gomes' 'Rua de Espinde'
#  'Rua Nova de Santa Cruz - São Victor' 'Rua Direita'
#  'Rua de Entre-Portas - Dume' 'Rua Juiz António Cândido Gomes - Maximinos'
#  'Rua de Resende' 'Cangosta do Jogo da Bola - Dume'
#  'Rua da Escola - Frossos' 'Rua da Carreira' 'Rua José da Cunha - Real'
#  'Rua José Estevão - Lomar' 'Rua Ernesto Nogueira'
#  'Rua Doutor Amândio César' 'Rua Alfredo Vieira Gomes' 'Rua do Canal']
# Valores únicos para a coluna  Latitude :  [41.55465985 41.50774612 41.54955    ... 41.5517743  41.553
#  41.52637533]
# Valores únicos para a coluna  Longitude :  [-8.43297084 -8.47745541 -8.43772    ... -8.4116957  -8.422
#  -8.41627635]
# Valores únicos para a coluna  Tipologia :  [nan 'T0' 'T4' 'T3' 'T1' 'T5' 'T2' 'T6' 'T10 ou superior' 'T7' 'T8']
# Valores únicos para a coluna  Nº Casas de Banho :  [nan '2' '3' '4 ou mais' '1']
# Valores únicos para a coluna  Área útil m/2 :  [32.0 nan 100.0 240.0 127.0 224.0 106.0 120.0 168.5 300.0 292.0 198.0
# Valores únicos para a coluna  Armário :  [nan True]
# Valores únicos para a coluna  Cozinha equipada :  [nan True]
# Valores únicos para a coluna  Garagem box :  [nan True]
# Valores únicos para a coluna  Gás canalizado :  [nan True]
# Valores únicos para a coluna  Lareira :  [nan True]
# Valores únicos para a coluna  Marquise :  [nan True]
# Valores únicos para a coluna  Suite :  [nan True]
# Valores únicos para a coluna  Varanda :  [nan True]
# Valores únicos para a coluna  Vista de cidade :  [nan True]
# Valores únicos para a coluna  Condição :  ['Usado' nan 'Ruína' 'Novo' 'Em construção' 'Renovado' 'Para recuperar']
# Valores únicos para a coluna  Despensa :  [nan True]
# Valores únicos para a coluna  Arrecadação :  [nan True]
# Valores únicos para a coluna  Porta blindada :  [nan True]
# Valores únicos para a coluna  Video Porteiro :  [nan True]
# Valores únicos para a coluna  Empreendimento :  [nan 'não' 'sim']
# Valores únicos para a coluna  Ar condicionado :  [nan True]
# Valores únicos para a coluna  Elevador :  [nan True]
# Valores únicos para a coluna  Estores elétricos :  [nan]
# Valores únicos para a coluna  Fibra ótica :  [nan True]
# Valores únicos para a coluna  Pré-instalação de ar condicionado :  [nan True]
# Valores únicos para a coluna  Terraço :  [nan True]
# Valores únicos para a coluna  Área de terreno m/2 :  [nan]
# Valores únicos para a coluna  Churrasco :  [nan True]
# Valores únicos para a coluna  Árvores de fruto :  [nan True]
# Valores únicos para a coluna  Sotão :  [nan True]
# Valores únicos para a coluna  Cave :  [nan True]
# Valores únicos para a coluna  Jardim :  [nan True]
# Valores únicos para a coluna  Aquecimento central :  [nan True]
# Valores únicos para a coluna  Caldeira :  [nan True]
# Valores únicos para a coluna  Acessibilidade a pessoas com mobilidade condicionada :  [nan True]
# Valores únicos para a coluna  Box 2 carros :  [nan]
# Valores únicos para a coluna  Detetor de gás :  [nan True]
# Valores únicos para a coluna  Painéis solares :  [nan True]
# Valores únicos para a coluna  Recuperação de calor :  [nan True]
# Valores únicos para a coluna  Vista de campo/serra :  [nan True]
# Valores únicos para a coluna  Box 1 carro :  [nan]
# Valores únicos para a coluna  Portaria :  [nan True]
# Valores únicos para a coluna  Estacionamento :  [nan True]
# Valores únicos para a coluna  Piso radiante :  [nan True]
# Valores únicos para a coluna  Som ambiente :  [nan True]
# Valores únicos para a coluna  Aspiração central :  [nan True]
# Valores únicos para a coluna  Finalidade :  [nan 'Habitação' 'Comércio' 'Zona agrícola']
# Valores únicos para a coluna  Tipo de terreno :  [nan 'Rústico' 'Urbano' 'Industrial' 'Urbanizável' 'Não urbanizável']
# Valores únicos para a coluna  Acesso pavimentado :  [nan True]
# Valores únicos para a coluna  Asfaltado :  [nan True]
# Valores únicos para a coluna  Iluminação pública :  [nan True]
# Valores únicos para a coluna  Zona arborizada :  [nan True]
# Valores únicos para a coluna  Declive :  [nan 'Plano' 'Moderado (entre 20º e 30º)' 'Suave (entre 10º e 20º)'
#  'Elevado (superior a 30º)']
# Valores únicos para a coluna  Ruína :  [nan True]
# Valores únicos para a coluna  Alarme :  [nan True]
# Valores únicos para a coluna  Furo de água :  [nan True]
# Valores únicos para a coluna  Domótica :  [nan True]
# Valores únicos para a coluna  Casa das máquinas :  [nan]
# Valores únicos para a coluna  Condomínio Fechado :  [nan True]
# Valores únicos para a coluna  Parque infantil :  [nan True]
# Valores únicos para a coluna  Piscina :  [nan True]
# Valores únicos para a coluna  Piscina Privada :  [nan True]
# Valores únicos para a coluna  Termoacumulador :  [nan True]
# Valores únicos para a coluna  Garagem exterior :  [nan True]
# Valores únicos para a coluna  Mobilado :  [nan True]
# Valores únicos para a coluna  Hidromassagem/jacuzzi :  [nan True]
# Valores únicos para a coluna  Quintal/horta :  [nan True]
# Valores únicos para a coluna  Ginásio :  [nan True]
# Valores únicos para a coluna  Kitchenette :  [nan True]
# Valores únicos para a coluna  Vigilância/segurança :  [nan True]
# Valores únicos para a coluna  Campo de ténis :  [nan True]
# Valores únicos para a coluna  Segurança 24 horas :  [nan True]
# Valores únicos para a coluna  Vedação :  [nan True]
# Valores únicos para a coluna  Parqueamento (1 carro) :  [nan True]
# Valores únicos para a coluna  Ligação a rede de água :  [nan True]
# Valores únicos para a coluna  Ligação a rede de saneamento :  [nan]
# Valores únicos para a coluna  Ligação a rede elétrica :  [nan True]
# Valores únicos para a coluna  Animais permitidos :  [nan True]
# Valores únicos para a coluna  Parqueamento (2 carros) :  [nan True]
# Valores únicos para a coluna  Cofre :  [nan True]
# Valores únicos para a coluna  Vista de rio :  [nan True]
# Valores únicos para a coluna  Nº divisões :  [ 2. nan  5.  3.  6.  4.]
# Valores únicos para a coluna  Tipo :  ['Loja' nan 'Restaurante' 'Bar' 'Box (2 carros)']
# Valores únicos para a coluna  Pisos :  [ 1. nan  3.  2.]
# Valores únicos para a coluna  Com WC :  [True nan]
# Valores únicos para a coluna  Montra :  [True nan]
# Valores únicos para a coluna  Anexo habitacional :  [nan True]
# Valores únicos para a coluna  Detetor de incêndio :  [nan]
# Valores únicos para a coluna  Detetor de Inundução :  [nan]
# Valores únicos para a coluna  Área (m/2) :  [nan 23.0 460.0 700.0 85.0 89.0 17.0 1018.0 120.0 19.0 15.0 800.0 572.0
#  150.0 40.0 540.0 332.0 475.0 100.0 454.0 280.0 3240.0 626.0 124.0 550.0
#  35.0 65.0 80.49 145.56 83.0 189.0 324.0 15.6 80.0 95.0 506.2 500.0 427.0
#  75.0 130.0 50.0 125.0 300.0 132.0 96.0 249.0 158.0 612.0 82.0 180.55
#  107.66 110.0 160.0 88.0 4024.0 92.0 222.0 750.0 36.0 270.0 475.37 186.0
#  140.0 55.0 38.0 90.0 1990.0 33.0 20.0 30.0 5.0 405.0 188.0 84.0 58.0
#  115.0 233.0 104.0 43.0 78.0 268.0 465.0 225.0 64.0 946.0 97.0 54.0 184.0
#  553.0 118.0 870.0 26.0 389.0 686.0 182.0 87.0 18.0 231.0 956.7 52.0 400.0
#  450.0 42.79 37.0 340.0 101.0 200.0 57.0 4526.0 117.0 127.0 119.0 61.0
#  208.0 277.0 751.0 305.0 4660.0 328.0 420.0 60.0 190.0 790.0 1628.0 330.0
#  161.0 496.0 76.0 1000.0 112.0 1628.53 70.0 650.0 105.0 28.0 91.0 1852.0
#  645.0 809.0 250.0 304.0 552.0 470.0 170.5 34.18 32.0 10.0 168.0 346.83
#  220.0 27.0 16.0 7042.0 174.0 15.2 69.0 600.0 456.0 170.0 22.0 99.0 46.0
#  952.0 421.0 851.0 4845.0 240.0 67.0 122.0 137.0 48.0 22.9]
# Valores únicos para a coluna  Vista de mar :  [nan True]
# Valores únicos para a coluna  Património classificado :  [nan True]
# Valores únicos para a coluna  Com cozinha :  [nan True]
# Valores únicos para a coluna  Imóvel de banca :  [nan True]
# Valores únicos para a coluna  Vista de lago :  [nan True]
# Valores únicos para a coluna  Fossa séptica :  [nan True]
# Valores únicos para a coluna  Licensa de construção :  [nan]
# Valores únicos para a coluna  Acesso a veículos pesados :  [nan True]
# Valores únicos para a coluna  Área administrativa :  [nan True]
# Valores únicos para a coluna  Copa :  [nan True]
# Valores únicos para a coluna  Recepção :  [nan True]
# Valores únicos para a coluna  Refeitório :  [nan]
# Valores únicos para a coluna  Sala de reuniões :  [nan]
# Valores únicos para a coluna  Área florestal :  [nan True]
# Valores únicos para a coluna  Percurso de água :  [nan True]
# Valores únicos para a coluna  Armazém :  [nan True]
# Valores únicos para a coluna  Adaptado a mobilidade reduzida :  [nan True]
# Valores únicos para a coluna  Terra batida :  [nan True]
# Valores únicos para a coluna  Video vigilância :  [nan True]
# Valores únicos para a coluna  Espaço frigorífico :  [nan]
# Valores únicos para a coluna  Espaço para arrumação :  [nan 'Sim']
# Valores únicos para a coluna  Casa de banho partilhada :  [nan True]
# Valores únicos para a coluna  Poço :  [nan True]
# Valores únicos para a coluna  Paisagem protegida :  [nan True]

# %% [markdown]
# **Dividir os dados por tipo de imóvel**

# %%
data_imo_trespasses = data_imo.loc[(data_imo['Tipo de imóvel'] == 'Trespasses')]
data_imo_trespasses.index = np.arange(1, len(data_imo_trespasses) + 1)

# %%
data_imo_trespasses.head()
# Out:
#          Id Tipo de imóvel   Preço  Preço m/2  \
# 1  12358735     Trespasses  123000       1025
# 2  15340571     Trespasses   99000        298
# 3  15089074     Trespasses   15990        160
# 4  15255657     Trespasses   73000        589
# 5  15046870     Trespasses   50000         91
#
#                                            Freguesia  \
# 1  Braga (São José de São Lázaro e São João do So...
# 2  Braga (São José de São Lázaro e São João do So...
# 3                   Braga (Maximinos, Sé e Cividade)
# 4                   Braga (Maximinos, Sé e Cividade)
# 5                                             Adaúfe
#
#                                       Rua   Latitude  Longitude Tipologia  \
# 1                                     NaN  41.550650  -8.425066       NaN
# 2  Praça da República - São João do Souto  41.551746  -8.423182       NaN
# 3                                     NaN  41.547620  -8.426740       NaN
# 4                                     NaN  41.545550  -8.427330       NaN
# 5                                     NaN  41.589984  -8.398076       NaN
#
#   Nº Casas de Banho Área útil m/2 Área bruta m/2  Ano construção  \
# 1               NaN           NaN            NaN             NaN
# 2               NaN           NaN            NaN             NaN
# 3               NaN           NaN            NaN             NaN
# 4               NaN           NaN            NaN             NaN
# 5               NaN           NaN            NaN             NaN
#
#   Certificado energético Armário Cozinha equipada Garagem box Gás canalizado  \
# 1                    NaN     NaN              NaN         NaN            NaN
# 2                      C     NaN              NaN         NaN            NaN
# 3                    NaN     NaN              NaN         NaN            NaN
# 4                    NaN     NaN              NaN         NaN            NaN
# 5                    NaN     NaN              NaN         NaN            NaN
#
#   Lareira Marquise Suite Varanda Vista de cidade Condição Despensa  \
# 1     NaN      NaN   NaN     NaN             NaN     Novo      NaN
# 2     NaN      NaN   NaN     NaN            True    Usado      NaN
# 3     NaN      NaN   NaN     NaN             NaN    Usado      NaN
# 4     NaN      NaN   NaN     NaN             NaN      NaN      NaN
# 5     NaN      NaN   NaN     NaN             NaN    Usado      NaN
#
#   Arrecadação Porta blindada Video Porteiro Empreendimento Ar condicionado  \
# 1         NaN            NaN            NaN            NaN             NaN
# 2         NaN            NaN            NaN            NaN             NaN
# 3         NaN            NaN            NaN            NaN             NaN
# 4         NaN            NaN            NaN            NaN             NaN
# 5         NaN            NaN            NaN            NaN             NaN
#
#   Elevador  Estores elétricos Fibra ótica Pré-instalação de ar condicionado  \
# 1      NaN                NaN         NaN                               NaN
# 2      NaN                NaN         NaN                               NaN
# 3      NaN                NaN         NaN                               NaN
# 4      NaN                NaN         NaN                               NaN
# 5      NaN                NaN         NaN                               NaN
#
#   Terraço  Área de terreno m/2 Churrasco Árvores de fruto Sotão Cave Jardim  \
# 1     NaN                  NaN       NaN              NaN   NaN  NaN    NaN
# 2     NaN                  NaN       NaN              NaN   NaN  NaN    NaN
# 3     NaN                  NaN       NaN              NaN   NaN  NaN    NaN
# 4     NaN                  NaN       NaN              NaN   NaN  NaN    NaN
# 5     NaN                  NaN       NaN              NaN   NaN  NaN    NaN
#
#   Aquecimento central Caldeira  \
# 1                 NaN      NaN
# 2                 NaN      NaN
# 3                 NaN      NaN
# 4                 NaN      NaN
# 5                 NaN      NaN
#
#   Acessibilidade a pessoas com mobilidade condicionada  Box 2 carros  \
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
# 5                                                NaN             NaN
#
#   Detetor de gás Painéis solares Recuperação de calor Vista de campo/serra  \
# 1            NaN             NaN                  NaN                  NaN
# 2            NaN             NaN                  NaN                  NaN
# 3            NaN             NaN                  NaN                  NaN
# 4            NaN             NaN                  NaN                  NaN
# 5            NaN             NaN                  NaN                  NaN
#
#    Box 1 carro Portaria Estacionamento Piso radiante Som ambiente  \
# 1          NaN      NaN            NaN           NaN          NaN
# 2          NaN      NaN           True           NaN          NaN
# 3          NaN      NaN            NaN           NaN          NaN
# 4          NaN      NaN            NaN           NaN          NaN
# 5          NaN      NaN            NaN           NaN          NaN
#
#   Aspiração central Finalidade Tipo de terreno Acesso pavimentado Asfaltado  \
# 1               NaN        NaN             NaN                NaN       NaN
# 2               NaN        NaN             NaN                NaN       NaN
# 3               NaN        NaN             NaN                NaN       NaN
# 4               NaN        NaN             NaN                NaN       NaN
# 5               NaN        NaN             NaN                NaN       NaN
#
#   Iluminação pública Zona arborizada Declive Ruína Alarme Furo de água  \
# 1                NaN             NaN     NaN   NaN    NaN          NaN
# 2                NaN             NaN     NaN   NaN    NaN          NaN
# 3                NaN             NaN     NaN   NaN    NaN          NaN
# 4                NaN             NaN     NaN   NaN    NaN          NaN
# 5                NaN             NaN     NaN   NaN    NaN          NaN
#
#   Domótica  Casa das máquinas Condomínio Fechado Parque infantil Piscina  \
# 1      NaN                NaN                NaN             NaN     NaN
# 2      NaN                NaN                NaN             NaN     NaN
# 3      NaN                NaN                NaN             NaN     NaN
# 4      NaN                NaN                NaN             NaN     NaN
# 5      NaN                NaN                NaN             NaN     NaN
#
#   Piscina Privada Termoacumulador Garagem exterior Mobilado  \
# 1             NaN             NaN              NaN      NaN
# 2             NaN             NaN              NaN      NaN
# 3             NaN             NaN              NaN      NaN
# 4             NaN             NaN              NaN      NaN
# 5             NaN             NaN              NaN      NaN
#
#   Hidromassagem/jacuzzi Quintal/horta Ginásio Kitchenette  \
# 1                   NaN           NaN     NaN         NaN
# 2                   NaN           NaN     NaN         NaN
# 3                   NaN           NaN     NaN         NaN
# 4                   NaN           NaN     NaN         NaN
# 5                   NaN           NaN     NaN         NaN
#
#   Vigilância/segurança Campo de ténis Segurança 24 horas Vedação  \
# 1                  NaN            NaN                NaN     NaN
# 2                  NaN            NaN                NaN     NaN
# 3                  NaN            NaN                NaN     NaN
# 4                  NaN            NaN                NaN     NaN
# 5                  NaN            NaN                NaN     NaN
#
#   Parqueamento (1 carro) Ligação a rede de água  Ligação a rede de saneamento  \
# 1                    NaN                    NaN                           NaN
# 2                    NaN                    NaN                           NaN
# 3                    NaN                    NaN                           NaN
# 4                    NaN                    NaN                           NaN
# 5                    NaN                    NaN                           NaN
#
#   Ligação a rede elétrica Animais permitidos Parqueamento (2 carros) Cofre  \
# 1                     NaN                NaN                     NaN   NaN
# 2                     NaN                NaN                     NaN   NaN
# 3                     NaN                NaN                     NaN   NaN
# 4                     NaN                NaN                     NaN   NaN
# 5                     NaN                NaN                     NaN   NaN
#
#   Vista de rio  Nº divisões  Tipo  Pisos Com WC Montra Anexo habitacional  \
# 1          NaN          NaN   NaN    NaN    NaN    NaN                NaN
# 2          NaN          3.0  Loja    NaN    NaN    NaN                NaN
# 3          NaN          NaN   NaN    NaN    NaN    NaN                NaN
# 4          NaN          NaN   NaN    NaN    NaN    NaN                NaN
# 5          NaN          NaN   NaN    NaN    NaN    NaN                NaN
#
#    Detetor de incêndio  Detetor de Inundução Área (m/2) Vista de mar  \
# 1                  NaN                   NaN        120          NaN
# 2                  NaN                   NaN        332          NaN
# 3                  NaN                   NaN        100          NaN
# 4                  NaN                   NaN        124          NaN
# 5                  NaN                   NaN        550          NaN
#
#   Património classificado Com cozinha Imóvel de banca Vista de lago  \
# 1                     NaN         NaN             NaN           NaN
# 2                     NaN         NaN             NaN           NaN
# 3                     NaN         NaN             NaN           NaN
# 4                     NaN         NaN             NaN           NaN
# 5                     NaN         NaN             NaN           NaN
#
#   Fossa séptica  Licensa de construção Acesso a veículos pesados  \
# 1           NaN                    NaN                       NaN
# 2           NaN                    NaN                       NaN
# 3           NaN                    NaN                       NaN
# 4           NaN                    NaN                       NaN
# 5           NaN                    NaN                       NaN
#
#   Área administrativa Copa Recepção Refeitório Sala de reuniões  \
# 1                 NaN  NaN      NaN        NaN              NaN
# 2                 NaN  NaN      NaN        NaN              NaN
# 3                 NaN  NaN      NaN        NaN              NaN
# 4                 NaN  NaN      NaN        NaN              NaN
# 5                 NaN  NaN      NaN        NaN              NaN
#
#   Área florestal Percurso de água Armazém Adaptado a mobilidade reduzida  \
# 1            NaN              NaN     NaN                            NaN
# 2            NaN              NaN     NaN                            NaN
# 3            NaN              NaN     NaN                            NaN
# 4            NaN              NaN     NaN                            NaN
# 5            NaN              NaN     NaN                            NaN
#
#   Terra batida Video vigilância  Espaço frigorífico Espaço para arrumação  \
# 1          NaN              NaN                 NaN                   NaN
# 2          NaN              NaN                 NaN                   NaN
# 3          NaN              NaN                 NaN                   NaN
# 4          NaN              NaN                 NaN                   NaN
# 5          NaN              NaN                 NaN                   NaN
#
#   Casa de banho partilhada Poço Paisagem protegida
# 1                      NaN  NaN                NaN
# 2                      NaN  NaN                NaN
# 3                      NaN  NaN                NaN
# 4                      NaN  NaN                NaN
# 5                      NaN  NaN                NaN

# %%
#data_imo_trespasses.info(verbose=True, null_counts=True)

# %% [markdown]
# ## Análise exploratória de dados

# %% [markdown]
# *Distribuição da feature 'Preço'*

# %%
fig = plt.figure(figsize = (20,5))
sns.set_style('darkgrid')
data_imo_trespasses['Preço'].hist(bins=30)
plt.xlabel('Preço')
# Out:
# Text(0.5, 0, 'Preço')

# %%
fig = plt.figure(figsize = (10,3))
sns.boxplot(x=data_imo_trespasses['Preço'])

# %% [markdown]
# *Distribuição da feature 'Preço' - Outliers visuais*

# %%
a_excluir = data_imo_trespasses[(data_imo_trespasses['Preço'] >= 200000)]
#a_excluir = data_imo_trespasses[(data_imo_trespasses['Preço'] >= 400000) | (data_imo_trespasses['Preço'] <= 150000)]
data_imo_trespasses = data_imo_trespasses.drop(a_excluir.index)
data_imo_trespasses.index = np.arange(1, len(data_imo_trespasses) + 1)
a_excluir
# Out:
#           Id Tipo de imóvel   Preço  Preço m/2  \
# 14  14464297     Trespasses  250000       2000
# 65  15304551     Trespasses  250000       1667
#
#                            Freguesia  Rua   Latitude  Longitude Tipologia  \
# 14  Braga (Maximinos, Sé e Cividade)  NaN  41.542927  -8.437615       NaN
# 65  Braga (Maximinos, Sé e Cividade)  NaN  41.549565  -8.430490       NaN
#
#    Nº Casas de Banho Área útil m/2 Área bruta m/2  Ano construção  \
# 14               NaN           NaN            NaN             NaN
# 65               NaN           NaN            NaN          2015.0
#
#    Certificado energético Armário Cozinha equipada Garagem box Gás canalizado  \
# 14                    NaN     NaN              NaN         NaN            NaN
# 65                      G     NaN              NaN         NaN            NaN
#
#    Lareira Marquise Suite Varanda Vista de cidade Condição Despensa  \
# 14     NaN      NaN   NaN     NaN             NaN    Usado      NaN
# 65     NaN      NaN   NaN     NaN             NaN    Usado      NaN
#
#    Arrecadação Porta blindada Video Porteiro Empreendimento Ar condicionado  \
# 14         NaN            NaN            NaN            NaN             NaN
# 65         NaN            NaN            NaN            NaN             NaN
#
#    Elevador  Estores elétricos Fibra ótica Pré-instalação de ar condicionado  \
# 14      NaN                NaN         NaN                               NaN
# 65      NaN                NaN         NaN                               NaN
#
#    Terraço  Área de terreno m/2 Churrasco Árvores de fruto Sotão Cave Jardim  \
# 14     NaN                  NaN       NaN              NaN   NaN  NaN    NaN
# 65     NaN                  NaN       NaN              NaN   NaN  NaN    NaN
#
#    Aquecimento central Caldeira  \
# 14                 NaN      NaN
# 65                 NaN      NaN
#
#    Acessibilidade a pessoas com mobilidade condicionada  Box 2 carros  \
# 14                                                NaN             NaN
# 65                                                NaN             NaN
#
#    Detetor de gás Painéis solares Recuperação de calor Vista de campo/serra  \
# 14            NaN             NaN                  NaN                  NaN
# 65            NaN             NaN                  NaN                  NaN
#
#     Box 1 carro Portaria Estacionamento Piso radiante Som ambiente  \
# 14          NaN      NaN            NaN           NaN          NaN
# 65          NaN      NaN            NaN           NaN          NaN
#
#    Aspiração central Finalidade Tipo de terreno Acesso pavimentado Asfaltado  \
# 14               NaN        NaN             NaN                NaN       NaN
# 65               NaN        NaN             NaN                NaN       NaN
#
#    Iluminação pública Zona arborizada Declive Ruína Alarme Furo de água  \
# 14                NaN             NaN     NaN   NaN    NaN          NaN
# 65                NaN             NaN     NaN   NaN    NaN          NaN
#
#    Domótica  Casa das máquinas Condomínio Fechado Parque infantil Piscina  \
# 14      NaN                NaN                NaN             NaN     NaN
# 65      NaN                NaN                NaN             NaN     NaN
#
#    Piscina Privada Termoacumulador Garagem exterior Mobilado  \
# 14             NaN             NaN              NaN      NaN
# 65             NaN             NaN              NaN      NaN
#
#    Hidromassagem/jacuzzi Quintal/horta Ginásio Kitchenette  \
# 14                   NaN           NaN     NaN         NaN
# 65                   NaN           NaN     NaN         NaN
#
#    Vigilância/segurança Campo de ténis Segurança 24 horas Vedação  \
# 14                  NaN            NaN                NaN     NaN
# 65                  NaN            NaN                NaN     NaN
#
#    Parqueamento (1 carro) Ligação a rede de água  \
# 14                    NaN                    NaN
# 65                    NaN                    NaN
#
#     Ligação a rede de saneamento Ligação a rede elétrica Animais permitidos  \
# 14                           NaN                     NaN                NaN
# 65                           NaN                     NaN                NaN
#
#    Parqueamento (2 carros) Cofre Vista de rio  Nº divisões         Tipo  \
# 14                     NaN   NaN          NaN          NaN          NaN
# 65                     NaN   NaN          NaN          NaN  Restaurante
#
#     Pisos Com WC Montra Anexo habitacional  Detetor de incêndio  \
# 14    NaN    NaN    NaN                NaN                  NaN
# 65    NaN   True    NaN                NaN                  NaN
#
#     Detetor de Inundução Área (m/2) Vista de mar Património classificado  \
# 14                   NaN        125          NaN                     NaN
# 65                   NaN        150          NaN                     NaN
#
#    Com cozinha Imóvel de banca Vista de lago Fossa séptica  \
# 14         NaN             NaN           NaN           NaN
# 65        True             NaN           NaN           NaN
#
#     Licensa de construção Acesso a veículos pesados Área administrativa Copa  \
# 14                    NaN                       NaN                 NaN  NaN
# 65                    NaN                       NaN                 NaN  NaN
#
#    Recepção Refeitório Sala de reuniões Área florestal Percurso de água  \
# 14      NaN        NaN              NaN            NaN              NaN
# 65      NaN        NaN              NaN            NaN              NaN
#
#    Armazém Adaptado a mobilidade reduzida Terra batida Video vigilância  \
# 14     NaN                            NaN          NaN              NaN
# 65     NaN                            NaN          NaN              NaN
#
#     Espaço frigorífico Espaço para arrumação Casa de banho partilhada Poço  \
# 14                 NaN                   NaN                      NaN  NaN
# 65                 NaN                   NaN                      NaN  NaN
#
#    Paisagem protegida
# 14                NaN
# 65                NaN

# %% [markdown]
# *Relação entre o Preço e outras variáveis*

# %%
fig = plt.figure(figsize = (30,15))

ax1 = fig.add_subplot(2,3,1)
ax1.scatter(data_imo_trespasses['Área (m/2)'], data_imo_trespasses['Preço'])
ax1.set_xlabel('Área')
ax1.set_ylabel('Preço')
# Out:
# Text(0, 0.5, 'Preço')

# %% [markdown]
# *Relacionamento do 'Preço' com outras features categóricas importantes*

# %%
cat_data = data_imo_trespasses[['Freguesia']]

# %%
for cat in cat_data.dtypes[:10].index.values:
    plt.figure(figsize=(20, 8))
    plt.xticks(rotation=90)
    sns.boxplot(x=cat, y='Preço', data=data_imo_trespasses) 
    sns.swarmplot(x=cat, y='Preço', data=data_imo_trespasses)
    plt.show()

# %% [markdown]
# **Dados em falta por coluna**

# %%
pd.set_option('display.max_rows', None)
percent_missing = data_imo_trespasses.isnull().sum() * 100 / len(data_imo_trespasses)
missing_value_data_imo_trespasses_columns = pd.DataFrame({'percent_missing (%)': percent_missing})
sort_data = missing_value_data_imo_trespasses_columns.copy()
sort_data.sort_values('percent_missing (%)', inplace=True, ascending=False)
sort_data
# Out:
#                                                     percent_missing (%)
# Declive                                                      100.000000
# Quintal/horta                                                100.000000
# Parqueamento (2 carros)                                      100.000000
# Animais permitidos                                           100.000000
# Ligação a rede elétrica                                      100.000000
# Ligação a rede de saneamento                                 100.000000
# Ligação a rede de água                                       100.000000
# Parqueamento (1 carro)                                       100.000000
# Vedação                                                      100.000000
# Segurança 24 horas                                           100.000000
# Campo de ténis                                               100.000000
# Vigilância/segurança                                         100.000000
# Kitchenette                                                  100.000000
# Ginásio                                                      100.000000
# Hidromassagem/jacuzzi                                        100.000000
# Iluminação pública                                           100.000000
# Mobilado                                                     100.000000
# Garagem exterior                                             100.000000
# Termoacumulador                                              100.000000
# Piscina Privada                                              100.000000
# Piscina                                                      100.000000
# Parque infantil                                              100.000000
# Condomínio Fechado                                           100.000000
# Casa das máquinas                                            100.000000
# Domótica                                                     100.000000
# Furo de água                                                 100.000000
# Alarme                                                       100.000000
# Ruína                                                        100.000000
# Cofre                                                        100.000000
# Vista de rio                                                 100.000000
# Pisos                                                        100.000000
# Montra                                                       100.000000
# Poço                                                         100.000000
# Casa de banho partilhada                                     100.000000
# Espaço para arrumação                                        100.000000
# Espaço frigorífico                                           100.000000
# Video vigilância                                             100.000000
# Terra batida                                                 100.000000
# Adaptado a mobilidade reduzida                               100.000000
# Armazém                                                      100.000000
# Percurso de água                                             100.000000
# Área florestal                                               100.000000
# Sala de reuniões                                             100.000000
# Refeitório                                                   100.000000
# Recepção                                                     100.000000
# Copa                                                         100.000000
# Área administrativa                                          100.000000
# Acesso a veículos pesados                                    100.000000
# Licensa de construção                                        100.000000
# Fossa séptica                                                100.000000
# Vista de lago                                                100.000000
# Imóvel de banca                                              100.000000
# Património classificado                                      100.000000
# Vista de mar                                                 100.000000
# Detetor de Inundução                                         100.000000
# Detetor de incêndio                                          100.000000
# Anexo habitacional                                           100.000000
# Zona arborizada                                              100.000000
# Paisagem protegida                                           100.000000
# Asfaltado                                                    100.000000
# Área de terreno m/2                                          100.000000
# Área bruta m/2                                               100.000000
# Fibra ótica                                                  100.000000
# Estores elétricos                                            100.000000
# Elevador                                                     100.000000
# Ar condicionado                                              100.000000
# Acesso pavimentado                                           100.000000
# Empreendimento                                               100.000000
# Video Porteiro                                               100.000000
# Porta blindada                                               100.000000
# Arrecadação                                                  100.000000
# Despensa                                                     100.000000
# Tipologia                                                    100.000000
# Nº Casas de Banho                                            100.000000
# Varanda                                                      100.000000
# Suite                                                        100.000000
# Marquise                                                     100.000000
# Lareira                                                      100.000000
# Gás canalizado                                               100.000000
# Garagem box                                                  100.000000
# Cozinha equipada                                             100.000000
# Armário                                                      100.000000
# Terraço                                                      100.000000
# Pré-instalação de ar condicionado                            100.000000
# Churrasco                                                    100.000000
# Painéis solares                                              100.000000
# Tipo de terreno                                              100.000000
# Finalidade                                                   100.000000
# Aspiração central                                            100.000000
# Som ambiente                                                 100.000000
# Piso radiante                                                100.000000
# Portaria                                                     100.000000
# Box 1 carro                                                  100.000000
# Vista de campo/serra                                         100.000000
# Árvores de fruto                                             100.000000
# Recuperação de calor                                         100.000000
# Detetor de gás                                               100.000000
# Box 2 carros                                                 100.000000
# Acessibilidade a pessoas com mobilidade condici...           100.000000
# Caldeira                                                     100.000000
# Aquecimento central                                          100.000000
# Jardim                                                       100.000000
# Cave                                                         100.000000
# Sotão                                                        100.000000
# Área útil m/2                                                100.000000
# Estacionamento                                                97.826087
# Com cozinha                                                   94.565217
# Rua                                                           94.565217
# Vista de cidade                                               92.391304
# Nº divisões                                                   90.217391
# Com WC                                                        88.043478
# Tipo                                                          83.695652
# Ano construção                                                80.434783
# Certificado energético                                        70.652174
# Condição                                                      27.173913
# Área (m/2)                                                     0.000000
# Longitude                                                      0.000000
# Latitude                                                       0.000000
# Tipo de imóvel                                                 0.000000
# Freguesia                                                      0.000000
# Preço m/2                                                      0.000000
# Preço                                                          0.000000
# Id                                                             0.000000

# %%
pd.set_option('display.max_rows', 10)

# %% [markdown]
# **Remover colunas que tenham mais de 30% (?) de missing values**

# %%
a_manter = list(missing_value_data_imo_trespasses_columns.index[missing_value_data_imo_trespasses_columns['percent_missing (%)'] < 30])
data_imo_trespasses = data_imo_trespasses[a_manter]
data_imo_trespasses
# Out:
#           Id Tipo de imóvel   Preço  Preço m/2  \
# 1   12358735     Trespasses  123000       1025
# 2   15340571     Trespasses   99000        298
# 3   15089074     Trespasses   15990        160
# 4   15255657     Trespasses   73000        589
# 5   15046870     Trespasses   50000         91
# ..       ...            ...     ...        ...
# 88  14991608     Trespasses   80000        727
# 89  15222039     Trespasses   50000        746
# 90  14667279     Trespasses   25000        417
# 91  13161934     Trespasses   67500        493
# 92  15322470     Trespasses  100000        250
#
#                                             Freguesia   Latitude  Longitude  \
# 1   Braga (São José de São Lázaro e São João do So...  41.550650  -8.425066
# 2   Braga (São José de São Lázaro e São João do So...  41.551746  -8.423182
# 3                    Braga (Maximinos, Sé e Cividade)  41.547620  -8.426740
# 4                    Braga (Maximinos, Sé e Cividade)  41.545550  -8.427330
# 5                                              Adaúfe  41.589984  -8.398076
# ..                                                ...        ...        ...
# 88                      Este (São Pedro e São Mamede)  41.570113  -8.356951
# 89                   Braga (Maximinos, Sé e Cividade)  41.546678  -8.433955
# 90  Braga (São José de São Lázaro e São João do So...  41.550650  -8.425066
# 91                                            Gualtar  41.564190  -8.405680
# 92                      Merelim (São Pedro) e Frossos  41.566420  -8.450972
#
#    Condição Área (m/2)
# 1      Novo        120
# 2     Usado        332
# 3     Usado        100
# 4       NaN        124
# 5     Usado        550
# ..      ...        ...
# 88    Usado        110
# 89    Usado         67
# 90    Usado         60
# 91    Usado        137
# 92    Usado        400
#
# [92 rows x 9 columns]

# %% [markdown]
# **Dados em falta por linha**

# %%
percent_missing = (1 - data_imo_trespasses.apply(lambda x: x.count(), axis=1) / len(data_imo_trespasses.columns)) * 100
missing_value_data_imo_trespasses_rows = pd.DataFrame({'percent_missing (%)': percent_missing})
sort_data = missing_value_data_imo_trespasses_rows.copy()
sort_data.sort_values('percent_missing (%)', inplace=True, ascending=False)
sort_data
# Out:
#     percent_missing (%)
# 71            11.111111
# 76            11.111111
# 72            11.111111
# 25            11.111111
# 27            11.111111
# ..                  ...
# 32             0.000000
# 31             0.000000
# 30             0.000000
# 29             0.000000
# 92             0.000000
#
# [92 rows x 1 columns]

# %% [markdown]
# **Remover linhas com percentagem de dados em falta superior a 50%**

# %%
a_excluir = missing_value_data_imo_trespasses_rows[(missing_value_data_imo_trespasses_rows['percent_missing (%)'] >= 50)]
data_imo_trespasses = data_imo_trespasses.drop(a_excluir.index)
data_imo_trespasses.index = np.arange(1, len(data_imo_trespasses) + 1)

# %% [markdown]
# **Inserir dados em falta**

# %%
for x in data_imo_trespasses.select_dtypes(include=['float64']).columns.tolist():
    median_value=data_imo_trespasses[x].median()
    data_imo_trespasses[x]=data_imo_trespasses[x].fillna(median_value)

for y in data_imo_trespasses.select_dtypes(include=['object']).columns.tolist():
    mode_value=data_imo_trespasses[y].mode()
    data_imo_trespasses[y]=data_imo_trespasses[y].fillna(mode_value[0])    
    
data_imo_trespasses
# Out:
#           Id Tipo de imóvel   Preço  Preço m/2  \
# 1   12358735     Trespasses  123000       1025
# 2   15340571     Trespasses   99000        298
# 3   15089074     Trespasses   15990        160
# 4   15255657     Trespasses   73000        589
# 5   15046870     Trespasses   50000         91
# ..       ...            ...     ...        ...
# 88  14991608     Trespasses   80000        727
# 89  15222039     Trespasses   50000        746
# 90  14667279     Trespasses   25000        417
# 91  13161934     Trespasses   67500        493
# 92  15322470     Trespasses  100000        250
#
#                                             Freguesia   Latitude  Longitude  \
# 1   Braga (São José de São Lázaro e São João do So...  41.550650  -8.425066
# 2   Braga (São José de São Lázaro e São João do So...  41.551746  -8.423182
# 3                    Braga (Maximinos, Sé e Cividade)  41.547620  -8.426740
# 4                    Braga (Maximinos, Sé e Cividade)  41.545550  -8.427330
# 5                                              Adaúfe  41.589984  -8.398076
# ..                                                ...        ...        ...
# 88                      Este (São Pedro e São Mamede)  41.570113  -8.356951
# 89                   Braga (Maximinos, Sé e Cividade)  41.546678  -8.433955
# 90  Braga (São José de São Lázaro e São João do So...  41.550650  -8.425066
# 91                                            Gualtar  41.564190  -8.405680
# 92                      Merelim (São Pedro) e Frossos  41.566420  -8.450972
#
#    Condição  Área (m/2)
# 1      Novo       120.0
# 2     Usado       332.0
# 3     Usado       100.0
# 4     Usado       124.0
# 5     Usado       550.0
# ..      ...         ...
# 88    Usado       110.0
# 89    Usado        67.0
# 90    Usado        60.0
# 91    Usado       137.0
# 92    Usado       400.0
#
# [92 rows x 9 columns]

# %%
sns.heatmap(data_imo_trespasses.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# ## Estruturação dos Dados

# %% [markdown]
# ## Inserção de dados acerca da localização do imóvel
#
# *www.google.com/maps/*

# %% [markdown]
# **Funções auxiliares**

# %%
def distance_coordinates(lat1,lon1,lat2,lon2):
    
    coords_1 = (lat1, lon1)
    coords_2 = (lat2, lon2)
    
    res = geopy.distance.geodesic(coords_1, coords_2).km

    return round(res,3)

def minDist(data_imo, values):
    distancias = []
    for index, row in data_imo.iterrows():
        min_dist = 99999999.9
        for value in values.values():
            dist = distance_coordinates(data_imo_trespasses.iloc[index-1]['Latitude'],data_imo_trespasses.iloc[index-1]['Longitude'],value[0],value[1])
            if dist < min_dist:
                min_dist = dist    
        distancias.append(min_dist)
    return distancias

# %% [markdown]
# **Centro da Cidade**

# %%
centro_cidade = {}
centro_cidade['Centro'] = 41.5514083,-8.4230248

# %%
data_imo_trespasses['Centro Cidade (km)'] = minDist(data_imo_trespasses, centro_cidade)

# %% [markdown]
# **Hospitais**

# %%
hospitais = {}
hospitais['Hospital de Braga'] = 41.5679738,-8.3990116
hospitais['Trofa Saúde - Braga Sul'] = 41.5246625,-8.4141593
hospitais['Trofa Saúde - Braga Centro'] = 41.5498965,-8.4187538
hospitais['Lusíadas Braga'] = 41.5476764,-8.4224197

# %%
data_imo_trespasses['Hospitais (km)'] = minDist(data_imo_trespasses, hospitais)

# %% [markdown]
# **Centros de Saúde**

# %%
centros_saude = {}
centros_saude['Braga Centro'] = 41.5471857,-8.4279198
centros_saude['Infias'] = 41.5602432,-8.4228005
centros_saude['USF do Minho'] = 41.5465815,-8.4147386
centros_saude['Clinica de Sao Marcos'] = 41.5454486,-8.426507
centros_saude['O Poverello'] = 41.5703584,-8.4114745
centros_saude['Clinica Cubana Braga'] = 41.5492599,-8.4262347
centros_saude['Clinica Médico - Cirurgica De Santa Tecla'] = 41.5489178,-8.4117642
centros_saude['Hemoatlantico - Braga'] = 41.5459355,-8.4314237
centros_saude['Centro de Vacinação Internacional'] = 41.5586578,-8.3999608
centros_saude['Clinica Enguardas'] = 41.5571581,-8.4127898
centros_saude['USF Braga Norte'] = 41.5603489,-8.4227264
centros_saude['USF Carandá'] = 41.5525337,-8.4123
centros_saude['USF Bracara Augusta'] = 41.5422297,-8.4105532
centros_saude['USF Maxisaúde'] = 41.5473324,-8.4279983
centros_saude['USF São Lourenço'] = 41.5142651,-8.4559502
centros_saude['USF São João de Braga'] = 41.5463782,-8.4145564
centros_saude['USF Manuel Rocha Peixoto'] = 41.5473003,-8.4279339
centros_saude['USF Gualtar'] = 41.5682764,-8.3871645
centros_saude['USF Saúde Oeste'] = 41.5325817,-8.4733681
centros_saude['USF Tadim'] = 41.5079792,-8.4879975
centros_saude['Gualtar'] = 41.5683003,-8.3872187
centros_saude['USF Esporões'] = 41.5120606,-8.4201814
centros_saude['USF Salutis'] = 41.5465247,-8.4147014
centros_saude['USP de Braga'] = 41.5588888,-8.3998833

# %%
data_imo_trespasses['Centros Saúde (km)'] = minDist(data_imo_trespasses, centros_saude)

# %% [markdown]
# **Centros Comerciais**

# %%
centroscomerciais = {}
centroscomerciais['Braga Parque'] = 41.5577669,-8.4060603
centroscomerciais['Minho Center'] = 41.540935,-8.400464
centroscomerciais['Nova Arcada'] = 41.579068,-8.429654

# %%
data_imo_trespasses['Centro Comerciais (km)'] = minDist(data_imo_trespasses, centroscomerciais)

# %% [markdown]
# **Escolas**

# %%
escolas = {}
escolas['Secundária Sá de Miranda'] = 41.5568137,-8.4182525
escolas['Básica Francisco Sanches'] = 41.5548131,-8.4118978
escolas['Básica de Gualtar'] = 41.5669867,-8.38796
escolas['Básica de Lamaçães'] = 41.5471216,-8.4016327
escolas['Secundária Carlos Amarante'] = 41.5509961,-8.413909
escolas['Básica de Palmeira'] = 41.5771831,-8.4245399
escolas['Secundária de Maximinos'] = 41.5424538,-8.4415713
escolas['Básica André Soares'] = 41.5470115,-8.415924
escolas['Básica do 1º Ciclo de São Vitor'] = 41.55186,-8.4129202
escolas['Básica de Real'] = 41.5577824,-8.4395854
escolas['Jardim Escola João de Deus'] = 41.5447436,-8.407904
escolas['Colégio Luso Internacional de Braga'] = 41.56979,-8.3885487
escolas['EB1 Quinta da Veiga'] = 41.5590263,-8.4239226
escolas['Secundária D. Maria II'] = 41.5487484,-8.4177364
escolas['Básica Bairro da Misericórdia'] = 41.5578043,-8.4262862
escolas['EB1 Carandá'] = 41.5452545,-8.4156397
escolas['Colégio Dom Diogo de Sousa'] = 41.5575,-8.415931
escolas['Centro Escolar Ponte Pedrinha'] = 41.5403601,-8.4294783
escolas['EB1/J1 Bairro da Alegria'] = 41.5638599,-8.402921

# %%
data_imo_trespasses['Escolas (km)'] = minDist(data_imo_trespasses, escolas)

# %% [markdown]
# **Universidades**

# %%
universidades = {}
universidades['Universidade do Minho - Campus de Gualtar'] = 41.5607319,-8.3962368
universidades['IPCA - Pólo de Braga'] = 41.5421121,-8.4210972
universidades['Universidade Católica Portuguesa'] = 41.554852,-8.4209143

# %%
data_imo_trespasses['Universidades (km)'] = minDist(data_imo_trespasses, universidades)

# %% [markdown]
# **Estação de Comboios**

# %%
estacao = {}
estacao['Estacao'] = 41.548143,-8.4344431

# %%
data_imo_trespasses['Estação de Comboios (km)'] = minDist(data_imo_trespasses, estacao)

# %% [markdown]
# **Parques Industriais**
#
# *www.igogo.pt/parques-industriais-braga/*

# %%
parques_industriais = {}
parques_industriais['Frossos'] = 41.5595545,-8.447319
parques_industriais['Quinta do Carreiro'] = 41.5653531,-8.4454561
parques_industriais['Adaúfe'] = 41.5974779,-8.4135554
parques_industriais['Celeirós'] = 41.5109663,-8.454419
parques_industriais['Marvilha'] = 41.5318363,-8.4735374
parques_industriais['Mire de Tibães'] = 41.5819656,-8.4767172
parques_industriais['Padim da Graça'] = 41.5692605,-8.4890601
parques_industriais['Pitancinhos'] = 41.5840245,-8.4219733
parques_industriais['Vilça'] = 41.5154222,-8.4937553

# %%
data_imo_trespasses['Parques Industriais (km)'] = minDist(data_imo_trespasses, parques_industriais)

# %% [markdown]
# **Central de Autocarros**

# %%
central_autocarros = {}
central_autocarros['Central'] = 41.555324,-8.425410

# %%
data_imo_trespasses['Central Autocarros (km)'] = minDist(data_imo_trespasses, central_autocarros)

# %% [markdown]
# **Bancos**

# %%
bancos = {}
bancos['BPI Frossos'] = 41.561298,-8.447379
bancos['BPI Gualtar'] = 41.5647823,-8.3876109
bancos['Crédito Agrícola Braga'] = 41.5514726,-8.4278259
bancos['Activo Bank'] = 41.5521836,-8.4267081
bancos['Banif Centro'] = 41.5524396,-8.4236611
bancos['Banco de Portugal'] = 41.5518264,-8.4234077
bancos['Montepio Centro'] = 41.5517009,-8.4180607
bancos['Montepio Centro 2'] = 41.5507289,-8.4250391
bancos['Novo Banco Centro'] = 41.5507776,-8.4238804
bancos['Banco de Investimento Global'] = 41.5495727,-8.4251216
bancos['Novo Banco Centro 2'] = 41.5492902,-8.4121129
bancos['Banco Millenium BCP São Lázaro'] = 41.5475307,-8.4210104
bancos['BBVA São Lázaro'] = 41.5464477,-8.4199778
bancos['Santander Totta Lamaçães'] = 41.5479773,-8.4033012
bancos['Caixa Geral de Depósito Lamaçães'] = 41.5480627,-8.4035902
bancos['BPI Dume'] = 41.5450355,-8.4019862
bancos['Novo Banco Maximinos'] = 41.5448869,-8.4337664
bancos['Caixa Geral de Depósitos Maximinos'] = 41.547196,-8.4338421
bancos['BPI N14'] = 41.53774,-8.434457

# %%
data_imo_trespasses['Bancos (km)'] = minDist(data_imo_trespasses, bancos)

# %% [markdown]
# **Correios**

# %%
correios = {}
correios['CTT Maximinos'] = 41.5444322,-8.4340695
correios['CTT São Lázaro'] = 41.544917,-8.420586
correios['CTT Fonte Seca'] = 41.535935,-8.4016483
correios['CTT 25 de Abril'] = 41.5474966,-8.4204056
correios['Estação de Correios de Santa Tecla'] = 41.5484275,-8.4118152
correios['CTT Nogueira, Fraiões e Lamaçães'] = 41.5480095,-8.4040274
correios['Posto de Correios de Braga (São José de Lázaro)'] = 41.5497985,-8.4193059
correios['CTT Largo de São Francisco'] = 41.5518429,-8.423987
correios['CTT Braga Parque'] = 41.556725,-8.4056481
correios['CTT Largo de Infias'] = 41.5579778,-8.4165392

# %%
data_imo_trespasses['Correios (km)'] = minDist(data_imo_trespasses, correios)

# %% [markdown]
# **Parques e zonas verdes**

# %%
parques_lazer = {}
parques_lazer['Parque de Lazer de Gerizes'] = 41.5835983,-8.449529
parques_lazer['Parque da Rodovia'] = 41.552828,-8.4031463
parques_lazer['Jardim da Avenida Central'] = 41.551519,-8.421523
parques_lazer['Parque São João da Ponte'] = 41.5454706,-8.4265083
parques_lazer['Parque da Ponte'] = 41.541304, -8.419441
parques_lazer['Parque de Lazer da Rampa da Falperra'] = 41.5309717,-8.3944834
parques_lazer['Parque de Lazer do Ribeiro dos Prados'] = 41.5052344,-8.4422877

# %%
data_imo_trespasses['Parques e Zonas Verdes (km)'] = minDist(data_imo_trespasses, parques_lazer)

# %% [markdown]
# **Serviços Públicos**
#
# *https://eportugal.gov.pt/locais-de-atendimento-de-servicos-publicos/-/pesquisa/search_stores*

# %%
servicos_publicos = {}
servicos_publicos['Finanças 1'] = 41.5498747,-8.4194008
servicos_publicos['Finanças 2'] = 41.5440114,-8.4358346
servicos_publicos['Segurança Social'] = 41.5477731,-8.4129363
servicos_publicos['Serviços de RSI'] = 41.5424794,-8.4360436
servicos_publicos['Gabinete de Atendimento ao Cidadão'] = 41.5561192,-8.4121799
servicos_publicos['Conservatória do Registo Civil'] = 41.5518773,-8.4222603
servicos_publicos['IEFP - Centro de Emprego'] = 41.5423426,-8.4339527
servicos_publicos['SEF - Loja do Cidadão de Braga'] = 41.5474961,-8.421969
servicos_publicos['Espaço Cidadão Sobreposta'] = 41.547783,-8.3619992
servicos_publicos['Espaço Cidadão Adaúfe'] = 41.5861605,-8.3926854
servicos_publicos['Espaço Cidadão Figueiredo'] = 41.5048946,-8.4349509
servicos_publicos['Espaço Cidadão Real'] = 41.5575145,-8.4440584
servicos_publicos['Espaço Cidadão S. Vicente'] = 41.5565553,-8.4241112
servicos_publicos['Espaço Cidadão Sequeira'] = 41.5323623,-8.4732977
servicos_publicos['Espaço Cidadão Tadim'] = 41.5057871,-8.4916939

# %%
data_imo_trespasses['Serviços Públicos (km)'] = minDist(data_imo_trespasses, servicos_publicos)

# %% [markdown]
# **Policia Municipal**

# %%
policia = {}
policia['Policia'] = 41.5495054,-8.4267993

# %%
data_imo_trespasses['Policia Municipal (km)'] = minDist(data_imo_trespasses, policia)

# %% [markdown]
# **Farmácias**
#
# *https://portalnacional.com.pt/braga/braga/farmacias/*

# %%
farmacias = {}
farmacias['Adaúfe'] = 41.5858796,-8.4020402
farmacias['Alvim - Merelim (São Pedro) e Frossos'] = 41.5595977,8.4479227
farmacias['Araújo Rodrigues - Celeirós'] = 41.5129219,-8.4503908
farmacias['Beatriz - São Vitor'] = 41.5492671,-8.4133199
farmacias['Braga - São Vitor'] = 41.5511534,-8.4064856
farmacias['Brito - São José de São Lázaro e São João do Souto'] = 41.5505688,-8.4228146
farmacias['Carmo - Merelim (São Pedro) e Frossos'] = 41.5716977,-8.45249
farmacias['Central - São José de São Lázaro e São João do Souto'] = 41.551847,-8.4250035
farmacias['Coelho - Maximinos, Sé e Cividade'] = 41.5514527,-8.4280069
farmacias['Cristal - São José de São Lázaro'] = 41.5486228,-8.4216631
farmacias['Santa Casa da Misericórdia - São José de São Lázaro e São João do Souto'] = 41.5490779,-8.4232058
farmacias['Esporões'] = 41.5119635,-8.4203129
farmacias['Gualtar'] = 41.565306,-8.3872187
farmacias['Lamaçães'] = 41.547976,-8.4012761
farmacias['Lomar'] = 41.5307238,-8.427394
farmacias['Henriquina - São Vitor'] = 41.5524657,-8.4139864
farmacias['Lima - São José de São Lázaro e São João do Souto'] = 41.5536114,-8.4235402
farmacias['Loureiro Basto - Palmeira'] = 41.5905331,-8.4295469
farmacias['Marques - São José de São Lázaro e São João do Souto'] = 41.550423,-8.423677
farmacias['Martins - São José de São Lázaro e São João do Souto'] = 41.5510726,-8.4223516
farmacias['Narcisa C. Dias - Veiga do Penso, Escudeiros e Penso'] = 41.4868491,-8.4292978
farmacias['Nova de Nogueira - Nogueira'] = 41.5304337,-8.4102638
farmacias['Nuno Barros - Real'] = 41.554171,-8.438716
farmacias['Oliveira - Ferreiros'] = 41.5345909,-8.4400511
farmacias['Osório - Ruães'] = 41.5808657,-8.4758667
farmacias['Pimenta - Cabreiros'] = 41.5334211,-8.4965154
farmacias['Farmácia Pimentel - Sao Vitor'] = 41.557452,-8.408761
farmacias['Farmácia Pinheiro - Maximinos, Sé e Cividadee'] = 41.5456516,-8.4334375
farmacias['Farmácia Pipa - Nogueira, Fraião e Lamaçães'] = 41.5435379,-8.3995875
farmacias['Farmácia Rodrigues - Maximinos, Sé e Cividade'] = 41.5503813,-8.4287748
farmacias['Farmácia Roma - São José de São Lázaro e São João do Souto'] = 41.5532189,-8.4237785
farmacias['Farmácia Santos - São Vicente'] = 41.5566642,-8.4197066
farmacias['Farmácia Santos da Cunha - Maximinos, Sé e Cividade'] = 41.5417512,-8.4298574
farmacias['Farmácia São João - São José de São Lázaro e São João do Souto'] = 41.5450471,-8.4196004
farmacias['Farmácia Silva - São Vítor'] = 41.551804,-8.4174405
farmacias['Farmácia Sousa Gomes - Maximinos, Sé e Cividade'] = 41.5512345,-8.4288927
farmacias['Farmácia Tebosa - Laião-Tebosa'] = 41.4863814,-8.4758655
farmacias['Farmácia Vidal - Tadim'] = 41.5078378,-8.4869193

# %%
data_imo_trespasses['Farmácias (km)'] = minDist(data_imo_trespasses, farmacias)

# %% [markdown]
# **Outliers (Localização do imóvel errada)**

# %%
a_excluir = data_imo_trespasses[(data_imo_trespasses['Centro Cidade (km)'] >= 30)]
data_imo_trespasses = data_imo_trespasses.drop(a_excluir.index)
data_imo_trespasses.index = np.arange(1, len(data_imo_trespasses) + 1)
#a_excluir

# %% [markdown]
# **Retirar identificadores**

# %%
data_imo_trespasses = data_imo_trespasses.drop(columns=['Preço m/2','Tipo de imóvel','Longitude','Latitude'])

# %% [markdown]
# ### Outliers Visuais

# %%
data_imo_trespasses["Área (m/2)"] = data_imo_trespasses["Área (m/2)"].astype(float)

# %% [markdown]
# *Preço*

# %%
fig = plt.figure(figsize = (20,5))
sns.set_style('darkgrid')
data_imo_trespasses['Preço'].hist(bins=30)
plt.xlabel('Preço')
# Out:
# Text(0.5, 0, 'Preço')

# %%
fig = plt.figure(figsize = (10,3))
sns.boxplot(x=data_imo_trespasses['Preço'])

# %%
a_excluir = data_imo_trespasses[(data_imo_trespasses['Preço'] >= 160000)]
data_imo_trespasses = data_imo_trespasses.drop(a_excluir.index)
data_imo_trespasses.index = np.arange(1, len(data_imo_trespasses) + 1)
a_excluir.shape
# Out:
# (1, 20)

# %% [markdown]
# *Área*

# %%
sns.jointplot(data_imo_trespasses['Área (m/2)'], data_imo_trespasses['Preço'], kind='reg')

# %%
a_excluir = data_imo_trespasses[(data_imo_trespasses['Área (m/2)'] >= 400)]
data_imo_trespasses = data_imo_trespasses.drop(a_excluir.index)
data_imo_trespasses.index = np.arange(1, len(data_imo_trespasses) + 1)
a_excluir.shape
# Out:
# (3, 20)

# %% [markdown]
# *Freguesia*

# %%
plt.figure(figsize=(20, 8))
plt.xticks(rotation=90)
sns.boxplot(data_imo_trespasses['Freguesia'], data_imo_trespasses['Preço'])
sns.swarmplot(data_imo_trespasses['Freguesia'], data_imo_trespasses['Preço'])
plt.show()

# %% [markdown]
# ### Encoding Str -> Int

# %%
data_imo_trespasses_mlp = data_imo_trespasses.copy()
data_imo_trespasses = data_imo_trespasses.drop(columns=['Id'])

# %%
#freguesia = pd.get_dummies(data_imo_trespasses['Freguesia'])
#tipologia = pd.get_dummies(data_imo_trespasses['Tipologia'])
#condicao = pd.get_dummies(data_imo_trespasses['Condição'])

#data_imo_trespasses.drop(['Freguesia','Tipologia','Condição'],axis=1,inplace=True)
#data_imo_trespasses = pd.concat([data_imo_trespasses,freguesia,tipologia,condicao],axis=1)
#data_imo_trespasses

from sklearn.preprocessing import LabelEncoder
cat_features = data_imo_trespasses.dtypes[data_imo_trespasses.dtypes == "object"].index 
for c in cat_features.to_list():
    lbl = LabelEncoder() 
    lbl.fit(list(data_imo_trespasses[c].values)) 
    data_imo_trespasses[c] = lbl.transform(list(data_imo_trespasses[c].values))

# %% [markdown]
# ### Outliers Z-Score

# %%
z = np.abs(stats.zscore(data_imo_trespasses))
threshold = 3
print(np.where(z > threshold))
# The first array contains the list of row numbers and second array respective column numbers
# Out:
# (array([ 0,  1,  6, 41, 41, 41, 41, 42, 42, 42, 42, 42, 42, 42, 42, 53, 53,
#        53, 55, 55, 55, 55, 55, 55, 55, 55, 72, 72, 72, 84, 84, 84],
#       dtype=int64), array([ 2,  3,  3,  7,  8,  9, 13,  4,  7,  8,  9, 12, 13, 14, 17, 10, 15,
#        18,  4,  7,  8,  9, 12, 13, 14, 17, 10, 15, 18, 10, 15, 18],
#       dtype=int64))

# %%
# Só fazer 1 vez
data_imo_trespasses = data_imo_trespasses[(np.abs(stats.zscore(data_imo_trespasses)) < 3).all(axis=1)]
data_imo_trespasses.index = np.arange(1, len(data_imo_trespasses) + 1)
data_imo_trespasses

#data_imo_trespasses = data_imo_trespasses[(np.abs(stats.zscore(data_imo_trespasses['Preço'])) < 1)]
#data_imo_trespasses.index = np.arange(1, len(data_imo_trespasses) + 1)
#data_imo_trespasses
# Out:
#      Preço  Freguesia  Condição  Área (m/2)  Centro Cidade (km)  \
# 1    15990          0         2       100.0               0.523
# 2    73000          0         2       124.0               0.743
# 3    15000         10         2        65.0               1.586
# 4   110000          9         2        83.0               0.809
# 5    45000          6         2       100.0               2.886
# ..     ...        ...       ...         ...                 ...
# 75   50000          2         2       120.0               5.495
# 76  120000          0         2       200.0               0.741
# 77   50000          0         2        67.0               1.052
# 78   25000          1         2        60.0               0.190
# 79   67500          5         2       137.0               2.027
#
#     Hospitais (km)  Centros Saúde (km)  Centro Comerciais (km)  Escolas (km)  \
# 1            0.361               0.106                   2.061         0.762
# 2            0.473               0.070                   2.234         0.604
# 3            1.314               0.547                   0.299         0.601
# 4            1.007               0.191                   1.329         0.170
# 5            0.314               1.712                   1.827         2.014
# ..             ...                 ...                     ...           ...
# 75           4.248               0.587                   6.084         3.835
# 76           0.882               0.519                   2.277         0.872
# 77           0.969               0.227                   2.633         0.790
# 78           0.397               0.183                   1.772         0.647
# 79           0.697               0.762                   0.714         0.233
#
#     Universidades (km)  Estação de Comboios (km)  Parques Industriais (km)  \
# 1                0.772                     0.645                     2.169
# 2                0.645                     0.660                     2.280
# 3                0.932                     2.603                     3.503
# 4                0.430                     1.564                     2.097
# 5                1.867                     3.030                     3.973
# ..                 ...                       ...                       ...
# 75               4.815                     4.672                     0.631
# 76               1.003                     0.399                     1.587
# 77               1.187                     0.168                     1.813
# 78               0.581                     0.830                     2.103
# 79               0.876                     2.989                     2.588
#
#     Central Autocarros (km)  Bancos (km)  Correios (km)  \
# 1                     0.863        0.255          0.522
# 2                     1.097        0.483          0.567
# 3                     1.726        0.806          0.179
# 4                     0.468        0.704          0.458
# 5                     3.362        2.179          1.316
# ..                      ...          ...            ...
# 75                    5.743        3.709          4.335
# 76                    0.711        0.342          0.665
# 77                    1.196        0.058          0.250
# 78                    0.520        0.009          0.160
# 79                    1.918        1.509          0.829
#
#     Parques e Zonas Verdes (km)  Serviços Públicos (km)  \
# 1                         0.240                   0.398
# 2                         0.069                   0.497
# 3                         0.301                   0.629
# 4                         0.792                   0.294
# 5                         1.513                   2.327
# ..                          ...                     ...
# 75                        1.782                   2.370
# 76                        0.778                   0.808
# 77                        0.636                   0.335
# 78                        0.311                   0.271
# 79                        1.279                   1.048
#
#     Policia Municipal (km)  Farmácias (km)
# 1                    0.209           0.336
# 2                    0.442           0.472
# 3                    1.950           0.415
# 4                    1.092           0.289
# 5                    2.813           0.418
# ..                     ...             ...
# 75                   5.140           0.977
# 76                   0.465           0.251
# 77                   0.675           0.122
# 78                   0.193           0.119
# 79                   2.401           0.791
#
# [79 rows x 19 columns]

# %% [markdown]
# **Análise exploratória dos dados sem outliers**

# %% [markdown]
# ----

# %% [markdown]
# ## Skewness

# %%
sns.distplot(data_imo_trespasses['Preço'], fit=stats.norm);
fig = plt.figure()
res = stats.probplot(data_imo_trespasses['Preço'], plot=plt)

# %%
sns.distplot(data_imo_trespasses['Área (m/2)'], fit=stats.norm);
fig = plt.figure()
res = stats.probplot(data_imo_trespasses['Área (m/2)'], plot=plt)

# %% [markdown]
# ## Dataset estruturado

# %%
data_imo_trespasses
# Out:
#      Preço  Freguesia  Condição  Área (m/2)  Centro Cidade (km)  \
# 1    15990          0         2       100.0               0.523
# 2    73000          0         2       124.0               0.743
# 3    15000         10         2        65.0               1.586
# 4   110000          9         2        83.0               0.809
# 5    45000          6         2       100.0               2.886
# ..     ...        ...       ...         ...                 ...
# 75   50000          2         2       120.0               5.495
# 76  120000          0         2       200.0               0.741
# 77   50000          0         2        67.0               1.052
# 78   25000          1         2        60.0               0.190
# 79   67500          5         2       137.0               2.027
#
#     Hospitais (km)  Centros Saúde (km)  Centro Comerciais (km)  Escolas (km)  \
# 1            0.361               0.106                   2.061         0.762
# 2            0.473               0.070                   2.234         0.604
# 3            1.314               0.547                   0.299         0.601
# 4            1.007               0.191                   1.329         0.170
# 5            0.314               1.712                   1.827         2.014
# ..             ...                 ...                     ...           ...
# 75           4.248               0.587                   6.084         3.835
# 76           0.882               0.519                   2.277         0.872
# 77           0.969               0.227                   2.633         0.790
# 78           0.397               0.183                   1.772         0.647
# 79           0.697               0.762                   0.714         0.233
#
#     Universidades (km)  Estação de Comboios (km)  Parques Industriais (km)  \
# 1                0.772                     0.645                     2.169
# 2                0.645                     0.660                     2.280
# 3                0.932                     2.603                     3.503
# 4                0.430                     1.564                     2.097
# 5                1.867                     3.030                     3.973
# ..                 ...                       ...                       ...
# 75               4.815                     4.672                     0.631
# 76               1.003                     0.399                     1.587
# 77               1.187                     0.168                     1.813
# 78               0.581                     0.830                     2.103
# 79               0.876                     2.989                     2.588
#
#     Central Autocarros (km)  Bancos (km)  Correios (km)  \
# 1                     0.863        0.255          0.522
# 2                     1.097        0.483          0.567
# 3                     1.726        0.806          0.179
# 4                     0.468        0.704          0.458
# 5                     3.362        2.179          1.316
# ..                      ...          ...            ...
# 75                    5.743        3.709          4.335
# 76                    0.711        0.342          0.665
# 77                    1.196        0.058          0.250
# 78                    0.520        0.009          0.160
# 79                    1.918        1.509          0.829
#
#     Parques e Zonas Verdes (km)  Serviços Públicos (km)  \
# 1                         0.240                   0.398
# 2                         0.069                   0.497
# 3                         0.301                   0.629
# 4                         0.792                   0.294
# 5                         1.513                   2.327
# ..                          ...                     ...
# 75                        1.782                   2.370
# 76                        0.778                   0.808
# 77                        0.636                   0.335
# 78                        0.311                   0.271
# 79                        1.279                   1.048
#
#     Policia Municipal (km)  Farmácias (km)
# 1                    0.209           0.336
# 2                    0.442           0.472
# 3                    1.950           0.415
# 4                    1.092           0.289
# 5                    2.813           0.418
# ..                     ...             ...
# 75                   5.140           0.977
# 76                   0.465           0.251
# 77                   0.675           0.122
# 78                   0.193           0.119
# 79                   2.401           0.791
#
# [79 rows x 19 columns]

# %% [markdown]
# ## Modelos de regressão

# %%
corr = data_imo_trespasses.corr()
plt.subplots(figsize=(20,9))
sns.heatmap(corr, annot=True)

# %%
top_feature = corr.index[abs(corr['Preço']>0.1)]
plt.subplots(figsize=(12, 8))
top_corr = data_imo_trespasses[top_feature].corr()
sns.heatmap(top_corr, annot=True)
plt.show()

# %% [markdown]
# **Features mais importantes relativamente ao target**

# %%
corr = data_imo_trespasses.corr()
corr.sort_values(['Preço'], ascending=False, inplace=True)
corr.Preço
# Out:
# Preço                          1.000000
# Área (m/2)                     0.386060
# Parques e Zonas Verdes (km)    0.041571
# Correios (km)                  0.003825
# Bancos (km)                    0.000570
#                                  ...
# Escolas (km)                  -0.059732
# Central Autocarros (km)       -0.070678
# Hospitais (km)                -0.096510
# Centros Saúde (km)            -0.110718
# Condição                      -0.179452
# Name: Preço, Length: 19, dtype: float64

# %% [markdown]
# ## Train Test Split

# %%
y = data_imo_trespasses['Preço']

# %%
X = data_imo_trespasses.drop('Preço',axis=1)

# %%
X = X.values
y = y.values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)
X_train.shape
# Out:
# (63, 18)

# %% [markdown]
# ### Regression Evaluation Metrics
#
#
# Here are three common evaluation metrics for regression problems:
#
# **Mean Absolute Error** (MAE) is the mean of the absolute value of the errors:
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
#
# **Mean Squared Error** (MSE) is the mean of the squared errors:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# **Root Mean Squared Error** (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$
#
# Comparing these metrics:
#
# - **MAE** is the easiest to understand, because it's the average error.
# - **MSE** is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# - **RMSE** is even more popular than MSE, because RMSE is interpretable in the "y" units.
#
# All of these are **loss functions**, because we want to minimize them.

# %% [markdown]
# **Funções auxiliares**

# %%
def printMetrics(y_test, predictions):
    print('MAE:', metrics.mean_absolute_error(y_test, predictions))
    print('MSE:', metrics.mean_squared_error(y_test, predictions))
    print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
    
def drawPlots(y_test, predictions, model):
    plt.plot(predictions, color= 'red')
    plt.plot(y_test, color= 'green')
    plt.title("Valores dos preços previstos e reais")
    plt.xlabel("Row")
    plt.ylabel("Preço")
    plt.legend(['previsto', 'real'], loc='upper right')
    plt.show()

    plt.plot(y_test, color= 'green')
    plt.plot(predictions, color= 'red')
    plt.title("Valores dos preços previstos e reais")
    plt.xlabel("Row")
    plt.ylabel("Preço")
    plt.legend(['real', 'previsto'], loc='upper right')
    plt.show()

    plt.scatter(predictions, y_test, alpha=.25,color='b') #alpha helps to show overlapping data
    plt.xlabel('Predicted Price')
    plt.ylabel('Actual Price')
    plt.title(model)
    plt.show()
    
    sns.jointplot(predictions, y_test, kind='reg')
    plt.xlabel('Predicted Price')
    plt.ylabel('Actual Price')
    plt.show()

# %% [markdown]
# ### Linear Regression

# %%
from sklearn import linear_model

# Compile the model
model = linear_model.LinearRegression()

# Fit the model
model.fit(X_train, y_train)

# Predict
predictions = model.predict(X_test)

# Metrics
printMetrics(y_test, predictions)
# Out:
# MAE: 28835.100320488633
# MSE: 1341383785.0616963
# RMSE: 36624.906621883645

# %%
print("Predict value " + str(predictions[10]))
print("Real value " + str(y_test[10]))
# Out:
# Predict value 43092.602679758376
# Real value 35000

# %%
drawPlots(y_test, predictions, 'Linear Regression')

# %% [markdown]
# ### RandomForestRegression

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# Compile the model
rf = RandomForestRegressor(random_state = 42)


#Hyperparamater tuning using RanodomSearchCV
param_grid = { 
    'n_estimators': [int(x) for x in np.linspace(start = 600, stop = 1300, num = 10)],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [12,14,16],
    'min_samples_split' : [2, 4, 6],
    'min_samples_leaf' : [1, 2]
}
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 5, n_jobs = -1, verbose = 2)
grid_search.fit(X_train, y_train)
print(grid_search.best_params_)
print(grid_search.best_score_)


# Fit the model
#rf.fit(X_train,y_train)

# Predict
#predictions = rf.predict(X_test)
predictions = grid_search.predict(X_test)

# Metrics
printMetrics(y_test, predictions)
# Out:
# Fitting 5 folds for each of 540 candidates, totalling 2700 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:   54.5s
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 997 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 1442 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done 1969 tasks      | elapsed: 12.6min
# [Parallel(n_jobs=-1)]: Done 2576 tasks      | elapsed: 16.6min
# [Parallel(n_jobs=-1)]: Done 2700 out of 2700 | elapsed: 17.4min finished
# {'max_depth': 16, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 600}
# 0.24754081074357304
# MAE: 22857.976562499996
# MSE: 1129715652.886657
# RMSE: 33611.24295361088

# %%
print("Predict value " + str(predictions[10]))
print("Real value " + str(y_test[10]))
# Out:
# Predict value 50745.816666666666
# Real value 35000

# %%
drawPlots(y_test, predictions, 'Random Forest')

# %% [markdown]
# ### Standard Machine Learning Models (TEMPORÁRIO)

# %%
# Standard ML Models for comparison
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR

# Splitting data into training/testing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error, median_absolute_error

# %%
def evaluate(X_train, X_test, y_train, y_test):
    # Names of models
    model_name_list = ['Linear Regression', 'ElasticNet Regression',
                      'Random Forest', 'Extra Trees', 'SVM',
                       'Gradient Boosted', 'Baseline']
    
    # Instantiate the models
    model1 = LinearRegression()
    model2 = ElasticNet(alpha=1.0, l1_ratio=0.5)
    model3 = RandomForestRegressor(n_estimators=50)
    model4 = ExtraTreesRegressor(n_estimators=50)
    model5 = SVR(kernel='rbf', degree=3, C=1.0, gamma='auto')
    model6 = GradientBoostingRegressor(n_estimators=20)
    
    # Dataframe for results
    results = pd.DataFrame(columns=['mae', 'rmse'], index = model_name_list)
    
    # Train and predict with each model
    for i, model in enumerate([model1, model2, model3, model4, model5, model6]):
        model.fit(X_train, y_train)
        predictions = model.predict(X_test)
        
        # Metrics
        mae = np.mean(abs(predictions - y_test))
        rmse = np.sqrt(np.mean((predictions - y_test) ** 2))
        
        # Insert results into the dataframe
        model_name = model_name_list[i]
        results.loc[model_name, :] = [mae, rmse]
    
    # Median Value Baseline Metrics
    baseline = np.median(y_train)
    baseline_mae = np.mean(abs(baseline - y_test))
    baseline_rmse = np.sqrt(np.mean((baseline - y_test) ** 2))
    
    results.loc['Baseline', :] = [baseline_mae, baseline_rmse]
    
    return results

# %%
results = evaluate(X_train, X_test, y_train, y_test)

# %%
# Matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib

# %%
fig = plt.figure(figsize = (20,10))
# Root mean squared error
ax =  plt.subplot(1, 2, 1)
results.sort_values('mae', ascending = True).plot.bar(y = 'mae', color = 'b', ax = ax)
plt.title('Model Mean Absolute Error'); plt.ylabel('MAE');

# Median absolute percentage error
ax = plt.subplot(1, 2, 2)
results.sort_values('rmse', ascending = True).plot.bar(y = 'rmse', color = 'r', ax = ax)
plt.title('Model Root Mean Squared Error'); plt.ylabel('RMSE');

plt.tight_layout()

# %% [markdown]
# ### Ridge Regression

# %% [markdown]
# **GridSearchCV**

# %%
from sklearn.linear_model import Ridge

# Parameters
params_ridge ={
        'alpha':[0.5,0.75,1,1.25,1.5],
        'solver':['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga'],
        'max_iter':[500,750,1000,1250,1500]
        }

# Compile the model
ridge = Ridge()
ridge_grid = GridSearchCV(estimator = ridge, param_grid = params_ridge, cv = 5, n_jobs = -1, verbose = 2)

# Fit the model
ridge_grid.fit(X_train, y_train)
print(ridge_grid.best_params_)
print(ridge_grid.best_score_)

# Predict
predictions = ridge_grid.predict(X_test)

# Metrics
printMetrics(y_test, predictions)
# Out:
# Fitting 5 folds for each of 175 candidates, totalling 875 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.0s
# {'alpha': 0.75, 'max_iter': 500, 'solver': 'saga'}
# -0.07761015934211304
# MAE: 29236.89721276376
# MSE: 1253093688.6196914
# RMSE: 35399.06338619274
# [Parallel(n_jobs=-1)]: Done 779 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 875 out of 875 | elapsed:    1.2s finished
# C:\Users\Rui\Anaconda3\envs\LEI\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)

# %%
print("Predict value " + str(predictions[10]))
print("Real value " + str(y_test[10]))
# Out:
# Predict value 52186.15337968655
# Real value 35000

# %%
drawPlots(y_test, predictions, 'Ridge Regression GridSearchCV')

# %% [markdown]
# ### GradientBoostingRegressor

# %% [markdown]
# **GridSearchCV**

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Parameters
params_gbr={
    'loss':['ls', 'lad', 'huber', 'quantile'],
    'n_estimators':[15,25,50,100],
    'min_samples_split':[1,2,3],
    'max_depth':[4,6,8,10],
    'max_features':['auto', 'sqrt', 'log2']
}

# Compile the model
gbr = GradientBoostingRegressor()
gbr_grid = GridSearchCV(estimator=gbr, param_grid=params_gbr, cv=5, n_jobs=-1, verbose=2)

# Fit the model
gbr_grid.fit(X_train, y_train)
print(gbr_grid.best_params_)
print(gbr_grid.best_score_)

# Predict
predictions = gbr_grid.predict(X_test)

# Metrics
printMetrics(y_test, predictions)
# Out:
# Fitting 5 folds for each of 576 candidates, totalling 2880 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 1163 tasks      | elapsed:   13.0s
# [Parallel(n_jobs=-1)]: Done 1538 tasks      | elapsed:   24.4s
# [Parallel(n_jobs=-1)]: Done 1984 tasks      | elapsed:   47.1s
# [Parallel(n_jobs=-1)]: Done 2880 out of 2880 | elapsed:  1.2min finished
# {'loss': 'huber', 'max_depth': 6, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 25}
# 0.29508892768432
# MAE: 24173.729577155776
# MSE: 1137425692.5864089
# RMSE: 33725.74228369791

# %%
print("Predict value " + str(predictions[10]))
print("Real value " + str(y_test[10]))
# Out:
# Predict value 64937.65155645928
# Real value 35000

# %%
drawPlots(y_test, predictions, 'GradientBoostingRegressor GridSearchCV')

# %% [markdown]
# ### Decision Tree Regression with AdaBoost

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor

rng = np.random.RandomState(1)

# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=4)

regr_2 = AdaBoostRegressor(DecisionTreeRegressor(max_depth=4), n_estimators=300, random_state=rng)

regr_1.fit(X, y)
regr_2.fit(X, y)

# Predict
y_1 = regr_1.predict(X)
y_2 = regr_2.predict(X)

# Metrics
printMetrics(y_2, y)
# Out:
# MAE: 10900.587013540837
# MSE: 204506398.61798176
# RMSE: 14300.573366756375

# %%
print("Predict value " + str(y_1[10]))
print("Real value " + str(y[10]))
# Out:
# Predict value 53000.0
# Real value 52000

# %%
drawPlots(y, y_1, 'Decision Tree Regression with AdaBoost')

# %% [markdown]
# ### LGBM & ANN - Data Preparation

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
data_imo_trespasses_mlp
# Out:
#           Id   Preço                                          Freguesia  \
# 1   12358735  123000  Braga (São José de São Lázaro e São João do So...
# 2   15340571   99000  Braga (São José de São Lázaro e São João do So...
# 3   15089074   15990                   Braga (Maximinos, Sé e Cividade)
# 4   15255657   73000                   Braga (Maximinos, Sé e Cividade)
# 5   15319709   15000                                         São Victor
# ..       ...     ...                                                ...
# 84  11165494  120000                   Braga (Maximinos, Sé e Cividade)
# 85  14991608   80000                      Este (São Pedro e São Mamede)
# 86  15222039   50000                   Braga (Maximinos, Sé e Cividade)
# 87  14667279   25000  Braga (São José de São Lázaro e São João do So...
# 88  13161934   67500                                            Gualtar
#
#    Condição  Área (m/2)  Centro Cidade (km)  Hospitais (km)  \
# 1      Novo       120.0               0.190           0.397
# 2     Usado       332.0               0.040           0.423
# 3     Usado       100.0               0.523           0.361
# 4     Usado       124.0               0.743           0.473
# 5     Usado        65.0               1.586           1.314
# ..      ...         ...                 ...             ...
# 84    Usado       200.0               0.741           0.882
# 85    Usado       110.0               5.890           3.516
# 86    Usado        67.0               1.052           0.969
# 87    Usado        60.0               0.190           0.397
# 88    Usado       137.0               2.027           0.697
#
#     Centros Saúde (km)  Centro Comerciais (km)  Escolas (km)  \
# 1                0.183                   1.772         0.647
# 2                0.376                   1.577         0.563
# 3                0.106                   2.061         0.762
# 4                0.070                   2.234         0.604
# 5                0.547                   0.299         0.601
# ..                 ...                     ...           ...
# 84               0.519                   2.277         0.872
# 85               2.528                   4.320         2.610
# 86               0.227                   2.633         0.790
# 87               0.183                   1.772         0.647
# 88               0.762                   0.714         0.233
#
#     Universidades (km)  Estação de Comboios (km)  Parques Industriais (km)  \
# 1                0.581                     0.830                     2.103
# 2                0.393                     1.021                     2.192
# 3                0.772                     0.645                     2.169
# 4                0.645                     0.660                     2.280
# 5                0.932                     2.603                     3.503
# ..                 ...                       ...                       ...
# 84               1.003                     0.399                     1.587
# 85               3.439                     6.910                     5.614
# 86               1.187                     0.168                     1.813
# 87               0.581                     0.830                     2.103
# 88               0.876                     2.989                     2.588
#
#     Central Autocarros (km)  Bancos (km)  Correios (km)  \
# 1                     0.520        0.009          0.160
# 2                     0.439        0.021          0.068
# 3                     0.863        0.255          0.522
# 4                     1.097        0.483          0.567
# 5                     1.726        0.806          0.179
# ..                      ...          ...            ...
# 84                    0.711        0.342          0.665
# 85                    5.942        2.625          4.326
# 86                    1.196        0.058          0.250
# 87                    0.520        0.009          0.160
# 88                    1.918        1.509          0.829
#
#     Parques e Zonas Verdes (km)  Serviços Públicos (km)  \
# 1                         0.311                   0.271
# 2                         0.141                   0.078
# 3                         0.240                   0.398
# 4                         0.069                   0.497
# 5                         0.301                   0.629
# ..                          ...                     ...
# 84                        0.778                   0.808
# 85                        4.305                   2.516
# 86                        0.636                   0.335
# 87                        0.311                   0.271
# 88                        1.279                   1.048
#
#     Policia Municipal (km)  Farmácias (km)
# 1                    0.193           0.119
# 2                    0.391           0.102
# 3                    0.209           0.336
# 4                    0.442           0.472
# 5                    1.950           0.415
# ..                     ...             ...
# 84                   0.465           0.251
# 85                   6.260           2.580
# 86                   0.675           0.122
# 87                   0.193           0.119
# 88                   2.401           0.791
#
# [88 rows x 20 columns]

# %%
data_imo_trespasses_mlp = pd.get_dummies(data_imo_trespasses_mlp)

# %%
data_imo_trespasses_mlp.shape
# Out:
# (88, 32)

# %%
y_mlp = data_imo_trespasses_mlp['Preço']
X_mlp = data_imo_trespasses_mlp.drop('Preço',axis=1)

from sklearn.model_selection import train_test_split
X_train_mlp, X_test_mlp, y_train_mlp, y_test_mlp = train_test_split(X, y, test_size=0.2, random_state=7)
X_train_mlp.shape
# Out:
# (63, 18)

# %%
y_train_mlp = pd.DataFrame({'Preço':y_train})

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc_y = StandardScaler()
sc_X = StandardScaler()
y_train_mlp = sc_y.fit_transform(y_train_mlp)
X_train_mlp = sc_X.fit_transform(X_train_mlp)
X_test_mlp = sc_X.transform(X_test_mlp)

# %%
y_train_mlp.shape
# Out:
# (63, 1)

# %%
flat_y_mlp = y_train_mlp.flatten()
flat_y_mlp.shape
# Out:
# (63,)

# %% [markdown]
# ### LGBM

# %%
import lightgbm as lgb

# create dataset for lightgbm
lgb_train = lgb.Dataset(X_train_mlp, flat_y_mlp)

# specify your configurations as a dict
params = {
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': {'l2', 'l1'},
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0
}

print('Starting training...')

# train
gbm = lgb.train(params, lgb_train, num_boost_round=250)

# predict
lgbm_prediction_tr = gbm.predict(X_train_mlp, num_iteration=gbm.best_iteration)
lgbm_prediction_te = gbm.predict(X_test_mlp, num_iteration=gbm.best_iteration)
# Out:
# Starting training...

# %%
train = lgbm_prediction_tr
test = lgbm_prediction_te

# %%
y_pred_mlp = sc_y.inverse_transform(lgbm_prediction_te)

# %%
y_pred_mlp
# Out:
# array([65016.12404524, 68927.42881697, 71778.1981942 , 83556.01122929,
#        61467.37115171, 39591.66408883, 27305.47530892, 45948.60820336,
#        73462.35457321, 16520.77149258, 60485.65751944, 60800.07634254,
#        65016.12404524, 45948.60820336, 92573.15666435, 68272.86520973])

# %%
# Metrics
printMetrics(y_test, y_pred_mlp)
# Out:
# MAE: 23279.734924934815
# MSE: 1057916657.1382061
# RMSE: 32525.630772334087

# %%
drawPlots(y_test, y_pred_mlp, 'LGBM')

# %% [markdown]
# ### ANN

# %%
def print_history_mae(history):
    print(history.history.keys())
    plt.plot(history.history['mae'])
    plt.plot(history.history['val_mae'])
    plt.title('model mae')
    plt.ylabel('mae')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()


def print_history_loss(history):
    print(history.history.keys())
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from keras import models, layers

model = models.Sequential()
model.add(layers.Dense(18, activation='relu', input_shape=[X_train.shape[1]]))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(32, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(layers.Dense(64, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(layers.Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(layers.Dense(1))

model.compile(optimizer='rmsprop', loss='mae', metrics=['mae'])

# %%
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 18)                342
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                608
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32)                128
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                2112
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               8320
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 12,407
# Trainable params: 11,959
# Non-trainable params: 448
# _________________________________________________________________
# None

# %%
model_filepath = 'min_vl_model.h5'
checkpoint = ModelCheckpoint(model_filepath, monitor = 'val_mae', verbose=1, save_best_only = True, mode='min')

history = model.fit(X_train_scaled, y_train, validation_split=0.2, epochs=3000, callbacks=[checkpoint])

model.load_weights(model_filepath)
# Out:
# Train on 50 samples, validate on 13 samples
# Epoch 1/3000
# 50/50 [==============================] - 1s 15ms/step - loss: 52051.7830 - mae: 52051.7812 - val_loss: 67676.1797 - val_mae: 67676.1797
#
# Epoch 00001: val_mae improved from inf to 67676.17969, saving model to min_vl_model.h5
# Epoch 2/3000
# 50/50 [==============================] - 0s 160us/step - loss: 
3000
# 50/50 [==============================] - 0s 180us/step - loss: 52050.9148 - mae: 52050.9141 - val_loss: 67675.2031 - val_mae: 67675.2031
#
# Epoch 00016: val_mae improved from 67675.26562 to 67675.20312, saving model to min_vl_model.h5
# Epoch 17/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52050.8581 - mae: 52050.8594 - val_loss: 67675.1250 - val_mae: 67675.1250
#
# Epoch 00017: val_mae improved from 67675.20312 to 67675.12500, saving model to min_vl_model.h5
# Epoch 18/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52050.7931 - mae: 52050.7891 - val_loss: 67675.0547 - val_mae: 67675.0547
#
# Epoch 00018: val_mae improved from 67675.12500 to 67675.05469, saving model to min_vl_model.h5
# Epoch 19/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52050.7294 - mae: 52050.7305 - val_loss: 67674.9922 - val_mae: 67674.9922
#
# Epoch 00019: val_mae improved from 67675.05469 to 67674.99219, saving model to min_vl_model.h5
# Epoch 20/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52050.6655 - mae: 52050.6641 - val_loss: 67674.9219 - val_mae: 67674.9219
#
# Epoch 00020: val_mae improved from 67674.99219 to 67674.92188, saving model to min_vl_model.h5
# Epoch 21/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52050.6044 - mae: 52050.6055 - val_loss: 67674.8438 - val_mae: 67674.8438
#
# Epoch 00021: val_mae improved from 67674.92188 to 67674.84375, saving model to min_vl_model.h5
# Epoch 22/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52050.5392 - mae: 52050.5391 - val_loss: 67674.7734 - val_mae: 67674.7734
#
# Epoch 00022: val_mae improved from 67674.84375 to 67674.77344, saving model to min_vl_model.h5
# Epoch 23/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52050.4694 - mae: 52050.4688 - val_loss: 67674.7031 - val_mae: 67674.7031
#
# Epoch 00023: val_mae improved from 67674.77344 to 67674.70312, saving model to min_vl_model.h5
# Epoch 24/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52050.4044 - mae: 52050.4062 - val_loss: 67674.6172 - val_mae: 67674.6172
#
# Epoch 00024: val_mae improved from 67674.70312 to 67674.61719, saving model to min_vl_model.h5
# Epoch 25/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52050.3334 - mae: 52050.3359 - val_loss: 67674.5547 - val_mae: 67674.5547
#
# Epoch 00025: val_mae improved from 67674.61719 to 67674.55469, saving model to min_vl_model.h5
# Epoch 26/3000
# 50/50 [==============================] - 0s 200us/step - loss: 52050.2619 - mae: 52050.2617 - val_loss: 67674.4766 - val_mae: 67674.4766
#
# Epoch 00026: val_mae improved from 67674.55469 to 67674.47656, saving model to min_vl_model.h5
# Epoch 27/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52050.1898 - mae: 52050.1914 - val_loss: 67674.3984 - val_mae: 67674.3984
#
# Epoch 00027: val_mae improved from 67674.47656 to 67674.39844, saving model to min_vl_model.h5
# Epoch 28/3000
# 50/50 [==============================] - 0s 200us/step - loss: 52050.1202 - mae: 52050.1211 - val_loss: 67674.3203 - val_mae: 67674.3203
#
# Epoch 00028: val_mae improved from 67674.39844 to 67674.32031, saving model to min_vl_model.h5
# Epoch 29/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52050.0445 - mae: 52050.0469 - val_loss: 67674.2422 - val_mae: 67674.2422
#
# Epoch 00029: val_mae improved from 67674.32031 to 67674.24219, saving model to min_vl_model.h5
# Epoch 30/3000
# 50/50 [==============================] - 0s 240us/step - loss: 52049.9719 - mae: 52049.9688 - val_loss: 67674.1641 - val_mae: 67674.1641
#
# Epoch 00030: val_mae improved from 67674.24219 to 67674.16406, saving model to min_vl_model.h5
# Epoch 31/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52049.8969 - mae: 52049.8984 - val_loss: 67674.0703 - val_mae: 67674.0703
#
# Epoch 00031: val_mae improved from 67674.16406 to 67674.07031, saving model to min_vl_model.h5
# Epoch 32/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52049.8203 - mae: 52049.8203 - val_loss: 67673.9922 - val_mae: 67673.9922
#
# Epoch 00032: val_mae improved from 67674.07031 to 67673.99219, saving model to min_vl_model.h5
# Epoch 33/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52049.7406 - mae: 52049.7383 - val_loss: 67673.9062 - val_mae: 67673.9062
#
# Epoch 00033: val_mae improved from 67673.99219 to 67673.90625, saving model to min_vl_model.h5
# Epoch 34/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52049.6608 - mae: 52049.6602 - val_loss: 67673.8203 - val_mae: 67673.8203
#
# Epoch 00034: val_mae improved from 67673.90625 to 67673.82031, saving model to min_vl_model.h5
# Epoch 35/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52049.5830 - mae: 52049.5781 - val_loss: 67673.7344 - val_mae: 67673.7344
#
# Epoch 00035: val_mae improved from 67673.82031 to 67673.73438, saving model to min_vl_model.h5
# Epoch 36/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52049.5002 - mae: 52049.5000 - val_loss: 67673.6484 - val_mae: 67673.6484
#
# Epoch 00036: val_mae improved from 67673.73438 to 67673.64844, saving model to min_vl_model.h5
# Epoch 37/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52049.4172 - mae: 52049.4219 - val_loss: 67673.5547 - val_mae: 67673.5547
#
# Epoch 00037: val_mae improved from 67673.64844 to 67673.55469, saving model to min_vl_model.h5
# Epoch 38/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52049.3380 - mae: 52049.3398 - val_loss: 67673.4688 - val_mae: 67673.4688
#
# Epoch 00038: val_mae improved from 67673.55469 to 67673.46875, saving model to min_vl_model.h5
# Epoch 39/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52049.2517 - mae: 52049.2500 - val_loss: 67673.3672 - val_mae: 67673.3672
#
# Epoch 00039: val_mae improved from 67673.46875 to 67673.36719, saving model to min_vl_model.h5
# Epoch 40/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52049.1655 - mae: 52049.1641 - val_loss: 67673.2656 - val_mae: 67673.2656
#
# Epoch 00040: val_mae improved from 67673.36719 to 67673.26562, saving model to min_vl_model.h5
# Epoch 41/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52049.0808 - mae: 52049.0781 - val_loss: 67673.1797 - val_mae: 67673.1797
#
# Epoch 00041: val_mae improved from 67673.26562 to 67673.17969, saving model to min_vl_model.h5
# Epoch 42/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52048.9930 - mae: 52048.9883 - val_loss: 67673.0781 - val_mae: 67673.0781
#
# Epoch 00042: val_mae improved from 67673.17969 to 67673.07812, saving model to min_vl_model.h5
# Epoch 43/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52048.9023 - mae: 52048.8984 - val_loss: 67672.9688 - val_mae: 67672.9688
#
# Epoch 00043: val_mae improved from 67673.07812 to 67672.96875, saving model to min_vl_model.h5
# Epoch 44/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52048.8077 - mae: 52048.8086 - val_loss: 67672.8672 - val_mae: 67672.8672
#
# Epoch 00044: val_mae improved from 67672.96875 to 67672.86719, saving model to min_vl_model.h5
# Epoch 45/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52048.7214 - mae: 52048.7188 - val_loss: 67672.7656 - val_mae: 67672.7656
#
# Epoch 00045: val_mae improved from 67672.86719 to 67672.76562, saving model to min_vl_model.h5
# Epoch 46/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52048.6277 - mae: 52048.6289 - val_loss: 67672.6484 - val_mae: 67672.6484
#
# Epoch 00046: val_mae improved from 67672.76562 to 67672.64844, saving model to min_vl_model.h5
# Epoch 47/3000
# 50/50 [==============================] - 0s 140us/step - loss: 
3000
# 50/50 [==============================] - 0s 140us/step - loss: 52045.2394 - mae: 52045.2383 - val_loss: 67668.9297 - val_mae: 67668.9297
#
# Epoch 00077: val_mae improved from 67669.06250 to 67668.92969, saving model to min_vl_model.h5
# Epoch 78/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52045.1122 - mae: 52045.1094 - val_loss: 67668.7812 - val_mae: 67668.7812
#
# Epoch 00078: val_mae improved from 67668.92969 to 67668.78125, saving model to min_vl_model.h5
# Epoch 79/3000
# 50/50 [==============================] - 0s 200us/step - loss: 52044.9869 - mae: 52044.9883 - val_loss: 67668.6562 - val_mae: 67668.6562
#
# Epoch 00079: val_mae improved from 67668.78125 to 67668.65625, saving model to min_vl_model.h5
# Epoch 80/3000
# 50/50 [==============================] - 0s 220us/step - loss: 52044.8573 - mae: 52044.8594 - val_loss: 67668.5234 - val_mae: 67668.5234
#
# Epoch 00080: val_mae improved from 67668.65625 to 67668.52344, saving model to min_vl_model.h5
# Epoch 81/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52044.7262 - mae: 52044.7266 - val_loss: 67668.3906 - val_mae: 67668.3906
#
# Epoch 00081: val_mae improved from 67668.52344 to 67668.39062, saving model to min_vl_model.h5
# Epoch 82/3000
# 50/50 [==============================] - 0s 200us/step - loss: 52044.5980 - mae: 52044.6016 - val_loss: 67668.2422 - val_mae: 67668.2422
#
# Epoch 00082: val_mae improved from 67668.39062 to 67668.24219, saving model to min_vl_model.h5
# Epoch 83/3000
# 50/50 [==============================] - 0s 300us/step - loss: 52044.4641 - mae: 52044.4648 - val_loss: 67668.0781 - val_mae: 67668.0781
#
# Epoch 00083: val_mae improved from 67668.24219 to 67668.07812, saving model to min_vl_model.h5
# Epoch 84/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52044.3323 - mae: 52044.3281 - val_loss: 67667.9219 - val_mae: 67667.9219
#
# Epoch 00084: val_mae improved from 67668.07812 to 67667.92188, saving model to min_vl_model.h5
# Epoch 85/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52044.1970 - mae: 52044.1992 - val_loss: 67667.7656 - val_mae: 67667.7656
#
# Epoch 00085: val_mae improved from 67667.92188 to 67667.76562, saving model to min_vl_model.h5
# Epoch 86/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52044.0642 - mae: 52044.0664 - val_loss: 67667.6328 - val_mae: 67667.6328
#
# Epoch 00086: val_mae improved from 67667.76562 to 67667.63281, saving model to min_vl_model.h5
# Epoch 87/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52043.9255 - mae: 52043.9258 - val_loss: 67667.4766 - val_mae: 67667.4766
#
# Epoch 00087: val_mae improved from 67667.63281 to 67667.47656, saving model to min_vl_model.h5
# Epoch 88/3000
# 50/50 [==============================] - 0s 220us/step - loss: 52043.7911 - mae: 52043.7891 - val_loss: 67667.3047 - val_mae: 67667.3047
#
# Epoch 00088: val_mae improved from 67667.47656 to 67667.30469, saving model to min_vl_model.h5
# Epoch 89/3000
# 50/50 [==============================] - 0s 200us/step - loss: 52043.6522 - mae: 52043.6484 - val_loss: 67667.1562 - val_mae: 67667.1562
#
# Epoch 00089: val_mae improved from 67667.30469 to 67667.15625, saving model to min_vl_model.h5
# Epoch 90/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52043.5120 - mae: 52043.5117 - val_loss: 67667.0000 - val_mae: 67667.0000
#
# Epoch 00090: val_mae improved from 67667.15625 to 67667.00000, saving model to min_vl_model.h5
# Epoch 91/3000
# 50/50 [==============================] - 0s 120us/step - loss: 52043.3708 - mae: 52043.3711 - val_loss: 67666.8516 - val_mae: 67666.8516
#
# Epoch 00091: val_mae improved from 67667.00000 to 67666.85156, saving model to min_vl_model.h5
# Epoch 92/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52043.2316 - mae: 52043.2305 - val_loss: 67666.7109 - val_mae: 67666.7109
#
# Epoch 00092: val_mae improved from 67666.85156 to 67666.71094, saving model to min_vl_model.h5
# Epoch 93/3000
# 50/50 [==============================] - 0s 220us/step - loss: 52043.0875 - mae: 52043.0898 - val_loss: 67666.5391 - val_mae: 67666.5391
#
# Epoch 00093: val_mae improved from 67666.71094 to 67666.53906, saving model to min_vl_model.h5
# Epoch 94/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52042.9464 - mae: 52042.9453 - val_loss: 67666.3828 - val_mae: 67666.3828
#
# Epoch 00094: val_mae improved from 67666.53906 to 67666.38281, saving model to min_vl_model.h5
# Epoch 95/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52042.7984 - mae: 52042.8008 - val_loss: 67666.2344 - val_mae: 67666.2344
#
# Epoch 00095: val_mae improved from 67666.38281 to 67666.23438, saving model to min_vl_model.h5
# Epoch 96/3000
# 50/50 [==============================] - 0s 220us/step - loss: 52042.6525 - mae: 52042.6484 - val_loss: 67666.0625 - val_mae: 67666.0625
#
# Epoch 00096: val_mae improved from 67666.23438 to 67666.06250, saving model to min_vl_model.h5
# Epoch 97/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52042.5075 - mae: 52042.5117 - val_loss: 67665.8906 - val_mae: 67665.8906
#
# Epoch 00097: val_mae improved from 67666.06250 to 67665.89062, saving model to min_vl_model.h5
# Epoch 98/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52042.3603 - mae: 52042.3594 - val_loss: 67665.7344 - val_mae: 67665.7344
#
# Epoch 00098: val_mae improved from 67665.89062 to 67665.73438, saving model to min_vl_model.h5
# Epoch 99/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52042.2105 - mae: 52042.2109 - val_loss: 67665.5703 - val_mae: 67665.5703
#
# Epoch 00099: val_mae improved from 67665.73438 to 67665.57031, saving model to min_vl_model.h5
# Epoch 100/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52042.0622 - mae: 52042.0586 - val_loss: 67665.4062 - val_mae: 67665.4062
#
# Epoch 00100: val_mae improved from 67665.57031 to 67665.40625, saving model to min_vl_model.h5
# Epoch 101/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52041.9109 - mae: 52041.9102 - val_loss: 67665.2578 - val_mae: 67665.2578
#
# Epoch 00101: val_mae improved from 67665.40625 to 67665.25781, saving model to min_vl_model.h5
# Epoch 102/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52041.7602 - mae: 52041.7617 - val_loss: 67665.0781 - val_mae: 67665.0781
#
# Epoch 00102: val_mae improved from 67665.25781 to 67665.07812, saving model to min_vl_model.h5
# Epoch 103/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52041.6056 - mae: 52041.6055 - val_loss: 67664.8984 - val_mae: 67664.8984
#
# Epoch 00103: val_mae improved from 67665.07812 to 67664.89844, saving model to min_vl_model.h5
# Epoch 104/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52041.4500 - mae: 52041.4492 - val_loss: 67664.7188 - val_mae: 67664.7188
#
# Epoch 00104: val_mae improved from 67664.89844 to 67664.71875, saving model to min_vl_model.h5
# Epoch 105/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52041.2952 - mae: 52041.2969 - val_loss: 67664.5703 - val_mae: 67664.5703
#
# Epoch 00105: val_mae improved from 67664.71875 to 67664.57031, saving model to min_vl_model.h5
# Epoch 106/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52041.1398 - mae: 52041.1406 - val_loss: 67664.3828 - val_mae: 67664.3828
#
# Epoch 00106: val_mae improved from 67664.57031 to 67664.38281, saving model to min_vl_model.h5
# Epoch 107/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52040.9837 - mae: 52040.9844 - val_loss: 67664.2266 - val_mae: 67664.2266
#
# Epoch 00107: val_mae improved from 67664.38281 to 67664.22656, saving model to min_vl_model.h5
# Epoch 108/3000
# 50/50 [==============================] - 0s 200us/step - loss: 52040.8253 - mae: 52040.8242 - val_loss: 67664.0469 - val_mae: 67664.0469
#
# Epoch 00108: val_mae improved from 67664.22656 to 67664.04688, saving model to min_vl_model.h5
# Epoch 109/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52040.6611 - mae: 52040.6602 - val_loss: 67663.9141 - val_mae: 67663.9141
#
# Epoch 00109: val_mae improved from 67664.04688 to 67663.91406, saving model to min_vl_model.h5
# Epoch 110/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52040.5052 - mae: 52040.5039 - val_loss: 67663.7344 - val_mae: 67663.7344
#
# Epoch 00110: val_mae improved from 67663.91406 to 67663.73438, saving model to min_vl_model.h5
# Epoch 111/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52040.3447 - mae: 52040.3438 - val_loss: 67663.5312 - val_mae: 67663.5312
#
# Epoch 00111: val_mae improved from 67663.73438 to 67663.53125, saving model to min_vl_model.h5
# Epoch 112/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52040.1780 - mae: 52040.1797 - val_loss: 67663.3516 - val_mae: 67663.3516
#
# Epoch 00112: val_mae improved from 67663.53125 to 67663.35156, saving model to min_vl_model.h5
# Epoch 113/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52040.0178 - mae: 52040.0195 - val_loss: 67663.1641 - val_mae: 67663.1641
#
# Epoch 00113: val_mae improved from 67663.35156 to 67663.16406, saving model to min_vl_model.h5
# Epoch 114/3000
# 50/50 [==============================] - 0s 120us/step - loss: 52039.8523 - mae: 52039.8516 - val_loss: 67662.9922 - val_mae: 67662.9922
#
# Epoch 00114: val_mae improved from 67663.16406 to 67662.99219, saving model to min_vl_model.h5
# Epoch 115/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52039.6847 - mae: 52039.6836 - val_loss: 67662.7656 - val_mae: 67662.7656
#
# Epoch 00115: val_mae improved from 67662.99219 to 67662.76562, saving model to min_vl_model.h5
# Epoch 116/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52039.5198 - mae: 52039.5195 - val_loss: 67662.5781 - val_mae: 67662.5781
#
# Epoch 00116: val_mae improved from 67662.76562 to 67662.57812, saving model to min_vl_model.h5
# Epoch 117/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52039.3530 - mae: 52039.3516 - val_loss: 67662.3984 - val_mae: 67662.3984
#
# Epoch 00117: val_mae improved from 67662.57812 to 67662.39844, saving model to min_vl_model.h5
# Epoch 118/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52039.1838 - mae: 52039.1836 - val_loss: 67662.1797 - val_mae: 67662.1797
#
# Epoch 00118: val_mae improved from 67662.39844 to 67662.17969, saving model to min_vl_model.h5
# Epoch 119/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52039.0119 - mae: 52039.0117 - val_loss: 67661.9531 - val_mae: 67661.9531
#
# Epoch 00119: val_mae improved from 67662.17969 to 67661.95312, saving model to min_vl_model.h5
# Epoch 120/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52038.8444 - mae: 52038.8438 - val_loss: 67661.7500 - val_mae: 67661.7500
#
# Epoch 00120: val_mae improved from 67661.95312 to 67661.75000, saving model to min_vl_model.h5
# Epoch 121/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52038.6717 - mae: 52038.6719 - val_loss: 67661.5938 - val_mae: 67661.5938
#
# Epoch 00121: val_mae improved from 67661.75000 to 67661.59375, saving model to min_vl_model.h5
# Epoch 122/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52038.4945 - mae: 52038.4961 - val_loss: 67661.3828 - val_mae: 67661.3828
#
# Epoch 00122: val_mae improved from 67661.59375 to 67661.38281, saving model to min_vl_model.h5
# Epoch 123/3000
# 50/50 [==============================] - 0s 200us/step - loss: 52038.3253 - mae: 52038.3242 - val_loss: 67661.1719 - val_mae: 67661.1719
#
# Epoch 00123: val_mae improved from 67661.38281 to 67661.17188, saving model to min_vl_model.h5
# Epoch 124/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52038.1475 - mae: 52038.1484 - val_loss: 67661.0078 - val_mae: 67661.0078
#
# Epoch 00124: val_mae improved from 67661.17188 to 67661.00781, saving model to min_vl_model.h5
# Epoch 125/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52037.9717 - mae: 52037.9688 - val_loss: 67660.8281 - val_mae: 67660.8281
#
# Epoch 00125: val_mae improved from 67661.00781 to 67660.82812, saving model to min_vl_model.h5
# Epoch 126/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52037.7953 - mae: 52037.7969 - val_loss: 67660.6250 - val_mae: 67660.6250
#
# Epoch 00126: val_mae improved from 67660.82812 to 67660.62500, saving model to min_vl_model.h5
# Epoch 127/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52037.6152 - mae: 52037.6133 - val_loss: 67660.4531 - val_mae: 67660.4531
#
# Epoch 00127: val_mae improved from 67660.62500 to 67660.45312, saving model to min_vl_model.h5
# Epoch 128/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52037.4353 - mae: 52037.4336 - val_loss: 67660.2578 - val_mae: 67660.2578
#
# Epoch 00128: val_mae improved from 67660.45312 to 67660.25781, saving model to min_vl_model.h5
# Epoch 129/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52037.2558 - mae: 52037.2539 - val_loss: 67660.0312 - val_mae: 67660.0312
#
# Epoch 00129: val_mae improved from 67660.25781 to 67660.03125, saving model to min_vl_model.h5
# Epoch 130/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52037.0719 - mae: 52037.0703 - val_loss: 67659.8438 - val_mae: 67659.8438
#
# Epoch 00130: val_mae improved from 67660.03125 to 67659.84375, saving model to min_vl_model.h5
# Epoch 131/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52036.8913 - mae: 52036.8906 - val_loss: 67659.6484 - val_mae: 67659.6484
#
# Epoch 00131: val_mae improved from 67659.84375 to 67659.64844, saving model to min_vl_model.h5
# Epoch 132/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52036.7070 - mae: 52036.7109 - val_loss: 67659.4062 - val_mae: 67659.4062
#
# Epoch 00132: val_mae improved from 67659.64844 to 67659.40625, saving model to min_vl_model.h5
# Epoch 133/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52036.5231 - mae: 52036.5234 - val_loss: 67659.2266 - val_mae: 67659.2266
#
# Epoch 00133: val_mae improved from 67659.40625 to 67659.22656, saving model to min_vl_model.h5
# Epoch 134/3000
# 50/50 [==============================] - 0s 240us/step - loss: 52036.3400 - mae: 52036.3398 - val_loss: 67659.0312 - val_mae: 67659.0312
#
# Epoch 00134: val_mae improved from 67659.22656 to 67659.03125, saving model to min_vl_model.h5
# Epoch 135/3000
# 50/50 [==============================] - 0s 200us/step - loss: 52036.1527 - mae: 52036.1484 - val_loss: 67658.8359 - val_mae: 67658.8359
#
# Epoch 00135: val_mae improved from 67659.03125 to 67658.83594, saving model to min_vl_model.h5
# Epoch 136/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52035.9622 - mae: 52035.9609 - val_loss: 67658.6641 - val_mae: 67658.6641
#
# Epoch 00136: val_mae improved from 67658.83594 to 67658.66406, saving model to min_vl_model.h5
# Epoch 137/3000
# 50/50 [==============================] - 0s 220us/step - loss: 52035.7736 - mae: 52035.7734 - val_loss: 67658.4531 - val_mae: 67658.4531
#
# Epoch 00137: val_mae improved from 67658.66406 to 67658.45312, saving model to min_vl_model.h5
# Epoch 138/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52035.5858 - mae: 52035.5859 - val_loss: 67658.2188 - val_mae: 67658.2188
#
# Epoch 00138: val_mae improved from 67658.45312 to 67658.21875, saving model to min_vl_model.h5
# Epoch 139/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52035.3945 - mae: 52035.3945 - val_loss: 67657.9922 - val_mae: 67657.9922
#
# Epoch 00139: val_mae improved from 67658.21875 to 67657.99219, saving model to min_vl_model.h5
# Epoch 140/3000
# 50/50 [==============================] - 0s 200us/step - loss: 52035.2022 - mae: 52035.1992 - val_loss: 67657.8516 - val_mae: 67657.8516
#
# Epoch 00140: val_mae improved from 67657.99219 to 67657.85156, saving model to min_vl_model.h5
# Epoch 141/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52035.0069 - mae: 52035.0117 - val_loss: 67657.6172 - val_mae: 67657.6172
#
# Epoch 00141: val_mae improved from 67657.85156 to 67657.61719, saving model to min_vl_model.h5
# Epoch 142/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52034.8123 - mae: 52034.8086 - val_loss: 67657.3906 - val_mae: 67657.3906
#
# Epoch 00142: val_mae improved from 67657.61719 to 67657.39062, saving model to min_vl_model.h5
# Epoch 143/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52034.6198 - mae: 52034.6211 - val_loss: 67657.1719 - val_mae: 67657.1719
#
# Epoch 00143: val_mae improved from 67657.39062 to 67657.17188, saving model to min_vl_model.h5
# Epoch 144/3000
# 50/50 [==============================] - 0s 162us/step - loss: 52034.4212 - mae: 52034.4219 - val_loss: 67656.9453 - val_mae: 67656.9453
#
# Epoch 00144: val_mae improved from 67657.17188 to 67656.94531, saving model to min_vl_model.h5
# Epoch 145/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52034.2247 - mae: 52034.2266 - val_loss: 67656.7812 - val_mae: 67656.7812
#
# Epoch 00145: val_mae improved from 67656.94531 to 67656.78125, saving model to min_vl_model.h5
# Epoch 146/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52034.0259 - mae: 52034.0234 - val_loss: 67656.5625 - val_mae: 67656.5625
#
# Epoch 00146: val_mae improved from 67656.78125 to 67656.56250, saving model to min_vl_model.h5
# Epoch 147/3000
# 50/50 [==============================] - 0s 219us/step - loss: 52033.8277 - mae: 52033.8281 - val_loss: 67656.3203 - val_mae: 67656.3203
#
# Epoch 00147: val_mae improved from 67656.56250 to 67656.32031, saving model to min_vl_model.h5
# Epoch 148/3000
# 50/50 [==============================] - 0s 200us/step - loss: 52033.6264 - mae: 52033.6250 - val_loss: 67656.1484 - val_mae: 67656.1484
#
# Epoch 00148: val_mae improved from 67656.32031 to 67656.14844, saving model to min_vl_model.h5
# Epoch 149/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52033.4275 - mae: 52033.4297 - val_loss: 67655.9531 - val_mae: 67655.9531
#
# Epoch 00149: val_mae improved from 67656.14844 to 67655.95312, saving model to min_vl_model.h5
# Epoch 150/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52033.2256 - mae: 52033.2266 - val_loss: 67655.7656 - val_mae: 67655.7656
#
# Epoch 00150: val_mae improved from 67655.95312 to 67655.76562, saving model to min_vl_model.h5
# Epoch 151/3000
# 50/50 [==============================] - 0s 200us/step - loss: 52033.0202 - mae: 52033.0195 - val_loss: 67655.4922 - val_mae: 67655.4922
#
# Epoch 00151: val_mae improved from 67655.76562 to 67655.49219, saving model to min_vl_model.h5
# Epoch 152/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52032.8138 - mae: 52032.8164 - val_loss: 67655.2578 - val_mae: 67655.2578
#
# Epoch 00152: val_mae improved from 67655.49219 to 67655.25781, saving model to min_vl_model.h5
# Epoch 153/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52032.6098 - mae: 52032.6094 - val_loss: 67654.9922 - val_mae: 67654.9922
#
# Epoch 00153: val_mae improved from 67655.25781 to 67654.99219, saving model to min_vl_model.h5
# Epoch 154/3000
# 50/50 [==============================] - 0s 200us/step - loss: 52032.4062 - mae: 52032.4062 - val_loss: 67654.7578 - val_mae: 67654.7578
#
# Epoch 00154: val_mae improved from 67654.99219 to 67654.75781, saving model to min_vl_model.h5
# Epoch 155/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52032.1922 - mae: 52032.1914 - val_loss: 67654.6250 - val_mae: 67654.6250
#
# Epoch 00155: val_mae improved from 67654.75781 to 67654.62500, saving model to min_vl_model.h5
# Epoch 156/3000
# 50/50 [==============================] - 0s 201us/step - loss: 52031.9887 - mae: 52031.9883 - val_loss: 67654.3828 - val_mae: 67654.3828
#
# Epoch 00156: val_mae improved from 67654.62500 to 67654.38281, saving model to min_vl_model.h5
# Epoch 157/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52031.7772 - mae: 52031.7812 - val_loss: 67654.1797 - val_mae: 67654.1797
#
# Epoch 00157: val_mae improved from 67654.38281 to 67654.17969, saving model to min_vl_model.h5
# Epoch 158/3000
# 50/50 [==============================] - 0s 220us/step - loss: 52031.5645 - mae: 52031.5664 - val_loss: 67653.9688 - val_mae: 67653.9688
#
# Epoch 00158: val_mae improved from 67654.17969 to 67653.96875, saving model to min_vl_model.h5
# Epoch 159/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52031.3531 - mae: 52031.3516 - val_loss: 67653.7031 - val_mae: 67653.7031
#
# Epoch 00159: val_mae improved from 67653.96875 to 67653.70312, saving model to min_vl_model.h5
# Epoch 160/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52031.1423 - mae: 52031.1406 - val_loss: 67653.4609 - val_mae: 67653.4609
#
# Epoch 00160: val_mae improved from 67653.70312 to 67653.46094, saving model to min_vl_model.h5
# Epoch 161/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52030.9252 - mae: 52030.9258 - val_loss: 67653.2578 - val_mae: 67653.2578
#
# Epoch 00161: val_mae improved from 67653.46094 to 67653.25781, saving model to min_vl_model.h5
# Epoch 162/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52030.7072 - mae: 52030.7109 - val_loss: 67653.0469 - val_mae: 67653.0469
#
# Epoch 00162: val_mae improved from 67653.25781 to 67653.04688, saving model to min_vl_model.h5
# Epoch 163/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52030.4952 - mae: 52030.4961 - val_loss: 67652.8125 - val_mae: 67652.8125
#
# Epoch 00163: val_mae improved from 67653.04688 to 67652.81250, saving model to min_vl_model.h5
# Epoch 164/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52030.2777 - mae: 52030.2812 - val_loss: 67652.5781 - val_mae: 67652.5781
#
# Epoch 00164: val_mae improved from 67652.81250 to 67652.57812, saving model to min_vl_model.h5
# Epoch 165/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52030.0602 - mae: 52030.0586 - val_loss: 67652.3125 - val_mae: 67652.3125
#
# Epoch 00165: val_mae improved from 67652.57812 to 67652.31250, saving model to min_vl_model.h5
# Epoch 166/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52029.8406 - mae: 52029.8398 - val_loss: 67652.0547 - val_mae: 67652.0547
#
# Epoch 00166: val_mae improved from 67652.31250 to 67652.05469, saving model to min_vl_model.h5
# Epoch 167/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52029.6197 - mae: 52029.6211 - val_loss: 67651.7734 - val_mae: 67651.7734
#
# Epoch 00167: val_mae improved from 67652.05469 to 67651.77344, saving model to min_vl_model.h5
# Epoch 168/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52029.3998 - mae: 52029.3984 - val_loss: 67651.5078 - val_mae: 67651.5078
#
# Epoch 00168: val_mae improved from 67651.77344 to 67651.50781, saving model to min_vl_model.h5
# Epoch 169/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52029.1744 - mae: 52029.1758 - val_loss: 67651.3203 - val_mae: 67651.3203
#
# Epoch 00169: val_mae improved from 67651.50781 to 67651.32031, saving model to min_vl_model.h5
# Epoch 170/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52028.9527 - mae: 52028.9492 - val_loss: 67651.0938 - val_mae: 67651.0938
#
# Epoch 00170: val_mae improved from 67651.32031 to 67651.09375, saving model to min_vl_model.h5
# Epoch 171/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52028.7297 - mae: 52028.7305 - val_loss: 67650.7656 - val_mae: 67650.7656
#
# Epoch 00171: val_mae improved from 67651.09375 to 67650.76562, saving model to min_vl_model.h5
# Epoch 172/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52028.4995 - mae: 52028.5000 - val_loss: 67650.4453 - val_mae: 67650.4453
#
# Epoch 00172: val_mae improved from 67650.76562 to 67650.44531, saving model to min_vl_model.h5
# Epoch 173/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52028.2752 - mae: 52028.2734 - val_loss: 67650.1562 - val_mae: 67650.1562
#
# Epoch 00173: val_mae improved from 67650.44531 to 67650.15625, saving model to min_vl_model.h5
# Epoch 174/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52028.0484 - mae: 52028.0508 - val_loss: 67650.0156 - val_mae: 67650.0156
#
# Epoch 00174: val_mae improved from 67650.15625 to 67650.01562, saving model to min_vl_model.h5
# Epoch 175/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52027.8211 - mae: 52027.8203 - val_loss: 67649.8203 - val_mae: 67649.8203
#
# Epoch 00175: val_mae improved from 67650.01562 to 67649.82031, saving model to min_vl_model.h5
# Epoch 176/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52027.5903 - mae: 52027.5898 - val_loss: 67649.5938 - val_mae: 67649.5938
#
# Epoch 00176: val_mae improved from 67649.82031 to 67649.59375, saving model to min_vl_model.h5
# Epoch 177/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52027.3592 - mae: 52027.3594 - val_loss: 67649.3203 - val_mae: 67649.3203
#
# Epoch 00177: val_mae improved from 67649.59375 to 67649.32031, saving model to min_vl_model.h5
# Epoch 178/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52027.1272 - mae: 52027.1289 - val_loss: 67649.0469 - val_mae: 67649.0469
#
# Epoch 00178: val_mae improved from 67649.32031 to 67649.04688, saving model to min_vl_model.h5
# Epoch 179/3000
# 50/50 [==============================] - 0s 140us/step - loss: 52026.8920 - mae: 52026.8906 - val_loss: 67648.8750 - val_mae: 67648.8750
#
# Epoch 00179: val_mae improved from 67649.04688 to 67648.87500, saving model to min_vl_model.h5
# Epoch 180/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52026.6600 - mae: 52026.6602 - val_loss: 67648.6406 - val_mae: 67648.6406
#
# Epoch 00180: val_mae improved from 67648.87500 to 67648.64062, saving model to min_vl_model.h5
# Epoch 181/3000
# 50/50 [==============================] - 0s 220us/step - loss: 52026.4253 - mae: 52026.4258 - val_loss: 67648.4688 - val_mae: 67648.4688
#
# Epoch 00181: val_mae improved from 67648.64062 to 67648.46875, saving model to min_vl_model.h5
# Epoch 182/3000
# 50/50 [==============================] - 0s 260us/step - loss: 52026.1906 - mae: 52026.1914 - val_loss: 67648.2422 - val_mae: 67648.2422
#
# Epoch 00182: val_mae improved from 67648.46875 to 67648.24219, saving model to min_vl_model.h5
# Epoch 183/3000
# 50/50 [==============================] - 0s 220us/step - loss: 52025.9530 - mae: 52025.9492 - val_loss: 67648.0078 - val_mae: 67648.0078
#
# Epoch 00183: val_mae improved from 67648.24219 to 67648.00781, saving model to min_vl_model.h5
# Epoch 184/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52025.7139 - mae: 52025.7148 - val_loss: 67647.7578 - val_mae: 67647.7578
#
# Epoch 00184: val_mae improved from 67648.00781 to 67647.75781, saving model to min_vl_model.h5
# Epoch 185/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52025.4758 - mae: 52025.4766 - val_loss: 67647.4922 - val_mae: 67647.4922
#
# Epoch 00185: val_mae improved from 67647.75781 to 67647.49219, saving model to min_vl_model.h5
# Epoch 186/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52025.2323 - mae: 52025.2305 - val_loss: 67647.2344 - val_mae: 67647.2344
#
# Epoch 00186: val_mae improved from 67647.49219 to 67647.23438, saving model to min_vl_model.h5
# Epoch 187/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52024.9928 - mae: 52024.9883 - val_loss: 67646.9531 - val_mae: 67646.9531
#
# Epoch 00187: val_mae improved from 67647.23438 to 67646.95312, saving model to min_vl_model.h5
# Epoch 188/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52024.7513 - mae: 52024.7500 - val_loss: 67646.6328 - val_mae: 67646.6328
#
# Epoch 00188: val_mae improved from 67646.95312 to 67646.63281, saving model to min_vl_model.h5
# Epoch 189/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52024.5070 - mae: 52024.5117 - val_loss: 67646.3828 - val_mae: 67646.3828
#
# Epoch 00189: val_mae improved from 67646.63281 to 67646.38281, saving model to min_vl_model.h5
# Epoch 190/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52024.2644 - mae: 52024.2656 - val_loss: 67646.1172 - val_mae: 67646.1172
#
# Epoch 00190: val_mae improved from 67646.38281 to 67646.11719, saving model to min_vl_model.h5
# Epoch 191/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52024.0195 - mae: 52024.0195 - val_loss: 67645.8594 - val_mae: 67645.8594
#
# Epoch 00191: val_mae improved from 67646.11719 to 67645.85938, saving model to min_vl_model.h5
# Epoch 192/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52023.7709 - mae: 52023.7695 - val_loss: 67645.5469 - val_mae: 67645.5469
#
# Epoch 00192: val_mae improved from 67645.85938 to 67645.54688, saving model to min_vl_model.h5
# Epoch 193/3000
# 50/50 [==============================] - 0s 160us/step - loss: 52023.5219 - mae: 52023.5195 - val_loss: 67645.3672 - val_mae: 67645.3672
#
# Epoch 00193: val_mae improved from 67645.54688 to 67645.36719, saving model to min_vl_model.h5
# Epoch 194/3000
# 50/50 [==============================] - 0s 180us/step - loss: 52023.2780 - mae: 52023.2812 - val_loss: 67645.1328 - val_mae: 67645.1328
#
# ...
#
# Epoch 02936: val_mae improved from 63111.67188 to 63107.05859, saving model to min_vl_model.h5
# Epoch 2937/3000
# 50/50 [==============================] - 0s 180us/step - loss: 47465.5720 - mae: 47465.5703 - val_loss: 63105.8320 - val_mae: 63105.8320
#
# Epoch 02937: val_mae improved from 63107.05859 to 63105.83203, saving model to min_vl_model.h5
# Epoch 2938/3000
# 50/50 [==============================] - 0s 140us/step - loss: 47462.5053 - mae: 47462.5039 - val_loss: 63102.2500 - val_mae: 63102.2500
#
# Epoch 02938: val_mae improved from 63105.83203 to 63102.25000, saving model to min_vl_model.h5
# Epoch 2939/3000
# 50/50 [==============================] - 0s 140us/step - loss: 47459.4356 - mae: 47459.4336 - val_loss: 63100.8164 - val_mae: 63100.8164
#
# Epoch 02939: val_mae improved from 63102.25000 to 63100.81641, saving model to min_vl_model.h5
# Epoch 2940/3000
# 50/50 [==============================] - 0s 180us/step - loss: 47456.3637 - mae: 47456.3633 - val_loss: 63098.1875 - val_mae: 63098.1875
#
# Epoch 02940: val_mae improved from 63100.81641 to 63098.18750, saving model to min_vl_model.h5
# Epoch 2941/3000
# 50/50 [==============================] - 0s 160us/step - loss: 47453.2897 - mae: 47453.2891 - val_loss: 63095.9375 - val_mae: 63095.9375
#
# Epoch 02941: val_mae improved from 63098.18750 to 63095.93750, saving model to min_vl_model.h5
# Epoch 2942/3000
# 50/50 [==============================] - 0s 160us/step - loss: 47450.2161 - mae: 47450.2148 - val_loss: 63091.1445 - val_mae: 63091.1445
#
# Epoch 02942: val_mae improved from 63095.93750 to 63091.14453, saving model to min_vl_model.h5
# Epoch 2943/3000
# 50/50 [==============================] - 0s 200us/step - loss: 47447.1439 - mae: 47447.1445 - val_loss: 63088.7227 - val_mae: 63088.7227
#
# Epoch 02943: val_mae improved from 63091.14453 to 63088.72266, saving model to min_vl_model.h5
# Epoch 2944/3000
# 50/50 [==============================] - 0s 160us/step - loss: 47444.0672 - mae: 47444.0703 - val_loss: 63084.6953 - val_mae: 63084.6953
#
# Epoch 02944: val_mae improved from 63088.72266 to 63084.69531, saving model to min_vl_model.h5
# Epoch 2945/3000
# 50/50 [==============================] - 0s 160us/step - loss: 47440.9894 - mae: 47440.9883 - val_loss: 63079.5859 - val_mae: 63079.5859
#
# Epoch 02945: val_mae improved from 63084.69531 to 63079.58594, saving model to min_vl_model.h5
# Epoch 2946/3000
# 50/50 [==============================] - 0s 160us/step - loss: 47437.9114 - mae: 47437.9102 - val_loss: 63075.8320 - val_mae: 63075.8320
#
# Epoch 02946: val_mae improved from 63079.58594 to 63075.83203, saving model to min_vl_model.h5
# Epoch 2947/3000
# 50/50 [==============================] - 0s 160us/step - loss: 47434.8347 - mae: 47434.8359 - val_loss: 63071.8945 - val_mae: 63071.8945
#
# Epoch 02947: val_mae improved from 63075.83203 to 63071.89453, saving model to min_vl_model.h5
# Epoch 2948/3000
# 50/50 [==============================] - 0s 220us/step - loss: 47431.7525 - mae: 47431.7500 - val_loss: 63068.4219 - val_mae: 63068.4219
#
# Epoch 02948: val_mae improved from 63071.89453 to 63068.42188, saving model to min_vl_model.h5
# Epoch 2949/3000
# 50/50 [==============================] - 0s 200us/step - loss: 47428.6753 - mae: 47428.6758 - val_loss: 63065.0234 - val_mae: 63065.0234
#
# Epoch 02949: val_mae improved from 63068.42188 to 63065.02344, saving model to min_vl_model.h5
# Epoch 2950/3000
# 50/50 [==============================] - 0s 160us/step - loss: 47425.5894 - mae: 47425.5898 - val_loss: 63060.6211 - val_mae: 63060.6211
#
# Epoch 02950: val_mae improved from 63065.02344 to 63060.62109, saving model to min_vl_model.h5
# Epoch 2951/3000
# 50/50 [==============================] - 0s 140us/step - loss: 47422.5095 - mae: 47422.5117 - val_loss: 63059.5859 - val_mae: 63059.5859
#
# Epoch 02951: val_mae improved from 63060.62109 to 63059.58594, saving model to min_vl_model.h5
# Epoch 2952/3000
# 50/50 [==============================] - 0s 160us/step - loss: 47419.4227 - mae: 47419.4219 - val_loss: 63057.8477 - val_mae: 63057.8477
#
# Epoch 02952: val_mae improved from 63059.58594 to 63057.84766, saving model to min_vl_model.h5
# Epoch 2953/3000
# 50/50 [==============================] - 0s 180us/step - loss: 47416.3380 - mae: 47416.3398 - val_loss: 63054.7344 - val_mae: 63054.7344
#
# Epoch 02953: val_mae improved from 63057.84766 to 63054.73438, saving model to min_vl_model.h5
# Epoch 2954/3000
# 50/50 [==============================] - 0s 140us/step - loss: 47413.2531 - mae: 47413.2500 - val_loss: 63051.7773 - val_mae: 63051.7773
#
# Epoch 02954: val_mae improved from 63054.73438 to 63051.77734, saving model to min_vl_model.h5
# Epoch 2955/3000
# 50/50 [==============================] - 0s 140us/step - loss: 47410.1628 - mae: 47410.1602 - val_loss: 63048.4727 - val_mae: 63048.4727
#
# Epoch 02955: val_mae improved from 63051.77734 to 63048.47266, saving model to min_vl_model.h5
# Epoch 2956/3000
# 50/50 [==============================] - 0s 140us/step - loss: 47407.0769 - mae: 47407.0742 - val_loss: 63045.3672 - val_mae: 63045.3672
#
# Epoch 02956: val_mae improved from 63048.47266 to 63045.36719, saving model to min_vl_model.h5
# Epoch 2957/3000
# 50/50 [==============================] - 0s 260us/step - loss: 47403.9863 - mae: 47403.9844 - val_loss: 63043.1016 - val_mae: 63043.1016
#
# Epoch 02957: val_mae improved from 63045.36719 to 63043.10156, saving model to min_vl_model.h5
# Epoch 2958/3000
# 50/50 [==============================] - 0s 140us/step - loss: 47400.8989 - mae: 47400.8984 - val_loss: 63036.8516 - val_mae: 63036.8516
#
# Epoch 02958: val_mae improved from 63043.10156 to 63036.85156, saving model to min_vl_model.h5
# Epoch 2959/3000
# 50/50 [==============================] - 0s 200us/step - loss: 47397.8064 - mae: 47397.8047 - val_loss: 63035.1602 - val_mae: 63035.1602
#
# Epoch 02959: val_mae improved from 63036.85156 to 63035.16016, saving model to min_vl_model.h5
# Epoch 2960/3000
# 50/50 [==============================] - 0s 180us/step - loss: 47394.7127 - mae: 47394.7109 - val_loss: 63032.0664 - val_mae: 63032.0664
#
# Epoch 02960: val_mae improved from 63035.16016 to 63032.06641, saving model to min_vl_model.h5
# Epoch 2961/3000
# 50/50 [==============================] - 0s 180us/step - loss: 47391.6227 - mae: 47391.6211 - val_loss: 63029.6055 - val_mae: 63029.6055
#
# Epoch 02961: val_mae improved from 63032.06641 to 63029.60547, saving model to min_vl_model.h5
# Epoch 2962/3000
# 50/50 [==============================] - 0s 180us/step - loss: 47388.5242 - mae: 47388.5234 - val_loss: 63025.7969 - val_mae: 63025.7969
#
# Epoch 02962: val_mae improved from 63029.60547 to 63025.79688, saving model to min_vl_model.h5
# Epoch 2963/3000
# 50/50 [==============================] - 0s 140us/step - loss: 47385.4306 - mae: 47385.4297 - val_loss: 63023.3594 - val_mae: 63023.3594
#
# Epoch 02963: val_mae improved from 63025.79688 to 63023.35938, saving model to min_vl_model.h5
# Epoch 2964/3000
# 50/50 [==============================] - 0s 200us/step - loss: 47382.3356 - mae: 47382.3359 - val_loss: 63021.1445 - val_mae: 63021.1445
#
# Epoch 02964: val_mae improved from 63023.35938 to 63021.14453, saving model to min_vl_model.h5
# Epoch 2965/3000
# 50/50 [==============================] - 0s 160us/step - loss: 47379.2375 - mae: 47379.2383 - val_loss: 63017.1602 - val_mae: 63017.1602
#
# Epoch 02965: val_mae improved from 63021.14453 to 63017.16016, saving model to min_vl_model.h5
# Epoch 2966/3000
# 50/50 [==============================] - 0s 180us/step - loss: 47376.1403 - mae: 47376.1406 - val_loss: 63011.4844 - val_mae: 63011.4844
#
# Epoch 02966: val_mae improved from 63017.16016 to 63011.48438, saving model to min_vl_model.h5
# Epoch 2967/3000
# 50/50 [==============================] - 0s 180us/step - loss: 47373.0413 - mae: 47373.0391 - val_loss: 63006.7695 - val_mae: 63006.7695
#
# Epoch 02967: val_mae improved from 63011.48438 to 63006.76953, saving model to min_vl_model.h5
# Epoch 2968/3000
# 50/50 [==============================] - 0s 200us/step - loss: 47369.9389 - mae: 47369.9414 - val_loss: 63003.4727 - val_mae: 63003.4727
#
# Epoch 02968: val_mae improved from 63006.76953 to 63003.47266, saving model to min_vl_model.h5
# Epoch 2969/3000
# 50/50 [==============================] - 0s 140us/step - loss: 47366.8369 - mae: 47366.8398 - val_loss: 63000.0664 - val_mae: 63000.0664
#
# Epoch 02969: val_mae improved from 63003.47266 to 63000.06641, saving model to min_vl_model.h5
# Epoch 2970/3000
# 50/50 [==============================] - 0s 160us/step - loss: 47363.7337 - mae: 47363.7344 - val_loss: 62997.3945 - val_mae: 62997.3945
#
# Epoch 02970: val_mae improved from 63000.06641 to 62997.39453, saving model to min_vl_model.h5
# Epoch 2971/3000
# 50/50 [==============================] - 0s 160us/step - loss: 47360.6327 - mae: 47360.6289 - val_loss: 62993.5039 - val_mae: 62993.5039
#
# Epoch 02971: val_mae improved from 62997.39453 to 62993.50391, saving model to min_vl_model.h5
# Epoch 2972/3000
# 50/50 [==============================] - 0s 180us/step - loss: 47357.5284 - mae: 47357.5312 - val_loss: 62992.0078 - val_mae: 62992.0078
#
# Epoch 02972: val_mae improved from 62993.50391 to 62992.00781, saving model to min_vl_model.h5
# Epoch 2973/3000
# 50/50 [==============================] - 0s 180us/step - loss: 47354.4206 - mae: 47354.4219 - val_loss: 62990.5781 - val_mae: 62990.5781
#
# Epoch 02973: val_mae improved from 62992.00781 to 62990.57812, saving model to min_vl_model.h5
# Epoch 2974/3000
# 50/50 [==============================] - 0s 180us/step - loss: 47351.3189 - mae: 47351.3203 - val_loss: 62985.1055 - val_mae: 62985.1055
#
# Epoch 02974: val_mae improved from 62990.57812 to 62985.10547, saving model to min_vl_model.h5
# Epoch 2975/3000
# 50/50 [==============================] - 0s 160us/step - loss: 47348.2102 - mae: 47348.2109 - val_loss: 62984.7266 - val_mae: 62984.7266
#
# Epoch 02975: val_mae improved from 62985.10547 to 62984.72656, saving model to min_vl_model.h5
# Epoch 2976/3000
# 50/50 [==============================] - 0s 160us/step - loss: 47345.0986 - mae: 47345.1016 - val_loss: 62983.0078 - val_mae: 62983.0078
#
# Epoch 02976: val_mae improved from 62984.72656 to 62983.00781, saving model to min_vl_model.h5
# Epoch 2977/3000
# 50/50 [==============================] - 0s 140us/step - loss: 47341.9895 - mae: 47341.9883 - val_loss: 62981.1602 - val_mae: 62981.1602
#
# Epoch 02977: val_mae improved from 62983.00781 to 62981.16016, saving model to min_vl_model.h5
# Epoch 2978/3000
# 50/50 [==============================] - 0s 160us/step - loss: 47338.8770 - mae: 47338.8789 - val_loss: 62979.3164 - val_mae: 62979.3164
#
# Epoch 02978: val_mae improved from 62981.16016 to 62979.31641, saving model to min_vl_model.h5
# Epoch 2979/3000
# 50/50 [==============================] - 0s 160us/step - loss: 47335.7644 - mae: 47335.7656 - val_loss: 62976.5469 - val_mae: 62976.5469
#
# Epoch 02979: val_mae improved from 62979.31641 to 62976.54688, saving model to min_vl_model.h5
# Epoch 2980/3000
# 50/50 [==============================] - 0s 180us/step - loss: 47332.6534 - mae: 47332.6562 - val_loss: 62973.9648 - val_mae: 62973.9648
#
# Epoch 02980: val_mae improved from 62976.54688 to 62973.96484, saving model to min_vl_model.h5
# Epoch 2981/3000
# 50/50 [==============================] - 0s 220us/step - loss: 47329.5430 - mae: 47329.5391 - val_loss: 62968.1484 - val_mae: 62968.1484
#
# Epoch 02981: val_mae improved from 62973.96484 to 62968.14844, saving model to min_vl_model.h5
# Epoch 2982/3000
# 50/50 [==============================] - 0s 140us/step - loss: 47326.4280 - mae: 47326.4297 - val_loss: 62963.6641 - val_mae: 62963.6641
#
# Epoch 02982: val_mae improved from 62968.14844 to 62963.66406, saving model to min_vl_model.h5
# Epoch 2983/3000
# 50/50 [==============================] - 0s 160us/step - loss: 47323.3084 - mae: 47323.3086 - val_loss: 62963.8594 - val_mae: 62963.8594
#
# Epoch 02983: val_mae did not improve from 62963.66406
# Epoch 2984/3000
# 50/50 [==============================] - 0s 180us/step - loss: 47320.1927 - mae: 47320.1914 - val_loss: 62961.7500 - val_mae: 62961.7500
#
# Epoch 02984: val_mae improved from 62963.66406 to 62961.75000, saving model to min_vl_model.h5
# Epoch 2985/3000
# 50/50 [==============================] - 0s 180us/step - loss: 47317.0725 - mae: 47317.0703 - val_loss: 62959.3477 - val_mae: 62959.3477
#
# Epoch 02985: val_mae improved from 62961.75000 to 62959.34766, saving model to min_vl_model.h5
# Epoch 2986/3000
# 50/50 [==============================] - 0s 160us/step - loss: 47313.9533 - mae: 47313.9531 - val_loss: 62953.8906 - val_mae: 62953.8906
#
# Epoch 02986: val_mae improved from 62959.34766 to 62953.89062, saving model to min_vl_model.h5
# Epoch 2987/3000
# 50/50 [==============================] - 0s 200us/step - loss: 47310.8398 - mae: 47310.8398 - val_loss: 62953.0859 - val_mae: 62953.0859
#
# Epoch 02987: val_mae improved from 62953.89062 to 62953.08594, saving model to min_vl_model.h5
# Epoch 2988/3000
# 50/50 [==============================] - 0s 180us/step - loss: 47307.7144 - mae: 47307.7148 - val_loss: 62950.8477 - val_mae: 62950.8477
#
# Epoch 02988: val_mae improved from 62953.08594 to 62950.84766, saving model to min_vl_model.h5
# Epoch 2989/3000
# 50/50 [==============================] - 0s 160us/step - loss: 47304.5942 - mae: 47304.5938 - val_loss: 62944.7578 - val_mae: 62944.7578
#
# Epoch 02989: val_mae improved from 62950.84766 to 62944.75781, saving model to min_vl_model.h5
# Epoch 2990/3000
# 50/50 [==============================] - 0s 200us/step - loss: 47301.4684 - mae: 47301.4688 - val_loss: 62940.5430 - val_mae: 62940.5430
#
# Epoch 02990: val_mae improved from 62944.75781 to 62940.54297, saving model to min_vl_model.h5
# Epoch 2991/3000
# 50/50 [==============================] - 0s 160us/step - loss: 47298.3466 - mae: 47298.3438 - val_loss: 62935.7227 - val_mae: 62935.7227
#
# Epoch 02991: val_mae improved from 62940.54297 to 62935.72266, saving model to min_vl_model.h5
# Epoch 2992/3000
# 50/50 [==============================] - 0s 140us/step - loss: 47295.2220 - mae: 47295.2188 - val_loss: 62933.8281 - val_mae: 62933.8281
#
# Epoch 02992: val_mae improved from 62935.72266 to 62933.82812, saving model to min_vl_model.h5
# Epoch 2993/3000
# 50/50 [==============================] - 0s 160us/step - loss: 47292.0955 - mae: 47292.0938 - val_loss: 62930.1094 - val_mae: 62930.1094
#
# Epoch 02993: val_mae improved from 62933.82812 to 62930.10938, saving model to min_vl_model.h5
# Epoch 2994/3000
# 50/50 [==============================] - 0s 200us/step - loss: 47288.9681 - mae: 47288.9688 - val_loss: 62928.7734 - val_mae: 62928.7734
#
# Epoch 02994: val_mae improved from 62930.10938 to 62928.77344, saving model to min_vl_model.h5
# Epoch 2995/3000
# 50/50 [==============================] - 0s 200us/step - loss: 47285.8378 - mae: 47285.8398 - val_loss: 62925.0000 - val_mae: 62925.0000
#
# Epoch 02995: val_mae improved from 62928.77344 to 62925.00000, saving model to min_vl_model.h5
# Epoch 2996/3000
# 50/50 [==============================] - 0s 160us/step - loss: 47282.7122 - mae: 47282.7109 - val_loss: 62921.7500 - val_mae: 62921.7500
#
# Epoch 02996: val_mae improved from 62925.00000 to 62921.75000, saving model to min_vl_model.h5
# Epoch 2997/3000
# 50/50 [==============================] - 0s 180us/step - loss: 47279.5800 - mae: 47279.5781 - val_loss: 62916.8086 - val_mae: 62916.8086
#
# Epoch 02997: val_mae improved from 62921.75000 to 62916.80859, saving model to min_vl_model.h5
# Epoch 2998/3000
# 50/50 [==============================] - 0s 200us/step - loss: 47276.4484 - mae: 47276.4492 - val_loss: 62910.3359 - val_mae: 62910.3359
#
# Epoch 02998: val_mae improved from 62916.80859 to 62910.33594, saving model to min_vl_model.h5
# Epoch 2999/3000
# 50/50 [==============================] - 0s 180us/step - loss: 47273.3169 - mae: 47273.3203 - val_loss: 62907.0859 - val_mae: 62907.0859
#
# Epoch 02999: val_mae improved from 62910.33594 to 62907.08594, saving model to min_vl_model.h5
# Epoch 3000/3000
# 50/50 [==============================] - 0s 200us/step - loss: 47270.1822 - mae: 47270.1797 - val_loss: 62906.2734 - val_mae: 62906.2734
#
# Epoch 03000: val_mae improved from 62907.08594 to 62906.27344, saving model to min_vl_model.h5

# %%
print_history_mae(history)
print_history_loss(history)
# Out:
# dict_keys(['val_loss', 'val_mae', 'loss', 'mae'])
# dict_keys(['val_loss', 'val_mae', 'loss', 'mae'])

# %%
y_pred_mlp = model.predict(X_test_scaled)

# %%
y_pred_mlp
# Out:
# array([[4770.884 ],
#        [4821.099 ],
#        [4760.7373],
#        [4757.574 ],
#        [4767.9556],
#        [4762.633 ],
#        [4786.362 ],
#        [4757.949 ],
#        [4783.1484],
#        [4769.615 ],
#        [4779.1533],
#        [4753.28  ],
#        [4769.256 ],
#        [4758.586 ],
#        [4760.3633],
#        [4755.8486]], dtype=float32)

# %%
y_preds = []

for item in y_pred_mlp:
    y_preds.append(item[0])

# %%
# Metrics
printMetrics(y_test, y_preds)
# Out:
# MAE: 58380.347229003906
# MSE: 4910677186.351109
# RMSE: 70076.22411596609

# %%
drawPlots(y_test, y_preds, 'MLP')
